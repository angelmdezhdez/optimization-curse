# %% [markdown]
# # Curso de Optimización I (DEMAT/CIMAT)
# # Tarea 3
#
# | Descripción:                         | Fechas                  |
# |--------------------------------------|-------------------------|
# | Fecha de publicación del documento:  | **Febrero 11, 2024**    |
# | Fecha límite de entrega de la tarea: | **Febrero 18, 2024**    |

# %% [markdown]
# ## Indicaciones
#
# Puede escribir el código de los algoritmos que se piden en una
# celda de este notebook o si lo prefiere, escribir las funciones
# en un archivo `.py` independiente e importar la funciones para
# usarlas en este notebook. Lo importante es que en el notebook
# aparezcan los resultados de la pruebas realizadas y que:
#
# - Si se requieren otros archivos para poder reproducir los resultados,
#   para mandar la tarea cree un archivo ZIP en el que incluya
#   el notebook y los archivos adicionales.
# - Si todos los códigos para que se requieren para reproducir los
#   resultados están en el notebook, no hace falta comprimir el notebook
#   y puede anexar este archivo en la tarea del Classroom.
# - Exportar el notebook a un archivo PDF y anexarlo en la tarea del
#   Classroom como un archivo independiente.
#   **No incluya el PDF dentro del ZIP**, porque la idea que lo pueda accesar
#   directamente para poner anotaciones y la calificación de cada ejercicio.
#
# En la descripción de los ejercicios se nombran algunas variables
# para el algoritmo, pero sólo es para facilitar la descripción.
# En la implementación pueden nombrar sus variables como gusten.
#
# En los algoritmos se describen las entradas de las
# funciones. La intención es que tomen en cuenta lo que requiere
# el algoritmo y que tiene que haber parámetros que permitan
# controlar el comportamiento del algoritmo,
# evitando que dejen fijo un valor y que no se puede modificar
# para hacer diferentes pruebas. Si quieren dar esta información
# usando un tipo de dato que contenga todos los valores o
# usar variables por separado, etc., lo pueden hacer y no usen
# variables globales si no es necesario.
#
# Lo mismo para los valores que devuelve una función.
# Pueden codificar como gusten la manera en que regresa los cálculos.
# El punto es que podamos tener acceso a los resultados para poder usarlos,
# y por eso no es conveniente que la función sólo imprima los valores
# sin devolverlos.
#
# Para los ejercicios teóricos puede escribir en la celda la solución, o
# si escribio la solución en una hoja, puede insertar una(s) foto(s) en la que
# se vea clara la solución. Si le es más facíl insertar la imagen en un procesador
# de texto como Word, lo puede utilizar y exportar el documento a PDF y subir
# el archivo. No lo compacte para que se pueda escribir anotaciones en el PDF.

# %% [markdown]
# _
#
# ```
#
#
#
#
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Ejercicio 1 (4 puntos)
#
# Programe el Algoritmo 3 de la Clase 6  de descenso máximo con backtracking
# para calcular el tamaño de paso $\alpha_k$ de manera inexacta.
#
# 1. Programar la función que implementa el algoritmo de backtracking
#    (Algoritmo 2 de la Clase 6) que usa la condición de descenso suficiente
#    (condición de Armijo) para seleccionar el tamaño de paso.
#    La función recibe como entrada:
# - el valor inicial $\alpha_{ini}$,
# - el valor $\rho \in (0,1)$,
# - la constante $c_1 \in (0,1)$ para la condición de Armijo,
# - el punto $\mathbf{x}_k$,
# - la función $f$,
# - el valor $f_k = f(\mathbf{x}_k)$,
# - el valor del gradiente  en el punto $\mathbf{x}_k$, $\nabla f_k$,
# - la dirección de descenso $\mathbf{p}_k$, y
# - el número máximo de iteraciones $N_b$.
#
# La función devuelve
# - el tamaño de paso $\alpha_k$,
# - el número $i_{k}$ de iteraciones realizadas por el algoritmo de backtracking
#
#
#
# 2. Programar la función que implementa el algoritmo de descenso máximo con
#    backtracking. Ésta recibe como entrada:
# - La función $f(\mathbf{x})$,
# - el gradiente $\nabla f(\mathbf{x})$ de la función $f$,
# - un punto inicial $\mathbf{x}_{0}$,
# - las tolerancia $\tau>0$,
# - el número máximo de iteraciones $N$ para el algoritmo de descenso máximo,
# - el valor inicial $\alpha_{ini}$,
# - el valor $\rho \in (0,1)$,
# - la constante $c_1 \in (0,1)$ para la condición de Armijo y
# - el número máximo de iteraciones $N_{gs}$ para el método de la sección dorada.
#
# La función devuelve
# - El último punto $\mathbf{x}_{k}$ generado por el algoritmo,
# - el número $k$ de iteraciones realizadas y
# - Una variable indicadora que es $True$ si el algoritmo termina por
#   cumplirse la condición de paro ($\|\alpha_k \mathbf{p}_{k}\| < \tau$) o
#   $False$ si termina porque se alcanzó el número máximo de iteraciones.
# - Si $n\ne 2$, devuelve un arreglo vació. En caso contrario, devuelve un
#   arreglo que contiene las componentes de los puntos de la secuencia, el
#   tamaño de paso y la cantidad de iteraciones que hizo el algoritmo
#   de backtracking en cada iteración:
#
# $$ \begin{array}{llll}
# x^{(0)}_1 & x^{(0)}_2 & \alpha_0 & i_0 \\
# x^{(1)}_1 & x^{(1)}_2 & \alpha_0 & i_1 \\
# \vdots &  \vdots &  \vdots &  \vdots \\
# x^{(k)}_1 & x^{(k)}_2 & \alpha_k & i_k \\
# \end{array} $$
#
# 3. Para probar el algoritmo, programe las siguientes funciones, calcule su gradiente
#    de manera analítica y programe la función correspondiente. Use cada punto
#    $\mathbf{x}_0$ como punto inicial del algoritmo.
#
# **Función de Himmelblau:** Para $\mathbf{x}=(x_1,x_2)$
#
# $$ f(\mathbf{x}) = (x_1^2 + x_2 - 11)^2 + (x_1 + x_2^2 - 7)^2. $$
# $$ \mathbf{x}_0 = (2.,4.) $$
# $$ \mathbf{x}_0 = (0.,0.) $$
#
#
# **Función de Beale :** Para $\mathbf{x}=(x_1,x_2)$
#
# $$ f(\mathbf{x}) = (1.5-x_1 + x_1x_2)^2 + (2.25 - x_1 + x_1x_2^2)^2 + (2.625 - x_1 + x_1x_2^3)^2.$$
# $$ \mathbf{x}_0 = (2.,3.) $$
# $$ \mathbf{x}_0 = (2.,4.) $$
#
#
# **Función de Rosenbrock:** Para $\mathbf{x}=(x_1,x_2, ..., x_n)$
#
# $$ f(\mathbf{x}) = \sum_{i=1}^{n-1} \left[100(x_{i+1} - x_i^2)^2 + (1-x_i)^2 \right]
# \quad n\geq 2.$$
# $$ \mathbf{x}_0 = (-2.1, 4.5) $$
# $$ \mathbf{x}_0 = (-1.2, 1.0) $$
# $$ \mathbf{x}_0 = (-2.1, 4.5, -2.1, 4.5, -2.1, 4.5, -2.1, 4.5, -2.1, 4.5) $$
# $$ \mathbf{x}_0 = (-1.2, 1.0, -1.2, 1.0, -1.2, 1.0, -1.2, 1.0, -1.2, 1.0) $$
#
# En la página [Test functions for optimization](https://en.wikipedia.org/wiki/Test_functions_for_optimization)
# pueden ver las gráficas de estas funciones y sus mínimos locales.
#
# Use
# - la  tolerancia $\tau = \sqrt{n}\epsilon_m^{1/2}$, donde $\epsilon_m$
#   es el épsilon de la máquina,
# - $\alpha_{ini} = 1.0$,
# - $\rho = 0.8$,
# - $c_1 = 0.1$,
# - el número de iteraciones máximas $N=30000$ para el descenso máximo
# - el número de iteraciones máximas $N_{b}=600$ para el método de backtracking.
#
# En cada caso imprima los resultados:
# - El número de iteraciones realizadas $k$
# - El punto $\mathbf{x}_k$ obtenido
# - $f(\mathbf{x}_k)$
# - $\|\nabla f(\mathbf{x}_k)\|$
# - La variable que indica si el algoritmo terminó porque se cumplió el criterio de paro o no.
# Además, si $n=2$, imprima
# - El valor promedio de los tamaños de paso $\alpha_0, \alpha_1, ..., \alpha_k$.
# - El valor promedio de las iteraciones $i_0, i_1, ..., i_k$ realizadas por el algoritmo de backtracking.
# - La gráfica de los contornos de nivel de la función y la trayectoria
#   de los puntos $\mathbf{x}_0, \mathbf{x}_1, ..., \mathbf{x}_k$.
#
# 3. Nocedal sugiere que la constante $c_1$ sea del orden de $0.0001$.
#    Use $c_1=0.0001$ y  repeta la prueba con la función de Beale y
#    explique en qué casos conviene usar un valor grande o pequeño de $c_1$.
#
# ### Solución:

# %%
#importamos librerías
import matplotlib.pyplot as plt
import numpy as np

# %%
#calculamos el epsilon de la máquina
eps_machine=1
while 1+eps_machine != 1:
  eps_machine/=2
print(eps_machine)
# Out:
# 1.1102230246251565e-16

# %%
def fncHimmelblau(x, fparam=None):
    return (x[0]**2 + x[1] - 11)**2 + (x[0] + x[1]**2 - 7)**2;


def contornosFnc2D(fncf, xleft, xright, ybottom, ytop, levels):
    # Crea una discretización uniforme del intervalo [xleft, xright]
    ax = np.linspace(xleft, xright, 250)
    # Crea una discretización uniforme del intervalo [ybottom, ytop]
    ay = np.linspace(ybottom, ytop, 250)
    # La matriz mX que tiene las abscisas
    mX, mY = np.meshgrid(ax, ay)
    # Se crea el arreglo mZ con los valores de la función en cada nodo
    vz = np.zeros( len(ax)*len(ay) )
    for i,xy in enumerate(zip(mX.flatten(), mY.flatten())):
        vz[i] = fncf(xy)
    mZ = vz.reshape( len(ay), len(ax) )
    # Grafica de las curvas de nivel
    fig, ax = plt.subplots()
    CS = ax.contour(mX, mY, mZ, levels, cmap='Wistia')

contornosFnc2D(fncHimmelblau, xleft=-5.5, xright=5.5, ybottom=-5.5, ytop=5.5,
               levels=[0.5, 5, 10, 25, 50, 100, 150, 250, 400])

# %%
def contornosFnc2D_modified(fncf, xleft, xright, ybottom, ytop, levels, puntos):
    # Crear una discretización uniforme del intervalo [xleft, xright]
    ax = np.linspace(xleft, xright, 250)
    # Crear una discretización uniforme del intervalo [ybottom, ytop]
    ay = np.linspace(ybottom, ytop, 200)
    # La matriz mX que tiene las abscisas
    mX, mY = np.meshgrid(ax, ay)
    # Se crea el arreglo mZ con los valores de la función en cada nodo
    mZ = mX.copy()
    for i, y in enumerate(ay):
        for j, x in enumerate(ax):
            mZ[i, j] = fncf(np.array([x, y]))

    # Grafica de las curvas de nivel
    fig, ax = plt.subplots()
    CS = ax.contour(mX, mY, mZ, levels, cmap='Wistia')

    puntos = np.array(puntos)
    ax.plot(puntos[:, 0], puntos[:, 1], color='red', label='Puntos')

    plt.xlabel('Eje X')
    plt.ylabel('Eje Y')
    plt.title('Curvas de Nivel y Puntos')
    plt.legend()
    plt.show()

# %%
#definimos la función de backtracking
def backtracking(a0, r, c, xk, f, df, pk, maxIter):
  a=a0
  for i in range(maxIter):
    if f(xk+a*pk)<= f(xk) + c*a*(np.dot(df(xk), pk)):
      return a, i+1, True
    a=r*a
  return a, maxIter, False

#definimos la función para descenso con bt
def max_dec_bt(f, df, x0, tol, maxIter1, a0, r, c, maxIter2):
  xk=x0
  ak=a0
  n=x0.shape[0]
  seqx=[xk.copy()]
  seqa=[ak]
  seqi=[]
  for i in range(maxIter1):
    gk=df(xk)
    pk=-gk
    step=backtracking(ak, r, c, xk, f, df, pk, maxIter2)
    if step[2]==False:
      print("BT llegó al max de iteraciones.")
    ak=step[0]
    seqi.append(step[1])
    if np.linalg.norm(ak*pk)<tol:
      if n==2:
        return xk, True, i+1, seqx, seqa, seqi
      else:
        return xk, True, i+1, [], seqa, seqi
    xk=xk+ak*pk
    seqx.append(xk.copy())
    seqa.append(ak)
  if n==2:
    return xk, False, maxIter1, seqx, seqa, seqi
  else:
    return xk, False, maxIter1, [], seqa, seqi

#para imprimir resultados
def solution(sol, f, df):
  print("El minimizador alcanzado es {}".format(sol[0]))
  print("¿Terminó por criterio de paro? {}".format(sol[1]))
  print("Iteraciones realizadas: {}".format(sol[2]))
  print("f(xk)={}".format(f(sol[0])))
  print("||Df(xk)||={}".format(np.linalg.norm(df(sol[0]))))
  print("Promedio de valores de alpha: {}".format(np.mean(sol[4])))
  print("Promedio de iteraciones de BT: {}".format(np.mean(sol[5])))

# %%
#definimos las funciones

def himmelblau(x):
  return (x[0]**2+x[1]-11)**2 + (x[0]+x[1]**2-7)**2

def Grad_himmelblau(x):
  d1=4*x[0]**3 + 4*x[0]*x[1] - 42*x[0] + 2*x[1]**2 - 14
  d2=4*x[1]**3 + 4*x[0]*x[1] + 2*x[0]**2 - 26*x[1] - 22
  return np.array([d1,d2])

def beale(x):
  return (1.5-x[0]+x[1]*x[0])**2 + (2.25-x[0]+x[0]*x[1]**2)**2 + (2.625-x[0]+x[0]*x[1]**3)**2

def Grad_beale(x):
  d1=2*(x[1]-1)*(1.5-x[0]+x[1]*x[0])+2*(x[1]**2-1)*(2.25-x[0]+x[0]*x[1]**2)+2*(x[1]**3-1)*(2.625-x[0]+x[0]*x[1]**3)
  d2=2*(x[0])*(1.5-x[0]+x[1]*x[0])+4*(x[0]*x[1])*(2.25-x[0]+x[0]*x[1]**2)+6*(x[0]*x[1]**2)*(2.625-x[0]+x[0]*x[1]**3)
  return np.array([d1, d2])

def rosenbrock(x):
  f=0
  n=x.shape[0]
  for i in range(n-1):
    f+=100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2
  return f

def Grad_rosenbrock(x):
  n=x.shape[0]
  grad=np.zeros(n)
  grad[0]=-2*(1-x[0])-400*x[0]*(x[1]-x[0]**2)
  grad[-1]=200*(x[-1]-x[-2]**2)
  for i in range(1,n-1):
    grad[i]=200*(x[i]-x[i-1]**2-2*x[i]*x[i+1]+2*x[i]**3) -2*(1-x[i])
  return grad

# %%
#definimos lo necesario
tol=np.sqrt(2*eps_machine)
a0=1.0
r=0.8
c=0.1
maxIter1=30000
maxIter2=600

# %%
#probamos con himmelblau con el primer punto
x_01=np.array([2.0, 4.0])
sol1=max_dec_bt(himmelblau, Grad_himmelblau, x_01, tol, maxIter1, a0, r, c, maxIter2)
solution(sol1,himmelblau, Grad_himmelblau)
points=sol1[3]
contornosFnc2D_modified(himmelblau, 0, 5, -4, 4, [10, 15, 20, 40, 80, 160, 320], points)
# Out:
# El minimizador alcanzado es [3.00000001 1.99999998]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 32
# f(xk)=4.328117073295844e-15
# ||Df(xk)||=4.718832772266488e-07
# Promedio de valores de alpha: 0.04870144855606069
# Promedio de iteraciones de BT: 1.5625

# %%
#himmelblau con el segundo punto
x_02=np.array([0.0, 0.0])
sol2=max_dec_bt(himmelblau, Grad_himmelblau, x_02, tol, maxIter1, a0, r, c, maxIter2)
solution(sol2,himmelblau, Grad_himmelblau)
points=sol2[3]
contornosFnc2D_modified(himmelblau, 0, 5, -4, 4, [10, 15, 20, 40, 80, 160, 320], points)
# Out:
# El minimizador alcanzado es [3.00000001 1.99999998]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 34
# f(xk)=4.9040414024929666e-15
# ||Df(xk)||=5.025041598711778e-07
# Promedio de valores de alpha: 0.05156588563406368
# Promedio de iteraciones de BT: 1.5294117647058822

# %%
#beale con el primer punto
x_03=np.array([2.0, 3.0])
sol3=max_dec_bt(beale, Grad_beale, x_03, tol, maxIter1, a0, r, c, maxIter2)
solution(sol3,beale, Grad_beale)
points=sol3[3]
contornosFnc2D_modified(beale, 0, 5, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.99873026 0.4996829 ]
# ¿Terminó por criterio de paro? False
# Iteraciones realizadas: 30000
# f(xk)=2.585223574952494e-07
# ||Df(xk)||=0.0003953363712689535
# Promedio de valores de alpha: 0.0006671363955675969
# Promedio de iteraciones de BT: 1.0011

# %%
#beale con el segundo punto
x_04=np.array([2.0, 4.0])
sol4=max_dec_bt(beale, Grad_beale, x_04, tol, maxIter1, a0, r, c, maxIter2)
solution(sol4,beale, Grad_beale)
points=sol4[3]
contornosFnc2D_modified(beale, -1.5, 5, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.90218504 0.47451549]
# ¿Terminó por criterio de paro? False
# Iteraciones realizadas: 30000
# f(xk)=0.001711516014036069
# ||Df(xk)||=0.035674168350838885
# Promedio de valores de alpha: 0.0001994801834669992
# Promedio de iteraciones de BT: 1.0013

# %%
#ahora con el primer punto de rosenbrock
x_05=np.array([-2.1, 4.5])
sol5=max_dec_bt(rosenbrock, Grad_rosenbrock, x_05, tol, maxIter1, a0, r, c, maxIter2)
solution(sol5,rosenbrock, Grad_rosenbrock)
points=sol5[3]
contornosFnc2D_modified(rosenbrock, -3, 3, -1, 5, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [0.99185642 0.98374641]
# ¿Terminó por criterio de paro? False
# Iteraciones realizadas: 30000
# f(xk)=6.64251279617095e-05
# ||Df(xk)||=0.007331566498145007
# Promedio de valores de alpha: 0.00043896689317659513
# Promedio de iteraciones de BT: 1.0011666666666668

# %%
#ahora con el segundo punto de rosenbrock
x_06=np.array([-1.2, 1.0])
sol6=max_dec_bt(rosenbrock, Grad_rosenbrock, x_06, tol, maxIter1, a0, r, c, maxIter2)
solution(sol6,rosenbrock, Grad_rosenbrock)
points=sol6[3]
contornosFnc2D_modified(rosenbrock, -3, 3, -1, 5, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [0.99998654 0.99997303]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 20876
# f(xk)=1.8134762013703172e-10
# ||Df(xk)||=1.203533814449945e-05
# Promedio de valores de alpha: 0.0012857826365243515
# Promedio de iteraciones de BT: 1.0014370569074535

# %%
#ahora con el tercer punto de rosenbrock
x_07=np.array([-2.1, 4.5, -2.1, 4.5, -2.1, 4.5, -2.1, 4.5, -2.1, 4.5])
sol7=max_dec_bt(rosenbrock, Grad_rosenbrock, x_07, np.sqrt(10*eps_machine), maxIter1, a0, r, c, maxIter2)
solution(sol7,rosenbrock, Grad_rosenbrock)
# Out:
# El minimizador alcanzado es [0.99976252 0.99952424 0.99904658 0.99808959 0.99617373 0.99234378
#  0.98470929 0.96957791 0.93992994 0.88315627]
# ¿Terminó por criterio de paro? False
# Iteraciones realizadas: 30000
# f(xk)=0.0048585832730700974
# ||Df(xk)||=0.07334621989048719
# Promedio de valores de alpha: 0.0001994801834669992
# Promedio de iteraciones de BT: 1.0013

# %%
#ahora con el cuarto punto de rosenbrock
x_08=np.array([-1.2, 1.0, -1.2, 1.0, -1.2, 1.0, -1.2, 1.0, -1.2, 1.0])
sol8=max_dec_bt(rosenbrock, Grad_rosenbrock, x_08, np.sqrt(10*eps_machine), maxIter1, a0, r, c, maxIter2)
solution(sol8,rosenbrock, Grad_rosenbrock)
# Out:
# El minimizador alcanzado es [0.99999989 0.99999978 0.99999955 0.9999991  0.9999982  0.99999638
#  0.99999275 0.99998546 0.99997085 0.99994156]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 19340
# f(xk)=1.1338443471285902e-09
# ||Df(xk)||=3.363138583940695e-05
# Promedio de valores de alpha: 0.0010742760251633596
# Promedio de iteraciones de BT: 1.0016028955532574

# %% [markdown]
# Ahora usarémos $c_1=0.0001$ con Beale.

# %%
#beale con el primer punto
x_09=np.array([2.0, 3.0])
c1=0.0001
sol9=max_dec_bt(beale, Grad_beale, x_09, tol, maxIter1, a0, r, c1, maxIter2)
solution(sol9,beale, Grad_beale)
points=sol9[3]
contornosFnc2D_modified(beale, -1.5, 5, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.99995158 0.49998791]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 29272
# f(xk)=3.7544304801750816e-10
# ||Df(xk)||=1.504619965426833e-05
# Promedio de valores de alpha: 0.0010244805381230508
# Promedio de iteraciones de BT: 1.0010590325225472

# %%
#beale con el segundo punto
x_010=np.array([2.0, 4.0])
sol10=max_dec_bt(beale, Grad_beale, x_010, tol, maxIter1, a0, r, c1, maxIter2)
solution(sol10,beale, Grad_beale)
points=sol10[3]
contornosFnc2D_modified(beale, -3, 5, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.96079278 0.49004481]
# ¿Terminó por criterio de paro? False
# Iteraciones realizadas: 30000
# f(xk)=0.00025719571050904525
# ||Df(xk)||=0.012984061498645057
# Promedio de valores de alpha: 0.00029293841164635374
# Promedio de iteraciones de BT: 1.0012333333333334

# %% [markdown]
# Notemos que, al cambiar el valor de $c$, para el caso del primer punto hubo una mejoria, pues el algoritmo logró terminar antes del máximo de iteraciones. Para el caso del segundo punto, aunque los resultados mejoran, no es una mejora radical, pero se obtienen mejores resultados.
#
# Hay que considerar que, depende mucho del punto de inicio, en el segundo caso, por la naturaleza de la función, parece que le cuesta más al algoritmo llegar al óptimo.
#
# Así que, una conclusión puede ser que, cambiar el valor de $c$ para obtener mejoras es una buena idea siempre y cuando se tenga claro que el punto inicial es lo suficientemente acertado para llegar más rápido al óptimo sin necesidad de alcanzar todas las iteraciones.

# %% [markdown]
# _
#
# ```
#
#
#
#
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Ejercicio 2 (3 puntos)
#
# Reprograme el Algoritmo 3 de la Clase 6  de descenso máximo
# para calcular el tamaño de paso inicial del algoritmo de backtracking.
#
# 1. Modifique la función del Punto 2 del Ejercicio 1 de modo que en la iteración
#    $k=0$ se invoque a la función que  ejecuta el backtracking usando el valor
#    $\alpha_{ini}$ dado, es decir,
#
#    $backtracking(f, \mathbf{x}_k, f_k, \nabla f_k, \mathbf{p}_k, \alpha_{ini}, \rho, c_1, N_b)$
#
#    y para $k>0$ se calcule el valor inicial del tamaño de paso como
#
# $$ \bar{\alpha} = \alpha_{k-1} \frac{\nabla f_{k-1}^\top \mathbf{p}_{k-1}}{\nabla f_{k}^\top \mathbf{p}_k} $$
#
#    y se use este valor al ejercutar backtracking:
#    $backtracking(f, \mathbf{x}_k, f_k, \nabla f_k, \mathbf{p}_k, \bar{\alpha}, \rho, c_1, N_b).$
#
# 2. Repita las pruebas del Ejercicio 1, imprimiendo los mismos resultados:
# - El número de iteraciones realizadas $k$
# - El punto $\mathbf{x}_k$ obtenido
# - $f(\mathbf{x}_k)$
# - $\|\nabla f(\mathbf{x}_k)\|$
# - La variable que indica si el algoritmo terminó porque se cumplió el criterio de paro o no.
# Además, si $n=2$, imprima
# - El valor promedio de los tamaños de paso $\alpha_0, \alpha_1, ..., \alpha_k$.
# - El valor promedio de las iteraciones $i_0, i_1, ..., i_k$ realizadas por el algoritmo de backtracking.
# - La gráfica de los contornos de nivel de la función y la trayectoria
#   de los puntos $\mathbf{x}_0, \mathbf{x}_1, ..., \mathbf{x}_k$.
#
# 3. Con base en el valor promedio de las iteraciones realizadas por el algoritmo de backtracking,
#    el valor $k$ y las gráficas, escriba un comentario sobre si el cambio realizado ayuda
#    al desempeño del método.
#    ¿Hay alguna diferencia entre importante entre calcular el tamaño de paso
#    de manera exacta con respecto a la búsqueda inexacta?
#
# ### Solución:

# %%
#modificamos la función
def max_dec_bt_modified(f, df, x0, tol, maxIter1, a0, r, c, maxIter2):
  xk=x0
  ak=a0
  n=x0.shape[0]
  seqx=[xk.copy()]
  seqa=[ak]
  seqi=[]
  gk=df(xk)
  pk=-gk
  step=backtracking(ak, r, c, xk, f, df, pk, maxIter2)
  if step[2]==False:
    print("BT llegó al max de iteraciones.")
  ak=step[0]
  seqi.append(step[1])
  if np.linalg.norm(ak*pk)<tol:
    if n==2:
      return xk, True, i+1, seqx, seqa, seqi
    else:
      return xk, True, i+1, [], seqa, seqi
  gk_old=gk
  pk_old=pk
  for i in range(1, maxIter1):
    gk=df(xk)
    pk=-gk
    ak=ak*min((np.dot(gk_old, pk_old))/(np.dot(gk, pk)), 100)
    step=backtracking(ak, r, c, xk, f, df, pk, maxIter2)
    if step[2]==False:
      print("BT llegó al max de iteraciones.")
    ak=step[0]
    seqi.append(step[1])
    if np.linalg.norm(ak*pk)<tol:
      if n==2:
        return xk, True, i+1, seqx, seqa, seqi
      else:
        return xk, True, i+1, [], seqa, seqi
    xk=xk+ak*pk
    gk_old=gk
    pk_old=pk
    seqx.append(xk.copy())
    seqa.append(ak)
  if n==2:
    return xk, False, maxIter1, seqx, seqa, seqi
  else:
    return xk, False, maxIter1, [], seqa, seqi

# %% [markdown]
# Ahora probamos resultados con la nueva función.

# %%
#probamos con himmelblau con el primer punto
x_01=np.array([2.0, 4.0])
sol1=max_dec_bt_modified(himmelblau, Grad_himmelblau, x_01, tol, maxIter1, a0, r, c, maxIter2)
solution(sol1,himmelblau, Grad_himmelblau)
points=sol1[3]
contornosFnc2D_modified(himmelblau, 0, 5, -4, 4, [10, 15, 20, 40, 80, 160, 320], points)
# Out:
# El minimizador alcanzado es [2.99999999 2.        ]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 41
# f(xk)=1.5753195356828441e-15
# ||Df(xk)||=5.091640473487686e-07
# Promedio de valores de alpha: 0.0442366966046494
# Promedio de iteraciones de BT: 5.7317073170731705

# %%
#himmelblau con el segundo punto
x_02=np.array([0.0, 0.0])
sol2=max_dec_bt_modified(himmelblau, Grad_himmelblau, x_02, tol, maxIter1, a0, r, c, maxIter2)
solution(sol2,himmelblau, Grad_himmelblau)
points=sol2[3]
contornosFnc2D_modified(himmelblau, 0, 5, -4, 4, [10, 15, 20, 40, 80, 160, 320], points)
# Out:
# El minimizador alcanzado es [2.99999999 2.        ]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 42
# f(xk)=2.76950134102607e-15
# ||Df(xk)||=6.751093374156111e-07
# Promedio de valores de alpha: 0.048055112201341704
# Promedio de iteraciones de BT: 5.142857142857143

# %%
#beale con el primer punto
x_03=np.array([2.0, 3.0])
sol3=max_dec_bt_modified(beale, Grad_beale, x_03, tol, maxIter1, a0, r, c, maxIter2)
solution(sol3,beale, Grad_beale)
points=sol3[3]
contornosFnc2D_modified(beale, 0, 5, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.99999914 0.4999998 ]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 577
# f(xk)=1.2312712118233691e-13
# ||Df(xk)||=7.354922925783439e-07
# Promedio de valores de alpha: 0.07502916848479252
# Promedio de iteraciones de BT: 1.3292894280762566

# %%
#beale con el segundo punto
x_04=np.array([2.0, 4.0])
sol4=max_dec_bt_modified(beale, Grad_beale, x_04, tol, maxIter1, a0, r, c, maxIter2)
solution(sol4,beale, Grad_beale)
points=sol4[3]
contornosFnc2D_modified(beale, -1.5, 8, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.99999911 0.49999976]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 596
# f(xk)=1.3463178870132325e-13
# ||Df(xk)||=8.172722237117477e-07
# Promedio de valores de alpha: 0.07246147111137426
# Promedio de iteraciones de BT: 1.320469798657718

# %%
#ahora con el primer punto de rosenbrock
x_05=np.array([-2.1, 4.5])
sol5=max_dec_bt_modified(rosenbrock, Grad_rosenbrock, x_05, tol, maxIter1, a0, r, c, maxIter2)
solution(sol5,rosenbrock, Grad_rosenbrock)
points=sol5[3]
contornosFnc2D_modified(rosenbrock, -3, 3, -1, 5, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [0.99999349 0.99998698]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 11455
# f(xk)=4.239932185537826e-11
# ||Df(xk)||=1.4517511327126736e-05
# Promedio de valores de alpha: 0.0027037115286946433
# Promedio de iteraciones de BT: 1.0147533828022697

# %%
#ahora con el segundo punto de rosenbrock
x_06=np.array([-1.2, 1.0])
sol6=max_dec_bt_modified(rosenbrock, Grad_rosenbrock, x_06, tol, maxIter1, a0, r, c, maxIter2)
solution(sol6,rosenbrock, Grad_rosenbrock)
points=sol6[3]
contornosFnc2D_modified(rosenbrock, -3, 3, -1, 5, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [0.99999336 0.99998673]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 7700
# f(xk)=4.4064045557114934e-11
# ||Df(xk)||=1.6443440132831363e-05
# Promedio de valores de alpha: 0.0037116660706341623
# Promedio de iteraciones de BT: 1.0232467532467533

# %%
#ahora con el tercer punto de rosenbrock
x_07=np.array([-2.1, 4.5, -2.1, 4.5, -2.1, 4.5, -2.1, 4.5, -2.1, 4.5])
sol7=max_dec_bt_modified(rosenbrock, Grad_rosenbrock, x_07, np.sqrt(10*eps_machine), maxIter1, a0, r, c, maxIter2)
solution(sol7,rosenbrock, Grad_rosenbrock)
# Out:
# El minimizador alcanzado es [0.99999992 0.99999985 0.99999968 0.9999994  0.99999875 0.99999753
#  0.99999501 0.99999004 0.99998    0.99995991]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 10564
# f(xk)=5.34511229987432e-10
# ||Df(xk)||=6.0712497161513005e-05
# Promedio de valores de alpha: 0.0020071900476094644
# Promedio de iteraciones de BT: 1.0210147671336616

# %%
#ahora con el cuarto punto de rosenbrock
x_08=np.array([-1.2, 1.0, -1.2, 1.0, -1.2, 1.0, -1.2, 1.0, -1.2, 1.0])
sol8=max_dec_bt_modified(rosenbrock, Grad_rosenbrock, x_08, np.sqrt(10*eps_machine), maxIter1, a0, r, c, maxIter2)
solution(sol8,rosenbrock, Grad_rosenbrock)
# Out:
# El minimizador alcanzado es [0.99999993 0.99999984 0.9999997  0.99999937 0.99999877 0.9999975
#  0.99999503 0.99998999 0.99997996 0.9999598 ]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 10472
# f(xk)=5.373628026086059e-10
# ||Df(xk)||=6.266577933618493e-05
# Promedio de valores de alpha: 0.0020393658508008395
# Promedio de iteraciones de BT: 1.018048128342246

# %% [markdown]
# Ahora usarémos $c_1=0.0001$ con Beale.

# %%
#beale con el primer punto
x_09=np.array([2.0, 3.0])
c1=0.0001
sol9=max_dec_bt_modified(beale, Grad_beale, x_09, tol, maxIter1, a0, r, c1, maxIter2)
solution(sol9,beale, Grad_beale)
points=sol9[3]
contornosFnc2D_modified(beale, -1.5, 5, -4, 4, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.9999993  0.49999981]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 605
# f(xk)=8.663545651206564e-14
# ||Df(xk)||=8.610968330768416e-07
# Promedio de valores de alpha: 0.07187727263757847
# Promedio de iteraciones de BT: 1.3603305785123967

# %%
#beale con el segundo punto
x_010=np.array([2.0, 4.0])
sol10=max_dec_bt_modified(beale, Grad_beale, x_010, tol, maxIter1, a0, r, c1, maxIter2)
solution(sol10,beale, Grad_beale)
points=sol10[3]
contornosFnc2D_modified(beale, -3, 5, -4, 5, [0.5, 5, 50, 250, 500, 1000, 1500, 2500, 4000], points)
# Out:
# El minimizador alcanzado es [2.99999924 0.4999998 ]
# ¿Terminó por criterio de paro? True
# Iteraciones realizadas: 550
# f(xk)=9.740191372724938e-14
# ||Df(xk)||=6.673320948933851e-07
# Promedio de valores de alpha: 0.07962025675850118
# Promedio de iteraciones de BT: 1.410909090909091

# %% [markdown]
# Definitivamente, la modificación del método logra mejores resultados y más aún con menos iteraciones. Si sobre todo eso consideramos la modificación de $c$ con la función de Beale se nota un cambio radical, pues para el segundo punto, la solución aún deja mucho que desear mientras que, al modificar $c$ logramos mucho mejores resultados y con menos iteraciones.
#
# La modificación a la función en definitiva es una buena opción, pero es importante mencionar que requiere de muchos cálculos más, pues el tener que estar calculando el $\alpha$ de entrada para BT puede ser una operación más pesada y aún más si las dimensiones crecen.

# %% [markdown]
# _
#
# ```
#
#
#
#
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Ejercicio 3 (1.5 puntos)
#
# Sea $f(\mathbf{x}) = f(x_1, x_2) = 5 + x_1^2 + x_2^2$. Si $\mathbf{x}_0 = (-1,1)^\top$,
# $\mathbf{p}_0 = (1,0)$ y $c_1=10^{-4}$.
# Verifique de $\mathbf{p}_0$ es una dirección de descenso y encuentre el valor
# más grande $\alpha>0$ que satisface la condición de descenso suficiente:
#
# $$ f(\mathbf{x}_0 + \alpha\mathbf{p}_0) \leq
# f(\mathbf{x}_0) + c_1 \alpha\mathbf{p}_0^\top\nabla f(\mathbf{p}_0). $$
#
# ### Solución:

# %% [markdown]
# Para verificar que $\mathbf{p}_0$ es una dirección de descenso, basta probar que $\mathbf{p}_0^\top\nabla f(\mathbf{x}_0)<0$. En efecto, notemos que $$\nabla f(\mathbf{x})=\begin{pmatrix} 2x_1\\ 2x_2\end{pmatrix}$$luego $$\mathbf{p}_0^\top\nabla f(\mathbf{x}_0)=-2<0$$por lo que $\mathbf{p}_0$ es una dirección de descenso.
#
# Para hallar el valor de $\alpha$, calculemos la expresión $$ f(\mathbf{x}_0 + \alpha\mathbf{p}_0) \leq
# f(\mathbf{x}_0) + c_1 \alpha\mathbf{p}_0^\top\nabla f(\mathbf{x}_0). $$de donde obtenemos la desigualdad $$\alpha^2 +2(10^{-4}-1)\alpha\leq 0$$Sea $\beta=2(10^{-4}-1)$, factorizando obtenemos lo siguiente: $$\alpha(\alpha +\beta)\leq 0$$Notemos que $\beta<0$ por lo que, para $\alpha\in[0,-\beta]$ se cumple la desigualdad de descenso suficiente. De aquí que el valor más grande de $\alpha$ que satisface la condición es $\alpha=2(1-10^{-4})$.

# %% [markdown]
# _
#
# ```
#
#
#
#
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Ejercicio 4 (1.5 puntos)
#
# Sea $f:\mathbb{R}^n \rightarrow \mathbb{R}$ y $\mathbf{S}$ una matriz no singular de tamaño $n \times n$.
# Si $\mathbf{x} = \mathbf{S}\mathbf{y}$ para $\mathbf{y} \in \mathbb{R}^n$ y definimos
# $g(\mathbf{y}) = f(\mathbf{S}\mathbf{y})$, aplicando la regla de la cadena muestre que
#
# $$ \nabla g(\mathbf{y}) =  \mathbf{S}^\top \nabla f(\mathbf{x}). $$
#
# Entonces aplicando el método de máximo descenso a la función $g$ es
#
# $$ \mathbf{y}_{k+1} = \mathbf{y}_k - \alpha_k \mathbf{S}^\top \nabla f(\mathbf{S}\mathbf{y}_k).$$
#
# Multiplicando por $\mathbf{S}$ ambos miembros de la ecuación y usando la notación
# $\mathbf{x}_k =\mathbf{S} \mathbf{y}_k$:
#
# $$ \mathbf{x}_{k+1} =  \mathbf{S} \mathbf{y}_{k+1} =
# \mathbf{S} \mathbf{y}_k - \alpha_k \mathbf{S}\mathbf{S}^\top \nabla f(\mathbf{S}\mathbf{y}_k)
# = \mathbf{x}_k - \alpha_k \mathbf{S}\mathbf{S}^\top \nabla f(\mathbf{x}_k).$$
#
# Si $\mathbf{D} = \mathbf{S}\mathbf{S}^\top$, obtenemos el método de *gradiente escalado*:
#
# $$ \mathbf{x}_{k+1} = \mathbf{x}_k - \alpha_k \mathbf{D} \nabla f(\mathbf{x}_k).$$
#
# Muestre que $-\mathbf{D} \nabla f(\mathbf{x}_k)$ es una dirección de descenso.
#
# ### Solución:

# %% [markdown]
# Tenemos que $$\nabla g(\mathbf{y})=\nabla f(\mathbf{Sy})$$luego, por la regla de la cadena, sabemos que $$\dfrac{\partial f(\mathbf{Ax})}{\partial \mathbf{x}}=\dfrac{\partial f(\mathbf{Ax})}{\partial \mathbf{Ax}}\dfrac{∂\mathbf{Ax}}{\partial \mathbf{x}}$$ y ya que $$\dfrac{∂\mathbf{Ax}}{\partial \mathbf{x}}=\mathbf{A}$$ tenemos entonces que $$\nabla g(\mathbf{y})=\mathbf{S}^\top\nabla f(\mathbf{x}).$$
#
# Para probar que $-\mathbf{D}\nabla f(\mathbf{x}_k)$ es dirección de descenso, si probamos que $$-[\nabla f(\mathbf{x}_k)]^\top\mathbf{D}\nabla f(\mathbf{x}_k) <0$$ habremos terminado. En efecto, \begin{equation*}
# \begin{split}
# -\nabla f(\mathbf{x}_k)^\top\mathbf{D}\nabla f(\mathbf{x}_k) &= -\nabla f(\mathbf{x}_k)^\top\mathbf{S}\mathbf{S}^\top\nabla f(\mathbf{x}_k) \\
# &=-[\mathbf{S}^\top\nabla f(\mathbf{x}_k)]^\top\mathbf{S}^\top\nabla f(\mathbf{x}_k) \\
# &=-\Vert\mathbf{S}^\top\nabla f(\mathbf{x}_k)\Vert ²\\
# &<0
# \end{split}
# \end{equation*} por lo que $-\mathbf{D}\nabla f(\mathbf{x}_k)$ es una dirección de descenso.

# %% [markdown]
# _
#
# ```
#
#
#
#
#
#
#
# ```
#
# ---
