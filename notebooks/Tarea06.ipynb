# %% [markdown]
# # Curso de Optimización I
# ## Tarea 6
#
# | Descripción:                         | Fechas               |
# |--------------------------------------|----------------------|
# | Fecha de publicación del documento:  | **Marzo 25, 2024**   |
# | Fecha límite de entrega de la tarea: | **Abril 14, 2024**   |
#
#
# ### Indicaciones
#
# - Envie el notebook con los códigos y las pruebas realizadas de cada ejercicio.
# - Si se requiren algunos scripts adicionales para poder reproducir las pruebas,
#   agreguelos en un ZIP junto con el notebook.
# - Genere un PDF del notebook y envielo por separado.

# %% [markdown]
# ---
#
# ## Ejercicio 1 (3 puntos)
#
# 1. Programe el método de gradiente conjugado lineal, Algoritmo 1 de la Clase 18,
#    para resolver el sistema de ecuaciones $\mathbf{A}\mathbf{x}=\mathbf{b}$, donde
#    $\mathbf{A}$ es una matriz simétrica y definida positiva.
#
#    Haga que la función devuelva el último punto  $\mathbf{x}_k$,
#    el último residual $\mathbf{r}_k$, el número de iteraciones $k$
#    y una variable binaria $bres$ que indique si se cumplió el criterio
#    de paro ($bres=True$) o si el algoritmo terminó por
#    iteraciones ($bres=False$).
#
# 2. Pruebe el algoritmo para resolver el sistema de ecuaciones
#
# $$ \mathbf{A}_1\mathbf{x}=\mathbf{b}_1$$
#
# donde
#
# $$ \mathbf{A}_1 = n\mathbf{I} + \mathbf{1} =
# \left[\begin{array}{llll} n      & 0      & \cdots & 0 \\
#                        0      & n      & \cdots & 0 \\
#                        \vdots & \vdots & \ddots & \vdots \\
#                        0      & 0      & \cdots & n \end{array}\right]
# + \left[\begin{array}{llll} 1    & 1      & \cdots & 1 \\
#                        1      & 1      & \cdots & 1 \\
#                        \vdots & \vdots & \ddots & \vdots \\
#                        1      & 1      & \cdots & 1 \end{array}\right],  \qquad
# \mathbf{b}_1 = \left[\begin{array}{l} 1 \\ 1 \\ \vdots \\ 1 \end{array}\right], $$
#
# $n$ es la dimensión de la variable independiente
# $\mathbf{x}=(x_1, x_2, ..., x_n)$,
# $\mathbf{I}$ es la matriz identidad y $\mathbf{1}$ es la matriz llena de 1's,
# ambas de tamaño $n$.
#
# También aplique el algoritmo para resolver el sistema
#
# $$ \mathbf{A}_2\mathbf{x}=\mathbf{b}_2$$
#
# donde  $\mathbf{A}_2 = [a_{ij}]$ con
#
# $$ a_{ij} = exp\left(-0.25(i-j)^2 \right),  \qquad
# \mathbf{b}_2 = \left[\begin{array}{l} 1 \\ 1 \\ \vdots \\ 1 \end{array}\right] $$
#
#
# - Use $\mathbf{x}_0$ como el vector cero, el máximo número de iteraciones
#   $N=n$ y una toleracia $\tau=\sqrt{n} \epsilon_m^{1/3}$,
#   donde $\epsilon_m$ es el épsilon máquina.
# - Pruebe el algoritmo resolviendo los dos sistemas de ecuaciones con $n=10, 100, 1000$ y
#   en cada caso imprima la siguiente información
#
# - la dimensión $n$,
# - el  número $k$ de iteraciones realizadas,
# - las primeras y últimas 4 entradas del punto $\mathbf{x}_k$ que devuelve el algoritmo,
# - la norma del residual $\mathbf{r}_k$,
# - la variable $bres$ para saber si el algoritmo puedo converger.
#
# ### Solución:

# %%
# importamos librerías
import numpy as np
import time

# %%
# creamos la función
def grad_conj(x0, A, b, maxIter, tol):
    xk = x0
    rk = A@xk - b
    pk = -rk
    for k in range(maxIter):
        rk_norm = np.linalg.norm(rk)
        if rk_norm < tol:
            return xk, rk, k+1, True
        ak = rk_norm**2 / (pk.T@A@pk)
        xk = xk + ak*pk
        rk = rk + ak*A@pk
        bk = np.dot(rk, rk)/rk_norm**2
        pk = -rk + bk*pk
    return xk, rk, maxIter, False

# %%
# función para imprimir resultados
def solution1(sol):
    print(f"Dimension: {len(sol[0])}")
    print(f"¿Terminó por criterio de paro?: {sol[-1]}")
    print(f"Número de iteraciones realizadas: {sol[2]}")
    print("La solución alcanzada es: ",sol[0][:4],"...", sol[0][-4:])
    print(f"La norma del residual final es: {np.linalg.norm(sol[1])}")

# %%
# definimos algunas constantes
eps = np.finfo(float).eps
n = [10, 100, 1000]

# %%
# para generar las matrices del primer ejercicio
def gen_matrix1(N):
    A = np.ones([N,N]) + N*np.eye(N)
    b = np.ones(N)
    return A, b

# %%
# para generar las segundas matrices del primer  ejercicio
def gen_matrix2(N):
    A = np.zeros([N,N])
    for i in range(N):
        for j in  range(N):
            A[i][j]=np.exp(-0.25*((i-j)**2))
    b = np.ones(N)
    return A, b

# %%
# para la primera matriz con la primer dimensión
A1, b1 = gen_matrix1(n[0])
x01 = np.zeros(n[0])
sol1 = grad_conj(x01, A1, b1, n[0], np.sqrt(n[0])*eps**(1/3.0))
solution1(sol1)
# Out:
# Dimension: 10
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 2
# La solución alcanzada es:  [0.05 0.05 0.05 0.05] ... [0.05 0.05 0.05 0.05]
# La norma del residual final es: 7.021666937153402e-16

# %%
# ahora con la segunda dimensión
A2, b2 = gen_matrix1(n[1])
x02 = np.zeros(n[1])
sol2 = grad_conj(x02, A2, b2, n[1], np.sqrt(n[1])*eps**(1/3.0))
solution1(sol2)
# Out:
# Dimension: 100
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 2
# La solución alcanzada es:  [0.005 0.005 0.005 0.005] ... [0.005 0.005 0.005 0.005]
# La norma del residual final es: 1.6011864169946884e-15

# %%
# ahora con la tercer dimensión
A3, b3 = gen_matrix1(n[2])
x03 = np.zeros(n[2])
sol3 = grad_conj(x03, A3, b3, n[2], np.sqrt(n[2])*eps**(1/3.0))
solution1(sol3)
# Out:
# Dimension: 1000
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 2
# La solución alcanzada es:  [0.0005 0.0005 0.0005 0.0005] ... [0.0005 0.0005 0.0005 0.0005]
# La norma del residual final es: 2.4130518021186067e-13

# %%
# ahora probaremos con la segunda matriz en la primer dimensión
A4, b4 = gen_matrix2(n[0])
x04 = np.zeros(n[0])
sol4 = grad_conj(x04, A4, b4, n[0], np.sqrt(n[0])*eps**(1/3.0))
solution1(sol4)
# Out:
# Dimension: 10
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 6
# La solución alcanzada es:  [ 1.36909916 -1.16637682  1.60908281 -0.61339053] ... [-0.61339053  1.60908281 -1.16637682  1.36909916]
# La norma del residual final es: 2.5050526736723508e-11

# %%
# ahora probaremos con la segunda dimension
A5, b5 = gen_matrix2(n[1])
x05 = np.zeros(n[1])
sol5 = grad_conj(x05, A5, b5, n[1], np.sqrt(n[1])*eps**(1/3.0))
solution1(sol5)
# Out:
# Dimension: 100
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 100
# La solución alcanzada es:  [ 1.44626669 -1.41632456  2.1104745  -1.42498036] ... [-1.42492833  2.11044145 -1.41636897  1.44632425]
# La norma del residual final es: 0.00013543899923613298

# %%
# ahora probaremos con la tercer dimension
A6, b6 = gen_matrix2(n[2])
x06 = np.zeros(n[2])
sol6 = grad_conj(x06, A6, b6, n[2], np.sqrt(n[2])*eps**(1/3.0))
solution1(sol6)
# Out:
# Dimension: 1000
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 263
# La solución alcanzada es:  [ 1.44628824 -1.41635954  2.1105181  -1.42507231] ... [-1.42507231  2.1105181  -1.41635954  1.44628824]
# La norma del residual final es: 0.00018766135270274152

# %% [markdown]
# ```
#
#
# ```
# ---

# %% [markdown]
# ## Ejercicio 2 (3.5 puntos)
#
# Programar el método de gradiente conjugado no lineal descrito en el Algoritmo 3
# de Clase 19 usando la fórmula de Fletcher-Reeves:
#
# $$ \beta_{k+1} = \frac{\nabla f_{k+1}^\top \nabla f_{k+1}}{\nabla f_{k}^\top\nabla f_{k}}  $$
#
# ```
#
#
# ```
#
# 1. Escriba la función que implemente el algoritmo.
#
# - La función debe recibir como argumentos $\mathbf{x}_0$, la función $f$ y
#   su gradiente, el número máximo de iteraciones $N$, la tolerancia $\tau$, y los
#   parámetros para el algoritmo de backtracking: factor $\rho$, la constante $c_1$
#   para la condición de descenso suficiente, la constante $c_2$ para la condición
#   de curvatura, y el máximo número de iteraciones $N_b$.
# - Agregue al algoritmo un contador
#   $nr$ que se incremente cada vez que se aplique el reinicio, es decir, cuando
#   se hace $\beta_{k+1}=0$.
#
# - Para calcular el tamaño de paso $\alpha_k$ use el algoritmo de backtracking
#   usando las condiciones de Wolfe con el valor inicial $\alpha_{ini}=1$.
#
# - Haga que la función devuelva el último punto  $\mathbf{x}_k$,
#   el último gradiente $\mathbf{g}_k$, el número de iteraciones $k$
#   y una variable binaria $bres$ que indique si se cumpli\'o el criterio
#   de paro ($bres=True$) o si el algoritmo terminó por
#   iteraciones ($bres=False$), y el contador $br·.
#
# 2. Pruebe el algoritmo usando la siguientes funciones con los puntos iniciales dados:
#
#
# **Función de cuadrática 1:** Para $\mathbf{x}=(x_1,x_2, ..., x_n)$
#
# - $f(\mathbf{x}) = \frac{1}{2} \mathbf{x}^\top\mathbf{A}_1\mathbf{x} - \mathbf{b}_1^\top\mathbf{x}$,
#   donde $\mathbf{A}_1$ y $\mathbf{b}_1$ están definidas como en el Ejercicio 1.
# - $\mathbf{x}_0 = (0,...,0)\in \mathbb{R}^{10}$
# - $\mathbf{x}_0 = (0,...,0)\in \mathbb{R}^{100}$
# - $\mathbf{x}_0 = (0,...,0)\in \mathbb{R}^{1000}$
#
# **Función de cuadrática 2:** Para $\mathbf{x}=(x_1,x_2, ..., x_n)$
#
# - $f(\mathbf{x}) = \frac{1}{2} \mathbf{x}^\top\mathbf{A}_2\mathbf{x} - \mathbf{b}_2^\top\mathbf{x}$,
#   donde $\mathbf{A}_2$ y $\mathbf{b}_2$ están definidas como en el Ejercicio 1.
# - $\mathbf{x}_0 = (0,...,0)\in \mathbb{R}^{10}$
# - $\mathbf{x}_0 = (0,...,0)\in \mathbb{R}^{100}$
# - $\mathbf{x}_0 = (0,...,0)\in \mathbb{R}^{1000}$
#
# **Función de Beale :** Para $\mathbf{x}=(x_1,x_2)$
#
# $$f(\mathbf{x}) = (1.5-x_1 + x_1x_2)^2 + (2.25 - x_1 + x_1x_2^2)^2 + (2.625 - x_1 + x_1x_2^3)^2.$$
# - $\mathbf{x}_0 = (2,3)$
#
#
# **Función de Himmelblau:** Para $\mathbf{x}=(x_1,x_2)$
#
# $$f(\mathbf{x}) = (x_1^2 + x_2 - 11)^2 + (x_1 + x_2^2 - 7)^2. $$
# - $\mathbf{x}_0 = (2,4)$
#
#
#
# **Función de Rosenbrock:** Para $\mathbf{x}=(x_1,x_2, ..., x_n)$
#
# $$ f(\mathbf{x}) = \sum_{i=1}^{n-1} \left[100(x_{i+1} - x_i^2)^2 + (1-x_i)^2 \right]
# \quad n\geq 2.$$
# - $\mathbf{x}_0 = (-1.2, 1.0)\in \mathbb{R}^{2}$
# - $\mathbf{x}_0 = (-1.2, 1.0, ..., -1.2, 1.0) \in \mathbb{R}^{20}$
# - $\mathbf{x}_0 = (-1.2, 1.0, ..., -1.2, 1.0) \in \mathbb{R}^{40}$
#
#
# 3. Fije $N=5000$, $\tau = \sqrt{n}\epsilon_m^{1/3}$, donde $n$ es la dimensión
#    de la variable $\mathbf{x}$ y $\epsilon_m$ es el épsilon máquina.
#    Para backtracking use $\rho=0.5$, $c_1=0.001$, $c_2=0.01$, $N_b=500$.
#
# 4. Para cada función de prueba imprima
#
# - la dimensión $n$,
# - $f(\mathbf{x}_0)$,
# - el  número $k$ de iteraciones realizadas,
# - $f(\mathbf{x}_k)$,
# - las primeras y últimas 4 entradas del punto $\mathbf{x}_k$ que devuelve el algoritmo,
# - la norma del vector gradiente $\mathbf{g}_k$,
# - la variable $bres$ para saber si el algoritmo puedo converger.
# - el número de reinicios $nr$.
#
#
# ### Solución:

# %%
def backtracking(a0, r, c1, c2, xk, f, df, pk, maxIter):
  a=a0
  for i in range(maxIter):
    # condicion de Armijo
    if f(xk+a*pk)<= f(xk) + c1*a*(np.dot(df(xk), pk)):
      # condición de curvatura
      if np.dot(df(xk+a*pk), pk) >= c2*np.dot(df(xk), pk):
        return a, i+1, True
    a=r*a
  return a, maxIter, False

# %%
# programamos la función
def nonlinear_grad_conj(f, grad, x0, a0, maxIter, tol, c1, c2, r, maxIter2):
    xk = x0
    gk = grad(xk)
    dk = -gk
    ak = a0
    nr = 0
    for k in range(maxIter):
        aux1 = np.dot(gk, gk)
        if np.sqrt(aux1) < tol:
            return xk, gk, k, True, nr
        z = backtracking(a0, r, c1, c2, xk, f, grad, dk, maxIter2)
        if z[-1]==False:
           print("Backtracking está consumiendo todas las iteraciones. k =",k)
        ak = z[0]
        xk = xk + ak*dk
        gk1 = grad(xk)
        aux2 = np.dot(gk1, gk1)
        if np.abs(np.dot(gk1,gk)) < 0.2*aux2:
            bk = aux2 / aux1
        else:
            bk = 0
            nr += 1
        gk = gk1.copy()
        dk = -gk + bk*dk
    return xk, gk, maxIter, False, nr

# %%
# función para imprimir resultados
def solution2(sol, f, x0):
    print(f"Dimension: {len(sol[0])}")
    print(f"¿Terminó por criterio de paro?: {sol[3]}")
    print(f"Número de iteraciones realizadas: {sol[2]}")
    print("La solución alcanzada es: ",sol[0][:4],"...", sol[0][-4:])
    print(f"f(xk)={f(sol[0])}")
    print(f"f(x0)={f(x0)}")
    print(f"La norma del gradiente final es: {np.linalg.norm(sol[1])}")
    print("Número de reinicios: ", sol[-1])

# %%
# funciones
def quadratic(x, A, b):
    return (x.T@(A@x))/2.0 - np.dot(b, x)

def Grad_quadratic(x, A, b):
    return A@x - b

def himmelblau(x):
  return (x[0]**2+x[1]-11)**2 + (x[0]+x[1]**2-7)**2

def Grad_himmelblau(x):
  d1=4*x[0]**3 + 4*x[0]*x[1] - 42*x[0] + 2*x[1]**2 - 14
  d2=4*x[1]**3 + 4*x[0]*x[1] + 2*x[0]**2 - 26*x[1] - 22
  return np.array([d1,d2])

def beale(x):
  return (1.5-x[0]+x[1]*x[0])**2 + (2.25-x[0]+x[0]*x[1]**2)**2 + (2.625-x[0]+x[0]*x[1]**3)**2

def Grad_beale(x):
  d1=2*(x[1]-1)*(1.5-x[0]+x[1]*x[0])+2*(x[1]**2-1)*(2.25-x[0]+x[0]*x[1]**2)+2*(x[1]**3-1)*(2.625-x[0]+x[0]*x[1]**3)
  d2=2*(x[0])*(1.5-x[0]+x[1]*x[0])+4*(x[0]*x[1])*(2.25-x[0]+x[0]*x[1]**2)+6*(x[0]*x[1]**2)*(2.625-x[0]+x[0]*x[1]**3)
  return np.array([d1, d2])

def rosenbrock(x):
  f=0
  n=x.shape[0]
  for i in range(n-1):
    f+=100*(x[i+1]-x[i]**2)**2 + (1-x[i])**2
  return f

def Grad_rosenbrock(x):
  n=x.shape[0]
  grad=np.zeros(n)
  grad[0]=-2*(1-x[0])-400*x[0]*(x[1]-x[0]**2)
  grad[-1]=200*(x[-1]-x[-2]**2)
  for i in range(1,n-1):
    grad[i]=200*(x[i]-x[i-1]**2-2*x[i]*x[i+1]+2*x[i]**3) -2*(1-x[i])
  return grad

# %%
# definimos
maxIter = 5000
rho = 0.5
c1 = 0.001
c2 = 0.01
maxIter2 = 500
a0 = 1

# %%
#probemos con la forma cuadratica, y el primer tipo de matriz con la primer dimension
A1, b1 = gen_matrix1(n[0])
sol1 = nonlinear_grad_conj(lambda x: quadratic(x, A1, b1),
                           lambda x: Grad_quadratic(x, A1, b1),
                           np.zeros(n[0]), a0, maxIter, np.sqrt(n[0])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol1, lambda x: quadratic(x, A1, b1), np.zeros(n[0]))
# Out:
# Dimension: 10
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 9
# La solución alcanzada es:  [0.05000019 0.05000019 0.05000019 0.05000019] ... [0.05000019 0.05000019 0.05000019 0.05000019]
# f(xk)=-0.24999999999636202
# f(x0)=0.0
# La norma del gradiente final es: 1.206313194339134e-05
# Número de reinicios:  9

# %%
#probemos con la segunda dimension
A2, b2 = gen_matrix1(n[1])
sol2 = nonlinear_grad_conj(lambda x: quadratic(x, A2, b2),
                           lambda x: Grad_quadratic(x, A2, b2),
                           np.zeros(n[1]), a0, maxIter, np.sqrt(n[1])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol2, lambda x: quadratic(x, A2, b2), np.zeros(n[1]))
# Out:
# Dimension: 100
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 21
# La solución alcanzada es:  [0.00500003 0.00500003 0.00500003 0.00500003] ... [0.00500003 0.00500003 0.00500003 0.00500003]
# f(xk)=-0.24999999999200045
# f(x0)=0.0
# La norma del gradiente final es: 5.656829153792843e-05
# Número de reinicios:  21

# %%
# con la tercer dimension
A3, b3 = gen_matrix1(n[2])
sol3 = nonlinear_grad_conj(lambda x: quadratic(x, A3, b3),
                           lambda x: Grad_quadratic(x, A3, b3),
                           np.zeros(n[2]), a0, maxIter, np.sqrt(n[2])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol3, lambda x: quadratic(x, A3, b3), np.zeros(n[2]))
# Out:
# Dimension: 1000
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 251
# La solución alcanzada es:  [0.0005 0.0005 0.0005 0.0005] ... [0.0005 0.0005 0.0005 0.0005]
# f(xk)=-0.24999999999146555
# f(x0)=0.0
# La norma del gradiente final es: 0.00018476304776620826
# Número de reinicios:  251

# %%
# con la segunda matriz y la primer dimensión
A4, b4 = gen_matrix2(n[0])
sol4 = nonlinear_grad_conj(lambda x: quadratic(x, A4, b4),
                           lambda x: Grad_quadratic(x, A4, b4),
                           np.zeros(n[0]), a0, maxIter, np.sqrt(n[0])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol4, lambda x: quadratic(x, A4, b4), np.zeros(n[0]))
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 12
# Backtracking está consumiendo todas las iteraciones. k = 20
# Backtracking está consumiendo todas las iteraciones. k = 22
# Backtracking está consumiendo todas las iteraciones. k = 25
# Backtracking está consumiendo todas las iteraciones. k = 27
# Backtracking está consumiendo todas las iteraciones. k = 43
# Backtracking está consumiendo todas las iteraciones. k = 45
# Backtracking está consumiendo todas las iteraciones. k = 48
# Backtracking está consumiendo todas las iteraciones. k = 50
# Backtracking está consumiendo todas las iteraciones. k = 53
# Backtracking está consumiendo todas las iteraciones. k = 55
# Backtracking está consumiendo todas las iteraciones. k = 58
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 63
# Backtracking está consumiendo todas las iteraciones. k = 65
# Backtracking está consumiendo todas las iteraciones. k = 68
# Backtracking está consumiendo todas las iteraciones. k = 70
# Backtracking está consumiendo todas las iteraciones. k = 73
# Backtracking está consumiendo todas las iteraciones. k = 75
# Backtracking está consumiendo todas las iteraciones. k = 78
# Backtracking está consumiendo todas las iteraciones. k = 80
# Backtracking está consumiendo todas las iteraciones. k = 83
# Backtracking está consumiendo todas las iteraciones. k = 85
# Backtracking está consumiendo todas las iteraciones. k = 88
# Backtracking está consumiendo todas las iteraciones. k = 90
# Backtracking está consumiendo todas las iteraciones. k = 93
# Backtracking está consumiendo todas las iteraciones. k = 95
# Backtracking está consumiendo todas las iteraciones. k = 194
# Backtracking está consumiendo todas las iteraciones. k = 198
# Backtracking está consumiendo todas las iteraciones. k = 202
# Backtracking está consumiendo todas las iteraciones. k = 206
# Backtracking está consumiendo todas las iteraciones. k = 209
# Backtracking está consumiendo todas las iteraciones. k = 211
# Backtracking está consumiendo todas las iteraciones. k = 214
# Backtracking está consumiendo todas las iteraciones. k = 216
# Backtracking está consumiendo todas las iteraciones. k = 219
# Backtracking está consumiendo todas las iteraciones. k = 221
# Backtracking está consumiendo todas las iteraciones. k = 224
# Backtracking está consumiendo todas las iteraciones. k = 226
# Backtracking está consumiendo todas las iteraciones. k = 229
# Backtracking está consumiendo todas las iteraciones. k = 231
# Backtracking está consumiendo todas las iteraciones. k = 234
# Backtracking está consumiendo todas las iteraciones. k = 236
# Backtracking está consumiendo todas las iteraciones. k = 239
# Backtracking está consumiendo todas las iteraciones. k = 241
# Backtracking está consumiendo todas las iteraciones. k = 244
# Backtracking está consumiendo todas las iteraciones. k = 246
# Backtracking está consumiendo todas las iteraciones. k = 249
# Backtracking está consumiendo todas las iteraciones. k = 251
# Backtracking está consumiendo todas las iteraciones. k = 254
# Backtracking está consumiendo todas las iteraciones. k = 256
# Backtracking está consumiendo todas las iteraciones. k = 259
# Backtracking está consumiendo todas las iteraciones. k = 261
# Backtracking está consumiendo todas las iteraciones. k = 264
# Backtracking está consumiendo todas las iteraciones. k = 266
# Backtracking está consumiendo todas las iteraciones. k = 269
# Backtracking está consumiendo todas las iteraciones. k = 271
# Backtracking está consumiendo todas las iteraciones. k = 274
# Backtracking está consumiendo todas las iteraciones. k = 276
# Backtracking está consumiendo todas las iteraciones. k = 279
# Backtracking está consumiendo todas las iteraciones. k = 281
# Backtracking está consumiendo todas las iteraciones. k = 284
# Backtracking está consumiendo todas las iteraciones. k = 286
# Backtracking está consumiendo todas las iteraciones. k = 289
# Backtracking está consumiendo todas las iteraciones. k = 291
# Backtracking está consumiendo todas las iteraciones. k = 294
# Backtracking está consumiendo todas las iteraciones. k = 296
# Backtracking está consumiendo todas las iteraciones. k = 299
# Backtracking está consumiendo todas las iteraciones. k = 301
# Backtracking está consumiendo todas las iteraciones. k = 304
# Backtracking está consumiendo todas las iteraciones. k = 306
# Backtracking está consumiendo todas las iteraciones. k = 309
# Backtracking está consumiendo todas las iteraciones. k = 311
# Backtracking está consumiendo todas las iteraciones. k = 407
# Backtracking está consumiendo todas las iteraciones. k = 411
# Backtracking está consumiendo todas las iteraciones. k = 415
# Backtracking está consumiendo todas las iteraciones. k = 419
# Backtracking está consumiendo todas las iteraciones. k = 422
# Backtracking está consumiendo todas las iteraciones. k = 424
# Backtracking está consumiendo todas las iteraciones. k = 427
# Backtracking está consumiendo todas las iteraciones. k = 429
# Backtracking está consumiendo todas las iteraciones. k = 432
# Backtracking está consumiendo todas las iteraciones. k = 434
# Backtracking está consumiendo todas las iteraciones. k = 437
# Backtracking está consumiendo todas las iteraciones. k = 439
# Backtracking está consumiendo todas las iteraciones. k = 442
# Backtracking está consumiendo todas las iteraciones. k = 444
# Backtracking está consumiendo todas las iteraciones. k = 447
# Backtracking está consumiendo todas las iteraciones. k = 449
# Backtracking está consumiendo todas las iteraciones. k = 452
# Backtracking está consumiendo todas las iteraciones. k = 454
# Backtracking está consumiendo todas las iteraciones. k = 457
# Backtracking está consumiendo todas las iteraciones. k = 459
# Backtracking está consumiendo todas las iteraciones. k = 462
# Backtracking está consumiendo todas las iteraciones. k = 464
# Backtracking está consumiendo todas las iteraciones. k = 467
# Backtracking está consumiendo todas las iteraciones. k = 469
# Backtracking está consumiendo todas las iteraciones. k = 472
# Backtracking está consumiendo todas las iteraciones. k = 474
# Backtracking está consumiendo todas las iteraciones. k = 477
# Backtracking está consumiendo todas las iteraciones. k = 479
# Backtracking está consumiendo todas las iteraciones. k = 482
# Backtracking está consumiendo todas las iteraciones. k = 484
# Backtracking está consumiendo todas las iteraciones. k = 487
# Backtracking está consumiendo todas las iteraciones. k = 489
# Backtracking está consumiendo todas las iteraciones. k = 492
# Backtracking está consumiendo todas las iteraciones. k = 494
# Backtracking está consumiendo todas las iteraciones. k = 497
# Backtracking está consumiendo todas las iteraciones. k = 499
# Backtracking está consumiendo todas las iteraciones. k = 502
# Backtracking está consumiendo todas las iteraciones. k = 504
# Backtracking está consumiendo todas las iteraciones. k = 507
# Backtracking está consumiendo todas las iteraciones. k = 509
# Backtracking está consumiendo todas las iteraciones. k = 512
# Backtracking está consumiendo todas las iteraciones. k = 514
# Backtracking está consumiendo todas las iteraciones. k = 517
# Backtracking está consumiendo todas las iteraciones. k = 519
# Backtracking está consumiendo todas las iteraciones. k = 522
# Backtracking está consumiendo todas las iteraciones. k = 524
# Backtracking está consumiendo todas las iteraciones. k = 527
# Backtracking está consumiendo todas las iteraciones. k = 529
# Backtracking está consumiendo todas las iteraciones. k = 625
# Backtracking está consumiendo todas las iteraciones. k = 629
# Backtracking está consumiendo todas las iteraciones. k = 633
# Backtracking está consumiendo todas las iteraciones. k = 637
# Backtracking está consumiendo todas las iteraciones. k = 640
# Backtracking está consumiendo todas las iteraciones. k = 642
# Backtracking está consumiendo todas las iteraciones. k = 645
# Backtracking está consumiendo todas las iteraciones. k = 647
# Backtracking está consumiendo todas las iteraciones. k = 650
# Backtracking está consumiendo todas las iteraciones. k = 652
# Backtracking está consumiendo todas las iteraciones. k = 655
# Backtracking está consumiendo todas las iteraciones. k = 657
# Backtracking está consumiendo todas las iteraciones. k = 660
# Backtracking está consumiendo todas las iteraciones. k = 662
# Backtracking está consumiendo todas las iteraciones. k = 665
# Backtracking está consumiendo todas las iteraciones. k = 667
# Backtracking está consumiendo todas las iteraciones. k = 670
# Backtracking está consumiendo todas las iteraciones. k = 672
# Backtracking está consumiendo todas las iteraciones. k = 675
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 680
# Backtracking está consumiendo todas las iteraciones. k = 682
# Backtracking está consumiendo todas las iteraciones. k = 685
# Backtracking está consumiendo todas las iteraciones. k = 687
# Backtracking está consumiendo todas las iteraciones. k = 690
# Backtracking está consumiendo todas las iteraciones. k = 692
# Backtracking está consumiendo todas las iteraciones. k = 695
# Backtracking está consumiendo todas las iteraciones. k = 697
# Backtracking está consumiendo todas las iteraciones. k = 700
# Backtracking está consumiendo todas las iteraciones. k = 702
# Backtracking está consumiendo todas las iteraciones. k = 705
# Backtracking está consumiendo todas las iteraciones. k = 707
# Backtracking está consumiendo todas las iteraciones. k = 710
# Backtracking está consumiendo todas las iteraciones. k = 712
# Backtracking está consumiendo todas las iteraciones. k = 715
# Backtracking está consumiendo todas las iteraciones. k = 717
# Backtracking está consumiendo todas las iteraciones. k = 720
# Backtracking está consumiendo todas las iteraciones. k = 722
# Backtracking está consumiendo todas las iteraciones. k = 725
# Backtracking está consumiendo todas las iteraciones. k = 727
# Backtracking está consumiendo todas las iteraciones. k = 730
# Backtracking está consumiendo todas las iteraciones. k = 732
# Backtracking está consumiendo todas las iteraciones. k = 735
# Backtracking está consumiendo todas las iteraciones. k = 737
# Backtracking está consumiendo todas las iteraciones. k = 740
# Backtracking está consumiendo todas las iteraciones. k = 742
# Backtracking está consumiendo todas las iteraciones. k = 745
# Backtracking está consumiendo todas las iteraciones. k = 747
# Backtracking está consumiendo todas las iteraciones. k = 843
# Backtracking está consumiendo todas las iteraciones. k = 847
# Backtracking está consumiendo todas las iteraciones. k = 851
# Backtracking está consumiendo todas las iteraciones. k = 855
# Backtracking está consumiendo todas las iteraciones. k = 858
# Backtracking está consumiendo todas las iteraciones. k = 860
# Backtracking está consumiendo todas las iteraciones. k = 863
# Backtracking está consumiendo todas las iteraciones. k = 865
# Backtracking está consumiendo todas las iteraciones. k = 868
# Backtracking está consumiendo todas las iteraciones. k = 870
# Backtracking está consumiendo todas las iteraciones. k = 873
# Backtracking está consumiendo todas las iteraciones. k = 875
# Backtracking está consumiendo todas las iteraciones. k = 878
# Backtracking está consumiendo todas las iteraciones. k = 880
# Backtracking está consumiendo todas las iteraciones. k = 883
# Backtracking está consumiendo todas las iteraciones. k = 885
# Backtracking está consumiendo todas las iteraciones. k = 888
# Backtracking está consumiendo todas las iteraciones. k = 890
# Backtracking está consumiendo todas las iteraciones. k = 893
# Backtracking está consumiendo todas las iteraciones. k = 895
# Backtracking está consumiendo todas las iteraciones. k = 898
# Backtracking está consumiendo todas las iteraciones. k = 900
# Backtracking está consumiendo todas las iteraciones. k = 903
# Backtracking está consumiendo todas las iteraciones. k = 905
# Backtracking está consumiendo todas las iteraciones. k = 908
# Backtracking está consumiendo todas las iteraciones. k = 910
# Backtracking está consumiendo todas las iteraciones. k = 913
# Backtracking está consumiendo todas las iteraciones. k = 915
# Backtracking está consumiendo todas las iteraciones. k = 918
# Backtracking está consumiendo todas las iteraciones. k = 920
# Backtracking está consumiendo todas las iteraciones. k = 923
# Backtracking está consumiendo todas las iteraciones. k = 925
# Backtracking está consumiendo todas las iteraciones. k = 928
# Backtracking está consumiendo todas las iteraciones. k = 930
# Backtracking está consumiendo todas las iteraciones. k = 933
# Backtracking está consumiendo todas las iteraciones. k = 935
# Backtracking está consumiendo todas las iteraciones. k = 938
# Backtracking está consumiendo todas las iteraciones. k = 940
# Backtracking está consumiendo todas las iteraciones. k = 943
# Backtracking está consumiendo todas las iteraciones. k = 945
# Backtracking está consumiendo todas las iteraciones. k = 948
# Backtracking está consumiendo todas las iteraciones. k = 950
# Backtracking está consumiendo todas las iteraciones. k = 953
# Backtracking está consumiendo todas las iteraciones. k = 955
# Backtracking está consumiendo todas las iteraciones. k = 958
# Backtracking está consumiendo todas las iteraciones. k = 960
# Backtracking está consumiendo todas las iteraciones. k = 1059
# Backtracking está consumiendo todas las iteraciones. k = 1063
# Backtracking está consumiendo todas las iteraciones. k = 1067
# Backtracking está consumiendo todas las iteraciones. k = 1070
# Backtracking está consumiendo todas las iteraciones. k = 1072
# Backtracking está consumiendo todas las iteraciones. k = 1075
# Backtracking está consumiendo todas las iteraciones. k = 1077
# Backtracking está consumiendo todas las iteraciones. k = 1080
# Backtracking está consumiendo todas las iteraciones. k = 1082
# Backtracking está consumiendo todas las iteraciones. k = 1085
# Backtracking está consumiendo todas las iteraciones. k = 1087
# Backtracking está consumiendo todas las iteraciones. k = 1090
# Backtracking está consumiendo todas las iteraciones. k = 1092
# Backtracking está consumiendo todas las iteraciones. k = 1095
# Backtracking está consumiendo todas las iteraciones. k = 1097
# Backtracking está consumiendo todas las iteraciones. k = 1100
# Backtracking está consumiendo todas las iteraciones. k = 1102
# Backtracking está consumiendo todas las iteraciones. k = 1105
# Backtracking está consumiendo todas las iteraciones. k = 1107
# Backtracking está consumiendo todas las iteraciones. k = 1110
# Backtracking está consumiendo todas las iteraciones. k = 1112
# Backtracking está consumiendo todas las iteraciones. k = 1115
# Backtracking está consumiendo todas las iteraciones. k = 1117
# Backtracking está consumiendo todas las iteraciones. k = 1120
# Backtracking está consumiendo todas las iteraciones. k = 1122
# Backtracking está consumiendo todas las iteraciones. k = 1125
# Backtracking está consumiendo todas las iteraciones. k = 1127
# Backtracking está consumiendo todas las iteraciones. k = 1130
# Backtracking está consumiendo todas las iteraciones. k = 1132
# Backtracking está consumiendo todas las iteraciones. k = 1135
# Backtracking está consumiendo todas las iteraciones. k = 1137
# Backtracking está consumiendo todas las iteraciones. k = 1140
# Backtracking está consumiendo todas las iteraciones. k = 1142
# Backtracking está consumiendo todas las iteraciones. k = 1145
# Backtracking está consumiendo todas las iteraciones. k = 1147
# Backtracking está consumiendo todas las iteraciones. k = 1150
# Backtracking está consumiendo todas las iteraciones. k = 1152
# Backtracking está consumiendo todas las iteraciones. k = 1155
# Backtracking está consumiendo todas las iteraciones. k = 1157
# Backtracking está consumiendo todas las iteraciones. k = 1160
# Backtracking está consumiendo todas las iteraciones. k = 1162
# Backtracking está consumiendo todas las iteraciones. k = 1165
# Backtracking está consumiendo todas las iteraciones. k = 1167
# Backtracking está consumiendo todas las iteraciones. k = 1170
# Backtracking está consumiendo todas las iteraciones. k = 1172
# Backtracking está consumiendo todas las iteraciones. k = 1175
# Backtracking está consumiendo todas las iteraciones. k = 1177
# Backtracking está consumiendo todas las iteraciones. k = 1273
# Backtracking está consumiendo todas las iteraciones. k = 1277
# Backtracking está consumiendo todas las iteraciones. k = 1281
# Backtracking está consumiendo todas las iteraciones. k = 1285
# Backtracking está consumiendo todas las iteraciones. k = 1288
# Backtracking está consumiendo todas las iteraciones. k = 1290
# Backtracking está consumiendo todas las iteraciones. k = 1293
# Backtracking está consumiendo todas las iteraciones. k = 1295
# Backtracking está consumiendo todas las iteraciones. k = 1298
# Backtracking está consumiendo todas las iteraciones. k = 1300
# Backtracking está consumiendo todas las iteraciones. k = 1303
# Backtracking está consumiendo todas las iteraciones. k = 1305
# Backtracking está consumiendo todas las iteraciones. k = 1308
# Backtracking está consumiendo todas las iteraciones. k = 1310
# Backtracking está consumiendo todas las iteraciones. k = 1313
# Backtracking está consumiendo todas las iteraciones. k = 1315
# Backtracking está consumiendo todas las iteraciones. k = 1318
# Backtracking está consumiendo todas las iteraciones. k = 1320
# Backtracking está consumiendo todas las iteraciones. k = 1323
# Backtracking está consumiendo todas las iteraciones. k = 1325
# Backtracking está consumiendo todas las iteraciones. k = 1328
# Backtracking está consumiendo todas las iteraciones. k = 1330
# Backtracking está consumiendo todas las iteraciones. k = 1333
# Backtracking está consumiendo todas las iteraciones. k = 1335
# Backtracking está consumiendo todas las iteraciones. k = 1338
# Backtracking está consumiendo todas las iteraciones. k = 1340
# Backtracking está consumiendo todas las iteraciones. k = 1343
# Backtracking está consumiendo todas las iteraciones. k = 1345
# Backtracking está consumiendo todas las iteraciones. k = 1348
# Backtracking está consumiendo todas las iteraciones. k = 1350
# Backtracking está consumiendo todas las iteraciones. k = 1353
# Backtracking está consumiendo todas las iteraciones. k = 1355
# Backtracking está consumiendo todas las iteraciones. k = 1358
# Backtracking está consumiendo todas las iteraciones. k = 1360
# Backtracking está consumiendo todas las iteraciones. k = 1363
# Backtracking está consumiendo todas las iteraciones. k = 1365
# Backtracking está consumiendo todas las iteraciones. k = 1368
# Backtracking está consumiendo todas las iteraciones. k = 1370
# Backtracking está consumiendo todas las iteraciones. k = 1373
# Backtracking está consumiendo todas las iteraciones. k = 1375
# Backtracking está consumiendo todas las iteraciones. k = 1378
# Backtracking está consumiendo todas las iteraciones. k = 1380
# Backtracking está consumiendo todas las iteraciones. k = 1383
# Backtracking está consumiendo todas las iteraciones. k = 1385
# Backtracking está consumiendo todas las iteraciones. k = 1388
# Backtracking está consumiendo todas las iteraciones. k = 1390
# Backtracking está consumiendo todas las iteraciones. k = 1393
# Backtracking está consumiendo todas las iteraciones. k = 1395
# Backtracking está consumiendo todas las iteraciones. k = 1491
# Backtracking está consumiendo todas las iteraciones. k = 1495
# Backtracking está consumiendo todas las iteraciones. k = 1499
# Backtracking está consumiendo todas las iteraciones. k = 1503
# Backtracking está consumiendo todas las iteraciones. k = 1506
# Backtracking está consumiendo todas las iteraciones. k = 1508
# Backtracking está consumiendo todas las iteraciones. k = 1511
# Backtracking está consumiendo todas las iteraciones. k = 1513
# Backtracking está consumiendo todas las iteraciones. k = 1516
# Backtracking está consumiendo todas las iteraciones. k = 1518
# Backtracking está consumiendo todas las iteraciones. k = 1521
# Backtracking está consumiendo todas las iteraciones. k = 1523
# Backtracking está consumiendo todas las iteraciones. k = 1526
# Backtracking está consumiendo todas las iteraciones. k = 1528
# Backtracking está consumiendo todas las iteraciones. k = 1531
# Backtracking está consumiendo todas las iteraciones. k = 1533
# Backtracking está consumiendo todas las iteraciones. k = 1536
# Backtracking está consumiendo todas las iteraciones. k = 1538
# Backtracking está consumiendo todas las iteraciones. k = 1541
# Backtracking está consumiendo todas las iteraciones. k = 1543
# Backtracking está consumiendo todas las iteraciones. k = 1546
# Backtracking está consumiendo todas las iteraciones. k = 1548
# Backtracking está consumiendo todas las iteraciones. k = 1551
# Backtracking está consumiendo todas las iteraciones. k = 1553
# Backtracking está consumiendo todas las iteraciones. k = 1556
# Backtracking está consumiendo todas las iteraciones. k = 1558
# Backtracking está consumiendo todas las iteraciones. k = 1561
# Backtracking está consumiendo todas las iteraciones. k = 1563
# Backtracking está consumiendo todas las iteraciones. k = 1566
# Backtracking está consumiendo todas las iteraciones. k = 1568
# Dimension: 10
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 1571
# La solución alcanzada es:  [ 1.36889566 -1.16586292  1.60838905 -0.61279115] ... [-0.61279115  1.60838905 -1.16586292  1.36889566]
# f(xk)=-1.7934207913526616
# f(x0)=0.0
# La norma del gradiente final es: 1.8950483039484323e-05
# Número de reinicios:  1230

# %%
# con la segunda dimension
A5, b5 = gen_matrix2(n[1])
sol5 = nonlinear_grad_conj(lambda x: quadratic(x, A5, b5),
                           lambda x: Grad_quadratic(x, A5, b5),
                           np.zeros(n[1]), a0, maxIter, np.sqrt(n[1])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol5, lambda x: quadratic(x, A5, b5), np.zeros(n[1]))
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 20
# Backtracking está consumiendo todas las iteraciones. k = 32
# Backtracking está consumiendo todas las iteraciones. k = 47
# Backtracking está consumiendo todas las iteraciones. k = 53
# Backtracking está consumiendo todas las iteraciones. k = 59
# Backtracking está consumiendo todas las iteraciones. k = 74
# Backtracking está consumiendo todas las iteraciones. k = 80
# Backtracking está consumiendo todas las iteraciones. k = 90
# Backtracking está consumiendo todas las iteraciones. k = 96
# Backtracking está consumiendo todas las iteraciones. k = 106
# Backtracking está consumiendo todas las iteraciones. k = 116
# Backtracking está consumiendo todas las iteraciones. k = 131
# Backtracking está consumiendo todas las iteraciones. k = 137
# Backtracking está consumiendo todas las iteraciones. k = 139
# Backtracking está consumiendo todas las iteraciones. k = 148
# Backtracking está consumiendo todas las iteraciones. k = 157
# Backtracking está consumiendo todas las iteraciones. k = 167
# Backtracking está consumiendo todas las iteraciones. k = 173
# Backtracking está consumiendo todas las iteraciones. k = 183
# Backtracking está consumiendo todas las iteraciones. k = 189
# Backtracking está consumiendo todas las iteraciones. k = 199
# Backtracking está consumiendo todas las iteraciones. k = 209
# Backtracking está consumiendo todas las iteraciones. k = 219
# Backtracking está consumiendo todas las iteraciones. k = 228
# Backtracking está consumiendo todas las iteraciones. k = 238
# Backtracking está consumiendo todas las iteraciones. k = 244
# Backtracking está consumiendo todas las iteraciones. k = 254
# Backtracking está consumiendo todas las iteraciones. k = 256
# Backtracking está consumiendo todas las iteraciones. k = 260
# Backtracking está consumiendo todas las iteraciones. k = 266
# Backtracking está consumiendo todas las iteraciones. k = 276
# Backtracking está consumiendo todas las iteraciones. k = 285
# Backtracking está consumiendo todas las iteraciones. k = 295
# Backtracking está consumiendo todas las iteraciones. k = 305
# Backtracking está consumiendo todas las iteraciones. k = 311
# Backtracking está consumiendo todas las iteraciones. k = 313
# Backtracking está consumiendo todas las iteraciones. k = 322
# Backtracking está consumiendo todas las iteraciones. k = 332
# Backtracking está consumiendo todas las iteraciones. k = 338
# Backtracking está consumiendo todas las iteraciones. k = 340
# Backtracking está consumiendo todas las iteraciones. k = 349
# Backtracking está consumiendo todas las iteraciones. k = 359
# Backtracking está consumiendo todas las iteraciones. k = 365
# Backtracking está consumiendo todas las iteraciones. k = 375
# Backtracking está consumiendo todas las iteraciones. k = 377
# Backtracking está consumiendo todas las iteraciones. k = 381
# Backtracking está consumiendo todas las iteraciones. k = 387
# Backtracking está consumiendo todas las iteraciones. k = 397
# Backtracking está consumiendo todas las iteraciones. k = 407
# Backtracking está consumiendo todas las iteraciones. k = 417
# Backtracking está consumiendo todas las iteraciones. k = 427
# Backtracking está consumiendo todas las iteraciones. k = 433
# Backtracking está consumiendo todas las iteraciones. k = 435
# Backtracking está consumiendo todas las iteraciones. k = 444
# Backtracking está consumiendo todas las iteraciones. k = 454
# Backtracking está consumiendo todas las iteraciones. k = 460
# Backtracking está consumiendo todas las iteraciones. k = 462
# Backtracking está consumiendo todas las iteraciones. k = 471
# Backtracking está consumiendo todas las iteraciones. k = 481
# Backtracking está consumiendo todas las iteraciones. k = 490
# Backtracking está consumiendo todas las iteraciones. k = 500
# Backtracking está consumiendo todas las iteraciones. k = 510
# Backtracking está consumiendo todas las iteraciones. k = 520
# Backtracking está consumiendo todas las iteraciones. k = 530
# Backtracking está consumiendo todas las iteraciones. k = 540
# Backtracking está consumiendo todas las iteraciones. k = 550
# Backtracking está consumiendo todas las iteraciones. k = 560
# Backtracking está consumiendo todas las iteraciones. k = 570
# Backtracking está consumiendo todas las iteraciones. k = 580
# Backtracking está consumiendo todas las iteraciones. k = 586
# Backtracking está consumiendo todas las iteraciones. k = 588
# Backtracking está consumiendo todas las iteraciones. k = 592
# Backtracking está consumiendo todas las iteraciones. k = 598
# Backtracking está consumiendo todas las iteraciones. k = 608
# Backtracking está consumiendo todas las iteraciones. k = 618
# Backtracking está consumiendo todas las iteraciones. k = 628
# Backtracking está consumiendo todas las iteraciones. k = 638
# Backtracking está consumiendo todas las iteraciones. k = 648
# Backtracking está consumiendo todas las iteraciones. k = 650
# Backtracking está consumiendo todas las iteraciones. k = 654
# Backtracking está consumiendo todas las iteraciones. k = 660
# Backtracking está consumiendo todas las iteraciones. k = 670
# Backtracking está consumiendo todas las iteraciones. k = 680
# Backtracking está consumiendo todas las iteraciones. k = 689
# Backtracking está consumiendo todas las iteraciones. k = 699
# Backtracking está consumiendo todas las iteraciones. k = 713
# Backtracking está consumiendo todas las iteraciones. k = 719
# Backtracking está consumiendo todas las iteraciones. k = 733
# Backtracking está consumiendo todas las iteraciones. k = 739
# Backtracking está consumiendo todas las iteraciones. k = 749
# Backtracking está consumiendo todas las iteraciones. k = 751
# Backtracking está consumiendo todas las iteraciones. k = 755
# Backtracking está consumiendo todas las iteraciones. k = 761
# Backtracking está consumiendo todas las iteraciones. k = 771
# Backtracking está consumiendo todas las iteraciones. k = 781
# Backtracking está consumiendo todas las iteraciones. k = 791
# Backtracking está consumiendo todas las iteraciones. k = 797
# Backtracking está consumiendo todas las iteraciones. k = 811
# Backtracking está consumiendo todas las iteraciones. k = 817
# Backtracking está consumiendo todas las iteraciones. k = 827
# Backtracking está consumiendo todas las iteraciones. k = 829
# Backtracking está consumiendo todas las iteraciones. k = 833
# Backtracking está consumiendo todas las iteraciones. k = 839
# Backtracking está consumiendo todas las iteraciones. k = 849
# Backtracking está consumiendo todas las iteraciones. k = 859
# Backtracking está consumiendo todas las iteraciones. k = 868
# Backtracking está consumiendo todas las iteraciones. k = 878
# Backtracking está consumiendo todas las iteraciones. k = 880
# Backtracking está consumiendo todas las iteraciones. k = 889
# Backtracking está consumiendo todas las iteraciones. k = 899
# Backtracking está consumiendo todas las iteraciones. k = 909
# Backtracking está consumiendo todas las iteraciones. k = 915
# Backtracking está consumiendo todas las iteraciones. k = 917
# Backtracking está consumiendo todas las iteraciones. k = 921
# Backtracking está consumiendo todas las iteraciones. k = 927
# Backtracking está consumiendo todas las iteraciones. k = 937
# Backtracking está consumiendo todas las iteraciones. k = 947
# Backtracking está consumiendo todas las iteraciones. k = 949
# Backtracking está consumiendo todas las iteraciones. k = 953
# Backtracking está consumiendo todas las iteraciones. k = 959
# Backtracking está consumiendo todas las iteraciones. k = 969
# Backtracking está consumiendo todas las iteraciones. k = 979
# Backtracking está consumiendo todas las iteraciones. k = 989
# Backtracking está consumiendo todas las iteraciones. k = 991
# Backtracking está consumiendo todas las iteraciones. k = 1000
# Backtracking está consumiendo todas las iteraciones. k = 1010
# Backtracking está consumiendo todas las iteraciones. k = 1020
# Backtracking está consumiendo todas las iteraciones. k = 1026
# Backtracking está consumiendo todas las iteraciones. k = 1028
# Backtracking está consumiendo todas las iteraciones. k = 1032
# Backtracking está consumiendo todas las iteraciones. k = 1038
# Backtracking está consumiendo todas las iteraciones. k = 1048
# Backtracking está consumiendo todas las iteraciones. k = 1058
# Backtracking está consumiendo todas las iteraciones. k = 1060
# Backtracking está consumiendo todas las iteraciones. k = 1069
# Backtracking está consumiendo todas las iteraciones. k = 1079
# Backtracking está consumiendo todas las iteraciones. k = 1089
# Backtracking está consumiendo todas las iteraciones. k = 1095
# Backtracking está consumiendo todas las iteraciones. k = 1097
# Backtracking está consumiendo todas las iteraciones. k = 1101
# Backtracking está consumiendo todas las iteraciones. k = 1107
# Backtracking está consumiendo todas las iteraciones. k = 1117
# Backtracking está consumiendo todas las iteraciones. k = 1127
# Backtracking está consumiendo todas las iteraciones. k = 1137
# Backtracking está consumiendo todas las iteraciones. k = 1147
# Backtracking está consumiendo todas las iteraciones. k = 1157
# Backtracking está consumiendo todas las iteraciones. k = 1167
# Backtracking está consumiendo todas las iteraciones. k = 1169
# Backtracking está consumiendo todas las iteraciones. k = 1173
# Backtracking está consumiendo todas las iteraciones. k = 1179
# Backtracking está consumiendo todas las iteraciones. k = 1189
# Backtracking está consumiendo todas las iteraciones. k = 1203
# Backtracking está consumiendo todas las iteraciones. k = 1209
# Backtracking está consumiendo todas las iteraciones. k = 1219
# Backtracking está consumiendo todas las iteraciones. k = 1221
# Backtracking está consumiendo todas las iteraciones. k = 1225
# Backtracking está consumiendo todas las iteraciones. k = 1231
# Backtracking está consumiendo todas las iteraciones. k = 1241
# Backtracking está consumiendo todas las iteraciones. k = 1251
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1271
# Backtracking está consumiendo todas las iteraciones. k = 1281
# Backtracking está consumiendo todas las iteraciones. k = 1291
# Backtracking está consumiendo todas las iteraciones. k = 1297
# Backtracking está consumiendo todas las iteraciones. k = 1311
# Backtracking está consumiendo todas las iteraciones. k = 1317
# Backtracking está consumiendo todas las iteraciones. k = 1331
# Backtracking está consumiendo todas las iteraciones. k = 1337
# Backtracking está consumiendo todas las iteraciones. k = 1347
# Backtracking está consumiendo todas las iteraciones. k = 1349
# Backtracking está consumiendo todas las iteraciones. k = 1353
# Backtracking está consumiendo todas las iteraciones. k = 1359
# Backtracking está consumiendo todas las iteraciones. k = 1369
# Backtracking está consumiendo todas las iteraciones. k = 1379
# Backtracking está consumiendo todas las iteraciones. k = 1381
# Backtracking está consumiendo todas las iteraciones. k = 1385
# Backtracking está consumiendo todas las iteraciones. k = 1391
# Backtracking está consumiendo todas las iteraciones. k = 1401
# Backtracking está consumiendo todas las iteraciones. k = 1411
# Backtracking está consumiendo todas las iteraciones. k = 1413
# Backtracking está consumiendo todas las iteraciones. k = 1417
# Backtracking está consumiendo todas las iteraciones. k = 1423
# Backtracking está consumiendo todas las iteraciones. k = 1433
# Backtracking está consumiendo todas las iteraciones. k = 1447
# Backtracking está consumiendo todas las iteraciones. k = 1453
# Backtracking está consumiendo todas las iteraciones. k = 1455
# Backtracking está consumiendo todas las iteraciones. k = 1464
# Backtracking está consumiendo todas las iteraciones. k = 1474
# Backtracking está consumiendo todas las iteraciones. k = 1483
# Backtracking está consumiendo todas las iteraciones. k = 1493
# Backtracking está consumiendo todas las iteraciones. k = 1507
# Backtracking está consumiendo todas las iteraciones. k = 1513
# Backtracking está consumiendo todas las iteraciones. k = 1515
# Backtracking está consumiendo todas las iteraciones. k = 1524
# Backtracking está consumiendo todas las iteraciones. k = 1534
# Backtracking está consumiendo todas las iteraciones. k = 1544
# Backtracking está consumiendo todas las iteraciones. k = 1550
# Backtracking está consumiendo todas las iteraciones. k = 1552
# Backtracking está consumiendo todas las iteraciones. k = 1561
# Backtracking está consumiendo todas las iteraciones. k = 1571
# Backtracking está consumiendo todas las iteraciones. k = 1581
# Backtracking está consumiendo todas las iteraciones. k = 1591
# Backtracking está consumiendo todas las iteraciones. k = 1597
# Backtracking está consumiendo todas las iteraciones. k = 1599
# Backtracking está consumiendo todas las iteraciones. k = 1608
# Backtracking está consumiendo todas las iteraciones. k = 1618
# Backtracking está consumiendo todas las iteraciones. k = 1628
# Backtracking está consumiendo todas las iteraciones. k = 1634
# Backtracking está consumiendo todas las iteraciones. k = 1636
# Backtracking está consumiendo todas las iteraciones. k = 1645
# Backtracking está consumiendo todas las iteraciones. k = 1655
# Backtracking está consumiendo todas las iteraciones. k = 1665
# Backtracking está consumiendo todas las iteraciones. k = 1674
# Backtracking está consumiendo todas las iteraciones. k = 1684
# Backtracking está consumiendo todas las iteraciones. k = 1686
# Backtracking está consumiendo todas las iteraciones. k = 1690
# Backtracking está consumiendo todas las iteraciones. k = 1696
# Backtracking está consumiendo todas las iteraciones. k = 1706
# Backtracking está consumiendo todas las iteraciones. k = 1720
# Backtracking está consumiendo todas las iteraciones. k = 1726
# Backtracking está consumiendo todas las iteraciones. k = 1728
# Backtracking está consumiendo todas las iteraciones. k = 1737
# Backtracking está consumiendo todas las iteraciones. k = 1747
# Backtracking está consumiendo todas las iteraciones. k = 1756
# Backtracking está consumiendo todas las iteraciones. k = 1766
# Backtracking está consumiendo todas las iteraciones. k = 1768
# Backtracking está consumiendo todas las iteraciones. k = 1777
# Backtracking está consumiendo todas las iteraciones. k = 1787
# Backtracking está consumiendo todas las iteraciones. k = 1797
# Backtracking está consumiendo todas las iteraciones. k = 1803
# Backtracking está consumiendo todas las iteraciones. k = 1805
# Backtracking está consumiendo todas las iteraciones. k = 1809
# Backtracking está consumiendo todas las iteraciones. k = 1815
# Backtracking está consumiendo todas las iteraciones. k = 1825
# Backtracking está consumiendo todas las iteraciones. k = 1835
# Backtracking está consumiendo todas las iteraciones. k = 1849
# Backtracking está consumiendo todas las iteraciones. k = 1855
# Backtracking está consumiendo todas las iteraciones. k = 1869
# Backtracking está consumiendo todas las iteraciones. k = 1875
# Backtracking está consumiendo todas las iteraciones. k = 1889
# Backtracking está consumiendo todas las iteraciones. k = 1895
# Backtracking está consumiendo todas las iteraciones. k = 1897
# Backtracking está consumiendo todas las iteraciones. k = 1906
# Backtracking está consumiendo todas las iteraciones. k = 1916
# Backtracking está consumiendo todas las iteraciones. k = 1926
# Backtracking está consumiendo todas las iteraciones. k = 1932
# Backtracking está consumiendo todas las iteraciones. k = 1934
# Backtracking está consumiendo todas las iteraciones. k = 1943
# Backtracking está consumiendo todas las iteraciones. k = 1953
# Backtracking está consumiendo todas las iteraciones. k = 1963
# Backtracking está consumiendo todas las iteraciones. k = 1973
# Backtracking está consumiendo todas las iteraciones. k = 1979
# Backtracking está consumiendo todas las iteraciones. k = 1981
# Backtracking está consumiendo todas las iteraciones. k = 1990
# Backtracking está consumiendo todas las iteraciones. k = 2000
# Backtracking está consumiendo todas las iteraciones. k = 2010
# Backtracking está consumiendo todas las iteraciones. k = 2020
# Backtracking está consumiendo todas las iteraciones. k = 2026
# Backtracking está consumiendo todas las iteraciones. k = 2040
# Backtracking está consumiendo todas las iteraciones. k = 2046
# Backtracking está consumiendo todas las iteraciones. k = 2060
# Backtracking está consumiendo todas las iteraciones. k = 2066
# Backtracking está consumiendo todas las iteraciones. k = 2068
# Backtracking está consumiendo todas las iteraciones. k = 2077
# Backtracking está consumiendo todas las iteraciones. k = 2087
# Backtracking está consumiendo todas las iteraciones. k = 2097
# Backtracking está consumiendo todas las iteraciones. k = 2103
# Backtracking está consumiendo todas las iteraciones. k = 2105
# Backtracking está consumiendo todas las iteraciones. k = 2114
# Backtracking está consumiendo todas las iteraciones. k = 2124
# Backtracking está consumiendo todas las iteraciones. k = 2134
# Backtracking está consumiendo todas las iteraciones. k = 2143
# Backtracking está consumiendo todas las iteraciones. k = 2153
# Backtracking está consumiendo todas las iteraciones. k = 2155
# Backtracking está consumiendo todas las iteraciones. k = 2164
# Backtracking está consumiendo todas las iteraciones. k = 2174
# Backtracking está consumiendo todas las iteraciones. k = 2184
# Backtracking está consumiendo todas las iteraciones. k = 2194
# Backtracking está consumiendo todas las iteraciones. k = 2200
# Backtracking está consumiendo todas las iteraciones. k = 2202
# Backtracking está consumiendo todas las iteraciones. k = 2206
# Backtracking está consumiendo todas las iteraciones. k = 2212
# Backtracking está consumiendo todas las iteraciones. k = 2222
# Backtracking está consumiendo todas las iteraciones. k = 2232
# Backtracking está consumiendo todas las iteraciones. k = 2234
# Backtracking está consumiendo todas las iteraciones. k = 2243
# Backtracking está consumiendo todas las iteraciones. k = 2253
# Backtracking está consumiendo todas las iteraciones. k = 2263
# Backtracking está consumiendo todas las iteraciones. k = 2273
# Backtracking está consumiendo todas las iteraciones. k = 2279
# Backtracking está consumiendo todas las iteraciones. k = 2281
# Backtracking está consumiendo todas las iteraciones. k = 2285
# Backtracking está consumiendo todas las iteraciones. k = 2291
# Backtracking está consumiendo todas las iteraciones. k = 2301
# Backtracking está consumiendo todas las iteraciones. k = 2311
# Backtracking está consumiendo todas las iteraciones. k = 2321
# Backtracking está consumiendo todas las iteraciones. k = 2331
# Backtracking está consumiendo todas las iteraciones. k = 2333
# Backtracking está consumiendo todas las iteraciones. k = 2337
# Backtracking está consumiendo todas las iteraciones. k = 2343
# Backtracking está consumiendo todas las iteraciones. k = 2353
# Backtracking está consumiendo todas las iteraciones. k = 2363
# Backtracking está consumiendo todas las iteraciones. k = 2377
# Backtracking está consumiendo todas las iteraciones. k = 2383
# Backtracking está consumiendo todas las iteraciones. k = 2393
# Backtracking está consumiendo todas las iteraciones. k = 2395
# Backtracking está consumiendo todas las iteraciones. k = 2399
# Backtracking está consumiendo todas las iteraciones. k = 2405
# Backtracking está consumiendo todas las iteraciones. k = 2415
# Backtracking está consumiendo todas las iteraciones. k = 2429
# Backtracking está consumiendo todas las iteraciones. k = 2435
# Backtracking está consumiendo todas las iteraciones. k = 2437
# Backtracking está consumiendo todas las iteraciones. k = 2446
# Backtracking está consumiendo todas las iteraciones. k = 2456
# Backtracking está consumiendo todas las iteraciones. k = 2465
# Backtracking está consumiendo todas las iteraciones. k = 2475
# Backtracking está consumiendo todas las iteraciones. k = 2477
# Backtracking está consumiendo todas las iteraciones. k = 2481
# Backtracking está consumiendo todas las iteraciones. k = 2487
# Backtracking está consumiendo todas las iteraciones. k = 2497
# Backtracking está consumiendo todas las iteraciones. k = 2499
# Backtracking está consumiendo todas las iteraciones. k = 2503
# Backtracking está consumiendo todas las iteraciones. k = 2509
# Backtracking está consumiendo todas las iteraciones. k = 2519
# Backtracking está consumiendo todas las iteraciones. k = 2529
# Backtracking está consumiendo todas las iteraciones. k = 2539
# Backtracking está consumiendo todas las iteraciones. k = 2541
# Backtracking está consumiendo todas las iteraciones. k = 2550
# Backtracking está consumiendo todas las iteraciones. k = 2560
# Backtracking está consumiendo todas las iteraciones. k = 2570
# Backtracking está consumiendo todas las iteraciones. k = 2580
# Backtracking está consumiendo todas las iteraciones. k = 2589
# Backtracking está consumiendo todas las iteraciones. k = 2599
# Backtracking está consumiendo todas las iteraciones. k = 2601
# Backtracking está consumiendo todas las iteraciones. k = 2605
# Backtracking está consumiendo todas las iteraciones. k = 2611
# Backtracking está consumiendo todas las iteraciones. k = 2621
# Backtracking está consumiendo todas las iteraciones. k = 2623
# Backtracking está consumiendo todas las iteraciones. k = 2632
# Backtracking está consumiendo todas las iteraciones. k = 2642
# Backtracking está consumiendo todas las iteraciones. k = 2652
# Backtracking está consumiendo todas las iteraciones. k = 2662
# Backtracking está consumiendo todas las iteraciones. k = 2668
# Backtracking está consumiendo todas las iteraciones. k = 2670
# Backtracking está consumiendo todas las iteraciones. k = 2674
# Backtracking está consumiendo todas las iteraciones. k = 2680
# Backtracking está consumiendo todas las iteraciones. k = 2690
# Backtracking está consumiendo todas las iteraciones. k = 2700
# Backtracking está consumiendo todas las iteraciones. k = 2702
# Backtracking está consumiendo todas las iteraciones. k = 2711
# Backtracking está consumiendo todas las iteraciones. k = 2721
# Backtracking está consumiendo todas las iteraciones. k = 2731
# Backtracking está consumiendo todas las iteraciones. k = 2741
# Backtracking está consumiendo todas las iteraciones. k = 2747
# Backtracking está consumiendo todas las iteraciones. k = 2749
# Backtracking está consumiendo todas las iteraciones. k = 2753
# Backtracking está consumiendo todas las iteraciones. k = 2759
# Backtracking está consumiendo todas las iteraciones. k = 2769
# Backtracking está consumiendo todas las iteraciones. k = 2779
# Backtracking está consumiendo todas las iteraciones. k = 2781
# Backtracking está consumiendo todas las iteraciones. k = 2785
# Backtracking está consumiendo todas las iteraciones. k = 2791
# Backtracking está consumiendo todas las iteraciones. k = 2801
# Backtracking está consumiendo todas las iteraciones. k = 2803
# Backtracking está consumiendo todas las iteraciones. k = 2807
# Backtracking está consumiendo todas las iteraciones. k = 2813
# Backtracking está consumiendo todas las iteraciones. k = 2823
# Backtracking está consumiendo todas las iteraciones. k = 2837
# Backtracking está consumiendo todas las iteraciones. k = 2843
# Backtracking está consumiendo todas las iteraciones. k = 2853
# Backtracking está consumiendo todas las iteraciones. k = 2855
# Backtracking está consumiendo todas las iteraciones. k = 2859
# Backtracking está consumiendo todas las iteraciones. k = 2865
# Backtracking está consumiendo todas las iteraciones. k = 2875
# Backtracking está consumiendo todas las iteraciones. k = 2889
# Backtracking está consumiendo todas las iteraciones. k = 2895
# Backtracking está consumiendo todas las iteraciones. k = 2897
# Backtracking está consumiendo todas las iteraciones. k = 2906
# Backtracking está consumiendo todas las iteraciones. k = 2916
# Backtracking está consumiendo todas las iteraciones. k = 2926
# Backtracking está consumiendo todas las iteraciones. k = 2935
# Backtracking está consumiendo todas las iteraciones. k = 2945
# Backtracking está consumiendo todas las iteraciones. k = 2955
# Backtracking está consumiendo todas las iteraciones. k = 2957
# Backtracking está consumiendo todas las iteraciones. k = 2966
# Backtracking está consumiendo todas las iteraciones. k = 2976
# Backtracking está consumiendo todas las iteraciones. k = 2986
# Backtracking está consumiendo todas las iteraciones. k = 2996
# Backtracking está consumiendo todas las iteraciones. k = 3006
# Backtracking está consumiendo todas las iteraciones. k = 3012
# Backtracking está consumiendo todas las iteraciones. k = 3014
# Backtracking está consumiendo todas las iteraciones. k = 3018
# Backtracking está consumiendo todas las iteraciones. k = 3024
# Backtracking está consumiendo todas las iteraciones. k = 3034
# Backtracking está consumiendo todas las iteraciones. k = 3036
# Backtracking está consumiendo todas las iteraciones. k = 3045
# Backtracking está consumiendo todas las iteraciones. k = 3055
# Backtracking está consumiendo todas las iteraciones. k = 3065
# Backtracking está consumiendo todas las iteraciones. k = 3074
# Backtracking está consumiendo todas las iteraciones. k = 3084
# Backtracking está consumiendo todas las iteraciones. k = 3086
# Backtracking está consumiendo todas las iteraciones. k = 3095
# Backtracking está consumiendo todas las iteraciones. k = 3105
# Backtracking está consumiendo todas las iteraciones. k = 3115
# Backtracking está consumiendo todas las iteraciones. k = 3125
# Backtracking está consumiendo todas las iteraciones. k = 3134
# Backtracking está consumiendo todas las iteraciones. k = 3144
# Backtracking está consumiendo todas las iteraciones. k = 3146
# Backtracking está consumiendo todas las iteraciones. k = 3150
# Backtracking está consumiendo todas las iteraciones. k = 3156
# Backtracking está consumiendo todas las iteraciones. k = 3166
# Backtracking está consumiendo todas las iteraciones. k = 3168
# Backtracking está consumiendo todas las iteraciones. k = 3177
# Backtracking está consumiendo todas las iteraciones. k = 3187
# Backtracking está consumiendo todas las iteraciones. k = 3197
# Backtracking está consumiendo todas las iteraciones. k = 3207
# Backtracking está consumiendo todas las iteraciones. k = 3213
# Backtracking está consumiendo todas las iteraciones. k = 3215
# Backtracking está consumiendo todas las iteraciones. k = 3219
# Backtracking está consumiendo todas las iteraciones. k = 3225
# Backtracking está consumiendo todas las iteraciones. k = 3235
# Backtracking está consumiendo todas las iteraciones. k = 3237
# Backtracking está consumiendo todas las iteraciones. k = 3246
# Backtracking está consumiendo todas las iteraciones. k = 3256
# Backtracking está consumiendo todas las iteraciones. k = 3266
# Backtracking está consumiendo todas las iteraciones. k = 3272
# Backtracking está consumiendo todas las iteraciones. k = 3274
# Backtracking está consumiendo todas las iteraciones. k = 3278
# Backtracking está consumiendo todas las iteraciones. k = 3284
# Backtracking está consumiendo todas las iteraciones. k = 3294
# Backtracking está consumiendo todas las iteraciones. k = 3304
# Backtracking está consumiendo todas las iteraciones. k = 3306
# Backtracking está consumiendo todas las iteraciones. k = 3310
# Backtracking está consumiendo todas las iteraciones. k = 3316
# Backtracking está consumiendo todas las iteraciones. k = 3326
# Backtracking está consumiendo todas las iteraciones. k = 3328
# Backtracking está consumiendo todas las iteraciones. k = 3332
# Backtracking está consumiendo todas las iteraciones. k = 3338
# Backtracking está consumiendo todas las iteraciones. k = 3348
# Backtracking está consumiendo todas las iteraciones. k = 3358
# Backtracking está consumiendo todas las iteraciones. k = 3372
# Backtracking está consumiendo todas las iteraciones. k = 3378
# Backtracking está consumiendo todas las iteraciones. k = 3380
# Backtracking está consumiendo todas las iteraciones. k = 3389
# Backtracking está consumiendo todas las iteraciones. k = 3399
# Backtracking está consumiendo todas las iteraciones. k = 3409
# Backtracking está consumiendo todas las iteraciones. k = 3418
# Backtracking está consumiendo todas las iteraciones. k = 3428
# Backtracking está consumiendo todas las iteraciones. k = 3430
# Backtracking está consumiendo todas las iteraciones. k = 3439
# Backtracking está consumiendo todas las iteraciones. k = 3449
# Backtracking está consumiendo todas las iteraciones. k = 3459
# Backtracking está consumiendo todas las iteraciones. k = 3465
# Backtracking está consumiendo todas las iteraciones. k = 3467
# Backtracking está consumiendo todas las iteraciones. k = 3471
# Backtracking está consumiendo todas las iteraciones. k = 3477
# Backtracking está consumiendo todas las iteraciones. k = 3487
# Backtracking está consumiendo todas las iteraciones. k = 3497
# Backtracking está consumiendo todas las iteraciones. k = 3507
# Backtracking está consumiendo todas las iteraciones. k = 3509
# Backtracking está consumiendo todas las iteraciones. k = 3513
# Backtracking está consumiendo todas las iteraciones. k = 3519
# Backtracking está consumiendo todas las iteraciones. k = 3529
# Backtracking está consumiendo todas las iteraciones. k = 3531
# Backtracking está consumiendo todas las iteraciones. k = 3535
# Backtracking está consumiendo todas las iteraciones. k = 3541
# Backtracking está consumiendo todas las iteraciones. k = 3551
# Backtracking está consumiendo todas las iteraciones. k = 3561
# Backtracking está consumiendo todas las iteraciones. k = 3563
# Backtracking está consumiendo todas las iteraciones. k = 3567
# Backtracking está consumiendo todas las iteraciones. k = 3573
# Backtracking está consumiendo todas las iteraciones. k = 3583
# Backtracking está consumiendo todas las iteraciones. k = 3585
# Backtracking está consumiendo todas las iteraciones. k = 3589
# Backtracking está consumiendo todas las iteraciones. k = 3595
# Backtracking está consumiendo todas las iteraciones. k = 3605
# Backtracking está consumiendo todas las iteraciones. k = 3615
# Backtracking está consumiendo todas las iteraciones. k = 3617
# Backtracking está consumiendo todas las iteraciones. k = 3626
# Backtracking está consumiendo todas las iteraciones. k = 3636
# Backtracking está consumiendo todas las iteraciones. k = 3646
# Backtracking está consumiendo todas las iteraciones. k = 3656
# Backtracking está consumiendo todas las iteraciones. k = 3666
# Backtracking está consumiendo todas las iteraciones. k = 3676
# Backtracking está consumiendo todas las iteraciones. k = 3686
# Backtracking está consumiendo todas las iteraciones. k = 3692
# Backtracking está consumiendo todas las iteraciones. k = 3694
# Backtracking está consumiendo todas las iteraciones. k = 3703
# Backtracking está consumiendo todas las iteraciones. k = 3713
# Backtracking está consumiendo todas las iteraciones. k = 3723
# Backtracking está consumiendo todas las iteraciones. k = 3729
# Backtracking está consumiendo todas las iteraciones. k = 3731
# Backtracking está consumiendo todas las iteraciones. k = 3735
# Backtracking está consumiendo todas las iteraciones. k = 3741
# Backtracking está consumiendo todas las iteraciones. k = 3751
# Backtracking está consumiendo todas las iteraciones. k = 3761
# Backtracking está consumiendo todas las iteraciones. k = 3763
# Backtracking está consumiendo todas las iteraciones. k = 3767
# Backtracking está consumiendo todas las iteraciones. k = 3773
# Backtracking está consumiendo todas las iteraciones. k = 3783
# Backtracking está consumiendo todas las iteraciones. k = 3785
# Backtracking está consumiendo todas las iteraciones. k = 3789
# Backtracking está consumiendo todas las iteraciones. k = 3795
# Backtracking está consumiendo todas las iteraciones. k = 3805
# Backtracking está consumiendo todas las iteraciones. k = 3819
# Backtracking está consumiendo todas las iteraciones. k = 3825
# Backtracking está consumiendo todas las iteraciones. k = 3827
# Backtracking está consumiendo todas las iteraciones. k = 3836
# Backtracking está consumiendo todas las iteraciones. k = 3846
# Backtracking está consumiendo todas las iteraciones. k = 3856
# Backtracking está consumiendo todas las iteraciones. k = 3866
# Backtracking está consumiendo todas las iteraciones. k = 3876
# Backtracking está consumiendo todas las iteraciones. k = 3882
# Backtracking está consumiendo todas las iteraciones. k = 3884
# Backtracking está consumiendo todas las iteraciones. k = 3893
# Backtracking está consumiendo todas las iteraciones. k = 3903
# Backtracking está consumiendo todas las iteraciones. k = 3913
# Backtracking está consumiendo todas las iteraciones. k = 3922
# Backtracking está consumiendo todas las iteraciones. k = 3932
# Backtracking está consumiendo todas las iteraciones. k = 3946
# Backtracking está consumiendo todas las iteraciones. k = 3952
# Backtracking está consumiendo todas las iteraciones. k = 3966
# Backtracking está consumiendo todas las iteraciones. k = 3972
# Backtracking está consumiendo todas las iteraciones. k = 3974
# Backtracking está consumiendo todas las iteraciones. k = 3983
# Backtracking está consumiendo todas las iteraciones. k = 3993
# Backtracking está consumiendo todas las iteraciones. k = 4003
# Backtracking está consumiendo todas las iteraciones. k = 4013
# Backtracking está consumiendo todas las iteraciones. k = 4019
# Backtracking está consumiendo todas las iteraciones. k = 4021
# Backtracking está consumiendo todas las iteraciones. k = 4025
# Backtracking está consumiendo todas las iteraciones. k = 4031
# Backtracking está consumiendo todas las iteraciones. k = 4041
# Backtracking está consumiendo todas las iteraciones. k = 4043
# Backtracking está consumiendo todas las iteraciones. k = 4047
# Backtracking está consumiendo todas las iteraciones. k = 4053
# Backtracking está consumiendo todas las iteraciones. k = 4063
# Backtracking está consumiendo todas las iteraciones. k = 4073
# Backtracking está consumiendo todas las iteraciones. k = 4083
# Backtracking está consumiendo todas las iteraciones. k = 4085
# Backtracking está consumiendo todas las iteraciones. k = 4094
# Backtracking está consumiendo todas las iteraciones. k = 4104
# Backtracking está consumiendo todas las iteraciones. k = 4114
# Backtracking está consumiendo todas las iteraciones. k = 4124
# Backtracking está consumiendo todas las iteraciones. k = 4134
# Backtracking está consumiendo todas las iteraciones. k = 4144
# Backtracking está consumiendo todas las iteraciones. k = 4154
# Backtracking está consumiendo todas las iteraciones. k = 4164
# Backtracking está consumiendo todas las iteraciones. k = 4174
# Backtracking está consumiendo todas las iteraciones. k = 4184
# Backtracking está consumiendo todas las iteraciones. k = 4190
# Backtracking está consumiendo todas las iteraciones. k = 4204
# Backtracking está consumiendo todas las iteraciones. k = 4210
# Backtracking está consumiendo todas las iteraciones. k = 4212
# Backtracking está consumiendo todas las iteraciones. k = 4221
# Backtracking está consumiendo todas las iteraciones. k = 4231
# Backtracking está consumiendo todas las iteraciones. k = 4241
# Backtracking está consumiendo todas las iteraciones. k = 4247
# Backtracking está consumiendo todas las iteraciones. k = 4249
# Backtracking está consumiendo todas las iteraciones. k = 4253
# Backtracking está consumiendo todas las iteraciones. k = 4259
# Backtracking está consumiendo todas las iteraciones. k = 4269
# Backtracking está consumiendo todas las iteraciones. k = 4271
# Backtracking está consumiendo todas las iteraciones. k = 4280
# Backtracking está consumiendo todas las iteraciones. k = 4290
# Backtracking está consumiendo todas las iteraciones. k = 4300
# Backtracking está consumiendo todas las iteraciones. k = 4309
# Backtracking está consumiendo todas las iteraciones. k = 4319
# Backtracking está consumiendo todas las iteraciones. k = 4329
# Backtracking está consumiendo todas las iteraciones. k = 4331
# Backtracking está consumiendo todas las iteraciones. k = 4335
# Backtracking está consumiendo todas las iteraciones. k = 4341
# Backtracking está consumiendo todas las iteraciones. k = 4351
# Backtracking está consumiendo todas las iteraciones. k = 4353
# Backtracking está consumiendo todas las iteraciones. k = 4357
# Backtracking está consumiendo todas las iteraciones. k = 4363
# Backtracking está consumiendo todas las iteraciones. k = 4373
# Backtracking está consumiendo todas las iteraciones. k = 4375
# Backtracking está consumiendo todas las iteraciones. k = 4384
# Backtracking está consumiendo todas las iteraciones. k = 4394
# Backtracking está consumiendo todas las iteraciones. k = 4404
# Backtracking está consumiendo todas las iteraciones. k = 4410
# Backtracking está consumiendo todas las iteraciones. k = 4412
# Backtracking está consumiendo todas las iteraciones. k = 4416
# Backtracking está consumiendo todas las iteraciones. k = 4422
# Backtracking está consumiendo todas las iteraciones. k = 4432
# Backtracking está consumiendo todas las iteraciones. k = 4442
# Backtracking está consumiendo todas las iteraciones. k = 4444
# Backtracking está consumiendo todas las iteraciones. k = 4448
# Backtracking está consumiendo todas las iteraciones. k = 4454
# Backtracking está consumiendo todas las iteraciones. k = 4464
# Backtracking está consumiendo todas las iteraciones. k = 4474
# Backtracking está consumiendo todas las iteraciones. k = 4484
# Backtracking está consumiendo todas las iteraciones. k = 4494
# Backtracking está consumiendo todas las iteraciones. k = 4496
# Backtracking está consumiendo todas las iteraciones. k = 4505
# Backtracking está consumiendo todas las iteraciones. k = 4515
# Backtracking está consumiendo todas las iteraciones. k = 4525
# Backtracking está consumiendo todas las iteraciones. k = 4531
# Backtracking está consumiendo todas las iteraciones. k = 4533
# Backtracking está consumiendo todas las iteraciones. k = 4542
# Backtracking está consumiendo todas las iteraciones. k = 4552
# Backtracking está consumiendo todas las iteraciones. k = 4562
# Backtracking está consumiendo todas las iteraciones. k = 4572
# Backtracking está consumiendo todas las iteraciones. k = 4578
# Backtracking está consumiendo todas las iteraciones. k = 4580
# Backtracking está consumiendo todas las iteraciones. k = 4589
# Backtracking está consumiendo todas las iteraciones. k = 4599
# Backtracking está consumiendo todas las iteraciones. k = 4609
# Backtracking está consumiendo todas las iteraciones. k = 4619
# Backtracking está consumiendo todas las iteraciones. k = 4629
# Backtracking está consumiendo todas las iteraciones. k = 4638
# Backtracking está consumiendo todas las iteraciones. k = 4648
# Backtracking está consumiendo todas las iteraciones. k = 4650
# Backtracking está consumiendo todas las iteraciones. k = 4659
# Backtracking está consumiendo todas las iteraciones. k = 4669
# Backtracking está consumiendo todas las iteraciones. k = 4679
# Backtracking está consumiendo todas las iteraciones. k = 4688
# Backtracking está consumiendo todas las iteraciones. k = 4698
# Backtracking está consumiendo todas las iteraciones. k = 4700
# Backtracking está consumiendo todas las iteraciones. k = 4704
# Backtracking está consumiendo todas las iteraciones. k = 4710
# Backtracking está consumiendo todas las iteraciones. k = 4720
# Backtracking está consumiendo todas las iteraciones. k = 4722
# Backtracking está consumiendo todas las iteraciones. k = 4726
# Backtracking está consumiendo todas las iteraciones. k = 4732
# Backtracking está consumiendo todas las iteraciones. k = 4742
# Backtracking está consumiendo todas las iteraciones. k = 4752
# Backtracking está consumiendo todas las iteraciones. k = 4754
# Backtracking está consumiendo todas las iteraciones. k = 4763
# Backtracking está consumiendo todas las iteraciones. k = 4773
# Backtracking está consumiendo todas las iteraciones. k = 4783
# Backtracking está consumiendo todas las iteraciones. k = 4793
# Backtracking está consumiendo todas las iteraciones. k = 4799
# Backtracking está consumiendo todas las iteraciones. k = 4801
# Backtracking está consumiendo todas las iteraciones. k = 4805
# Backtracking está consumiendo todas las iteraciones. k = 4811
# Backtracking está consumiendo todas las iteraciones. k = 4821
# Backtracking está consumiendo todas las iteraciones. k = 4831
# Backtracking está consumiendo todas las iteraciones. k = 4833
# Backtracking está consumiendo todas las iteraciones. k = 4837
# Backtracking está consumiendo todas las iteraciones. k = 4843
# Backtracking está consumiendo todas las iteraciones. k = 4853
# Backtracking está consumiendo todas las iteraciones. k = 4855
# Backtracking está consumiendo todas las iteraciones. k = 4859
# Backtracking está consumiendo todas las iteraciones. k = 4865
# Backtracking está consumiendo todas las iteraciones. k = 4875
# Backtracking está consumiendo todas las iteraciones. k = 4877
# Backtracking está consumiendo todas las iteraciones. k = 4886
# Backtracking está consumiendo todas las iteraciones. k = 4896
# Backtracking está consumiendo todas las iteraciones. k = 4906
# Backtracking está consumiendo todas las iteraciones. k = 4912
# Backtracking está consumiendo todas las iteraciones. k = 4914
# Backtracking está consumiendo todas las iteraciones. k = 4918
# Backtracking está consumiendo todas las iteraciones. k = 4924
# Backtracking está consumiendo todas las iteraciones. k = 4934
# Backtracking está consumiendo todas las iteraciones. k = 4944
# Backtracking está consumiendo todas las iteraciones. k = 4954
# Backtracking está consumiendo todas las iteraciones. k = 4968
# Backtracking está consumiendo todas las iteraciones. k = 4974
# Backtracking está consumiendo todas las iteraciones. k = 4976
# Backtracking está consumiendo todas las iteraciones. k = 4985
# Backtracking está consumiendo todas las iteraciones. k = 4995
# Dimension: 100
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 5000
# La solución alcanzada es:  [ 1.44208203 -1.40322734  2.08547332 -1.38700249] ... [-1.38700249  2.08547332 -1.40322734  1.44208203]
# f(xk)=-14.494288080223397
# f(x0)=0.0
# La norma del gradiente final es: 0.0007956071640097329
# Número de reinicios:  4013

# %%
# con la última dimensión
A6, b6 = gen_matrix2(n[2])
sol6 = nonlinear_grad_conj(lambda x: quadratic(x, A6, b6),
                           lambda x: Grad_quadratic(x, A6, b6),
                           np.zeros(n[2]), a0, maxIter, np.sqrt(n[2])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol6, lambda x: quadratic(x, A6, b6), np.zeros(n[2]))
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 26
# Backtracking está consumiendo todas las iteraciones. k = 37
# Backtracking está consumiendo todas las iteraciones. k = 43
# Backtracking está consumiendo todas las iteraciones. k = 49
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 70
# Backtracking está consumiendo todas las iteraciones. k = 76
# Backtracking está consumiendo todas las iteraciones. k = 86
# Backtracking está consumiendo todas las iteraciones. k = 92
# Backtracking está consumiendo todas las iteraciones. k = 102
# Backtracking está consumiendo todas las iteraciones. k = 108
# Backtracking está consumiendo todas las iteraciones. k = 118
# Backtracking está consumiendo todas las iteraciones. k = 124
# Backtracking está consumiendo todas las iteraciones. k = 134
# Backtracking está consumiendo todas las iteraciones. k = 144
# Backtracking está consumiendo todas las iteraciones. k = 150
# Backtracking está consumiendo todas las iteraciones. k = 165
# Backtracking está consumiendo todas las iteraciones. k = 174
# Backtracking está consumiendo todas las iteraciones. k = 183
# Backtracking está consumiendo todas las iteraciones. k = 192
# Backtracking está consumiendo todas las iteraciones. k = 202
# Backtracking está consumiendo todas las iteraciones. k = 208
# Backtracking está consumiendo todas las iteraciones. k = 218
# Backtracking está consumiendo todas las iteraciones. k = 224
# Backtracking está consumiendo todas las iteraciones. k = 226
# Backtracking está consumiendo todas las iteraciones. k = 235
# Backtracking está consumiendo todas las iteraciones. k = 241
# Backtracking está consumiendo todas las iteraciones. k = 243
# Backtracking está consumiendo todas las iteraciones. k = 252
# Backtracking está consumiendo todas las iteraciones. k = 261
# Backtracking está consumiendo todas las iteraciones. k = 270
# Backtracking está consumiendo todas las iteraciones. k = 280
# Backtracking está consumiendo todas las iteraciones. k = 286
# Backtracking está consumiendo todas las iteraciones. k = 296
# Backtracking está consumiendo todas las iteraciones. k = 306
# Backtracking está consumiendo todas las iteraciones. k = 308
# Backtracking está consumiendo todas las iteraciones. k = 317
# Backtracking está consumiendo todas las iteraciones. k = 332
# Backtracking está consumiendo todas las iteraciones. k = 342
# Backtracking está consumiendo todas las iteraciones. k = 348
# Backtracking está consumiendo todas las iteraciones. k = 358
# Backtracking está consumiendo todas las iteraciones. k = 367
# Backtracking está consumiendo todas las iteraciones. k = 377
# Backtracking está consumiendo todas las iteraciones. k = 383
# Backtracking está consumiendo todas las iteraciones. k = 393
# Backtracking está consumiendo todas las iteraciones. k = 402
# Backtracking está consumiendo todas las iteraciones. k = 412
# Backtracking está consumiendo todas las iteraciones. k = 418
# Backtracking está consumiendo todas las iteraciones. k = 428
# Backtracking está consumiendo todas las iteraciones. k = 438
# Backtracking está consumiendo todas las iteraciones. k = 447
# Backtracking está consumiendo todas las iteraciones. k = 457
# Backtracking está consumiendo todas las iteraciones. k = 463
# Backtracking está consumiendo todas las iteraciones. k = 473
# Backtracking está consumiendo todas las iteraciones. k = 475
# Backtracking está consumiendo todas las iteraciones. k = 479
# Backtracking está consumiendo todas las iteraciones. k = 485
# Backtracking está consumiendo todas las iteraciones. k = 495
# Backtracking está consumiendo todas las iteraciones. k = 501
# Backtracking está consumiendo todas las iteraciones. k = 511
# Backtracking está consumiendo todas las iteraciones. k = 513
# Backtracking está consumiendo todas las iteraciones. k = 517
# Backtracking está consumiendo todas las iteraciones. k = 523
# Backtracking está consumiendo todas las iteraciones. k = 533
# Backtracking está consumiendo todas las iteraciones. k = 539
# Backtracking está consumiendo todas las iteraciones. k = 549
# Backtracking está consumiendo todas las iteraciones. k = 551
# Backtracking está consumiendo todas las iteraciones. k = 560
# Backtracking está consumiendo todas las iteraciones. k = 570
# Backtracking está consumiendo todas las iteraciones. k = 576
# Backtracking está consumiendo todas las iteraciones. k = 586
# Backtracking está consumiendo todas las iteraciones. k = 596
# Backtracking está consumiendo todas las iteraciones. k = 598
# Backtracking está consumiendo todas las iteraciones. k = 607
# Backtracking está consumiendo todas las iteraciones. k = 617
# Backtracking está consumiendo todas las iteraciones. k = 623
# Backtracking está consumiendo todas las iteraciones. k = 633
# Backtracking está consumiendo todas las iteraciones. k = 643
# Backtracking está consumiendo todas las iteraciones. k = 649
# Backtracking está consumiendo todas las iteraciones. k = 659
# Backtracking está consumiendo todas las iteraciones. k = 661
# Backtracking está consumiendo todas las iteraciones. k = 670
# Backtracking está consumiendo todas las iteraciones. k = 680
# Backtracking está consumiendo todas las iteraciones. k = 686
# Backtracking está consumiendo todas las iteraciones. k = 696
# Backtracking está consumiendo todas las iteraciones. k = 706
# Backtracking está consumiendo todas las iteraciones. k = 716
# Backtracking está consumiendo todas las iteraciones. k = 726
# Backtracking está consumiendo todas las iteraciones. k = 732
# Backtracking está consumiendo todas las iteraciones. k = 742
# Backtracking está consumiendo todas las iteraciones. k = 752
# Backtracking está consumiendo todas las iteraciones. k = 762
# Backtracking está consumiendo todas las iteraciones. k = 772
# Backtracking está consumiendo todas las iteraciones. k = 782
# Backtracking está consumiendo todas las iteraciones. k = 792
# Backtracking está consumiendo todas las iteraciones. k = 798
# Backtracking está consumiendo todas las iteraciones. k = 800
# Backtracking está consumiendo todas las iteraciones. k = 809
# Backtracking está consumiendo todas las iteraciones. k = 819
# Backtracking está consumiendo todas las iteraciones. k = 825
# Backtracking está consumiendo todas las iteraciones. k = 835
# Backtracking está consumiendo todas las iteraciones. k = 849
# Backtracking está consumiendo todas las iteraciones. k = 855
# Backtracking está consumiendo todas las iteraciones. k = 865
# Backtracking está consumiendo todas las iteraciones. k = 875
# Backtracking está consumiendo todas las iteraciones. k = 881
# Backtracking está consumiendo todas las iteraciones. k = 891
# Backtracking está consumiendo todas las iteraciones. k = 901
# Backtracking está consumiendo todas las iteraciones. k = 907
# Backtracking está consumiendo todas las iteraciones. k = 909
# Backtracking está consumiendo todas las iteraciones. k = 918
# Backtracking está consumiendo todas las iteraciones. k = 928
# Backtracking está consumiendo todas las iteraciones. k = 934
# Backtracking está consumiendo todas las iteraciones. k = 944
# Backtracking está consumiendo todas las iteraciones. k = 954
# Backtracking está consumiendo todas las iteraciones. k = 963
# Backtracking está consumiendo todas las iteraciones. k = 973
# Backtracking está consumiendo todas las iteraciones. k = 983
# Backtracking está consumiendo todas las iteraciones. k = 989
# Backtracking está consumiendo todas las iteraciones. k = 999
# Backtracking está consumiendo todas las iteraciones. k = 1009
# Backtracking está consumiendo todas las iteraciones. k = 1018
# Backtracking está consumiendo todas las iteraciones. k = 1028
# Backtracking está consumiendo todas las iteraciones. k = 1034
# Backtracking está consumiendo todas las iteraciones. k = 1048
# Backtracking está consumiendo todas las iteraciones. k = 1054
# Backtracking está consumiendo todas las iteraciones. k = 1064
# Backtracking está consumiendo todas las iteraciones. k = 1074
# Backtracking está consumiendo todas las iteraciones. k = 1080
# Backtracking está consumiendo todas las iteraciones. k = 1090
# Backtracking está consumiendo todas las iteraciones. k = 1092
# Backtracking está consumiendo todas las iteraciones. k = 1101
# Backtracking está consumiendo todas las iteraciones. k = 1111
# Backtracking está consumiendo todas las iteraciones. k = 1117
# Backtracking está consumiendo todas las iteraciones. k = 1127
# Backtracking está consumiendo todas las iteraciones. k = 1137
# Backtracking está consumiendo todas las iteraciones. k = 1147
# Backtracking está consumiendo todas las iteraciones. k = 1153
# Backtracking está consumiendo todas las iteraciones. k = 1163
# Backtracking está consumiendo todas las iteraciones. k = 1173
# Backtracking está consumiendo todas las iteraciones. k = 1183
# Backtracking está consumiendo todas las iteraciones. k = 1193
# Backtracking está consumiendo todas las iteraciones. k = 1199
# Backtracking está consumiendo todas las iteraciones. k = 1201
# Backtracking está consumiendo todas las iteraciones. k = 1210
# Backtracking está consumiendo todas las iteraciones. k = 1220
# Backtracking está consumiendo todas las iteraciones. k = 1226
# Backtracking está consumiendo todas las iteraciones. k = 1236
# Backtracking está consumiendo todas las iteraciones. k = 1246
# Backtracking está consumiendo todas las iteraciones. k = 1256
# Backtracking está consumiendo todas las iteraciones. k = 1262
# Backtracking está consumiendo todas las iteraciones. k = 1272
# Backtracking está consumiendo todas las iteraciones. k = 1282
# Backtracking está consumiendo todas las iteraciones. k = 1292
# Backtracking está consumiendo todas las iteraciones. k = 1294
# Backtracking está consumiendo todas las iteraciones. k = 1303
# Backtracking está consumiendo todas las iteraciones. k = 1313
# Backtracking está consumiendo todas las iteraciones. k = 1319
# Backtracking está consumiendo todas las iteraciones. k = 1329
# Backtracking está consumiendo todas las iteraciones. k = 1331
# Backtracking está consumiendo todas las iteraciones. k = 1340
# Backtracking está consumiendo todas las iteraciones. k = 1350
# Backtracking está consumiendo todas las iteraciones. k = 1356
# Backtracking está consumiendo todas las iteraciones. k = 1358
# Backtracking está consumiendo todas las iteraciones. k = 1367
# Backtracking está consumiendo todas las iteraciones. k = 1377
# Backtracking está consumiendo todas las iteraciones. k = 1383
# Backtracking está consumiendo todas las iteraciones. k = 1393
# Backtracking está consumiendo todas las iteraciones. k = 1403
# Backtracking está consumiendo todas las iteraciones. k = 1413
# Backtracking está consumiendo todas las iteraciones. k = 1419
# Backtracking está consumiendo todas las iteraciones. k = 1421
# Backtracking está consumiendo todas las iteraciones. k = 1430
# Backtracking está consumiendo todas las iteraciones. k = 1440
# Backtracking está consumiendo todas las iteraciones. k = 1446
# Backtracking está consumiendo todas las iteraciones. k = 1456
# Backtracking está consumiendo todas las iteraciones. k = 1466
# Backtracking está consumiendo todas las iteraciones. k = 1472
# Backtracking está consumiendo todas las iteraciones. k = 1474
# Backtracking está consumiendo todas las iteraciones. k = 1483
# Backtracking está consumiendo todas las iteraciones. k = 1493
# Backtracking está consumiendo todas las iteraciones. k = 1499
# Backtracking está consumiendo todas las iteraciones. k = 1509
# Backtracking está consumiendo todas las iteraciones. k = 1511
# Backtracking está consumiendo todas las iteraciones. k = 1520
# Backtracking está consumiendo todas las iteraciones. k = 1530
# Backtracking está consumiendo todas las iteraciones. k = 1536
# Backtracking está consumiendo todas las iteraciones. k = 1546
# Backtracking está consumiendo todas las iteraciones. k = 1556
# Backtracking está consumiendo todas las iteraciones. k = 1558
# Backtracking está consumiendo todas las iteraciones. k = 1567
# Backtracking está consumiendo todas las iteraciones. k = 1577
# Backtracking está consumiendo todas las iteraciones. k = 1583
# Backtracking está consumiendo todas las iteraciones. k = 1593
# Backtracking está consumiendo todas las iteraciones. k = 1603
# Backtracking está consumiendo todas las iteraciones. k = 1613
# Backtracking está consumiendo todas las iteraciones. k = 1623
# Backtracking está consumiendo todas las iteraciones. k = 1633
# Backtracking está consumiendo todas las iteraciones. k = 1643
# Backtracking está consumiendo todas las iteraciones. k = 1653
# Backtracking está consumiendo todas las iteraciones. k = 1659
# Backtracking está consumiendo todas las iteraciones. k = 1669
# Backtracking está consumiendo todas las iteraciones. k = 1679
# Backtracking está consumiendo todas las iteraciones. k = 1689
# Backtracking está consumiendo todas las iteraciones. k = 1698
# Backtracking está consumiendo todas las iteraciones. k = 1708
# Backtracking está consumiendo todas las iteraciones. k = 1717
# Backtracking está consumiendo todas las iteraciones. k = 1727
# Backtracking está consumiendo todas las iteraciones. k = 1736
# Backtracking está consumiendo todas las iteraciones. k = 1746
# Backtracking está consumiendo todas las iteraciones. k = 1755
# Backtracking está consumiendo todas las iteraciones. k = 1765
# Backtracking está consumiendo todas las iteraciones. k = 1775
# Backtracking está consumiendo todas las iteraciones. k = 1781
# Backtracking está consumiendo todas las iteraciones. k = 1783
# Backtracking está consumiendo todas las iteraciones. k = 1792
# Backtracking está consumiendo todas las iteraciones. k = 1801
# Backtracking está consumiendo todas las iteraciones. k = 1811
# Backtracking está consumiendo todas las iteraciones. k = 1821
# Backtracking está consumiendo todas las iteraciones. k = 1831
# Backtracking está consumiendo todas las iteraciones. k = 1841
# Backtracking está consumiendo todas las iteraciones. k = 1850
# Backtracking está consumiendo todas las iteraciones. k = 1860
# Backtracking está consumiendo todas las iteraciones. k = 1870
# Backtracking está consumiendo todas las iteraciones. k = 1876
# Backtracking está consumiendo todas las iteraciones. k = 1886
# Backtracking está consumiendo todas las iteraciones. k = 1896
# Backtracking está consumiendo todas las iteraciones. k = 1906
# Backtracking está consumiendo todas las iteraciones. k = 1916
# Backtracking está consumiendo todas las iteraciones. k = 1926
# Backtracking está consumiendo todas las iteraciones. k = 1928
# Backtracking está consumiendo todas las iteraciones. k = 1937
# Backtracking está consumiendo todas las iteraciones. k = 1947
# Backtracking está consumiendo todas las iteraciones. k = 1953
# Backtracking está consumiendo todas las iteraciones. k = 1963
# Backtracking está consumiendo todas las iteraciones. k = 1973
# Backtracking está consumiendo todas las iteraciones. k = 1983
# Backtracking está consumiendo todas las iteraciones. k = 1992
# Backtracking está consumiendo todas las iteraciones. k = 2002
# Backtracking está consumiendo todas las iteraciones. k = 2012
# Backtracking está consumiendo todas las iteraciones. k = 2021
# Backtracking está consumiendo todas las iteraciones. k = 2031
# Backtracking está consumiendo todas las iteraciones. k = 2040
# Backtracking está consumiendo todas las iteraciones. k = 2050
# Backtracking está consumiendo todas las iteraciones. k = 2056
# Backtracking está consumiendo todas las iteraciones. k = 2058
# Backtracking está consumiendo todas las iteraciones. k = 2067
# Backtracking está consumiendo todas las iteraciones. k = 2077
# Backtracking está consumiendo todas las iteraciones. k = 2083
# Backtracking está consumiendo todas las iteraciones. k = 2085
# Backtracking está consumiendo todas las iteraciones. k = 2094
# Backtracking está consumiendo todas las iteraciones. k = 2104
# Backtracking está consumiendo todas las iteraciones. k = 2110
# Backtracking está consumiendo todas las iteraciones. k = 2120
# Backtracking está consumiendo todas las iteraciones. k = 2130
# Backtracking está consumiendo todas las iteraciones. k = 2132
# Backtracking está consumiendo todas las iteraciones. k = 2136
# Backtracking está consumiendo todas las iteraciones. k = 2142
# Backtracking está consumiendo todas las iteraciones. k = 2152
# Backtracking está consumiendo todas las iteraciones. k = 2161
# Backtracking está consumiendo todas las iteraciones. k = 2171
# Backtracking está consumiendo todas las iteraciones. k = 2180
# Backtracking está consumiendo todas las iteraciones. k = 2190
# Backtracking está consumiendo todas las iteraciones. k = 2200
# Backtracking está consumiendo todas las iteraciones. k = 2210
# Backtracking está consumiendo todas las iteraciones. k = 2220
# Backtracking está consumiendo todas las iteraciones. k = 2226
# Backtracking está consumiendo todas las iteraciones. k = 2236
# Backtracking está consumiendo todas las iteraciones. k = 2238
# Backtracking está consumiendo todas las iteraciones. k = 2247
# Backtracking está consumiendo todas las iteraciones. k = 2257
# Backtracking está consumiendo todas las iteraciones. k = 2263
# Backtracking está consumiendo todas las iteraciones. k = 2273
# Backtracking está consumiendo todas las iteraciones. k = 2283
# Backtracking está consumiendo todas las iteraciones. k = 2293
# Backtracking está consumiendo todas las iteraciones. k = 2295
# Backtracking está consumiendo todas las iteraciones. k = 2304
# Backtracking está consumiendo todas las iteraciones. k = 2314
# Backtracking está consumiendo todas las iteraciones. k = 2320
# Backtracking está consumiendo todas las iteraciones. k = 2330
# Backtracking está consumiendo todas las iteraciones. k = 2332
# Backtracking está consumiendo todas las iteraciones. k = 2341
# Backtracking está consumiendo todas las iteraciones. k = 2351
# Backtracking está consumiendo todas las iteraciones. k = 2357
# Backtracking está consumiendo todas las iteraciones. k = 2367
# Backtracking está consumiendo todas las iteraciones. k = 2369
# Backtracking está consumiendo todas las iteraciones. k = 2378
# Backtracking está consumiendo todas las iteraciones. k = 2388
# Backtracking está consumiendo todas las iteraciones. k = 2394
# Backtracking está consumiendo todas las iteraciones. k = 2404
# Backtracking está consumiendo todas las iteraciones. k = 2414
# Backtracking está consumiendo todas las iteraciones. k = 2424
# Backtracking está consumiendo todas las iteraciones. k = 2434
# Backtracking está consumiendo todas las iteraciones. k = 2443
# Backtracking está consumiendo todas las iteraciones. k = 2453
# Backtracking está consumiendo todas las iteraciones. k = 2463
# Backtracking está consumiendo todas las iteraciones. k = 2473
# Backtracking está consumiendo todas las iteraciones. k = 2479
# Backtracking está consumiendo todas las iteraciones. k = 2481
# Backtracking está consumiendo todas las iteraciones. k = 2490
# Backtracking está consumiendo todas las iteraciones. k = 2500
# Backtracking está consumiendo todas las iteraciones. k = 2506
# Backtracking está consumiendo todas las iteraciones. k = 2516
# Backtracking está consumiendo todas las iteraciones. k = 2518
# Backtracking está consumiendo todas las iteraciones. k = 2522
# Backtracking está consumiendo todas las iteraciones. k = 2528
# Backtracking está consumiendo todas las iteraciones. k = 2538
# Backtracking está consumiendo todas las iteraciones. k = 2548
# Backtracking está consumiendo todas las iteraciones. k = 2554
# Backtracking está consumiendo todas las iteraciones. k = 2564
# Backtracking está consumiendo todas las iteraciones. k = 2566
# Backtracking está consumiendo todas las iteraciones. k = 2575
# Backtracking está consumiendo todas las iteraciones. k = 2585
# Backtracking está consumiendo todas las iteraciones. k = 2591
# Backtracking está consumiendo todas las iteraciones. k = 2593
# Backtracking está consumiendo todas las iteraciones. k = 2602
# Backtracking está consumiendo todas las iteraciones. k = 2612
# Backtracking está consumiendo todas las iteraciones. k = 2618
# Backtracking está consumiendo todas las iteraciones. k = 2628
# Backtracking está consumiendo todas las iteraciones. k = 2630
# Backtracking está consumiendo todas las iteraciones. k = 2634
# Backtracking está consumiendo todas las iteraciones. k = 2640
# Backtracking está consumiendo todas las iteraciones. k = 2650
# Backtracking está consumiendo todas las iteraciones. k = 2660
# Backtracking está consumiendo todas las iteraciones. k = 2666
# Backtracking está consumiendo todas las iteraciones. k = 2668
# Backtracking está consumiendo todas las iteraciones. k = 2677
# Backtracking está consumiendo todas las iteraciones. k = 2687
# Backtracking está consumiendo todas las iteraciones. k = 2693
# Backtracking está consumiendo todas las iteraciones. k = 2703
# Backtracking está consumiendo todas las iteraciones. k = 2713
# Backtracking está consumiendo todas las iteraciones. k = 2723
# Backtracking está consumiendo todas las iteraciones. k = 2737
# Backtracking está consumiendo todas las iteraciones. k = 2743
# Backtracking está consumiendo todas las iteraciones. k = 2753
# Backtracking está consumiendo todas las iteraciones. k = 2763
# Backtracking está consumiendo todas las iteraciones. k = 2773
# Backtracking está consumiendo todas las iteraciones. k = 2779
# Backtracking está consumiendo todas las iteraciones. k = 2781
# Backtracking está consumiendo todas las iteraciones. k = 2790
# Backtracking está consumiendo todas las iteraciones. k = 2800
# Backtracking está consumiendo todas las iteraciones. k = 2806
# Backtracking está consumiendo todas las iteraciones. k = 2816
# Backtracking está consumiendo todas las iteraciones. k = 2826
# Backtracking está consumiendo todas las iteraciones. k = 2828
# Backtracking está consumiendo todas las iteraciones. k = 2837
# Backtracking está consumiendo todas las iteraciones. k = 2847
# Backtracking está consumiendo todas las iteraciones. k = 2853
# Backtracking está consumiendo todas las iteraciones. k = 2863
# Backtracking está consumiendo todas las iteraciones. k = 2865
# Backtracking está consumiendo todas las iteraciones. k = 2874
# Backtracking está consumiendo todas las iteraciones. k = 2884
# Backtracking está consumiendo todas las iteraciones. k = 2890
# Backtracking está consumiendo todas las iteraciones. k = 2900
# Backtracking está consumiendo todas las iteraciones. k = 2902
# Backtracking está consumiendo todas las iteraciones. k = 2911
# Backtracking está consumiendo todas las iteraciones. k = 2921
# Backtracking está consumiendo todas las iteraciones. k = 2927
# Backtracking está consumiendo todas las iteraciones. k = 2937
# Backtracking está consumiendo todas las iteraciones. k = 2947
# Backtracking está consumiendo todas las iteraciones. k = 2949
# Backtracking está consumiendo todas las iteraciones. k = 2958
# Backtracking está consumiendo todas las iteraciones. k = 2968
# Backtracking está consumiendo todas las iteraciones. k = 2974
# Backtracking está consumiendo todas las iteraciones. k = 2976
# Backtracking está consumiendo todas las iteraciones. k = 2985
# Backtracking está consumiendo todas las iteraciones. k = 2995
# Backtracking está consumiendo todas las iteraciones. k = 3001
# Backtracking está consumiendo todas las iteraciones. k = 3011
# Backtracking está consumiendo todas las iteraciones. k = 3013
# Backtracking está consumiendo todas las iteraciones. k = 3017
# Backtracking está consumiendo todas las iteraciones. k = 3023
# Backtracking está consumiendo todas las iteraciones. k = 3033
# Backtracking está consumiendo todas las iteraciones. k = 3042
# Backtracking está consumiendo todas las iteraciones. k = 3052
# Backtracking está consumiendo todas las iteraciones. k = 3062
# Backtracking está consumiendo todas las iteraciones. k = 3068
# Backtracking está consumiendo todas las iteraciones. k = 3078
# Backtracking está consumiendo todas las iteraciones. k = 3088
# Backtracking está consumiendo todas las iteraciones. k = 3090
# Backtracking está consumiendo todas las iteraciones. k = 3099
# Backtracking está consumiendo todas las iteraciones. k = 3109
# Backtracking está consumiendo todas las iteraciones. k = 3115
# Backtracking está consumiendo todas las iteraciones. k = 3125
# Backtracking está consumiendo todas las iteraciones. k = 3127
# Backtracking está consumiendo todas las iteraciones. k = 3136
# Backtracking está consumiendo todas las iteraciones. k = 3146
# Backtracking está consumiendo todas las iteraciones. k = 3152
# Backtracking está consumiendo todas las iteraciones. k = 3162
# Backtracking está consumiendo todas las iteraciones. k = 3172
# Backtracking está consumiendo todas las iteraciones. k = 3182
# Backtracking está consumiendo todas las iteraciones. k = 3192
# Backtracking está consumiendo todas las iteraciones. k = 3198
# Backtracking está consumiendo todas las iteraciones. k = 3200
# Backtracking está consumiendo todas las iteraciones. k = 3209
# Backtracking está consumiendo todas las iteraciones. k = 3219
# Backtracking está consumiendo todas las iteraciones. k = 3225
# Backtracking está consumiendo todas las iteraciones. k = 3227
# Backtracking está consumiendo todas las iteraciones. k = 3236
# Backtracking está consumiendo todas las iteraciones. k = 3246
# Backtracking está consumiendo todas las iteraciones. k = 3252
# Backtracking está consumiendo todas las iteraciones. k = 3262
# Backtracking está consumiendo todas las iteraciones. k = 3272
# Backtracking está consumiendo todas las iteraciones. k = 3282
# Backtracking está consumiendo todas las iteraciones. k = 3284
# Backtracking está consumiendo todas las iteraciones. k = 3288
# Backtracking está consumiendo todas las iteraciones. k = 3294
# Backtracking está consumiendo todas las iteraciones. k = 3304
# Backtracking está consumiendo todas las iteraciones. k = 3313
# Backtracking está consumiendo todas las iteraciones. k = 3323
# Backtracking está consumiendo todas las iteraciones. k = 3333
# Backtracking está consumiendo todas las iteraciones. k = 3342
# Backtracking está consumiendo todas las iteraciones. k = 3352
# Backtracking está consumiendo todas las iteraciones. k = 3362
# Backtracking está consumiendo todas las iteraciones. k = 3372
# Backtracking está consumiendo todas las iteraciones. k = 3382
# Backtracking está consumiendo todas las iteraciones. k = 3384
# Backtracking está consumiendo todas las iteraciones. k = 3393
# Backtracking está consumiendo todas las iteraciones. k = 3403
# Backtracking está consumiendo todas las iteraciones. k = 3409
# Backtracking está consumiendo todas las iteraciones. k = 3411
# Backtracking está consumiendo todas las iteraciones. k = 3420
# Backtracking está consumiendo todas las iteraciones. k = 3430
# Backtracking está consumiendo todas las iteraciones. k = 3436
# Backtracking está consumiendo todas las iteraciones. k = 3446
# Backtracking está consumiendo todas las iteraciones. k = 3456
# Backtracking está consumiendo todas las iteraciones. k = 3466
# Backtracking está consumiendo todas las iteraciones. k = 3475
# Backtracking está consumiendo todas las iteraciones. k = 3485
# Backtracking está consumiendo todas las iteraciones. k = 3495
# Backtracking está consumiendo todas las iteraciones. k = 3501
# Backtracking está consumiendo todas las iteraciones. k = 3511
# Backtracking está consumiendo todas las iteraciones. k = 3513
# Backtracking está consumiendo todas las iteraciones. k = 3517
# Backtracking está consumiendo todas las iteraciones. k = 3523
# Backtracking está consumiendo todas las iteraciones. k = 3533
# Backtracking está consumiendo todas las iteraciones. k = 3543
# Backtracking está consumiendo todas las iteraciones. k = 3549
# Backtracking está consumiendo todas las iteraciones. k = 3551
# Backtracking está consumiendo todas las iteraciones. k = 3555
# Backtracking está consumiendo todas las iteraciones. k = 3561
# Backtracking está consumiendo todas las iteraciones. k = 3571
# Backtracking está consumiendo todas las iteraciones. k = 3577
# Backtracking está consumiendo todas las iteraciones. k = 3579
# Backtracking está consumiendo todas las iteraciones. k = 3583
# Backtracking está consumiendo todas las iteraciones. k = 3589
# Backtracking está consumiendo todas las iteraciones. k = 3599
# Backtracking está consumiendo todas las iteraciones. k = 3605
# Backtracking está consumiendo todas las iteraciones. k = 3607
# Backtracking está consumiendo todas las iteraciones. k = 3616
# Backtracking está consumiendo todas las iteraciones. k = 3626
# Backtracking está consumiendo todas las iteraciones. k = 3632
# Backtracking está consumiendo todas las iteraciones. k = 3634
# Backtracking está consumiendo todas las iteraciones. k = 3643
# Backtracking está consumiendo todas las iteraciones. k = 3653
# Backtracking está consumiendo todas las iteraciones. k = 3659
# Backtracking está consumiendo todas las iteraciones. k = 3669
# Backtracking está consumiendo todas las iteraciones. k = 3671
# Backtracking está consumiendo todas las iteraciones. k = 3675
# Backtracking está consumiendo todas las iteraciones. k = 3681
# Backtracking está consumiendo todas las iteraciones. k = 3691
# Backtracking está consumiendo todas las iteraciones. k = 3700
# Backtracking está consumiendo todas las iteraciones. k = 3710
# Backtracking está consumiendo todas las iteraciones. k = 3719
# Backtracking está consumiendo todas las iteraciones. k = 3729
# Backtracking está consumiendo todas las iteraciones. k = 3739
# Backtracking está consumiendo todas las iteraciones. k = 3749
# Backtracking está consumiendo todas las iteraciones. k = 3759
# Backtracking está consumiendo todas las iteraciones. k = 3761
# Backtracking está consumiendo todas las iteraciones. k = 3770
# Backtracking está consumiendo todas las iteraciones. k = 3780
# Backtracking está consumiendo todas las iteraciones. k = 3786
# Backtracking está consumiendo todas las iteraciones. k = 3796
# Backtracking está consumiendo todas las iteraciones. k = 3806
# Backtracking está consumiendo todas las iteraciones. k = 3816
# Backtracking está consumiendo todas las iteraciones. k = 3826
# Backtracking está consumiendo todas las iteraciones. k = 3828
# Backtracking está consumiendo todas las iteraciones. k = 3837
# Backtracking está consumiendo todas las iteraciones. k = 3847
# Backtracking está consumiendo todas las iteraciones. k = 3853
# Backtracking está consumiendo todas las iteraciones. k = 3863
# Backtracking está consumiendo todas las iteraciones. k = 3873
# Backtracking está consumiendo todas las iteraciones. k = 3883
# Backtracking está consumiendo todas las iteraciones. k = 3892
# Backtracking está consumiendo todas las iteraciones. k = 3902
# Backtracking está consumiendo todas las iteraciones. k = 3912
# Backtracking está consumiendo todas las iteraciones. k = 3922
# Backtracking está consumiendo todas las iteraciones. k = 3928
# Backtracking está consumiendo todas las iteraciones. k = 3930
# Backtracking está consumiendo todas las iteraciones. k = 3939
# Backtracking está consumiendo todas las iteraciones. k = 3949
# Backtracking está consumiendo todas las iteraciones. k = 3955
# Backtracking está consumiendo todas las iteraciones. k = 3957
# Backtracking está consumiendo todas las iteraciones. k = 3966
# Backtracking está consumiendo todas las iteraciones. k = 3976
# Backtracking está consumiendo todas las iteraciones. k = 3982
# Backtracking está consumiendo todas las iteraciones. k = 3992
# Backtracking está consumiendo todas las iteraciones. k = 4002
# Backtracking está consumiendo todas las iteraciones. k = 4012
# Backtracking está consumiendo todas las iteraciones. k = 4022
# Backtracking está consumiendo todas las iteraciones. k = 4032
# Backtracking está consumiendo todas las iteraciones. k = 4042
# Backtracking está consumiendo todas las iteraciones. k = 4052
# Backtracking está consumiendo todas las iteraciones. k = 4062
# Backtracking está consumiendo todas las iteraciones. k = 4068
# Backtracking está consumiendo todas las iteraciones. k = 4070
# Backtracking está consumiendo todas las iteraciones. k = 4079
# Backtracking está consumiendo todas las iteraciones. k = 4089
# Backtracking está consumiendo todas las iteraciones. k = 4095
# Backtracking está consumiendo todas las iteraciones. k = 4097
# Backtracking está consumiendo todas las iteraciones. k = 4106
# Backtracking está consumiendo todas las iteraciones. k = 4116
# Backtracking está consumiendo todas las iteraciones. k = 4122
# Backtracking está consumiendo todas las iteraciones. k = 4136
# Backtracking está consumiendo todas las iteraciones. k = 4142
# Backtracking está consumiendo todas las iteraciones. k = 4152
# Backtracking está consumiendo todas las iteraciones. k = 4162
# Backtracking está consumiendo todas las iteraciones. k = 4172
# Backtracking está consumiendo todas las iteraciones. k = 4178
# Backtracking está consumiendo todas las iteraciones. k = 4188
# Backtracking está consumiendo todas las iteraciones. k = 4198
# Backtracking está consumiendo todas las iteraciones. k = 4200
# Backtracking está consumiendo todas las iteraciones. k = 4209
# Backtracking está consumiendo todas las iteraciones. k = 4219
# Backtracking está consumiendo todas las iteraciones. k = 4225
# Backtracking está consumiendo todas las iteraciones. k = 4235
# Backtracking está consumiendo todas las iteraciones. k = 4245
# Backtracking está consumiendo todas las iteraciones. k = 4255
# Backtracking está consumiendo todas las iteraciones. k = 4265
# Backtracking está consumiendo todas las iteraciones. k = 4271
# Backtracking está consumiendo todas las iteraciones. k = 4273
# Backtracking está consumiendo todas las iteraciones. k = 4282
# Backtracking está consumiendo todas las iteraciones. k = 4292
# Backtracking está consumiendo todas las iteraciones. k = 4298
# Backtracking está consumiendo todas las iteraciones. k = 4300
# Backtracking está consumiendo todas las iteraciones. k = 4309
# Backtracking está consumiendo todas las iteraciones. k = 4319
# Backtracking está consumiendo todas las iteraciones. k = 4325
# Backtracking está consumiendo todas las iteraciones. k = 4335
# Backtracking está consumiendo todas las iteraciones. k = 4337
# Backtracking está consumiendo todas las iteraciones. k = 4341
# Backtracking está consumiendo todas las iteraciones. k = 4347
# Backtracking está consumiendo todas las iteraciones. k = 4357
# Backtracking está consumiendo todas las iteraciones. k = 4367
# Backtracking está consumiendo todas las iteraciones. k = 4373
# Backtracking está consumiendo todas las iteraciones. k = 4383
# Backtracking está consumiendo todas las iteraciones. k = 4393
# Backtracking está consumiendo todas las iteraciones. k = 4395
# Backtracking está consumiendo todas las iteraciones. k = 4399
# Backtracking está consumiendo todas las iteraciones. k = 4405
# Backtracking está consumiendo todas las iteraciones. k = 4415
# Backtracking está consumiendo todas las iteraciones. k = 4425
# Backtracking está consumiendo todas las iteraciones. k = 4434
# Backtracking está consumiendo todas las iteraciones. k = 4444
# Backtracking está consumiendo todas las iteraciones. k = 4450
# Backtracking está consumiendo todas las iteraciones. k = 4452
# Backtracking está consumiendo todas las iteraciones. k = 4461
# Backtracking está consumiendo todas las iteraciones. k = 4471
# Backtracking está consumiendo todas las iteraciones. k = 4477
# Backtracking está consumiendo todas las iteraciones. k = 4479
# Backtracking está consumiendo todas las iteraciones. k = 4488
# Backtracking está consumiendo todas las iteraciones. k = 4498
# Backtracking está consumiendo todas las iteraciones. k = 4504
# Backtracking está consumiendo todas las iteraciones. k = 4514
# Backtracking está consumiendo todas las iteraciones. k = 4524
# Backtracking está consumiendo todas las iteraciones. k = 4526
# Backtracking está consumiendo todas las iteraciones. k = 4535
# Backtracking está consumiendo todas las iteraciones. k = 4545
# Backtracking está consumiendo todas las iteraciones. k = 4551
# Backtracking está consumiendo todas las iteraciones. k = 4561
# Backtracking está consumiendo todas las iteraciones. k = 4563
# Backtracking está consumiendo todas las iteraciones. k = 4572
# Backtracking está consumiendo todas las iteraciones. k = 4582
# Backtracking está consumiendo todas las iteraciones. k = 4588
# Backtracking está consumiendo todas las iteraciones. k = 4598
# Backtracking está consumiendo todas las iteraciones. k = 4608
# Backtracking está consumiendo todas las iteraciones. k = 4618
# Backtracking está consumiendo todas las iteraciones. k = 4628
# Backtracking está consumiendo todas las iteraciones. k = 4634
# Backtracking está consumiendo todas las iteraciones. k = 4636
# Backtracking está consumiendo todas las iteraciones. k = 4645
# Backtracking está consumiendo todas las iteraciones. k = 4655
# Backtracking está consumiendo todas las iteraciones. k = 4661
# Backtracking está consumiendo todas las iteraciones. k = 4671
# Backtracking está consumiendo todas las iteraciones. k = 4681
# Backtracking está consumiendo todas las iteraciones. k = 4683
# Backtracking está consumiendo todas las iteraciones. k = 4692
# Backtracking está consumiendo todas las iteraciones. k = 4702
# Backtracking está consumiendo todas las iteraciones. k = 4708
# Backtracking está consumiendo todas las iteraciones. k = 4718
# Backtracking está consumiendo todas las iteraciones. k = 4720
# Backtracking está consumiendo todas las iteraciones. k = 4729
# Backtracking está consumiendo todas las iteraciones. k = 4739
# Backtracking está consumiendo todas las iteraciones. k = 4745
# Backtracking está consumiendo todas las iteraciones. k = 4755
# Backtracking está consumiendo todas las iteraciones. k = 4757
# Backtracking está consumiendo todas las iteraciones. k = 4761
# Backtracking está consumiendo todas las iteraciones. k = 4767
# Backtracking está consumiendo todas las iteraciones. k = 4777
# Backtracking está consumiendo todas las iteraciones. k = 4783
# Backtracking está consumiendo todas las iteraciones. k = 4785
# Backtracking está consumiendo todas las iteraciones. k = 4789
# Backtracking está consumiendo todas las iteraciones. k = 4795
# Backtracking está consumiendo todas las iteraciones. k = 4805
# Backtracking está consumiendo todas las iteraciones. k = 4811
# Backtracking está consumiendo todas las iteraciones. k = 4813
# Backtracking está consumiendo todas las iteraciones. k = 4817
# Backtracking está consumiendo todas las iteraciones. k = 4823
# Backtracking está consumiendo todas las iteraciones. k = 4833
# Backtracking está consumiendo todas las iteraciones. k = 4839
# Backtracking está consumiendo todas las iteraciones. k = 4841
# Backtracking está consumiendo todas las iteraciones. k = 4845
# Backtracking está consumiendo todas las iteraciones. k = 4851
# Backtracking está consumiendo todas las iteraciones. k = 4861
# Backtracking está consumiendo todas las iteraciones. k = 4870
# Backtracking está consumiendo todas las iteraciones. k = 4880
# Backtracking está consumiendo todas las iteraciones. k = 4889
# Backtracking está consumiendo todas las iteraciones. k = 4899
# Backtracking está consumiendo todas las iteraciones. k = 4905
# Backtracking está consumiendo todas las iteraciones. k = 4907
# Backtracking está consumiendo todas las iteraciones. k = 4916
# Backtracking está consumiendo todas las iteraciones. k = 4926
# Backtracking está consumiendo todas las iteraciones. k = 4932
# Backtracking está consumiendo todas las iteraciones. k = 4934
# Backtracking está consumiendo todas las iteraciones. k = 4943
# Backtracking está consumiendo todas las iteraciones. k = 4953
# Backtracking está consumiendo todas las iteraciones. k = 4959
# Backtracking está consumiendo todas las iteraciones. k = 4969
# Backtracking está consumiendo todas las iteraciones. k = 4971
# Backtracking está consumiendo todas las iteraciones. k = 4975
# Backtracking está consumiendo todas las iteraciones. k = 4981
# Backtracking está consumiendo todas las iteraciones. k = 4991
# Dimension: 1000
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 5000
# La solución alcanzada es:  [ 1.44220785 -1.40362446  2.08621863 -1.38813373] ... [-1.38813373  2.08621863 -1.40362446  1.44220785]
# f(xk)=-141.43694653833245
# f(x0)=0.0
# La norma del gradiente final es: 0.00033853544033816355
# Número de reinicios:  4029

# %%
# con beale
x07 = np.array([2,3])
sol7 = nonlinear_grad_conj(beale, Grad_beale, x07, a0, maxIter, np.sqrt(2)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol7, beale, x07)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 42
# Backtracking está consumiendo todas las iteraciones. k = 53
# Backtracking está consumiendo todas las iteraciones. k = 70
# Dimension: 2
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 78
# La solución alcanzada es:  [2.99998551 0.49999649] ... [2.99998551 0.49999649]
# f(xk)=3.377431057983643e-11
# f(x0)=3347.203125
# La norma del gradiente final es: 6.924867590358913e-06
# Número de reinicios:  65

# %%
# con himmelbleau
x08 = np.array([2,4])
sol8 = nonlinear_grad_conj(himmelblau, Grad_himmelblau, x08, a0, maxIter, np.sqrt(2)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol8, himmelblau, x08)
# Out:
# Dimension: 2
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 37
# La solución alcanzada es:  [ 3.58442828 -1.84812653] ... [ 3.58442828 -1.84812653]
# f(xk)=2.0568411702376188e-13
# f(x0)=130
# La norma del gradiente final es: 6.585280714101221e-06
# Número de reinicios:  36

# %%
# con rosen
x09 = np.array([-1.2,1])
sol9 = nonlinear_grad_conj(rosenbrock, Grad_rosenbrock, x09, a0, maxIter, np.sqrt(2)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol9, rosenbrock, x09)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 23
# Backtracking está consumiendo todas las iteraciones. k = 25
# Backtracking está consumiendo todas las iteraciones. k = 36
# Backtracking está consumiendo todas las iteraciones. k = 38
# Backtracking está consumiendo todas las iteraciones. k = 113
# Backtracking está consumiendo todas las iteraciones. k = 115
# Backtracking está consumiendo todas las iteraciones. k = 130
# Backtracking está consumiendo todas las iteraciones. k = 141
# Backtracking está consumiendo todas las iteraciones. k = 152
# Backtracking está consumiendo todas las iteraciones. k = 163
# Backtracking está consumiendo todas las iteraciones. k = 165
# Backtracking está consumiendo todas las iteraciones. k = 180
# Backtracking está consumiendo todas las iteraciones. k = 191
# Backtracking está consumiendo todas las iteraciones. k = 193
# Backtracking está consumiendo todas las iteraciones. k = 208
# Backtracking está consumiendo todas las iteraciones. k = 210
# Backtracking está consumiendo todas las iteraciones. k = 225
# Backtracking está consumiendo todas las iteraciones. k = 227
# Backtracking está consumiendo todas las iteraciones. k = 366
# Backtracking está consumiendo todas las iteraciones. k = 368
# Backtracking está consumiendo todas las iteraciones. k = 370
# Backtracking está consumiendo todas las iteraciones. k = 372
# Backtracking está consumiendo todas las iteraciones. k = 374
# Backtracking está consumiendo todas las iteraciones. k = 398
# Backtracking está consumiendo todas las iteraciones. k = 400
# Backtracking está consumiendo todas las iteraciones. k = 402
# Backtracking está consumiendo todas las iteraciones. k = 404
# Backtracking está consumiendo todas las iteraciones. k = 406
# Backtracking está consumiendo todas las iteraciones. k = 434
# Backtracking está consumiendo todas las iteraciones. k = 436
# Backtracking está consumiendo todas las iteraciones. k = 438
# Backtracking está consumiendo todas las iteraciones. k = 440
# Backtracking está consumiendo todas las iteraciones. k = 442
# Backtracking está consumiendo todas las iteraciones. k = 470
# Backtracking está consumiendo todas las iteraciones. k = 472
# Backtracking está consumiendo todas las iteraciones. k = 474
# Backtracking está consumiendo todas las iteraciones. k = 476
# Backtracking está consumiendo todas las iteraciones. k = 478
# Backtracking está consumiendo todas las iteraciones. k = 506
# Backtracking está consumiendo todas las iteraciones. k = 508
# Backtracking está consumiendo todas las iteraciones. k = 510
# Backtracking está consumiendo todas las iteraciones. k = 512
# Backtracking está consumiendo todas las iteraciones. k = 514
# Backtracking está consumiendo todas las iteraciones. k = 545
# Backtracking está consumiendo todas las iteraciones. k = 547
# Backtracking está consumiendo todas las iteraciones. k = 549
# Backtracking está consumiendo todas las iteraciones. k = 551
# Backtracking está consumiendo todas las iteraciones. k = 575
# Backtracking está consumiendo todas las iteraciones. k = 577
# Backtracking está consumiendo todas las iteraciones. k = 579
# Backtracking está consumiendo todas las iteraciones. k = 581
# Backtracking está consumiendo todas las iteraciones. k = 583
# Backtracking está consumiendo todas las iteraciones. k = 611
# Backtracking está consumiendo todas las iteraciones. k = 613
# Backtracking está consumiendo todas las iteraciones. k = 615
# Backtracking está consumiendo todas las iteraciones. k = 617
# Backtracking está consumiendo todas las iteraciones. k = 619
# Backtracking está consumiendo todas las iteraciones. k = 647
# Backtracking está consumiendo todas las iteraciones. k = 649
# Backtracking está consumiendo todas las iteraciones. k = 651
# Backtracking está consumiendo todas las iteraciones. k = 653
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 679
# Backtracking está consumiendo todas las iteraciones. k = 681
# Backtracking está consumiendo todas las iteraciones. k = 683
# Backtracking está consumiendo todas las iteraciones. k = 685
# Backtracking está consumiendo todas las iteraciones. k = 709
# Backtracking está consumiendo todas las iteraciones. k = 711
# Backtracking está consumiendo todas las iteraciones. k = 713
# Backtracking está consumiendo todas las iteraciones. k = 715
# Backtracking está consumiendo todas las iteraciones. k = 739
# Backtracking está consumiendo todas las iteraciones. k = 741
# Backtracking está consumiendo todas las iteraciones. k = 743
# Backtracking está consumiendo todas las iteraciones. k = 745
# Backtracking está consumiendo todas las iteraciones. k = 747
# Backtracking está consumiendo todas las iteraciones. k = 775
# Backtracking está consumiendo todas las iteraciones. k = 777
# Backtracking está consumiendo todas las iteraciones. k = 779
# Backtracking está consumiendo todas las iteraciones. k = 781
# Backtracking está consumiendo todas las iteraciones. k = 805
# Backtracking está consumiendo todas las iteraciones. k = 807
# Backtracking está consumiendo todas las iteraciones. k = 809
# Backtracking está consumiendo todas las iteraciones. k = 811
# Backtracking está consumiendo todas las iteraciones. k = 813
# Backtracking está consumiendo todas las iteraciones. k = 841
# Backtracking está consumiendo todas las iteraciones. k = 843
# Backtracking está consumiendo todas las iteraciones. k = 845
# Backtracking está consumiendo todas las iteraciones. k = 847
# Backtracking está consumiendo todas las iteraciones. k = 871
# Backtracking está consumiendo todas las iteraciones. k = 873
# Backtracking está consumiendo todas las iteraciones. k = 875
# Backtracking está consumiendo todas las iteraciones. k = 877
# Backtracking está consumiendo todas las iteraciones. k = 879
# Backtracking está consumiendo todas las iteraciones. k = 907
# Backtracking está consumiendo todas las iteraciones. k = 909
# Backtracking está consumiendo todas las iteraciones. k = 911
# Backtracking está consumiendo todas las iteraciones. k = 913
# Backtracking está consumiendo todas las iteraciones. k = 937
# Backtracking está consumiendo todas las iteraciones. k = 939
# Backtracking está consumiendo todas las iteraciones. k = 941
# Backtracking está consumiendo todas las iteraciones. k = 943
# Backtracking está consumiendo todas las iteraciones. k = 945
# Backtracking está consumiendo todas las iteraciones. k = 975
# Backtracking está consumiendo todas las iteraciones. k = 977
# Backtracking está consumiendo todas las iteraciones. k = 979
# Backtracking está consumiendo todas las iteraciones. k = 981
# Backtracking está consumiendo todas las iteraciones. k = 983
# Backtracking está consumiendo todas las iteraciones. k = 1006
# Backtracking está consumiendo todas las iteraciones. k = 1008
# Backtracking está consumiendo todas las iteraciones. k = 1010
# Backtracking está consumiendo todas las iteraciones. k = 1012
# Backtracking está consumiendo todas las iteraciones. k = 1014
# Backtracking está consumiendo todas las iteraciones. k = 1038
# Backtracking está consumiendo todas las iteraciones. k = 1040
# Backtracking está consumiendo todas las iteraciones. k = 1042
# Backtracking está consumiendo todas las iteraciones. k = 1044
# Backtracking está consumiendo todas las iteraciones. k = 1068
# Backtracking está consumiendo todas las iteraciones. k = 1070
# Backtracking está consumiendo todas las iteraciones. k = 1072
# Backtracking está consumiendo todas las iteraciones. k = 1074
# Backtracking está consumiendo todas las iteraciones. k = 1098
# Backtracking está consumiendo todas las iteraciones. k = 1100
# Backtracking está consumiendo todas las iteraciones. k = 1102
# Backtracking está consumiendo todas las iteraciones. k = 1104
# Backtracking está consumiendo todas las iteraciones. k = 1106
# Backtracking está consumiendo todas las iteraciones. k = 1133
# Backtracking está consumiendo todas las iteraciones. k = 1135
# Backtracking está consumiendo todas las iteraciones. k = 1137
# Backtracking está consumiendo todas las iteraciones. k = 1139
# Backtracking está consumiendo todas las iteraciones. k = 1141
# Backtracking está consumiendo todas las iteraciones. k = 1165
# Backtracking está consumiendo todas las iteraciones. k = 1167
# Backtracking está consumiendo todas las iteraciones. k = 1169
# Backtracking está consumiendo todas las iteraciones. k = 1171
# Backtracking está consumiendo todas las iteraciones. k = 1195
# Backtracking está consumiendo todas las iteraciones. k = 1197
# Backtracking está consumiendo todas las iteraciones. k = 1199
# Backtracking está consumiendo todas las iteraciones. k = 1201
# Backtracking está consumiendo todas las iteraciones. k = 1225
# Backtracking está consumiendo todas las iteraciones. k = 1227
# Backtracking está consumiendo todas las iteraciones. k = 1229
# Backtracking está consumiendo todas las iteraciones. k = 1231
# Backtracking está consumiendo todas las iteraciones. k = 1255
# Backtracking está consumiendo todas las iteraciones. k = 1257
# Backtracking está consumiendo todas las iteraciones. k = 1259
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1285
# Backtracking está consumiendo todas las iteraciones. k = 1287
# Backtracking está consumiendo todas las iteraciones. k = 1289
# Backtracking está consumiendo todas las iteraciones. k = 1291
# Backtracking está consumiendo todas las iteraciones. k = 1293
# Backtracking está consumiendo todas las iteraciones. k = 1323
# Backtracking está consumiendo todas las iteraciones. k = 1325
# Backtracking está consumiendo todas las iteraciones. k = 1327
# Backtracking está consumiendo todas las iteraciones. k = 1329
# Backtracking está consumiendo todas las iteraciones. k = 1331
# Backtracking está consumiendo todas las iteraciones. k = 1358
# Backtracking está consumiendo todas las iteraciones. k = 1360
# Backtracking está consumiendo todas las iteraciones. k = 1362
# Backtracking está consumiendo todas las iteraciones. k = 1364
# Backtracking está consumiendo todas las iteraciones. k = 1366
# Backtracking está consumiendo todas las iteraciones. k = 1394
# Backtracking está consumiendo todas las iteraciones. k = 1396
# Backtracking está consumiendo todas las iteraciones. k = 1398
# Backtracking está consumiendo todas las iteraciones. k = 1400
# Backtracking está consumiendo todas las iteraciones. k = 1424
# Backtracking está consumiendo todas las iteraciones. k = 1426
# Backtracking está consumiendo todas las iteraciones. k = 1428
# Backtracking está consumiendo todas las iteraciones. k = 1430
# Backtracking está consumiendo todas las iteraciones. k = 1454
# Backtracking está consumiendo todas las iteraciones. k = 1456
# Backtracking está consumiendo todas las iteraciones. k = 1458
# Backtracking está consumiendo todas las iteraciones. k = 1460
# Backtracking está consumiendo todas las iteraciones. k = 1483
# Backtracking está consumiendo todas las iteraciones. k = 1485
# Backtracking está consumiendo todas las iteraciones. k = 1487
# Backtracking está consumiendo todas las iteraciones. k = 1489
# Backtracking está consumiendo todas las iteraciones. k = 1491
# Backtracking está consumiendo todas las iteraciones. k = 1514
# Backtracking está consumiendo todas las iteraciones. k = 1516
# Backtracking está consumiendo todas las iteraciones. k = 1518
# Backtracking está consumiendo todas las iteraciones. k = 1520
# Backtracking está consumiendo todas las iteraciones. k = 1522
# Backtracking está consumiendo todas las iteraciones. k = 1545
# Backtracking está consumiendo todas las iteraciones. k = 1547
# Backtracking está consumiendo todas las iteraciones. k = 1549
# Backtracking está consumiendo todas las iteraciones. k = 1551
# Backtracking está consumiendo todas las iteraciones. k = 1553
# Backtracking está consumiendo todas las iteraciones. k = 1576
# Backtracking está consumiendo todas las iteraciones. k = 1578
# Backtracking está consumiendo todas las iteraciones. k = 1580
# Backtracking está consumiendo todas las iteraciones. k = 1582
# Backtracking está consumiendo todas las iteraciones. k = 1584
# Backtracking está consumiendo todas las iteraciones. k = 1607
# Backtracking está consumiendo todas las iteraciones. k = 1609
# Backtracking está consumiendo todas las iteraciones. k = 1611
# Backtracking está consumiendo todas las iteraciones. k = 1613
# Backtracking está consumiendo todas las iteraciones. k = 1615
# Backtracking está consumiendo todas las iteraciones. k = 1642
# Backtracking está consumiendo todas las iteraciones. k = 1644
# Backtracking está consumiendo todas las iteraciones. k = 1646
# Backtracking está consumiendo todas las iteraciones. k = 1648
# Backtracking está consumiendo todas las iteraciones. k = 1650
# Backtracking está consumiendo todas las iteraciones. k = 1673
# Backtracking está consumiendo todas las iteraciones. k = 1675
# Backtracking está consumiendo todas las iteraciones. k = 1677
# Backtracking está consumiendo todas las iteraciones. k = 1679
# Backtracking está consumiendo todas las iteraciones. k = 1681
# Backtracking está consumiendo todas las iteraciones. k = 1704
# Backtracking está consumiendo todas las iteraciones. k = 1706
# Backtracking está consumiendo todas las iteraciones. k = 1708
# Backtracking está consumiendo todas las iteraciones. k = 1710
# Backtracking está consumiendo todas las iteraciones. k = 1712
# Backtracking está consumiendo todas las iteraciones. k = 1739
# Backtracking está consumiendo todas las iteraciones. k = 1741
# Backtracking está consumiendo todas las iteraciones. k = 1743
# Backtracking está consumiendo todas las iteraciones. k = 1745
# Backtracking está consumiendo todas las iteraciones. k = 1747
# Backtracking está consumiendo todas las iteraciones. k = 1770
# Backtracking está consumiendo todas las iteraciones. k = 1772
# Backtracking está consumiendo todas las iteraciones. k = 1774
# Backtracking está consumiendo todas las iteraciones. k = 1776
# Backtracking está consumiendo todas las iteraciones. k = 1778
# Backtracking está consumiendo todas las iteraciones. k = 1805
# Backtracking está consumiendo todas las iteraciones. k = 1807
# Backtracking está consumiendo todas las iteraciones. k = 1809
# Backtracking está consumiendo todas las iteraciones. k = 1811
# Backtracking está consumiendo todas las iteraciones. k = 1813
# Backtracking está consumiendo todas las iteraciones. k = 1836
# Backtracking está consumiendo todas las iteraciones. k = 1838
# Backtracking está consumiendo todas las iteraciones. k = 1840
# Backtracking está consumiendo todas las iteraciones. k = 1842
# Backtracking está consumiendo todas las iteraciones. k = 1844
# Backtracking está consumiendo todas las iteraciones. k = 1871
# Backtracking está consumiendo todas las iteraciones. k = 1873
# Backtracking está consumiendo todas las iteraciones. k = 1875
# Backtracking está consumiendo todas las iteraciones. k = 1877
# Backtracking está consumiendo todas las iteraciones. k = 1879
# Backtracking está consumiendo todas las iteraciones. k = 1906
# Backtracking está consumiendo todas las iteraciones. k = 1908
# Backtracking está consumiendo todas las iteraciones. k = 1910
# Backtracking está consumiendo todas las iteraciones. k = 1912
# Backtracking está consumiendo todas las iteraciones. k = 1914
# Backtracking está consumiendo todas las iteraciones. k = 1937
# Backtracking está consumiendo todas las iteraciones. k = 1939
# Backtracking está consumiendo todas las iteraciones. k = 1941
# Backtracking está consumiendo todas las iteraciones. k = 1943
# Backtracking está consumiendo todas las iteraciones. k = 1945
# Backtracking está consumiendo todas las iteraciones. k = 1972
# Backtracking está consumiendo todas las iteraciones. k = 1974
# Backtracking está consumiendo todas las iteraciones. k = 1976
# Backtracking está consumiendo todas las iteraciones. k = 1978
# Backtracking está consumiendo todas las iteraciones. k = 1980
# Backtracking está consumiendo todas las iteraciones. k = 2007
# Backtracking está consumiendo todas las iteraciones. k = 2009
# Backtracking está consumiendo todas las iteraciones. k = 2011
# Backtracking está consumiendo todas las iteraciones. k = 2013
# Backtracking está consumiendo todas las iteraciones. k = 2015
# Backtracking está consumiendo todas las iteraciones. k = 2042
# Backtracking está consumiendo todas las iteraciones. k = 2044
# Backtracking está consumiendo todas las iteraciones. k = 2046
# Backtracking está consumiendo todas las iteraciones. k = 2048
# Backtracking está consumiendo todas las iteraciones. k = 2050
# Backtracking está consumiendo todas las iteraciones. k = 2077
# Backtracking está consumiendo todas las iteraciones. k = 2079
# Backtracking está consumiendo todas las iteraciones. k = 2081
# Backtracking está consumiendo todas las iteraciones. k = 2083
# Backtracking está consumiendo todas las iteraciones. k = 2085
# Backtracking está consumiendo todas las iteraciones. k = 2112
# Backtracking está consumiendo todas las iteraciones. k = 2114
# Backtracking está consumiendo todas las iteraciones. k = 2116
# Backtracking está consumiendo todas las iteraciones. k = 2118
# Backtracking está consumiendo todas las iteraciones. k = 2120
# Backtracking está consumiendo todas las iteraciones. k = 2147
# Backtracking está consumiendo todas las iteraciones. k = 2149
# Backtracking está consumiendo todas las iteraciones. k = 2151
# Backtracking está consumiendo todas las iteraciones. k = 2153
# Backtracking está consumiendo todas las iteraciones. k = 2155
# Backtracking está consumiendo todas las iteraciones. k = 2182
# Backtracking está consumiendo todas las iteraciones. k = 2184
# Backtracking está consumiendo todas las iteraciones. k = 2186
# Backtracking está consumiendo todas las iteraciones. k = 2188
# Backtracking está consumiendo todas las iteraciones. k = 2190
# Backtracking está consumiendo todas las iteraciones. k = 2220
# Backtracking está consumiendo todas las iteraciones. k = 2222
# Backtracking está consumiendo todas las iteraciones. k = 2224
# Backtracking está consumiendo todas las iteraciones. k = 2226
# Backtracking está consumiendo todas las iteraciones. k = 2249
# Backtracking está consumiendo todas las iteraciones. k = 2251
# Backtracking está consumiendo todas las iteraciones. k = 2253
# Backtracking está consumiendo todas las iteraciones. k = 2255
# Backtracking está consumiendo todas las iteraciones. k = 2257
# Backtracking está consumiendo todas las iteraciones. k = 2280
# Backtracking está consumiendo todas las iteraciones. k = 2282
# Backtracking está consumiendo todas las iteraciones. k = 2284
# Backtracking está consumiendo todas las iteraciones. k = 2286
# Backtracking está consumiendo todas las iteraciones. k = 2288
# Backtracking está consumiendo todas las iteraciones. k = 2315
# Backtracking está consumiendo todas las iteraciones. k = 2317
# Backtracking está consumiendo todas las iteraciones. k = 2319
# Backtracking está consumiendo todas las iteraciones. k = 2321
# Backtracking está consumiendo todas las iteraciones. k = 2323
# Backtracking está consumiendo todas las iteraciones. k = 2353
# Backtracking está consumiendo todas las iteraciones. k = 2355
# Backtracking está consumiendo todas las iteraciones. k = 2357
# Backtracking está consumiendo todas las iteraciones. k = 2359
# Backtracking está consumiendo todas las iteraciones. k = 2382
# Backtracking está consumiendo todas las iteraciones. k = 2384
# Backtracking está consumiendo todas las iteraciones. k = 2386
# Backtracking está consumiendo todas las iteraciones. k = 2388
# Backtracking está consumiendo todas las iteraciones. k = 2390
# Backtracking está consumiendo todas las iteraciones. k = 2417
# Backtracking está consumiendo todas las iteraciones. k = 2419
# Backtracking está consumiendo todas las iteraciones. k = 2421
# Backtracking está consumiendo todas las iteraciones. k = 2423
# Backtracking está consumiendo todas las iteraciones. k = 2425
# Backtracking está consumiendo todas las iteraciones. k = 2452
# Backtracking está consumiendo todas las iteraciones. k = 2454
# Backtracking está consumiendo todas las iteraciones. k = 2456
# Backtracking está consumiendo todas las iteraciones. k = 2458
# Backtracking está consumiendo todas las iteraciones. k = 2460
# Backtracking está consumiendo todas las iteraciones. k = 2487
# Backtracking está consumiendo todas las iteraciones. k = 2489
# Backtracking está consumiendo todas las iteraciones. k = 2491
# Backtracking está consumiendo todas las iteraciones. k = 2493
# Backtracking está consumiendo todas las iteraciones. k = 2495
# Backtracking está consumiendo todas las iteraciones. k = 2525
# Backtracking está consumiendo todas las iteraciones. k = 2527
# Backtracking está consumiendo todas las iteraciones. k = 2529
# Backtracking está consumiendo todas las iteraciones. k = 2531
# Backtracking está consumiendo todas las iteraciones. k = 2554
# Backtracking está consumiendo todas las iteraciones. k = 2556
# Backtracking está consumiendo todas las iteraciones. k = 2558
# Backtracking está consumiendo todas las iteraciones. k = 2560
# Backtracking está consumiendo todas las iteraciones. k = 2562
# Backtracking está consumiendo todas las iteraciones. k = 2589
# Backtracking está consumiendo todas las iteraciones. k = 2591
# Backtracking está consumiendo todas las iteraciones. k = 2593
# Backtracking está consumiendo todas las iteraciones. k = 2595
# Backtracking está consumiendo todas las iteraciones. k = 2597
# Backtracking está consumiendo todas las iteraciones. k = 2624
# Backtracking está consumiendo todas las iteraciones. k = 2626
# Backtracking está consumiendo todas las iteraciones. k = 2628
# Backtracking está consumiendo todas las iteraciones. k = 2630
# Backtracking está consumiendo todas las iteraciones. k = 2654
# Backtracking está consumiendo todas las iteraciones. k = 2656
# Backtracking está consumiendo todas las iteraciones. k = 2658
# Backtracking está consumiendo todas las iteraciones. k = 2660
# Backtracking está consumiendo todas las iteraciones. k = 2683
# Backtracking está consumiendo todas las iteraciones. k = 2685
# Backtracking está consumiendo todas las iteraciones. k = 2687
# Backtracking está consumiendo todas las iteraciones. k = 2689
# Backtracking está consumiendo todas las iteraciones. k = 2691
# Backtracking está consumiendo todas las iteraciones. k = 2718
# Backtracking está consumiendo todas las iteraciones. k = 2720
# Backtracking está consumiendo todas las iteraciones. k = 2722
# Backtracking está consumiendo todas las iteraciones. k = 2724
# Backtracking está consumiendo todas las iteraciones. k = 2726
# Backtracking está consumiendo todas las iteraciones. k = 2756
# Backtracking está consumiendo todas las iteraciones. k = 2758
# Backtracking está consumiendo todas las iteraciones. k = 2760
# Backtracking está consumiendo todas las iteraciones. k = 2762
# Backtracking está consumiendo todas las iteraciones. k = 2785
# Backtracking está consumiendo todas las iteraciones. k = 2787
# Backtracking está consumiendo todas las iteraciones. k = 2789
# Backtracking está consumiendo todas las iteraciones. k = 2791
# Backtracking está consumiendo todas las iteraciones. k = 2793
# Backtracking está consumiendo todas las iteraciones. k = 2820
# Backtracking está consumiendo todas las iteraciones. k = 2822
# Backtracking está consumiendo todas las iteraciones. k = 2824
# Backtracking está consumiendo todas las iteraciones. k = 2826
# Backtracking está consumiendo todas las iteraciones. k = 2850
# Backtracking está consumiendo todas las iteraciones. k = 2852
# Backtracking está consumiendo todas las iteraciones. k = 2854
# Backtracking está consumiendo todas las iteraciones. k = 2856
# Backtracking está consumiendo todas las iteraciones. k = 2879
# Backtracking está consumiendo todas las iteraciones. k = 2881
# Backtracking está consumiendo todas las iteraciones. k = 2883
# Backtracking está consumiendo todas las iteraciones. k = 2885
# Backtracking está consumiendo todas las iteraciones. k = 2887
# Backtracking está consumiendo todas las iteraciones. k = 2914
# Backtracking está consumiendo todas las iteraciones. k = 2916
# Backtracking está consumiendo todas las iteraciones. k = 2918
# Backtracking está consumiendo todas las iteraciones. k = 2920
# Backtracking está consumiendo todas las iteraciones. k = 2943
# Backtracking está consumiendo todas las iteraciones. k = 2945
# Backtracking está consumiendo todas las iteraciones. k = 2947
# Backtracking está consumiendo todas las iteraciones. k = 2949
# Backtracking está consumiendo todas las iteraciones. k = 2951
# Backtracking está consumiendo todas las iteraciones. k = 2974
# Backtracking está consumiendo todas las iteraciones. k = 2976
# Backtracking está consumiendo todas las iteraciones. k = 2978
# Backtracking está consumiendo todas las iteraciones. k = 2980
# Backtracking está consumiendo todas las iteraciones. k = 2982
# Backtracking está consumiendo todas las iteraciones. k = 3012
# Backtracking está consumiendo todas las iteraciones. k = 3014
# Backtracking está consumiendo todas las iteraciones. k = 3016
# Backtracking está consumiendo todas las iteraciones. k = 3018
# Backtracking está consumiendo todas las iteraciones. k = 3041
# Backtracking está consumiendo todas las iteraciones. k = 3043
# Backtracking está consumiendo todas las iteraciones. k = 3045
# Backtracking está consumiendo todas las iteraciones. k = 3047
# Backtracking está consumiendo todas las iteraciones. k = 3049
# Backtracking está consumiendo todas las iteraciones. k = 3076
# Backtracking está consumiendo todas las iteraciones. k = 3078
# Backtracking está consumiendo todas las iteraciones. k = 3080
# Backtracking está consumiendo todas las iteraciones. k = 3082
# Backtracking está consumiendo todas las iteraciones. k = 3105
# Backtracking está consumiendo todas las iteraciones. k = 3107
# Backtracking está consumiendo todas las iteraciones. k = 3109
# Backtracking está consumiendo todas las iteraciones. k = 3111
# Backtracking está consumiendo todas las iteraciones. k = 3113
# Backtracking está consumiendo todas las iteraciones. k = 3136
# Backtracking está consumiendo todas las iteraciones. k = 3138
# Backtracking está consumiendo todas las iteraciones. k = 3140
# Backtracking está consumiendo todas las iteraciones. k = 3142
# Backtracking está consumiendo todas las iteraciones. k = 3165
# Backtracking está consumiendo todas las iteraciones. k = 3167
# Backtracking está consumiendo todas las iteraciones. k = 3169
# Backtracking está consumiendo todas las iteraciones. k = 3171
# Backtracking está consumiendo todas las iteraciones. k = 3173
# Backtracking está consumiendo todas las iteraciones. k = 3196
# Backtracking está consumiendo todas las iteraciones. k = 3198
# Backtracking está consumiendo todas las iteraciones. k = 3200
# Backtracking está consumiendo todas las iteraciones. k = 3202
# Backtracking está consumiendo todas las iteraciones. k = 3204
# Backtracking está consumiendo todas las iteraciones. k = 3234
# Backtracking está consumiendo todas las iteraciones. k = 3236
# Backtracking está consumiendo todas las iteraciones. k = 3238
# Backtracking está consumiendo todas las iteraciones. k = 3240
# Backtracking está consumiendo todas las iteraciones. k = 3263
# Backtracking está consumiendo todas las iteraciones. k = 3265
# Backtracking está consumiendo todas las iteraciones. k = 3267
# Backtracking está consumiendo todas las iteraciones. k = 3269
# Backtracking está consumiendo todas las iteraciones. k = 3271
# Backtracking está consumiendo todas las iteraciones. k = 3301
# Backtracking está consumiendo todas las iteraciones. k = 3303
# Backtracking está consumiendo todas las iteraciones. k = 3305
# Backtracking está consumiendo todas las iteraciones. k = 3307
# Backtracking está consumiendo todas las iteraciones. k = 3330
# Backtracking está consumiendo todas las iteraciones. k = 3332
# Backtracking está consumiendo todas las iteraciones. k = 3334
# Backtracking está consumiendo todas las iteraciones. k = 3336
# Backtracking está consumiendo todas las iteraciones. k = 3338
# Backtracking está consumiendo todas las iteraciones. k = 3368
# Backtracking está consumiendo todas las iteraciones. k = 3370
# Backtracking está consumiendo todas las iteraciones. k = 3372
# Backtracking está consumiendo todas las iteraciones. k = 3374
# Backtracking está consumiendo todas las iteraciones. k = 3397
# Backtracking está consumiendo todas las iteraciones. k = 3399
# Backtracking está consumiendo todas las iteraciones. k = 3401
# Backtracking está consumiendo todas las iteraciones. k = 3403
# Backtracking está consumiendo todas las iteraciones. k = 3405
# Backtracking está consumiendo todas las iteraciones. k = 3434
# Backtracking está consumiendo todas las iteraciones. k = 3436
# Backtracking está consumiendo todas las iteraciones. k = 3438
# Backtracking está consumiendo todas las iteraciones. k = 3440
# Backtracking está consumiendo todas las iteraciones. k = 3442
# Backtracking está consumiendo todas las iteraciones. k = 3465
# Backtracking está consumiendo todas las iteraciones. k = 3467
# Backtracking está consumiendo todas las iteraciones. k = 3469
# Backtracking está consumiendo todas las iteraciones. k = 3471
# Backtracking está consumiendo todas las iteraciones. k = 3473
# Backtracking está consumiendo todas las iteraciones. k = 3502
# Backtracking está consumiendo todas las iteraciones. k = 3504
# Backtracking está consumiendo todas las iteraciones. k = 3506
# Backtracking está consumiendo todas las iteraciones. k = 3508
# Backtracking está consumiendo todas las iteraciones. k = 3510
# Backtracking está consumiendo todas las iteraciones. k = 3533
# Backtracking está consumiendo todas las iteraciones. k = 3535
# Backtracking está consumiendo todas las iteraciones. k = 3537
# Backtracking está consumiendo todas las iteraciones. k = 3539
# Backtracking está consumiendo todas las iteraciones. k = 3562
# Backtracking está consumiendo todas las iteraciones. k = 3564
# Backtracking está consumiendo todas las iteraciones. k = 3566
# Backtracking está consumiendo todas las iteraciones. k = 3568
# Backtracking está consumiendo todas las iteraciones. k = 3570
# Backtracking está consumiendo todas las iteraciones. k = 3593
# Backtracking está consumiendo todas las iteraciones. k = 3595
# Backtracking está consumiendo todas las iteraciones. k = 3597
# Backtracking está consumiendo todas las iteraciones. k = 3599
# Backtracking está consumiendo todas las iteraciones. k = 3622
# Backtracking está consumiendo todas las iteraciones. k = 3624
# Backtracking está consumiendo todas las iteraciones. k = 3626
# Backtracking está consumiendo todas las iteraciones. k = 3628
# Backtracking está consumiendo todas las iteraciones. k = 3630
# Backtracking está consumiendo todas las iteraciones. k = 3653
# Backtracking está consumiendo todas las iteraciones. k = 3655
# Backtracking está consumiendo todas las iteraciones. k = 3657
# Backtracking está consumiendo todas las iteraciones. k = 3659
# Backtracking está consumiendo todas las iteraciones. k = 3682
# Backtracking está consumiendo todas las iteraciones. k = 3684
# Backtracking está consumiendo todas las iteraciones. k = 3686
# Backtracking está consumiendo todas las iteraciones. k = 3688
# Backtracking está consumiendo todas las iteraciones. k = 3690
# Backtracking está consumiendo todas las iteraciones. k = 3713
# Backtracking está consumiendo todas las iteraciones. k = 3715
# Backtracking está consumiendo todas las iteraciones. k = 3717
# Backtracking está consumiendo todas las iteraciones. k = 3719
# Backtracking está consumiendo todas las iteraciones. k = 3742
# Backtracking está consumiendo todas las iteraciones. k = 3744
# Backtracking está consumiendo todas las iteraciones. k = 3746
# Backtracking está consumiendo todas las iteraciones. k = 3748
# Backtracking está consumiendo todas las iteraciones. k = 3750
# Backtracking está consumiendo todas las iteraciones. k = 3773
# Backtracking está consumiendo todas las iteraciones. k = 3775
# Backtracking está consumiendo todas las iteraciones. k = 3777
# Backtracking está consumiendo todas las iteraciones. k = 3779
# Backtracking está consumiendo todas las iteraciones. k = 3802
# Backtracking está consumiendo todas las iteraciones. k = 3804
# Backtracking está consumiendo todas las iteraciones. k = 3806
# Backtracking está consumiendo todas las iteraciones. k = 3808
# Backtracking está consumiendo todas las iteraciones. k = 3810
# Backtracking está consumiendo todas las iteraciones. k = 3837
# Backtracking está consumiendo todas las iteraciones. k = 3839
# Backtracking está consumiendo todas las iteraciones. k = 3841
# Backtracking está consumiendo todas las iteraciones. k = 3843
# Backtracking está consumiendo todas las iteraciones. k = 3845
# Backtracking está consumiendo todas las iteraciones. k = 3874
# Backtracking está consumiendo todas las iteraciones. k = 3876
# Backtracking está consumiendo todas las iteraciones. k = 3878
# Backtracking está consumiendo todas las iteraciones. k = 3880
# Backtracking está consumiendo todas las iteraciones. k = 3882
# Backtracking está consumiendo todas las iteraciones. k = 3905
# Backtracking está consumiendo todas las iteraciones. k = 3907
# Backtracking está consumiendo todas las iteraciones. k = 3909
# Backtracking está consumiendo todas las iteraciones. k = 3911
# Backtracking está consumiendo todas las iteraciones. k = 3934
# Backtracking está consumiendo todas las iteraciones. k = 3936
# Backtracking está consumiendo todas las iteraciones. k = 3938
# Backtracking está consumiendo todas las iteraciones. k = 3940
# Backtracking está consumiendo todas las iteraciones. k = 3942
# Backtracking está consumiendo todas las iteraciones. k = 3969
# Backtracking está consumiendo todas las iteraciones. k = 3971
# Backtracking está consumiendo todas las iteraciones. k = 3973
# Backtracking está consumiendo todas las iteraciones. k = 3975
# Backtracking está consumiendo todas las iteraciones. k = 3977
# Backtracking está consumiendo todas las iteraciones. k = 4006
# Backtracking está consumiendo todas las iteraciones. k = 4008
# Backtracking está consumiendo todas las iteraciones. k = 4010
# Backtracking está consumiendo todas las iteraciones. k = 4012
# Backtracking está consumiendo todas las iteraciones. k = 4014
# Backtracking está consumiendo todas las iteraciones. k = 4037
# Backtracking está consumiendo todas las iteraciones. k = 4039
# Backtracking está consumiendo todas las iteraciones. k = 4041
# Backtracking está consumiendo todas las iteraciones. k = 4043
# Backtracking está consumiendo todas las iteraciones. k = 4066
# Backtracking está consumiendo todas las iteraciones. k = 4068
# Backtracking está consumiendo todas las iteraciones. k = 4070
# Backtracking está consumiendo todas las iteraciones. k = 4072
# Backtracking está consumiendo todas las iteraciones. k = 4074
# Backtracking está consumiendo todas las iteraciones. k = 4101
# Backtracking está consumiendo todas las iteraciones. k = 4103
# Backtracking está consumiendo todas las iteraciones. k = 4105
# Backtracking está consumiendo todas las iteraciones. k = 4107
# Backtracking está consumiendo todas las iteraciones. k = 4130
# Backtracking está consumiendo todas las iteraciones. k = 4132
# Backtracking está consumiendo todas las iteraciones. k = 4134
# Backtracking está consumiendo todas las iteraciones. k = 4136
# Backtracking está consumiendo todas las iteraciones. k = 4138
# Backtracking está consumiendo todas las iteraciones. k = 4161
# Backtracking está consumiendo todas las iteraciones. k = 4163
# Backtracking está consumiendo todas las iteraciones. k = 4165
# Backtracking está consumiendo todas las iteraciones. k = 4167
# Backtracking está consumiendo todas las iteraciones. k = 4190
# Backtracking está consumiendo todas las iteraciones. k = 4192
# Backtracking está consumiendo todas las iteraciones. k = 4194
# Backtracking está consumiendo todas las iteraciones. k = 4196
# Backtracking está consumiendo todas las iteraciones. k = 4198
# Backtracking está consumiendo todas las iteraciones. k = 4225
# Backtracking está consumiendo todas las iteraciones. k = 4227
# Backtracking está consumiendo todas las iteraciones. k = 4229
# Backtracking está consumiendo todas las iteraciones. k = 4231
# Backtracking está consumiendo todas las iteraciones. k = 4233
# Backtracking está consumiendo todas las iteraciones. k = 4262
# Backtracking está consumiendo todas las iteraciones. k = 4264
# Backtracking está consumiendo todas las iteraciones. k = 4266
# Backtracking está consumiendo todas las iteraciones. k = 4268
# Backtracking está consumiendo todas las iteraciones. k = 4270
# Backtracking está consumiendo todas las iteraciones. k = 4297
# Backtracking está consumiendo todas las iteraciones. k = 4299
# Backtracking está consumiendo todas las iteraciones. k = 4301
# Backtracking está consumiendo todas las iteraciones. k = 4303
# Backtracking está consumiendo todas las iteraciones. k = 4326
# Backtracking está consumiendo todas las iteraciones. k = 4328
# Backtracking está consumiendo todas las iteraciones. k = 4330
# Backtracking está consumiendo todas las iteraciones. k = 4332
# Backtracking está consumiendo todas las iteraciones. k = 4334
# Backtracking está consumiendo todas las iteraciones. k = 4357
# Backtracking está consumiendo todas las iteraciones. k = 4359
# Backtracking está consumiendo todas las iteraciones. k = 4361
# Backtracking está consumiendo todas las iteraciones. k = 4363
# Backtracking está consumiendo todas las iteraciones. k = 4386
# Backtracking está consumiendo todas las iteraciones. k = 4388
# Backtracking está consumiendo todas las iteraciones. k = 4390
# Backtracking está consumiendo todas las iteraciones. k = 4392
# Backtracking está consumiendo todas las iteraciones. k = 4394
# Backtracking está consumiendo todas las iteraciones. k = 4421
# Backtracking está consumiendo todas las iteraciones. k = 4423
# Backtracking está consumiendo todas las iteraciones. k = 4425
# Backtracking está consumiendo todas las iteraciones. k = 4427
# Backtracking está consumiendo todas las iteraciones. k = 4450
# Backtracking está consumiendo todas las iteraciones. k = 4452
# Backtracking está consumiendo todas las iteraciones. k = 4454
# Backtracking está consumiendo todas las iteraciones. k = 4456
# Backtracking está consumiendo todas las iteraciones. k = 4458
# Backtracking está consumiendo todas las iteraciones. k = 4481
# Backtracking está consumiendo todas las iteraciones. k = 4483
# Backtracking está consumiendo todas las iteraciones. k = 4485
# Backtracking está consumiendo todas las iteraciones. k = 4487
# Backtracking está consumiendo todas las iteraciones. k = 4510
# Backtracking está consumiendo todas las iteraciones. k = 4512
# Backtracking está consumiendo todas las iteraciones. k = 4514
# Backtracking está consumiendo todas las iteraciones. k = 4516
# Backtracking está consumiendo todas las iteraciones. k = 4518
# Backtracking está consumiendo todas las iteraciones. k = 4545
# Backtracking está consumiendo todas las iteraciones. k = 4547
# Backtracking está consumiendo todas las iteraciones. k = 4549
# Backtracking está consumiendo todas las iteraciones. k = 4551
# Backtracking está consumiendo todas las iteraciones. k = 4574
# Backtracking está consumiendo todas las iteraciones. k = 4576
# Backtracking está consumiendo todas las iteraciones. k = 4578
# Backtracking está consumiendo todas las iteraciones. k = 4580
# Backtracking está consumiendo todas las iteraciones. k = 4582
# Backtracking está consumiendo todas las iteraciones. k = 4609
# Backtracking está consumiendo todas las iteraciones. k = 4611
# Backtracking está consumiendo todas las iteraciones. k = 4613
# Backtracking está consumiendo todas las iteraciones. k = 4615
# Backtracking está consumiendo todas las iteraciones. k = 4638
# Backtracking está consumiendo todas las iteraciones. k = 4640
# Backtracking está consumiendo todas las iteraciones. k = 4642
# Backtracking está consumiendo todas las iteraciones. k = 4644
# Backtracking está consumiendo todas las iteraciones. k = 4646
# Backtracking está consumiendo todas las iteraciones. k = 4669
# Backtracking está consumiendo todas las iteraciones. k = 4671
# Backtracking está consumiendo todas las iteraciones. k = 4673
# Backtracking está consumiendo todas las iteraciones. k = 4675
# Backtracking está consumiendo todas las iteraciones. k = 4698
# Backtracking está consumiendo todas las iteraciones. k = 4700
# Backtracking está consumiendo todas las iteraciones. k = 4702
# Backtracking está consumiendo todas las iteraciones. k = 4704
# Backtracking está consumiendo todas las iteraciones. k = 4706
# Backtracking está consumiendo todas las iteraciones. k = 4733
# Backtracking está consumiendo todas las iteraciones. k = 4735
# Backtracking está consumiendo todas las iteraciones. k = 4737
# Backtracking está consumiendo todas las iteraciones. k = 4739
# Backtracking está consumiendo todas las iteraciones. k = 4762
# Backtracking está consumiendo todas las iteraciones. k = 4764
# Backtracking está consumiendo todas las iteraciones. k = 4766
# Backtracking está consumiendo todas las iteraciones. k = 4768
# Backtracking está consumiendo todas las iteraciones. k = 4770
# Backtracking está consumiendo todas las iteraciones. k = 4797
# Backtracking está consumiendo todas las iteraciones. k = 4799
# Backtracking está consumiendo todas las iteraciones. k = 4801
# Backtracking está consumiendo todas las iteraciones. k = 4803
# Backtracking está consumiendo todas las iteraciones. k = 4826
# Backtracking está consumiendo todas las iteraciones. k = 4828
# Backtracking está consumiendo todas las iteraciones. k = 4830
# Backtracking está consumiendo todas las iteraciones. k = 4832
# Backtracking está consumiendo todas las iteraciones. k = 4834
# Backtracking está consumiendo todas las iteraciones. k = 4861
# Backtracking está consumiendo todas las iteraciones. k = 4863
# Backtracking está consumiendo todas las iteraciones. k = 4865
# Backtracking está consumiendo todas las iteraciones. k = 4867
# Backtracking está consumiendo todas las iteraciones. k = 4890
# Backtracking está consumiendo todas las iteraciones. k = 4892
# Backtracking está consumiendo todas las iteraciones. k = 4894
# Backtracking está consumiendo todas las iteraciones. k = 4896
# Backtracking está consumiendo todas las iteraciones. k = 4898
# Backtracking está consumiendo todas las iteraciones. k = 4925
# Backtracking está consumiendo todas las iteraciones. k = 4927
# Backtracking está consumiendo todas las iteraciones. k = 4929
# Backtracking está consumiendo todas las iteraciones. k = 4931
# Backtracking está consumiendo todas las iteraciones. k = 4954
# Backtracking está consumiendo todas las iteraciones. k = 4956
# Backtracking está consumiendo todas las iteraciones. k = 4958
# Backtracking está consumiendo todas las iteraciones. k = 4960
# Backtracking está consumiendo todas las iteraciones. k = 4962
# Backtracking está consumiendo todas las iteraciones. k = 4989
# Backtracking está consumiendo todas las iteraciones. k = 4991
# Backtracking está consumiendo todas las iteraciones. k = 4993
# Backtracking está consumiendo todas las iteraciones. k = 4995
# Dimension: 2
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 5000
# La solución alcanzada es:  [1.00002802 1.0000563 ] ... [1.00002802 1.0000563 ]
# f(xk)=7.91905382065622e-10
# f(x0)=24.199999999999996
# La norma del gradiente final es: 6.996835096014605e-05
# Número de reinicios:  4248

# %%
# con rosen
x010 = np.ones(20)
for i in range(0, 20, 2):
    x010[i] = -1.2
sol10 = nonlinear_grad_conj(rosenbrock, Grad_rosenbrock, x010, a0, maxIter, np.sqrt(20)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol10, rosenbrock, x010)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 54
# Backtracking está consumiendo todas las iteraciones. k = 161
# Backtracking está consumiendo todas las iteraciones. k = 173
# Backtracking está consumiendo todas las iteraciones. k = 222
# Backtracking está consumiendo todas las iteraciones. k = 238
# Backtracking está consumiendo todas las iteraciones. k = 250
# Backtracking está consumiendo todas las iteraciones. k = 255
# Backtracking está consumiendo todas las iteraciones. k = 272
# Backtracking está consumiendo todas las iteraciones. k = 288
# Backtracking está consumiendo todas las iteraciones. k = 304
# Backtracking está consumiendo todas las iteraciones. k = 320
# Backtracking está consumiendo todas las iteraciones. k = 340
# Backtracking está consumiendo todas las iteraciones. k = 360
# Backtracking está consumiendo todas las iteraciones. k = 369
# Backtracking está consumiendo todas las iteraciones. k = 378
# Backtracking está consumiendo todas las iteraciones. k = 383
# Backtracking está consumiendo todas las iteraciones. k = 403
# Backtracking está consumiendo todas las iteraciones. k = 412
# Backtracking está consumiendo todas las iteraciones. k = 429
# Backtracking está consumiendo todas las iteraciones. k = 434
# Backtracking está consumiendo todas las iteraciones. k = 443
# Backtracking está consumiendo todas las iteraciones. k = 468
# Backtracking está consumiendo todas las iteraciones. k = 473
# Backtracking está consumiendo todas las iteraciones. k = 482
# Backtracking está consumiendo todas las iteraciones. k = 492
# Backtracking está consumiendo todas las iteraciones. k = 519
# Dimension: 20
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 810
# La solución alcanzada es:  [1.         1.00000001 1.00000001 1.00000001] ... [0.99999989 0.99999977 0.99999952 0.99999903]
# f(xk)=1.1884710583585588e-12
# f(x0)=4597.999999999999
# La norma del gradiente final es: 2.676452149090309e-05
# Número de reinicios:  671

# %%
# con rosen
x011 = np.ones(40)
for i in range(0, 40, 2):
    x011[i] = -1.2
sol11 = nonlinear_grad_conj(rosenbrock, Grad_rosenbrock, x011, a0, maxIter, np.sqrt(40)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol11, rosenbrock, x011)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 71
# Backtracking está consumiendo todas las iteraciones. k = 158
# Backtracking está consumiendo todas las iteraciones. k = 252
# Backtracking está consumiendo todas las iteraciones. k = 257
# Backtracking está consumiendo todas las iteraciones. k = 278
# Backtracking está consumiendo todas las iteraciones. k = 298
# Backtracking está consumiendo todas las iteraciones. k = 303
# Backtracking está consumiendo todas las iteraciones. k = 313
# Backtracking está consumiendo todas las iteraciones. k = 335
# Backtracking está consumiendo todas las iteraciones. k = 340
# Backtracking está consumiendo todas las iteraciones. k = 349
# Backtracking está consumiendo todas las iteraciones. k = 379
# Backtracking está consumiendo todas las iteraciones. k = 384
# Backtracking está consumiendo todas las iteraciones. k = 412
# Backtracking está consumiendo todas las iteraciones. k = 417
# Backtracking está consumiendo todas las iteraciones. k = 422
# Backtracking está consumiendo todas las iteraciones. k = 431
# Backtracking está consumiendo todas las iteraciones. k = 460
# Backtracking está consumiendo todas las iteraciones. k = 465
# Backtracking está consumiendo todas las iteraciones. k = 470
# Backtracking está consumiendo todas las iteraciones. k = 479
# Backtracking está consumiendo todas las iteraciones. k = 489
# Backtracking está consumiendo todas las iteraciones. k = 554
# Backtracking está consumiendo todas las iteraciones. k = 559
# Backtracking está consumiendo todas las iteraciones. k = 564
# Backtracking está consumiendo todas las iteraciones. k = 569
# Backtracking está consumiendo todas las iteraciones. k = 574
# Backtracking está consumiendo todas las iteraciones. k = 579
# Backtracking está consumiendo todas las iteraciones. k = 584
# Backtracking está consumiendo todas las iteraciones. k = 589
# Backtracking está consumiendo todas las iteraciones. k = 594
# Backtracking está consumiendo todas las iteraciones. k = 599
# Backtracking está consumiendo todas las iteraciones. k = 604
# Backtracking está consumiendo todas las iteraciones. k = 609
# Backtracking está consumiendo todas las iteraciones. k = 614
# Backtracking está consumiendo todas las iteraciones. k = 619
# Backtracking está consumiendo todas las iteraciones. k = 624
# Backtracking está consumiendo todas las iteraciones. k = 629
# Backtracking está consumiendo todas las iteraciones. k = 634
# Backtracking está consumiendo todas las iteraciones. k = 639
# Backtracking está consumiendo todas las iteraciones. k = 644
# Backtracking está consumiendo todas las iteraciones. k = 649
# Backtracking está consumiendo todas las iteraciones. k = 727
# Backtracking está consumiendo todas las iteraciones. k = 757
# Backtracking está consumiendo todas las iteraciones. k = 779
# Backtracking está consumiendo todas las iteraciones. k = 797
# Backtracking está consumiendo todas las iteraciones. k = 811
# Backtracking está consumiendo todas las iteraciones. k = 825
# Backtracking está consumiendo todas las iteraciones. k = 839
# Backtracking está consumiendo todas las iteraciones. k = 849
# Backtracking está consumiendo todas las iteraciones. k = 859
# Backtracking está consumiendo todas las iteraciones. k = 869
# Backtracking está consumiendo todas las iteraciones. k = 879
# Backtracking está consumiendo todas las iteraciones. k = 889
# Backtracking está consumiendo todas las iteraciones. k = 911
# Backtracking está consumiendo todas las iteraciones. k = 921
# Backtracking está consumiendo todas las iteraciones. k = 931
# Backtracking está consumiendo todas las iteraciones. k = 949
# Backtracking está consumiendo todas las iteraciones. k = 959
# Backtracking está consumiendo todas las iteraciones. k = 969
# Backtracking está consumiendo todas las iteraciones. k = 992
# Backtracking está consumiendo todas las iteraciones. k = 1002
# Backtracking está consumiendo todas las iteraciones. k = 1012
# Backtracking está consumiendo todas las iteraciones. k = 1030
# Backtracking está consumiendo todas las iteraciones. k = 1040
# Backtracking está consumiendo todas las iteraciones. k = 1049
# Backtracking está consumiendo todas las iteraciones. k = 1067
# Backtracking está consumiendo todas las iteraciones. k = 1077
# Backtracking está consumiendo todas las iteraciones. k = 1086
# Backtracking está consumiendo todas las iteraciones. k = 1108
# Backtracking está consumiendo todas las iteraciones. k = 1118
# Backtracking está consumiendo todas las iteraciones. k = 1136
# Backtracking está consumiendo todas las iteraciones. k = 1146
# Backtracking está consumiendo todas las iteraciones. k = 1164
# Backtracking está consumiendo todas las iteraciones. k = 1174
# Backtracking está consumiendo todas las iteraciones. k = 1193
# Backtracking está consumiendo todas las iteraciones. k = 1203
# Backtracking está consumiendo todas las iteraciones. k = 1217
# Backtracking está consumiendo todas las iteraciones. k = 1227
# Backtracking está consumiendo todas las iteraciones. k = 1237
# Backtracking está consumiendo todas las iteraciones. k = 1251
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1275
# Backtracking está consumiendo todas las iteraciones. k = 1285
# Backtracking está consumiendo todas las iteraciones. k = 1299
# Backtracking está consumiendo todas las iteraciones. k = 1318
# Backtracking está consumiendo todas las iteraciones. k = 1337
# Backtracking está consumiendo todas las iteraciones. k = 1347
# Backtracking está consumiendo todas las iteraciones. k = 1362
# Backtracking está consumiendo todas las iteraciones. k = 1372
# Backtracking está consumiendo todas las iteraciones. k = 1381
# Backtracking está consumiendo todas las iteraciones. k = 1395
# Backtracking está consumiendo todas las iteraciones. k = 1410
# Backtracking está consumiendo todas las iteraciones. k = 1420
# Backtracking está consumiendo todas las iteraciones. k = 1434
# Backtracking está consumiendo todas las iteraciones. k = 1444
# Backtracking está consumiendo todas las iteraciones. k = 1458
# Backtracking está consumiendo todas las iteraciones. k = 1477
# Backtracking está consumiendo todas las iteraciones. k = 1496
# Backtracking está consumiendo todas las iteraciones. k = 1506
# Backtracking está consumiendo todas las iteraciones. k = 1520
# Backtracking está consumiendo todas las iteraciones. k = 1535
# Backtracking está consumiendo todas las iteraciones. k = 1545
# Backtracking está consumiendo todas las iteraciones. k = 1559
# Backtracking está consumiendo todas las iteraciones. k = 1569
# Backtracking está consumiendo todas las iteraciones. k = 1579
# Backtracking está consumiendo todas las iteraciones. k = 1589
# Backtracking está consumiendo todas las iteraciones. k = 1603
# Backtracking está consumiendo todas las iteraciones. k = 1618
# Backtracking está consumiendo todas las iteraciones. k = 1628
# Backtracking está consumiendo todas las iteraciones. k = 1638
# Backtracking está consumiendo todas las iteraciones. k = 1648
# Backtracking está consumiendo todas las iteraciones. k = 1662
# Backtracking está consumiendo todas las iteraciones. k = 1677
# Backtracking está consumiendo todas las iteraciones. k = 1687
# Backtracking está consumiendo todas las iteraciones. k = 1705
# Backtracking está consumiendo todas las iteraciones. k = 1724
# Backtracking está consumiendo todas las iteraciones. k = 1739
# Backtracking está consumiendo todas las iteraciones. k = 1758
# Backtracking está consumiendo todas las iteraciones. k = 1773
# Backtracking está consumiendo todas las iteraciones. k = 1788
# Backtracking está consumiendo todas las iteraciones. k = 1798
# Backtracking está consumiendo todas las iteraciones. k = 1808
# Backtracking está consumiendo todas las iteraciones. k = 1827
# Backtracking está consumiendo todas las iteraciones. k = 1842
# Backtracking está consumiendo todas las iteraciones. k = 1857
# Backtracking está consumiendo todas las iteraciones. k = 1866
# Backtracking está consumiendo todas las iteraciones. k = 1880
# Backtracking está consumiendo todas las iteraciones. k = 1895
# Backtracking está consumiendo todas las iteraciones. k = 1914
# Backtracking está consumiendo todas las iteraciones. k = 1929
# Backtracking está consumiendo todas las iteraciones. k = 1944
# Backtracking está consumiendo todas las iteraciones. k = 1954
# Backtracking está consumiendo todas las iteraciones. k = 1968
# Backtracking está consumiendo todas las iteraciones. k = 1977
# Backtracking está consumiendo todas las iteraciones. k = 1987
# Backtracking está consumiendo todas las iteraciones. k = 2006
# Backtracking está consumiendo todas las iteraciones. k = 2021
# Backtracking está consumiendo todas las iteraciones. k = 2036
# Backtracking está consumiendo todas las iteraciones. k = 2045
# Backtracking está consumiendo todas las iteraciones. k = 2055
# Backtracking está consumiendo todas las iteraciones. k = 2070
# Backtracking está consumiendo todas las iteraciones. k = 2080
# Backtracking está consumiendo todas las iteraciones. k = 2090
# Backtracking está consumiendo todas las iteraciones. k = 2105
# Backtracking está consumiendo todas las iteraciones. k = 2120
# Backtracking está consumiendo todas las iteraciones. k = 2135
# Backtracking está consumiendo todas las iteraciones. k = 2144
# Backtracking está consumiendo todas las iteraciones. k = 2154
# Backtracking está consumiendo todas las iteraciones. k = 2169
# Backtracking está consumiendo todas las iteraciones. k = 2179
# Backtracking está consumiendo todas las iteraciones. k = 2189
# Backtracking está consumiendo todas las iteraciones. k = 2204
# Backtracking está consumiendo todas las iteraciones. k = 2214
# Backtracking está consumiendo todas las iteraciones. k = 2224
# Backtracking está consumiendo todas las iteraciones. k = 2234
# Backtracking está consumiendo todas las iteraciones. k = 2244
# Backtracking está consumiendo todas las iteraciones. k = 2259
# Backtracking está consumiendo todas las iteraciones. k = 2268
# Backtracking está consumiendo todas las iteraciones. k = 2278
# Backtracking está consumiendo todas las iteraciones. k = 2293
# Backtracking está consumiendo todas las iteraciones. k = 2303
# Backtracking está consumiendo todas las iteraciones. k = 2313
# Backtracking está consumiendo todas las iteraciones. k = 2323
# Backtracking está consumiendo todas las iteraciones. k = 2333
# Backtracking está consumiendo todas las iteraciones. k = 2344
# Backtracking está consumiendo todas las iteraciones. k = 2359
# Backtracking está consumiendo todas las iteraciones. k = 2374
# Backtracking está consumiendo todas las iteraciones. k = 2389
# Backtracking está consumiendo todas las iteraciones. k = 2400
# Backtracking está consumiendo todas las iteraciones. k = 2415
# Dimension: 40
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 2742
# La solución alcanzada es:  [1.         1.00000001 1.00000001 1.00000001] ... [0.99999834 0.9999967  0.99999341 0.9999868 ]
# f(xk)=5.902678837484547e-11
# f(x0)=9680.0
# La norma del gradiente final es: 3.7214792621553013e-05
# Número de reinicios:  2338

# %% [markdown]
# ```
#
#
# ```
# ---

# %% [markdown]
# ## Ejercicio 3 (3.5 puntos)
#
# Programar el método de gradiente conjugado no lineal de usando la fórmula de
# Hestenes-Stiefel:
#
# En este caso el algoritmo es igual al del Ejercicio 2, con excepción del cálculo de $\beta_{k+1}$. Primero se calcula el vector $\mathbf{y}_k$ y luego $\beta_{k+1}$:
#
# $$ \mathbf{y}_k =  \nabla f_{k+1}-\nabla f_{k} $$
# $$ \beta_{k+1} =   \frac{\nabla f_{k+1}^\top\mathbf{y}_k }{\nabla p_{k}^\top\mathbf{y}_k}  $$
#
# 1. Repita el Ejercicio 2 usando la fórmula de Hestenes-Stiefel.
# 2. ¿Hay alguna diferencia que indique que es mejor usar la fórmula de Hestenes-Stiefel
#    respesto a Fletcher-Reeves?
# 3. La cantidad de reinicios puede indicar que tanto se comporta el algoritmo
#    como el algoritmo de descenso máximo. Agregue un comentario sobre esto
#    de acuerdo a los resultados obtenidos para cada fórmula.
#
# ### Solución:

# %%
# escribimos la función
def nonlinear_grad_conj1(f, grad, x0, a0, maxIter, tol, c1, c2, r, maxIter2):
    xk = x0
    gk = grad(xk)
    dk = -gk
    ak = a0
    nr = 0
    for k in range(maxIter):
        if np.linalg.norm(gk) < tol:
            return xk, gk, k, True, nr
        z = backtracking(a0, r, c1, c2, xk, f, grad, dk, maxIter2)
        if z[-1]==False:
            print("Backtracking está consumiendo todas las iteraciones. k =",k)
        ak = z[0]
        xk = xk + ak*dk
        gk1 = grad(xk)
        yk = gk1 - gk
        if np.abs(np.dot(gk1,gk)) < 0.2*np.dot(gk1, gk1):
            bk = np.dot(gk1, yk) / np.dot(yk, dk)
        else:
            bk = 0
            nr += 1
        dk = -gk1 + bk*dk
        gk = gk1
    return xk, gk, maxIter, False, nr

# %%
#probemos con la forma cuadratica, y el primer tipo de matriz con la primer dimension
sol1 = nonlinear_grad_conj1(lambda x: quadratic(x, A1, b1),
                           lambda x: Grad_quadratic(x, A1, b1),
                           np.zeros(n[0]), a0, maxIter, np.sqrt(n[0])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol1, lambda x: quadratic(x, A1, b1), np.zeros(n[0]))
# Out:
# Dimension: 10
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 9
# La solución alcanzada es:  [0.05000019 0.05000019 0.05000019 0.05000019] ... [0.05000019 0.05000019 0.05000019 0.05000019]
# f(xk)=-0.24999999999636202
# f(x0)=0.0
# La norma del gradiente final es: 1.206313194339134e-05
# Número de reinicios:  9

# %%
#probemos con la segunda dimension
sol2 = nonlinear_grad_conj1(lambda x: quadratic(x, A2, b2),
                           lambda x: Grad_quadratic(x, A2, b2),
                           np.zeros(n[1]), a0, maxIter, np.sqrt(n[1])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol2, lambda x: quadratic(x, A2, b2), np.zeros(n[1]))
# Out:
# Dimension: 100
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 21
# La solución alcanzada es:  [0.00500003 0.00500003 0.00500003 0.00500003] ... [0.00500003 0.00500003 0.00500003 0.00500003]
# f(xk)=-0.24999999999200045
# f(x0)=0.0
# La norma del gradiente final es: 5.656829153792843e-05
# Número de reinicios:  21

# %%
# con la tercer dimension
sol3 = nonlinear_grad_conj1(lambda x: quadratic(x, A3, b3),
                           lambda x: Grad_quadratic(x, A3, b3),
                           np.zeros(n[2]), a0, maxIter, np.sqrt(n[2])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol3, lambda x: quadratic(x, A3, b3), np.zeros(n[2]))
# Out:
# Dimension: 1000
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 251
# La solución alcanzada es:  [0.0005 0.0005 0.0005 0.0005] ... [0.0005 0.0005 0.0005 0.0005]
# f(xk)=-0.24999999999146555
# f(x0)=0.0
# La norma del gradiente final es: 0.00018476304776620826
# Número de reinicios:  251

# %%
# con la segunda matriz y la primer dimensión
sol4 = nonlinear_grad_conj1(lambda x: quadratic(x, A4, b4),
                           lambda x: Grad_quadratic(x, A4, b4),
                           np.zeros(n[0]), a0, maxIter, np.sqrt(n[0])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol4, lambda x: quadratic(x, A4, b4), np.zeros(n[0]))
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 12
# Backtracking está consumiendo todas las iteraciones. k = 20
# Backtracking está consumiendo todas las iteraciones. k = 22
# Backtracking está consumiendo todas las iteraciones. k = 25
# Backtracking está consumiendo todas las iteraciones. k = 27
# Backtracking está consumiendo todas las iteraciones. k = 43
# Backtracking está consumiendo todas las iteraciones. k = 45
# Backtracking está consumiendo todas las iteraciones. k = 48
# Backtracking está consumiendo todas las iteraciones. k = 50
# Backtracking está consumiendo todas las iteraciones. k = 53
# Backtracking está consumiendo todas las iteraciones. k = 55
# Backtracking está consumiendo todas las iteraciones. k = 58
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 63
# Backtracking está consumiendo todas las iteraciones. k = 65
# Backtracking está consumiendo todas las iteraciones. k = 68
# Backtracking está consumiendo todas las iteraciones. k = 70
# Backtracking está consumiendo todas las iteraciones. k = 73
# Backtracking está consumiendo todas las iteraciones. k = 75
# Backtracking está consumiendo todas las iteraciones. k = 78
# Backtracking está consumiendo todas las iteraciones. k = 80
# Backtracking está consumiendo todas las iteraciones. k = 83
# Backtracking está consumiendo todas las iteraciones. k = 85
# Backtracking está consumiendo todas las iteraciones. k = 88
# Backtracking está consumiendo todas las iteraciones. k = 90
# Backtracking está consumiendo todas las iteraciones. k = 93
# Backtracking está consumiendo todas las iteraciones. k = 95
# Backtracking está consumiendo todas las iteraciones. k = 194
# Backtracking está consumiendo todas las iteraciones. k = 198
# Backtracking está consumiendo todas las iteraciones. k = 202
# Backtracking está consumiendo todas las iteraciones. k = 206
# Backtracking está consumiendo todas las iteraciones. k = 209
# Backtracking está consumiendo todas las iteraciones. k = 211
# Backtracking está consumiendo todas las iteraciones. k = 214
# Backtracking está consumiendo todas las iteraciones. k = 216
# Backtracking está consumiendo todas las iteraciones. k = 219
# Backtracking está consumiendo todas las iteraciones. k = 221
# Backtracking está consumiendo todas las iteraciones. k = 224
# Backtracking está consumiendo todas las iteraciones. k = 226
# Backtracking está consumiendo todas las iteraciones. k = 229
# Backtracking está consumiendo todas las iteraciones. k = 231
# Backtracking está consumiendo todas las iteraciones. k = 234
# Backtracking está consumiendo todas las iteraciones. k = 236
# Backtracking está consumiendo todas las iteraciones. k = 239
# Backtracking está consumiendo todas las iteraciones. k = 241
# Backtracking está consumiendo todas las iteraciones. k = 244
# Backtracking está consumiendo todas las iteraciones. k = 246
# Backtracking está consumiendo todas las iteraciones. k = 249
# Backtracking está consumiendo todas las iteraciones. k = 251
# Backtracking está consumiendo todas las iteraciones. k = 254
# Backtracking está consumiendo todas las iteraciones. k = 256
# Backtracking está consumiendo todas las iteraciones. k = 259
# Backtracking está consumiendo todas las iteraciones. k = 261
# Backtracking está consumiendo todas las iteraciones. k = 264
# Backtracking está consumiendo todas las iteraciones. k = 266
# Backtracking está consumiendo todas las iteraciones. k = 269
# Backtracking está consumiendo todas las iteraciones. k = 271
# Backtracking está consumiendo todas las iteraciones. k = 274
# Backtracking está consumiendo todas las iteraciones. k = 276
# Backtracking está consumiendo todas las iteraciones. k = 279
# Backtracking está consumiendo todas las iteraciones. k = 281
# Backtracking está consumiendo todas las iteraciones. k = 284
# Backtracking está consumiendo todas las iteraciones. k = 286
# Backtracking está consumiendo todas las iteraciones. k = 289
# Backtracking está consumiendo todas las iteraciones. k = 291
# Backtracking está consumiendo todas las iteraciones. k = 294
# Backtracking está consumiendo todas las iteraciones. k = 296
# Backtracking está consumiendo todas las iteraciones. k = 299
# Backtracking está consumiendo todas las iteraciones. k = 301
# Backtracking está consumiendo todas las iteraciones. k = 304
# Backtracking está consumiendo todas las iteraciones. k = 306
# Backtracking está consumiendo todas las iteraciones. k = 309
# Backtracking está consumiendo todas las iteraciones. k = 311
# Backtracking está consumiendo todas las iteraciones. k = 407
# Backtracking está consumiendo todas las iteraciones. k = 411
# Backtracking está consumiendo todas las iteraciones. k = 415
# Backtracking está consumiendo todas las iteraciones. k = 419
# Backtracking está consumiendo todas las iteraciones. k = 422
# Backtracking está consumiendo todas las iteraciones. k = 424
# Backtracking está consumiendo todas las iteraciones. k = 427
# Backtracking está consumiendo todas las iteraciones. k = 429
# Backtracking está consumiendo todas las iteraciones. k = 432
# Backtracking está consumiendo todas las iteraciones. k = 434
# Backtracking está consumiendo todas las iteraciones. k = 437
# Backtracking está consumiendo todas las iteraciones. k = 439
# Backtracking está consumiendo todas las iteraciones. k = 442
# Backtracking está consumiendo todas las iteraciones. k = 444
# Backtracking está consumiendo todas las iteraciones. k = 447
# Backtracking está consumiendo todas las iteraciones. k = 449
# Backtracking está consumiendo todas las iteraciones. k = 452
# Backtracking está consumiendo todas las iteraciones. k = 454
# Backtracking está consumiendo todas las iteraciones. k = 457
# Backtracking está consumiendo todas las iteraciones. k = 459
# Backtracking está consumiendo todas las iteraciones. k = 462
# Backtracking está consumiendo todas las iteraciones. k = 464
# Backtracking está consumiendo todas las iteraciones. k = 467
# Backtracking está consumiendo todas las iteraciones. k = 469
# Backtracking está consumiendo todas las iteraciones. k = 472
# Backtracking está consumiendo todas las iteraciones. k = 474
# Backtracking está consumiendo todas las iteraciones. k = 477
# Backtracking está consumiendo todas las iteraciones. k = 479
# Backtracking está consumiendo todas las iteraciones. k = 482
# Backtracking está consumiendo todas las iteraciones. k = 484
# Backtracking está consumiendo todas las iteraciones. k = 487
# Backtracking está consumiendo todas las iteraciones. k = 489
# Backtracking está consumiendo todas las iteraciones. k = 492
# Backtracking está consumiendo todas las iteraciones. k = 494
# Backtracking está consumiendo todas las iteraciones. k = 497
# Backtracking está consumiendo todas las iteraciones. k = 499
# Backtracking está consumiendo todas las iteraciones. k = 502
# Backtracking está consumiendo todas las iteraciones. k = 504
# Backtracking está consumiendo todas las iteraciones. k = 507
# Backtracking está consumiendo todas las iteraciones. k = 509
# Backtracking está consumiendo todas las iteraciones. k = 512
# Backtracking está consumiendo todas las iteraciones. k = 514
# Backtracking está consumiendo todas las iteraciones. k = 517
# Backtracking está consumiendo todas las iteraciones. k = 519
# Backtracking está consumiendo todas las iteraciones. k = 522
# Backtracking está consumiendo todas las iteraciones. k = 524
# Backtracking está consumiendo todas las iteraciones. k = 527
# Backtracking está consumiendo todas las iteraciones. k = 529
# Backtracking está consumiendo todas las iteraciones. k = 625
# Backtracking está consumiendo todas las iteraciones. k = 629
# Backtracking está consumiendo todas las iteraciones. k = 633
# Backtracking está consumiendo todas las iteraciones. k = 637
# Backtracking está consumiendo todas las iteraciones. k = 640
# Backtracking está consumiendo todas las iteraciones. k = 642
# Backtracking está consumiendo todas las iteraciones. k = 645
# Backtracking está consumiendo todas las iteraciones. k = 647
# Backtracking está consumiendo todas las iteraciones. k = 650
# Backtracking está consumiendo todas las iteraciones. k = 652
# Backtracking está consumiendo todas las iteraciones. k = 655
# Backtracking está consumiendo todas las iteraciones. k = 657
# Backtracking está consumiendo todas las iteraciones. k = 660
# Backtracking está consumiendo todas las iteraciones. k = 662
# Backtracking está consumiendo todas las iteraciones. k = 665
# Backtracking está consumiendo todas las iteraciones. k = 667
# Backtracking está consumiendo todas las iteraciones. k = 670
# Backtracking está consumiendo todas las iteraciones. k = 672
# Backtracking está consumiendo todas las iteraciones. k = 675
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 680
# Backtracking está consumiendo todas las iteraciones. k = 682
# Backtracking está consumiendo todas las iteraciones. k = 685
# Backtracking está consumiendo todas las iteraciones. k = 687
# Backtracking está consumiendo todas las iteraciones. k = 690
# Backtracking está consumiendo todas las iteraciones. k = 692
# Backtracking está consumiendo todas las iteraciones. k = 695
# Backtracking está consumiendo todas las iteraciones. k = 697
# Backtracking está consumiendo todas las iteraciones. k = 700
# Backtracking está consumiendo todas las iteraciones. k = 702
# Backtracking está consumiendo todas las iteraciones. k = 705
# Backtracking está consumiendo todas las iteraciones. k = 707
# Backtracking está consumiendo todas las iteraciones. k = 710
# Backtracking está consumiendo todas las iteraciones. k = 712
# Backtracking está consumiendo todas las iteraciones. k = 715
# Backtracking está consumiendo todas las iteraciones. k = 717
# Backtracking está consumiendo todas las iteraciones. k = 720
# Backtracking está consumiendo todas las iteraciones. k = 722
# Backtracking está consumiendo todas las iteraciones. k = 725
# Backtracking está consumiendo todas las iteraciones. k = 727
# Backtracking está consumiendo todas las iteraciones. k = 730
# Backtracking está consumiendo todas las iteraciones. k = 732
# Backtracking está consumiendo todas las iteraciones. k = 735
# Backtracking está consumiendo todas las iteraciones. k = 737
# Backtracking está consumiendo todas las iteraciones. k = 740
# Backtracking está consumiendo todas las iteraciones. k = 742
# Backtracking está consumiendo todas las iteraciones. k = 745
# Backtracking está consumiendo todas las iteraciones. k = 747
# Backtracking está consumiendo todas las iteraciones. k = 843
# Backtracking está consumiendo todas las iteraciones. k = 847
# Backtracking está consumiendo todas las iteraciones. k = 851
# Backtracking está consumiendo todas las iteraciones. k = 855
# Backtracking está consumiendo todas las iteraciones. k = 858
# Backtracking está consumiendo todas las iteraciones. k = 860
# Backtracking está consumiendo todas las iteraciones. k = 863
# Backtracking está consumiendo todas las iteraciones. k = 865
# Backtracking está consumiendo todas las iteraciones. k = 868
# Backtracking está consumiendo todas las iteraciones. k = 870
# Backtracking está consumiendo todas las iteraciones. k = 873
# Backtracking está consumiendo todas las iteraciones. k = 875
# Backtracking está consumiendo todas las iteraciones. k = 878
# Backtracking está consumiendo todas las iteraciones. k = 880
# Backtracking está consumiendo todas las iteraciones. k = 883
# Backtracking está consumiendo todas las iteraciones. k = 885
# Backtracking está consumiendo todas las iteraciones. k = 888
# Backtracking está consumiendo todas las iteraciones. k = 890
# Backtracking está consumiendo todas las iteraciones. k = 893
# Backtracking está consumiendo todas las iteraciones. k = 895
# Backtracking está consumiendo todas las iteraciones. k = 898
# Backtracking está consumiendo todas las iteraciones. k = 900
# Backtracking está consumiendo todas las iteraciones. k = 903
# Backtracking está consumiendo todas las iteraciones. k = 905
# Backtracking está consumiendo todas las iteraciones. k = 908
# Backtracking está consumiendo todas las iteraciones. k = 910
# Backtracking está consumiendo todas las iteraciones. k = 913
# Backtracking está consumiendo todas las iteraciones. k = 915
# Backtracking está consumiendo todas las iteraciones. k = 918
# Backtracking está consumiendo todas las iteraciones. k = 920
# Backtracking está consumiendo todas las iteraciones. k = 923
# Backtracking está consumiendo todas las iteraciones. k = 925
# Backtracking está consumiendo todas las iteraciones. k = 928
# Backtracking está consumiendo todas las iteraciones. k = 930
# Backtracking está consumiendo todas las iteraciones. k = 933
# Backtracking está consumiendo todas las iteraciones. k = 935
# Backtracking está consumiendo todas las iteraciones. k = 938
# Backtracking está consumiendo todas las iteraciones. k = 940
# Backtracking está consumiendo todas las iteraciones. k = 943
# Backtracking está consumiendo todas las iteraciones. k = 945
# Backtracking está consumiendo todas las iteraciones. k = 948
# Backtracking está consumiendo todas las iteraciones. k = 950
# Backtracking está consumiendo todas las iteraciones. k = 953
# Backtracking está consumiendo todas las iteraciones. k = 955
# Backtracking está consumiendo todas las iteraciones. k = 958
# Backtracking está consumiendo todas las iteraciones. k = 960
# Backtracking está consumiendo todas las iteraciones. k = 1059
# Backtracking está consumiendo todas las iteraciones. k = 1063
# Backtracking está consumiendo todas las iteraciones. k = 1067
# Backtracking está consumiendo todas las iteraciones. k = 1070
# Backtracking está consumiendo todas las iteraciones. k = 1072
# Backtracking está consumiendo todas las iteraciones. k = 1075
# Backtracking está consumiendo todas las iteraciones. k = 1077
# Backtracking está consumiendo todas las iteraciones. k = 1080
# Backtracking está consumiendo todas las iteraciones. k = 1082
# Backtracking está consumiendo todas las iteraciones. k = 1085
# Backtracking está consumiendo todas las iteraciones. k = 1087
# Backtracking está consumiendo todas las iteraciones. k = 1090
# Backtracking está consumiendo todas las iteraciones. k = 1092
# Backtracking está consumiendo todas las iteraciones. k = 1095
# Backtracking está consumiendo todas las iteraciones. k = 1097
# Backtracking está consumiendo todas las iteraciones. k = 1100
# Backtracking está consumiendo todas las iteraciones. k = 1102
# Backtracking está consumiendo todas las iteraciones. k = 1105
# Backtracking está consumiendo todas las iteraciones. k = 1107
# Backtracking está consumiendo todas las iteraciones. k = 1110
# Backtracking está consumiendo todas las iteraciones. k = 1112
# Backtracking está consumiendo todas las iteraciones. k = 1115
# Backtracking está consumiendo todas las iteraciones. k = 1117
# Backtracking está consumiendo todas las iteraciones. k = 1120
# Backtracking está consumiendo todas las iteraciones. k = 1122
# Backtracking está consumiendo todas las iteraciones. k = 1125
# Backtracking está consumiendo todas las iteraciones. k = 1127
# Backtracking está consumiendo todas las iteraciones. k = 1130
# Backtracking está consumiendo todas las iteraciones. k = 1132
# Backtracking está consumiendo todas las iteraciones. k = 1135
# Backtracking está consumiendo todas las iteraciones. k = 1137
# Backtracking está consumiendo todas las iteraciones. k = 1140
# Backtracking está consumiendo todas las iteraciones. k = 1142
# Backtracking está consumiendo todas las iteraciones. k = 1145
# Backtracking está consumiendo todas las iteraciones. k = 1147
# Backtracking está consumiendo todas las iteraciones. k = 1150
# Backtracking está consumiendo todas las iteraciones. k = 1152
# Backtracking está consumiendo todas las iteraciones. k = 1155
# Backtracking está consumiendo todas las iteraciones. k = 1157
# Backtracking está consumiendo todas las iteraciones. k = 1160
# Backtracking está consumiendo todas las iteraciones. k = 1162
# Backtracking está consumiendo todas las iteraciones. k = 1165
# Backtracking está consumiendo todas las iteraciones. k = 1167
# Backtracking está consumiendo todas las iteraciones. k = 1170
# Backtracking está consumiendo todas las iteraciones. k = 1172
# Backtracking está consumiendo todas las iteraciones. k = 1175
# Backtracking está consumiendo todas las iteraciones. k = 1177
# Backtracking está consumiendo todas las iteraciones. k = 1273
# Backtracking está consumiendo todas las iteraciones. k = 1277
# Backtracking está consumiendo todas las iteraciones. k = 1281
# Backtracking está consumiendo todas las iteraciones. k = 1285
# Backtracking está consumiendo todas las iteraciones. k = 1288
# Backtracking está consumiendo todas las iteraciones. k = 1290
# Backtracking está consumiendo todas las iteraciones. k = 1293
# Backtracking está consumiendo todas las iteraciones. k = 1295
# Backtracking está consumiendo todas las iteraciones. k = 1298
# Backtracking está consumiendo todas las iteraciones. k = 1300
# Backtracking está consumiendo todas las iteraciones. k = 1303
# Backtracking está consumiendo todas las iteraciones. k = 1305
# Backtracking está consumiendo todas las iteraciones. k = 1308
# Backtracking está consumiendo todas las iteraciones. k = 1310
# Backtracking está consumiendo todas las iteraciones. k = 1313
# Backtracking está consumiendo todas las iteraciones. k = 1315
# Backtracking está consumiendo todas las iteraciones. k = 1318
# Backtracking está consumiendo todas las iteraciones. k = 1320
# Backtracking está consumiendo todas las iteraciones. k = 1323
# Backtracking está consumiendo todas las iteraciones. k = 1325
# Backtracking está consumiendo todas las iteraciones. k = 1328
# Backtracking está consumiendo todas las iteraciones. k = 1330
# Backtracking está consumiendo todas las iteraciones. k = 1333
# Backtracking está consumiendo todas las iteraciones. k = 1335
# Backtracking está consumiendo todas las iteraciones. k = 1338
# Backtracking está consumiendo todas las iteraciones. k = 1340
# Backtracking está consumiendo todas las iteraciones. k = 1343
# Backtracking está consumiendo todas las iteraciones. k = 1345
# Backtracking está consumiendo todas las iteraciones. k = 1348
# Backtracking está consumiendo todas las iteraciones. k = 1350
# Backtracking está consumiendo todas las iteraciones. k = 1353
# Backtracking está consumiendo todas las iteraciones. k = 1355
# Backtracking está consumiendo todas las iteraciones. k = 1358
# Backtracking está consumiendo todas las iteraciones. k = 1360
# Backtracking está consumiendo todas las iteraciones. k = 1363
# Backtracking está consumiendo todas las iteraciones. k = 1365
# Backtracking está consumiendo todas las iteraciones. k = 1368
# Backtracking está consumiendo todas las iteraciones. k = 1370
# Backtracking está consumiendo todas las iteraciones. k = 1373
# Backtracking está consumiendo todas las iteraciones. k = 1375
# Backtracking está consumiendo todas las iteraciones. k = 1378
# Backtracking está consumiendo todas las iteraciones. k = 1380
# Backtracking está consumiendo todas las iteraciones. k = 1383
# Backtracking está consumiendo todas las iteraciones. k = 1385
# Backtracking está consumiendo todas las iteraciones. k = 1388
# Backtracking está consumiendo todas las iteraciones. k = 1390
# Backtracking está consumiendo todas las iteraciones. k = 1393
# Backtracking está consumiendo todas las iteraciones. k = 1395
# Backtracking está consumiendo todas las iteraciones. k = 1491
# Backtracking está consumiendo todas las iteraciones. k = 1495
# Backtracking está consumiendo todas las iteraciones. k = 1499
# Backtracking está consumiendo todas las iteraciones. k = 1503
# Backtracking está consumiendo todas las iteraciones. k = 1506
# Backtracking está consumiendo todas las iteraciones. k = 1508
# Backtracking está consumiendo todas las iteraciones. k = 1511
# Backtracking está consumiendo todas las iteraciones. k = 1513
# Backtracking está consumiendo todas las iteraciones. k = 1516
# Backtracking está consumiendo todas las iteraciones. k = 1518
# Backtracking está consumiendo todas las iteraciones. k = 1521
# Backtracking está consumiendo todas las iteraciones. k = 1523
# Backtracking está consumiendo todas las iteraciones. k = 1526
# Backtracking está consumiendo todas las iteraciones. k = 1528
# Backtracking está consumiendo todas las iteraciones. k = 1531
# Backtracking está consumiendo todas las iteraciones. k = 1533
# Backtracking está consumiendo todas las iteraciones. k = 1536
# Backtracking está consumiendo todas las iteraciones. k = 1538
# Backtracking está consumiendo todas las iteraciones. k = 1541
# Backtracking está consumiendo todas las iteraciones. k = 1543
# Backtracking está consumiendo todas las iteraciones. k = 1546
# Backtracking está consumiendo todas las iteraciones. k = 1548
# Backtracking está consumiendo todas las iteraciones. k = 1551
# Backtracking está consumiendo todas las iteraciones. k = 1553
# Backtracking está consumiendo todas las iteraciones. k = 1556
# Backtracking está consumiendo todas las iteraciones. k = 1558
# Backtracking está consumiendo todas las iteraciones. k = 1561
# Backtracking está consumiendo todas las iteraciones. k = 1563
# Backtracking está consumiendo todas las iteraciones. k = 1566
# Backtracking está consumiendo todas las iteraciones. k = 1568
# Dimension: 10
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 1571
# La solución alcanzada es:  [ 1.36889566 -1.16586292  1.60838905 -0.61279115] ... [-0.61279115  1.60838905 -1.16586292  1.36889566]
# f(xk)=-1.7934207913526616
# f(x0)=0.0
# La norma del gradiente final es: 1.8950483039484323e-05
# Número de reinicios:  1230

# %%
# con la segunda dimension
sol5 = nonlinear_grad_conj1(lambda x: quadratic(x, A5, b5),
                           lambda x: Grad_quadratic(x, A5, b5),
                           np.zeros(n[1]), a0, maxIter, np.sqrt(n[1])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol5, lambda x: quadratic(x, A5, b5), np.zeros(n[1]))
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 20
# Backtracking está consumiendo todas las iteraciones. k = 32
# Backtracking está consumiendo todas las iteraciones. k = 34
# Backtracking está consumiendo todas las iteraciones. k = 39
# Backtracking está consumiendo todas las iteraciones. k = 41
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 66
# Backtracking está consumiendo todas las iteraciones. k = 68
# Backtracking está consumiendo todas las iteraciones. k = 73
# Backtracking está consumiendo todas las iteraciones. k = 75
# Backtracking está consumiendo todas las iteraciones. k = 84
# Backtracking está consumiendo todas las iteraciones. k = 90
# Backtracking está consumiendo todas las iteraciones. k = 96
# Backtracking está consumiendo todas las iteraciones. k = 98
# Backtracking está consumiendo todas las iteraciones. k = 107
# Backtracking está consumiendo todas las iteraciones. k = 113
# Backtracking está consumiendo todas las iteraciones. k = 115
# Backtracking está consumiendo todas las iteraciones. k = 120
# Backtracking está consumiendo todas las iteraciones. k = 122
# Backtracking está consumiendo todas las iteraciones. k = 131
# Backtracking está consumiendo todas las iteraciones. k = 137
# Backtracking está consumiendo todas las iteraciones. k = 139
# Backtracking está consumiendo todas las iteraciones. k = 148
# Backtracking está consumiendo todas las iteraciones. k = 154
# Backtracking está consumiendo todas las iteraciones. k = 156
# Backtracking está consumiendo todas las iteraciones. k = 165
# Backtracking está consumiendo todas las iteraciones. k = 171
# Backtracking está consumiendo todas las iteraciones. k = 173
# Backtracking está consumiendo todas las iteraciones. k = 182
# Backtracking está consumiendo todas las iteraciones. k = 188
# Backtracking está consumiendo todas las iteraciones. k = 190
# Backtracking está consumiendo todas las iteraciones. k = 199
# Backtracking está consumiendo todas las iteraciones. k = 205
# Backtracking está consumiendo todas las iteraciones. k = 207
# Backtracking está consumiendo todas las iteraciones. k = 216
# Backtracking está consumiendo todas las iteraciones. k = 222
# Backtracking está consumiendo todas las iteraciones. k = 224
# Backtracking está consumiendo todas las iteraciones. k = 233
# Backtracking está consumiendo todas las iteraciones. k = 239
# Backtracking está consumiendo todas las iteraciones. k = 241
# Backtracking está consumiendo todas las iteraciones. k = 250
# Backtracking está consumiendo todas las iteraciones. k = 252
# Backtracking está consumiendo todas las iteraciones. k = 257
# Backtracking está consumiendo todas las iteraciones. k = 259
# Backtracking está consumiendo todas las iteraciones. k = 263
# Backtracking está consumiendo todas las iteraciones. k = 269
# Backtracking está consumiendo todas las iteraciones. k = 271
# Backtracking está consumiendo todas las iteraciones. k = 280
# Backtracking está consumiendo todas las iteraciones. k = 286
# Backtracking está consumiendo todas las iteraciones. k = 288
# Backtracking está consumiendo todas las iteraciones. k = 297
# Backtracking está consumiendo todas las iteraciones. k = 303
# Backtracking está consumiendo todas las iteraciones. k = 305
# Backtracking está consumiendo todas las iteraciones. k = 314
# Backtracking está consumiendo todas las iteraciones. k = 316
# Backtracking está consumiendo todas las iteraciones. k = 321
# Backtracking está consumiendo todas las iteraciones. k = 323
# Backtracking está consumiendo todas las iteraciones. k = 327
# Backtracking está consumiendo todas las iteraciones. k = 333
# Backtracking está consumiendo todas las iteraciones. k = 335
# Backtracking está consumiendo todas las iteraciones. k = 344
# Backtracking está consumiendo todas las iteraciones. k = 350
# Backtracking está consumiendo todas las iteraciones. k = 352
# Backtracking está consumiendo todas las iteraciones. k = 361
# Backtracking está consumiendo todas las iteraciones. k = 367
# Backtracking está consumiendo todas las iteraciones. k = 369
# Backtracking está consumiendo todas las iteraciones. k = 378
# Backtracking está consumiendo todas las iteraciones. k = 380
# Backtracking está consumiendo todas las iteraciones. k = 389
# Backtracking está consumiendo todas las iteraciones. k = 395
# Backtracking está consumiendo todas las iteraciones. k = 397
# Backtracking está consumiendo todas las iteraciones. k = 406
# Backtracking está consumiendo todas las iteraciones. k = 412
# Backtracking está consumiendo todas las iteraciones. k = 414
# Backtracking está consumiendo todas las iteraciones. k = 423
# Backtracking está consumiendo todas las iteraciones. k = 425
# Backtracking está consumiendo todas las iteraciones. k = 434
# Backtracking está consumiendo todas las iteraciones. k = 440
# Backtracking está consumiendo todas las iteraciones. k = 442
# Backtracking está consumiendo todas las iteraciones. k = 451
# Backtracking está consumiendo todas las iteraciones. k = 453
# Backtracking está consumiendo todas las iteraciones. k = 458
# Backtracking está consumiendo todas las iteraciones. k = 460
# Backtracking está consumiendo todas las iteraciones. k = 464
# Backtracking está consumiendo todas las iteraciones. k = 470
# Backtracking está consumiendo todas las iteraciones. k = 472
# Backtracking está consumiendo todas las iteraciones. k = 481
# Backtracking está consumiendo todas las iteraciones. k = 487
# Backtracking está consumiendo todas las iteraciones. k = 489
# Backtracking está consumiendo todas las iteraciones. k = 498
# Backtracking está consumiendo todas las iteraciones. k = 500
# Backtracking está consumiendo todas las iteraciones. k = 509
# Backtracking está consumiendo todas las iteraciones. k = 515
# Backtracking está consumiendo todas las iteraciones. k = 517
# Backtracking está consumiendo todas las iteraciones. k = 526
# Backtracking está consumiendo todas las iteraciones. k = 532
# Backtracking está consumiendo todas las iteraciones. k = 534
# Backtracking está consumiendo todas las iteraciones. k = 538
# Backtracking está consumiendo todas las iteraciones. k = 544
# Backtracking está consumiendo todas las iteraciones. k = 546
# Backtracking está consumiendo todas las iteraciones. k = 555
# Backtracking está consumiendo todas las iteraciones. k = 561
# Backtracking está consumiendo todas las iteraciones. k = 563
# Backtracking está consumiendo todas las iteraciones. k = 572
# Backtracking está consumiendo todas las iteraciones. k = 574
# Backtracking está consumiendo todas las iteraciones. k = 583
# Backtracking está consumiendo todas las iteraciones. k = 589
# Backtracking está consumiendo todas las iteraciones. k = 591
# Backtracking está consumiendo todas las iteraciones. k = 600
# Backtracking está consumiendo todas las iteraciones. k = 602
# Backtracking está consumiendo todas las iteraciones. k = 607
# Backtracking está consumiendo todas las iteraciones. k = 609
# Backtracking está consumiendo todas las iteraciones. k = 613
# Backtracking está consumiendo todas las iteraciones. k = 619
# Backtracking está consumiendo todas las iteraciones. k = 621
# Backtracking está consumiendo todas las iteraciones. k = 630
# Backtracking está consumiendo todas las iteraciones. k = 636
# Backtracking está consumiendo todas las iteraciones. k = 638
# Backtracking está consumiendo todas las iteraciones. k = 642
# Backtracking está consumiendo todas las iteraciones. k = 648
# Backtracking está consumiendo todas las iteraciones. k = 650
# Backtracking está consumiendo todas las iteraciones. k = 659
# Backtracking está consumiendo todas las iteraciones. k = 665
# Backtracking está consumiendo todas las iteraciones. k = 667
# Backtracking está consumiendo todas las iteraciones. k = 676
# Backtracking está consumiendo todas las iteraciones. k = 678
# Backtracking está consumiendo todas las iteraciones. k = 687
# Backtracking está consumiendo todas las iteraciones. k = 693
# Backtracking está consumiendo todas las iteraciones. k = 695
# Backtracking está consumiendo todas las iteraciones. k = 704
# Backtracking está consumiendo todas las iteraciones. k = 706
# Backtracking está consumiendo todas las iteraciones. k = 715
# Backtracking está consumiendo todas las iteraciones. k = 721
# Backtracking está consumiendo todas las iteraciones. k = 723
# Backtracking está consumiendo todas las iteraciones. k = 732
# Backtracking está consumiendo todas las iteraciones. k = 734
# Backtracking está consumiendo todas las iteraciones. k = 739
# Backtracking está consumiendo todas las iteraciones. k = 741
# Backtracking está consumiendo todas las iteraciones. k = 745
# Backtracking está consumiendo todas las iteraciones. k = 751
# Backtracking está consumiendo todas las iteraciones. k = 753
# Backtracking está consumiendo todas las iteraciones. k = 762
# Backtracking está consumiendo todas las iteraciones. k = 768
# Backtracking está consumiendo todas las iteraciones. k = 770
# Backtracking está consumiendo todas las iteraciones. k = 774
# Backtracking está consumiendo todas las iteraciones. k = 780
# Backtracking está consumiendo todas las iteraciones. k = 782
# Backtracking está consumiendo todas las iteraciones. k = 791
# Backtracking está consumiendo todas las iteraciones. k = 797
# Backtracking está consumiendo todas las iteraciones. k = 799
# Backtracking está consumiendo todas las iteraciones. k = 808
# Backtracking está consumiendo todas las iteraciones. k = 810
# Backtracking está consumiendo todas las iteraciones. k = 819
# Backtracking está consumiendo todas las iteraciones. k = 825
# Backtracking está consumiendo todas las iteraciones. k = 827
# Backtracking está consumiendo todas las iteraciones. k = 836
# Backtracking está consumiendo todas las iteraciones. k = 838
# Backtracking está consumiendo todas las iteraciones. k = 847
# Backtracking está consumiendo todas las iteraciones. k = 853
# Backtracking está consumiendo todas las iteraciones. k = 855
# Backtracking está consumiendo todas las iteraciones. k = 864
# Backtracking está consumiendo todas las iteraciones. k = 866
# Backtracking está consumiendo todas las iteraciones. k = 875
# Backtracking está consumiendo todas las iteraciones. k = 881
# Backtracking está consumiendo todas las iteraciones. k = 883
# Backtracking está consumiendo todas las iteraciones. k = 892
# Backtracking está consumiendo todas las iteraciones. k = 894
# Backtracking está consumiendo todas las iteraciones. k = 903
# Backtracking está consumiendo todas las iteraciones. k = 909
# Backtracking está consumiendo todas las iteraciones. k = 911
# Backtracking está consumiendo todas las iteraciones. k = 920
# Backtracking está consumiendo todas las iteraciones. k = 922
# Backtracking está consumiendo todas las iteraciones. k = 931
# Backtracking está consumiendo todas las iteraciones. k = 937
# Backtracking está consumiendo todas las iteraciones. k = 939
# Backtracking está consumiendo todas las iteraciones. k = 948
# Backtracking está consumiendo todas las iteraciones. k = 950
# Backtracking está consumiendo todas las iteraciones. k = 959
# Backtracking está consumiendo todas las iteraciones. k = 965
# Backtracking está consumiendo todas las iteraciones. k = 967
# Backtracking está consumiendo todas las iteraciones. k = 976
# Backtracking está consumiendo todas las iteraciones. k = 978
# Backtracking está consumiendo todas las iteraciones. k = 983
# Backtracking está consumiendo todas las iteraciones. k = 985
# Backtracking está consumiendo todas las iteraciones. k = 989
# Backtracking está consumiendo todas las iteraciones. k = 995
# Backtracking está consumiendo todas las iteraciones. k = 997
# Backtracking está consumiendo todas las iteraciones. k = 1006
# Backtracking está consumiendo todas las iteraciones. k = 1008
# Backtracking está consumiendo todas las iteraciones. k = 1013
# Backtracking está consumiendo todas las iteraciones. k = 1015
# Backtracking está consumiendo todas las iteraciones. k = 1019
# Backtracking está consumiendo todas las iteraciones. k = 1025
# Backtracking está consumiendo todas las iteraciones. k = 1027
# Backtracking está consumiendo todas las iteraciones. k = 1036
# Backtracking está consumiendo todas las iteraciones. k = 1038
# Backtracking está consumiendo todas las iteraciones. k = 1043
# Backtracking está consumiendo todas las iteraciones. k = 1045
# Backtracking está consumiendo todas las iteraciones. k = 1049
# Backtracking está consumiendo todas las iteraciones. k = 1055
# Backtracking está consumiendo todas las iteraciones. k = 1057
# Backtracking está consumiendo todas las iteraciones. k = 1066
# Backtracking está consumiendo todas las iteraciones. k = 1072
# Backtracking está consumiendo todas las iteraciones. k = 1074
# Backtracking está consumiendo todas las iteraciones. k = 1078
# Backtracking está consumiendo todas las iteraciones. k = 1084
# Backtracking está consumiendo todas las iteraciones. k = 1086
# Backtracking está consumiendo todas las iteraciones. k = 1095
# Backtracking está consumiendo todas las iteraciones. k = 1101
# Backtracking está consumiendo todas las iteraciones. k = 1103
# Backtracking está consumiendo todas las iteraciones. k = 1107
# Backtracking está consumiendo todas las iteraciones. k = 1113
# Backtracking está consumiendo todas las iteraciones. k = 1115
# Backtracking está consumiendo todas las iteraciones. k = 1124
# Backtracking está consumiendo todas las iteraciones. k = 1130
# Backtracking está consumiendo todas las iteraciones. k = 1132
# Backtracking está consumiendo todas las iteraciones. k = 1136
# Backtracking está consumiendo todas las iteraciones. k = 1142
# Backtracking está consumiendo todas las iteraciones. k = 1144
# Backtracking está consumiendo todas las iteraciones. k = 1153
# Backtracking está consumiendo todas las iteraciones. k = 1159
# Backtracking está consumiendo todas las iteraciones. k = 1161
# Backtracking está consumiendo todas las iteraciones. k = 1165
# Backtracking está consumiendo todas las iteraciones. k = 1171
# Backtracking está consumiendo todas las iteraciones. k = 1173
# Backtracking está consumiendo todas las iteraciones. k = 1182
# Backtracking está consumiendo todas las iteraciones. k = 1188
# Backtracking está consumiendo todas las iteraciones. k = 1190
# Backtracking está consumiendo todas las iteraciones. k = 1194
# Backtracking está consumiendo todas las iteraciones. k = 1200
# Backtracking está consumiendo todas las iteraciones. k = 1202
# Backtracking está consumiendo todas las iteraciones. k = 1211
# Backtracking está consumiendo todas las iteraciones. k = 1217
# Backtracking está consumiendo todas las iteraciones. k = 1219
# Backtracking está consumiendo todas las iteraciones. k = 1223
# Backtracking está consumiendo todas las iteraciones. k = 1229
# Backtracking está consumiendo todas las iteraciones. k = 1231
# Backtracking está consumiendo todas las iteraciones. k = 1240
# Backtracking está consumiendo todas las iteraciones. k = 1242
# Backtracking está consumiendo todas las iteraciones. k = 1247
# Backtracking está consumiendo todas las iteraciones. k = 1249
# Backtracking está consumiendo todas las iteraciones. k = 1253
# Backtracking está consumiendo todas las iteraciones. k = 1259
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1270
# Backtracking está consumiendo todas las iteraciones. k = 1272
# Backtracking está consumiendo todas las iteraciones. k = 1277
# Backtracking está consumiendo todas las iteraciones. k = 1279
# Backtracking está consumiendo todas las iteraciones. k = 1283
# Backtracking está consumiendo todas las iteraciones. k = 1289
# Backtracking está consumiendo todas las iteraciones. k = 1291
# Backtracking está consumiendo todas las iteraciones. k = 1300
# Backtracking está consumiendo todas las iteraciones. k = 1302
# Backtracking está consumiendo todas las iteraciones. k = 1307
# Backtracking está consumiendo todas las iteraciones. k = 1309
# Backtracking está consumiendo todas las iteraciones. k = 1313
# Backtracking está consumiendo todas las iteraciones. k = 1319
# Backtracking está consumiendo todas las iteraciones. k = 1321
# Backtracking está consumiendo todas las iteraciones. k = 1330
# Backtracking está consumiendo todas las iteraciones. k = 1332
# Backtracking está consumiendo todas las iteraciones. k = 1341
# Backtracking está consumiendo todas las iteraciones. k = 1347
# Backtracking está consumiendo todas las iteraciones. k = 1349
# Backtracking está consumiendo todas las iteraciones. k = 1358
# Backtracking está consumiendo todas las iteraciones. k = 1360
# Backtracking está consumiendo todas las iteraciones. k = 1369
# Backtracking está consumiendo todas las iteraciones. k = 1375
# Backtracking está consumiendo todas las iteraciones. k = 1377
# Backtracking está consumiendo todas las iteraciones. k = 1386
# Backtracking está consumiendo todas las iteraciones. k = 1388
# Backtracking está consumiendo todas las iteraciones. k = 1397
# Backtracking está consumiendo todas las iteraciones. k = 1403
# Backtracking está consumiendo todas las iteraciones. k = 1405
# Backtracking está consumiendo todas las iteraciones. k = 1414
# Backtracking está consumiendo todas las iteraciones. k = 1416
# Backtracking está consumiendo todas las iteraciones. k = 1425
# Backtracking está consumiendo todas las iteraciones. k = 1431
# Backtracking está consumiendo todas las iteraciones. k = 1433
# Backtracking está consumiendo todas las iteraciones. k = 1442
# Backtracking está consumiendo todas las iteraciones. k = 1444
# Backtracking está consumiendo todas las iteraciones. k = 1453
# Backtracking está consumiendo todas las iteraciones. k = 1459
# Backtracking está consumiendo todas las iteraciones. k = 1461
# Backtracking está consumiendo todas las iteraciones. k = 1470
# Backtracking está consumiendo todas las iteraciones. k = 1472
# Backtracking está consumiendo todas las iteraciones. k = 1481
# Backtracking está consumiendo todas las iteraciones. k = 1487
# Backtracking está consumiendo todas las iteraciones. k = 1489
# Backtracking está consumiendo todas las iteraciones. k = 1498
# Backtracking está consumiendo todas las iteraciones. k = 1500
# Backtracking está consumiendo todas las iteraciones. k = 1509
# Backtracking está consumiendo todas las iteraciones. k = 1515
# Backtracking está consumiendo todas las iteraciones. k = 1517
# Backtracking está consumiendo todas las iteraciones. k = 1526
# Backtracking está consumiendo todas las iteraciones. k = 1528
# Backtracking está consumiendo todas las iteraciones. k = 1537
# Backtracking está consumiendo todas las iteraciones. k = 1543
# Backtracking está consumiendo todas las iteraciones. k = 1545
# Backtracking está consumiendo todas las iteraciones. k = 1554
# Backtracking está consumiendo todas las iteraciones. k = 1556
# Backtracking está consumiendo todas las iteraciones. k = 1565
# Backtracking está consumiendo todas las iteraciones. k = 1571
# Backtracking está consumiendo todas las iteraciones. k = 1573
# Backtracking está consumiendo todas las iteraciones. k = 1577
# Backtracking está consumiendo todas las iteraciones. k = 1583
# Backtracking está consumiendo todas las iteraciones. k = 1585
# Backtracking está consumiendo todas las iteraciones. k = 1594
# Backtracking está consumiendo todas las iteraciones. k = 1600
# Backtracking está consumiendo todas las iteraciones. k = 1602
# Backtracking está consumiendo todas las iteraciones. k = 1606
# Backtracking está consumiendo todas las iteraciones. k = 1612
# Backtracking está consumiendo todas las iteraciones. k = 1614
# Backtracking está consumiendo todas las iteraciones. k = 1623
# Backtracking está consumiendo todas las iteraciones. k = 1629
# Backtracking está consumiendo todas las iteraciones. k = 1631
# Backtracking está consumiendo todas las iteraciones. k = 1635
# Backtracking está consumiendo todas las iteraciones. k = 1641
# Backtracking está consumiendo todas las iteraciones. k = 1643
# Backtracking está consumiendo todas las iteraciones. k = 1652
# Backtracking está consumiendo todas las iteraciones. k = 1654
# Backtracking está consumiendo todas las iteraciones. k = 1659
# Backtracking está consumiendo todas las iteraciones. k = 1661
# Backtracking está consumiendo todas las iteraciones. k = 1665
# Backtracking está consumiendo todas las iteraciones. k = 1671
# Backtracking está consumiendo todas las iteraciones. k = 1673
# Backtracking está consumiendo todas las iteraciones. k = 1682
# Backtracking está consumiendo todas las iteraciones. k = 1684
# Backtracking está consumiendo todas las iteraciones. k = 1693
# Backtracking está consumiendo todas las iteraciones. k = 1699
# Backtracking está consumiendo todas las iteraciones. k = 1701
# Backtracking está consumiendo todas las iteraciones. k = 1710
# Backtracking está consumiendo todas las iteraciones. k = 1712
# Backtracking está consumiendo todas las iteraciones. k = 1721
# Backtracking está consumiendo todas las iteraciones. k = 1727
# Backtracking está consumiendo todas las iteraciones. k = 1729
# Backtracking está consumiendo todas las iteraciones. k = 1738
# Backtracking está consumiendo todas las iteraciones. k = 1740
# Backtracking está consumiendo todas las iteraciones. k = 1749
# Backtracking está consumiendo todas las iteraciones. k = 1755
# Backtracking está consumiendo todas las iteraciones. k = 1757
# Backtracking está consumiendo todas las iteraciones. k = 1766
# Backtracking está consumiendo todas las iteraciones. k = 1768
# Backtracking está consumiendo todas las iteraciones. k = 1777
# Backtracking está consumiendo todas las iteraciones. k = 1783
# Backtracking está consumiendo todas las iteraciones. k = 1785
# Backtracking está consumiendo todas las iteraciones. k = 1794
# Backtracking está consumiendo todas las iteraciones. k = 1796
# Backtracking está consumiendo todas las iteraciones. k = 1805
# Backtracking está consumiendo todas las iteraciones. k = 1811
# Backtracking está consumiendo todas las iteraciones. k = 1813
# Backtracking está consumiendo todas las iteraciones. k = 1822
# Backtracking está consumiendo todas las iteraciones. k = 1824
# Backtracking está consumiendo todas las iteraciones. k = 1833
# Backtracking está consumiendo todas las iteraciones. k = 1839
# Backtracking está consumiendo todas las iteraciones. k = 1841
# Backtracking está consumiendo todas las iteraciones. k = 1845
# Backtracking está consumiendo todas las iteraciones. k = 1851
# Backtracking está consumiendo todas las iteraciones. k = 1853
# Backtracking está consumiendo todas las iteraciones. k = 1862
# Backtracking está consumiendo todas las iteraciones. k = 1868
# Backtracking está consumiendo todas las iteraciones. k = 1870
# Backtracking está consumiendo todas las iteraciones. k = 1874
# Backtracking está consumiendo todas las iteraciones. k = 1880
# Backtracking está consumiendo todas las iteraciones. k = 1882
# Backtracking está consumiendo todas las iteraciones. k = 1891
# Backtracking está consumiendo todas las iteraciones. k = 1893
# Backtracking está consumiendo todas las iteraciones. k = 1898
# Backtracking está consumiendo todas las iteraciones. k = 1900
# Backtracking está consumiendo todas las iteraciones. k = 1904
# Backtracking está consumiendo todas las iteraciones. k = 1910
# Backtracking está consumiendo todas las iteraciones. k = 1912
# Backtracking está consumiendo todas las iteraciones. k = 1921
# Backtracking está consumiendo todas las iteraciones. k = 1923
# Backtracking está consumiendo todas las iteraciones. k = 1932
# Backtracking está consumiendo todas las iteraciones. k = 1938
# Backtracking está consumiendo todas las iteraciones. k = 1940
# Backtracking está consumiendo todas las iteraciones. k = 1949
# Backtracking está consumiendo todas las iteraciones. k = 1951
# Backtracking está consumiendo todas las iteraciones. k = 1960
# Backtracking está consumiendo todas las iteraciones. k = 1966
# Backtracking está consumiendo todas las iteraciones. k = 1968
# Backtracking está consumiendo todas las iteraciones. k = 1977
# Backtracking está consumiendo todas las iteraciones. k = 1979
# Backtracking está consumiendo todas las iteraciones. k = 1988
# Backtracking está consumiendo todas las iteraciones. k = 1994
# Backtracking está consumiendo todas las iteraciones. k = 1996
# Backtracking está consumiendo todas las iteraciones. k = 2005
# Backtracking está consumiendo todas las iteraciones. k = 2007
# Backtracking está consumiendo todas las iteraciones. k = 2016
# Backtracking está consumiendo todas las iteraciones. k = 2022
# Backtracking está consumiendo todas las iteraciones. k = 2024
# Backtracking está consumiendo todas las iteraciones. k = 2033
# Backtracking está consumiendo todas las iteraciones. k = 2035
# Backtracking está consumiendo todas las iteraciones. k = 2044
# Backtracking está consumiendo todas las iteraciones. k = 2050
# Backtracking está consumiendo todas las iteraciones. k = 2052
# Backtracking está consumiendo todas las iteraciones. k = 2056
# Backtracking está consumiendo todas las iteraciones. k = 2062
# Backtracking está consumiendo todas las iteraciones. k = 2064
# Backtracking está consumiendo todas las iteraciones. k = 2073
# Backtracking está consumiendo todas las iteraciones. k = 2079
# Backtracking está consumiendo todas las iteraciones. k = 2081
# Backtracking está consumiendo todas las iteraciones. k = 2085
# Backtracking está consumiendo todas las iteraciones. k = 2091
# Backtracking está consumiendo todas las iteraciones. k = 2093
# Backtracking está consumiendo todas las iteraciones. k = 2102
# Backtracking está consumiendo todas las iteraciones. k = 2104
# Backtracking está consumiendo todas las iteraciones. k = 2109
# Backtracking está consumiendo todas las iteraciones. k = 2111
# Backtracking está consumiendo todas las iteraciones. k = 2115
# Backtracking está consumiendo todas las iteraciones. k = 2121
# Backtracking está consumiendo todas las iteraciones. k = 2123
# Backtracking está consumiendo todas las iteraciones. k = 2132
# Backtracking está consumiendo todas las iteraciones. k = 2134
# Backtracking está consumiendo todas las iteraciones. k = 2143
# Backtracking está consumiendo todas las iteraciones. k = 2149
# Backtracking está consumiendo todas las iteraciones. k = 2151
# Backtracking está consumiendo todas las iteraciones. k = 2160
# Backtracking está consumiendo todas las iteraciones. k = 2162
# Backtracking está consumiendo todas las iteraciones. k = 2171
# Backtracking está consumiendo todas las iteraciones. k = 2177
# Backtracking está consumiendo todas las iteraciones. k = 2179
# Backtracking está consumiendo todas las iteraciones. k = 2188
# Backtracking está consumiendo todas las iteraciones. k = 2190
# Backtracking está consumiendo todas las iteraciones. k = 2199
# Backtracking está consumiendo todas las iteraciones. k = 2205
# Backtracking está consumiendo todas las iteraciones. k = 2207
# Backtracking está consumiendo todas las iteraciones. k = 2216
# Backtracking está consumiendo todas las iteraciones. k = 2218
# Backtracking está consumiendo todas las iteraciones. k = 2227
# Backtracking está consumiendo todas las iteraciones. k = 2233
# Backtracking está consumiendo todas las iteraciones. k = 2235
# Backtracking está consumiendo todas las iteraciones. k = 2239
# Backtracking está consumiendo todas las iteraciones. k = 2245
# Backtracking está consumiendo todas las iteraciones. k = 2247
# Backtracking está consumiendo todas las iteraciones. k = 2256
# Backtracking está consumiendo todas las iteraciones. k = 2262
# Backtracking está consumiendo todas las iteraciones. k = 2264
# Backtracking está consumiendo todas las iteraciones. k = 2268
# Backtracking está consumiendo todas las iteraciones. k = 2274
# Backtracking está consumiendo todas las iteraciones. k = 2276
# Backtracking está consumiendo todas las iteraciones. k = 2285
# Backtracking está consumiendo todas las iteraciones. k = 2287
# Backtracking está consumiendo todas las iteraciones. k = 2296
# Backtracking está consumiendo todas las iteraciones. k = 2302
# Backtracking está consumiendo todas las iteraciones. k = 2304
# Backtracking está consumiendo todas las iteraciones. k = 2313
# Backtracking está consumiendo todas las iteraciones. k = 2315
# Backtracking está consumiendo todas las iteraciones. k = 2324
# Backtracking está consumiendo todas las iteraciones. k = 2330
# Backtracking está consumiendo todas las iteraciones. k = 2332
# Backtracking está consumiendo todas las iteraciones. k = 2341
# Backtracking está consumiendo todas las iteraciones. k = 2343
# Backtracking está consumiendo todas las iteraciones. k = 2352
# Backtracking está consumiendo todas las iteraciones. k = 2358
# Backtracking está consumiendo todas las iteraciones. k = 2360
# Backtracking está consumiendo todas las iteraciones. k = 2369
# Backtracking está consumiendo todas las iteraciones. k = 2371
# Backtracking está consumiendo todas las iteraciones. k = 2380
# Backtracking está consumiendo todas las iteraciones. k = 2386
# Backtracking está consumiendo todas las iteraciones. k = 2388
# Backtracking está consumiendo todas las iteraciones. k = 2392
# Backtracking está consumiendo todas las iteraciones. k = 2398
# Backtracking está consumiendo todas las iteraciones. k = 2400
# Backtracking está consumiendo todas las iteraciones. k = 2409
# Backtracking está consumiendo todas las iteraciones. k = 2415
# Backtracking está consumiendo todas las iteraciones. k = 2417
# Backtracking está consumiendo todas las iteraciones. k = 2421
# Backtracking está consumiendo todas las iteraciones. k = 2427
# Backtracking está consumiendo todas las iteraciones. k = 2429
# Backtracking está consumiendo todas las iteraciones. k = 2438
# Backtracking está consumiendo todas las iteraciones. k = 2440
# Backtracking está consumiendo todas las iteraciones. k = 2445
# Backtracking está consumiendo todas las iteraciones. k = 2447
# Backtracking está consumiendo todas las iteraciones. k = 2451
# Backtracking está consumiendo todas las iteraciones. k = 2457
# Backtracking está consumiendo todas las iteraciones. k = 2459
# Backtracking está consumiendo todas las iteraciones. k = 2468
# Backtracking está consumiendo todas las iteraciones. k = 2470
# Backtracking está consumiendo todas las iteraciones. k = 2479
# Backtracking está consumiendo todas las iteraciones. k = 2485
# Backtracking está consumiendo todas las iteraciones. k = 2487
# Backtracking está consumiendo todas las iteraciones. k = 2496
# Backtracking está consumiendo todas las iteraciones. k = 2498
# Backtracking está consumiendo todas las iteraciones. k = 2507
# Backtracking está consumiendo todas las iteraciones. k = 2513
# Backtracking está consumiendo todas las iteraciones. k = 2515
# Backtracking está consumiendo todas las iteraciones. k = 2524
# Backtracking está consumiendo todas las iteraciones. k = 2526
# Backtracking está consumiendo todas las iteraciones. k = 2535
# Backtracking está consumiendo todas las iteraciones. k = 2541
# Backtracking está consumiendo todas las iteraciones. k = 2543
# Backtracking está consumiendo todas las iteraciones. k = 2552
# Backtracking está consumiendo todas las iteraciones. k = 2554
# Backtracking está consumiendo todas las iteraciones. k = 2563
# Backtracking está consumiendo todas las iteraciones. k = 2569
# Backtracking está consumiendo todas las iteraciones. k = 2571
# Backtracking está consumiendo todas las iteraciones. k = 2575
# Backtracking está consumiendo todas las iteraciones. k = 2581
# Backtracking está consumiendo todas las iteraciones. k = 2583
# Backtracking está consumiendo todas las iteraciones. k = 2592
# Backtracking está consumiendo todas las iteraciones. k = 2594
# Backtracking está consumiendo todas las iteraciones. k = 2599
# Backtracking está consumiendo todas las iteraciones. k = 2601
# Backtracking está consumiendo todas las iteraciones. k = 2605
# Backtracking está consumiendo todas las iteraciones. k = 2611
# Backtracking está consumiendo todas las iteraciones. k = 2613
# Backtracking está consumiendo todas las iteraciones. k = 2622
# Backtracking está consumiendo todas las iteraciones. k = 2624
# Backtracking está consumiendo todas las iteraciones. k = 2633
# Backtracking está consumiendo todas las iteraciones. k = 2639
# Backtracking está consumiendo todas las iteraciones. k = 2641
# Backtracking está consumiendo todas las iteraciones. k = 2650
# Backtracking está consumiendo todas las iteraciones. k = 2652
# Backtracking está consumiendo todas las iteraciones. k = 2661
# Backtracking está consumiendo todas las iteraciones. k = 2667
# Backtracking está consumiendo todas las iteraciones. k = 2669
# Backtracking está consumiendo todas las iteraciones. k = 2678
# Backtracking está consumiendo todas las iteraciones. k = 2680
# Backtracking está consumiendo todas las iteraciones. k = 2689
# Backtracking está consumiendo todas las iteraciones. k = 2695
# Backtracking está consumiendo todas las iteraciones. k = 2697
# Backtracking está consumiendo todas las iteraciones. k = 2701
# Backtracking está consumiendo todas las iteraciones. k = 2707
# Backtracking está consumiendo todas las iteraciones. k = 2709
# Backtracking está consumiendo todas las iteraciones. k = 2718
# Backtracking está consumiendo todas las iteraciones. k = 2724
# Backtracking está consumiendo todas las iteraciones. k = 2726
# Backtracking está consumiendo todas las iteraciones. k = 2730
# Backtracking está consumiendo todas las iteraciones. k = 2736
# Backtracking está consumiendo todas las iteraciones. k = 2738
# Backtracking está consumiendo todas las iteraciones. k = 2747
# Backtracking está consumiendo todas las iteraciones. k = 2749
# Backtracking está consumiendo todas las iteraciones. k = 2754
# Backtracking está consumiendo todas las iteraciones. k = 2756
# Backtracking está consumiendo todas las iteraciones. k = 2760
# Backtracking está consumiendo todas las iteraciones. k = 2766
# Backtracking está consumiendo todas las iteraciones. k = 2768
# Backtracking está consumiendo todas las iteraciones. k = 2777
# Backtracking está consumiendo todas las iteraciones. k = 2779
# Backtracking está consumiendo todas las iteraciones. k = 2788
# Backtracking está consumiendo todas las iteraciones. k = 2794
# Backtracking está consumiendo todas las iteraciones. k = 2796
# Backtracking está consumiendo todas las iteraciones. k = 2805
# Backtracking está consumiendo todas las iteraciones. k = 2807
# Backtracking está consumiendo todas las iteraciones. k = 2816
# Backtracking está consumiendo todas las iteraciones. k = 2822
# Backtracking está consumiendo todas las iteraciones. k = 2824
# Backtracking está consumiendo todas las iteraciones. k = 2833
# Backtracking está consumiendo todas las iteraciones. k = 2835
# Backtracking está consumiendo todas las iteraciones. k = 2844
# Backtracking está consumiendo todas las iteraciones. k = 2850
# Backtracking está consumiendo todas las iteraciones. k = 2852
# Backtracking está consumiendo todas las iteraciones. k = 2856
# Backtracking está consumiendo todas las iteraciones. k = 2862
# Backtracking está consumiendo todas las iteraciones. k = 2864
# Backtracking está consumiendo todas las iteraciones. k = 2873
# Backtracking está consumiendo todas las iteraciones. k = 2879
# Backtracking está consumiendo todas las iteraciones. k = 2881
# Backtracking está consumiendo todas las iteraciones. k = 2885
# Backtracking está consumiendo todas las iteraciones. k = 2891
# Backtracking está consumiendo todas las iteraciones. k = 2893
# Backtracking está consumiendo todas las iteraciones. k = 2902
# Backtracking está consumiendo todas las iteraciones. k = 2904
# Backtracking está consumiendo todas las iteraciones. k = 2913
# Backtracking está consumiendo todas las iteraciones. k = 2919
# Backtracking está consumiendo todas las iteraciones. k = 2921
# Backtracking está consumiendo todas las iteraciones. k = 2930
# Backtracking está consumiendo todas las iteraciones. k = 2932
# Backtracking está consumiendo todas las iteraciones. k = 2941
# Backtracking está consumiendo todas las iteraciones. k = 2947
# Backtracking está consumiendo todas las iteraciones. k = 2949
# Backtracking está consumiendo todas las iteraciones. k = 2958
# Backtracking está consumiendo todas las iteraciones. k = 2960
# Backtracking está consumiendo todas las iteraciones. k = 2969
# Backtracking está consumiendo todas las iteraciones. k = 2975
# Backtracking está consumiendo todas las iteraciones. k = 2977
# Backtracking está consumiendo todas las iteraciones. k = 2986
# Backtracking está consumiendo todas las iteraciones. k = 2988
# Backtracking está consumiendo todas las iteraciones. k = 2997
# Backtracking está consumiendo todas las iteraciones. k = 3003
# Backtracking está consumiendo todas las iteraciones. k = 3005
# Backtracking está consumiendo todas las iteraciones. k = 3009
# Backtracking está consumiendo todas las iteraciones. k = 3015
# Backtracking está consumiendo todas las iteraciones. k = 3017
# Backtracking está consumiendo todas las iteraciones. k = 3026
# Backtracking está consumiendo todas las iteraciones. k = 3028
# Backtracking está consumiendo todas las iteraciones. k = 3033
# Backtracking está consumiendo todas las iteraciones. k = 3035
# Backtracking está consumiendo todas las iteraciones. k = 3039
# Backtracking está consumiendo todas las iteraciones. k = 3045
# Backtracking está consumiendo todas las iteraciones. k = 3047
# Backtracking está consumiendo todas las iteraciones. k = 3056
# Backtracking está consumiendo todas las iteraciones. k = 3058
# Backtracking está consumiendo todas las iteraciones. k = 3067
# Backtracking está consumiendo todas las iteraciones. k = 3073
# Backtracking está consumiendo todas las iteraciones. k = 3075
# Backtracking está consumiendo todas las iteraciones. k = 3084
# Backtracking está consumiendo todas las iteraciones. k = 3086
# Backtracking está consumiendo todas las iteraciones. k = 3095
# Backtracking está consumiendo todas las iteraciones. k = 3101
# Backtracking está consumiendo todas las iteraciones. k = 3103
# Backtracking está consumiendo todas las iteraciones. k = 3112
# Backtracking está consumiendo todas las iteraciones. k = 3114
# Backtracking está consumiendo todas las iteraciones. k = 3123
# Backtracking está consumiendo todas las iteraciones. k = 3129
# Backtracking está consumiendo todas las iteraciones. k = 3131
# Backtracking está consumiendo todas las iteraciones. k = 3135
# Backtracking está consumiendo todas las iteraciones. k = 3141
# Backtracking está consumiendo todas las iteraciones. k = 3143
# Backtracking está consumiendo todas las iteraciones. k = 3152
# Backtracking está consumiendo todas las iteraciones. k = 3158
# Backtracking está consumiendo todas las iteraciones. k = 3160
# Backtracking está consumiendo todas las iteraciones. k = 3164
# Backtracking está consumiendo todas las iteraciones. k = 3170
# Backtracking está consumiendo todas las iteraciones. k = 3172
# Backtracking está consumiendo todas las iteraciones. k = 3181
# Backtracking está consumiendo todas las iteraciones. k = 3183
# Backtracking está consumiendo todas las iteraciones. k = 3192
# Backtracking está consumiendo todas las iteraciones. k = 3198
# Backtracking está consumiendo todas las iteraciones. k = 3200
# Backtracking está consumiendo todas las iteraciones. k = 3209
# Backtracking está consumiendo todas las iteraciones. k = 3211
# Backtracking está consumiendo todas las iteraciones. k = 3220
# Backtracking está consumiendo todas las iteraciones. k = 3226
# Backtracking está consumiendo todas las iteraciones. k = 3228
# Backtracking está consumiendo todas las iteraciones. k = 3237
# Backtracking está consumiendo todas las iteraciones. k = 3239
# Backtracking está consumiendo todas las iteraciones. k = 3248
# Backtracking está consumiendo todas las iteraciones. k = 3254
# Backtracking está consumiendo todas las iteraciones. k = 3256
# Backtracking está consumiendo todas las iteraciones. k = 3260
# Backtracking está consumiendo todas las iteraciones. k = 3266
# Backtracking está consumiendo todas las iteraciones. k = 3268
# Backtracking está consumiendo todas las iteraciones. k = 3277
# Backtracking está consumiendo todas las iteraciones. k = 3283
# Backtracking está consumiendo todas las iteraciones. k = 3285
# Backtracking está consumiendo todas las iteraciones. k = 3289
# Backtracking está consumiendo todas las iteraciones. k = 3295
# Backtracking está consumiendo todas las iteraciones. k = 3297
# Backtracking está consumiendo todas las iteraciones. k = 3306
# Backtracking está consumiendo todas las iteraciones. k = 3308
# Backtracking está consumiendo todas las iteraciones. k = 3317
# Backtracking está consumiendo todas las iteraciones. k = 3323
# Backtracking está consumiendo todas las iteraciones. k = 3325
# Backtracking está consumiendo todas las iteraciones. k = 3334
# Backtracking está consumiendo todas las iteraciones. k = 3336
# Backtracking está consumiendo todas las iteraciones. k = 3345
# Backtracking está consumiendo todas las iteraciones. k = 3351
# Backtracking está consumiendo todas las iteraciones. k = 3353
# Backtracking está consumiendo todas las iteraciones. k = 3362
# Backtracking está consumiendo todas las iteraciones. k = 3364
# Backtracking está consumiendo todas las iteraciones. k = 3373
# Backtracking está consumiendo todas las iteraciones. k = 3379
# Backtracking está consumiendo todas las iteraciones. k = 3381
# Backtracking está consumiendo todas las iteraciones. k = 3385
# Backtracking está consumiendo todas las iteraciones. k = 3391
# Backtracking está consumiendo todas las iteraciones. k = 3393
# Backtracking está consumiendo todas las iteraciones. k = 3402
# Backtracking está consumiendo todas las iteraciones. k = 3408
# Backtracking está consumiendo todas las iteraciones. k = 3410
# Backtracking está consumiendo todas las iteraciones. k = 3414
# Backtracking está consumiendo todas las iteraciones. k = 3420
# Backtracking está consumiendo todas las iteraciones. k = 3422
# Backtracking está consumiendo todas las iteraciones. k = 3431
# Backtracking está consumiendo todas las iteraciones. k = 3433
# Backtracking está consumiendo todas las iteraciones. k = 3442
# Backtracking está consumiendo todas las iteraciones. k = 3448
# Backtracking está consumiendo todas las iteraciones. k = 3450
# Backtracking está consumiendo todas las iteraciones. k = 3459
# Backtracking está consumiendo todas las iteraciones. k = 3461
# Backtracking está consumiendo todas las iteraciones. k = 3470
# Backtracking está consumiendo todas las iteraciones. k = 3476
# Backtracking está consumiendo todas las iteraciones. k = 3478
# Backtracking está consumiendo todas las iteraciones. k = 3487
# Backtracking está consumiendo todas las iteraciones. k = 3489
# Backtracking está consumiendo todas las iteraciones. k = 3498
# Backtracking está consumiendo todas las iteraciones. k = 3504
# Backtracking está consumiendo todas las iteraciones. k = 3506
# Backtracking está consumiendo todas las iteraciones. k = 3510
# Backtracking está consumiendo todas las iteraciones. k = 3516
# Backtracking está consumiendo todas las iteraciones. k = 3518
# Backtracking está consumiendo todas las iteraciones. k = 3527
# Backtracking está consumiendo todas las iteraciones. k = 3533
# Backtracking está consumiendo todas las iteraciones. k = 3535
# Backtracking está consumiendo todas las iteraciones. k = 3539
# Backtracking está consumiendo todas las iteraciones. k = 3545
# Backtracking está consumiendo todas las iteraciones. k = 3547
# Backtracking está consumiendo todas las iteraciones. k = 3556
# Backtracking está consumiendo todas las iteraciones. k = 3558
# Backtracking está consumiendo todas las iteraciones. k = 3567
# Backtracking está consumiendo todas las iteraciones. k = 3573
# Backtracking está consumiendo todas las iteraciones. k = 3575
# Backtracking está consumiendo todas las iteraciones. k = 3584
# Backtracking está consumiendo todas las iteraciones. k = 3586
# Backtracking está consumiendo todas las iteraciones. k = 3595
# Backtracking está consumiendo todas las iteraciones. k = 3601
# Backtracking está consumiendo todas las iteraciones. k = 3603
# Backtracking está consumiendo todas las iteraciones. k = 3612
# Backtracking está consumiendo todas las iteraciones. k = 3614
# Backtracking está consumiendo todas las iteraciones. k = 3623
# Backtracking está consumiendo todas las iteraciones. k = 3629
# Backtracking está consumiendo todas las iteraciones. k = 3631
# Backtracking está consumiendo todas las iteraciones. k = 3635
# Backtracking está consumiendo todas las iteraciones. k = 3641
# Backtracking está consumiendo todas las iteraciones. k = 3643
# Backtracking está consumiendo todas las iteraciones. k = 3652
# Backtracking está consumiendo todas las iteraciones. k = 3658
# Backtracking está consumiendo todas las iteraciones. k = 3660
# Backtracking está consumiendo todas las iteraciones. k = 3664
# Backtracking está consumiendo todas las iteraciones. k = 3670
# Backtracking está consumiendo todas las iteraciones. k = 3672
# Backtracking está consumiendo todas las iteraciones. k = 3681
# Backtracking está consumiendo todas las iteraciones. k = 3683
# Backtracking está consumiendo todas las iteraciones. k = 3692
# Backtracking está consumiendo todas las iteraciones. k = 3698
# Backtracking está consumiendo todas las iteraciones. k = 3700
# Backtracking está consumiendo todas las iteraciones. k = 3709
# Backtracking está consumiendo todas las iteraciones. k = 3711
# Backtracking está consumiendo todas las iteraciones. k = 3720
# Backtracking está consumiendo todas las iteraciones. k = 3726
# Backtracking está consumiendo todas las iteraciones. k = 3728
# Backtracking está consumiendo todas las iteraciones. k = 3737
# Backtracking está consumiendo todas las iteraciones. k = 3739
# Backtracking está consumiendo todas las iteraciones. k = 3748
# Backtracking está consumiendo todas las iteraciones. k = 3754
# Backtracking está consumiendo todas las iteraciones. k = 3756
# Backtracking está consumiendo todas las iteraciones. k = 3760
# Backtracking está consumiendo todas las iteraciones. k = 3766
# Backtracking está consumiendo todas las iteraciones. k = 3768
# Backtracking está consumiendo todas las iteraciones. k = 3777
# Backtracking está consumiendo todas las iteraciones. k = 3783
# Backtracking está consumiendo todas las iteraciones. k = 3785
# Backtracking está consumiendo todas las iteraciones. k = 3789
# Backtracking está consumiendo todas las iteraciones. k = 3795
# Backtracking está consumiendo todas las iteraciones. k = 3797
# Backtracking está consumiendo todas las iteraciones. k = 3806
# Backtracking está consumiendo todas las iteraciones. k = 3808
# Backtracking está consumiendo todas las iteraciones. k = 3817
# Backtracking está consumiendo todas las iteraciones. k = 3823
# Backtracking está consumiendo todas las iteraciones. k = 3825
# Backtracking está consumiendo todas las iteraciones. k = 3834
# Backtracking está consumiendo todas las iteraciones. k = 3836
# Backtracking está consumiendo todas las iteraciones. k = 3845
# Backtracking está consumiendo todas las iteraciones. k = 3851
# Backtracking está consumiendo todas las iteraciones. k = 3853
# Backtracking está consumiendo todas las iteraciones. k = 3862
# Backtracking está consumiendo todas las iteraciones. k = 3864
# Backtracking está consumiendo todas las iteraciones. k = 3873
# Backtracking está consumiendo todas las iteraciones. k = 3879
# Backtracking está consumiendo todas las iteraciones. k = 3881
# Backtracking está consumiendo todas las iteraciones. k = 3885
# Backtracking está consumiendo todas las iteraciones. k = 3891
# Backtracking está consumiendo todas las iteraciones. k = 3893
# Backtracking está consumiendo todas las iteraciones. k = 3902
# Backtracking está consumiendo todas las iteraciones. k = 3908
# Backtracking está consumiendo todas las iteraciones. k = 3910
# Backtracking está consumiendo todas las iteraciones. k = 3914
# Backtracking está consumiendo todas las iteraciones. k = 3920
# Backtracking está consumiendo todas las iteraciones. k = 3922
# Backtracking está consumiendo todas las iteraciones. k = 3931
# Backtracking está consumiendo todas las iteraciones. k = 3933
# Backtracking está consumiendo todas las iteraciones. k = 3942
# Backtracking está consumiendo todas las iteraciones. k = 3948
# Backtracking está consumiendo todas las iteraciones. k = 3950
# Backtracking está consumiendo todas las iteraciones. k = 3959
# Backtracking está consumiendo todas las iteraciones. k = 3961
# Backtracking está consumiendo todas las iteraciones. k = 3970
# Backtracking está consumiendo todas las iteraciones. k = 3976
# Backtracking está consumiendo todas las iteraciones. k = 3978
# Backtracking está consumiendo todas las iteraciones. k = 3987
# Backtracking está consumiendo todas las iteraciones. k = 3989
# Backtracking está consumiendo todas las iteraciones. k = 3998
# Backtracking está consumiendo todas las iteraciones. k = 4004
# Backtracking está consumiendo todas las iteraciones. k = 4006
# Backtracking está consumiendo todas las iteraciones. k = 4010
# Backtracking está consumiendo todas las iteraciones. k = 4016
# Backtracking está consumiendo todas las iteraciones. k = 4018
# Backtracking está consumiendo todas las iteraciones. k = 4027
# Backtracking está consumiendo todas las iteraciones. k = 4029
# Backtracking está consumiendo todas las iteraciones. k = 4034
# Backtracking está consumiendo todas las iteraciones. k = 4036
# Backtracking está consumiendo todas las iteraciones. k = 4040
# Backtracking está consumiendo todas las iteraciones. k = 4046
# Backtracking está consumiendo todas las iteraciones. k = 4048
# Backtracking está consumiendo todas las iteraciones. k = 4057
# Backtracking está consumiendo todas las iteraciones. k = 4059
# Backtracking está consumiendo todas las iteraciones. k = 4068
# Backtracking está consumiendo todas las iteraciones. k = 4074
# Backtracking está consumiendo todas las iteraciones. k = 4076
# Backtracking está consumiendo todas las iteraciones. k = 4085
# Backtracking está consumiendo todas las iteraciones. k = 4087
# Backtracking está consumiendo todas las iteraciones. k = 4096
# Backtracking está consumiendo todas las iteraciones. k = 4102
# Backtracking está consumiendo todas las iteraciones. k = 4104
# Backtracking está consumiendo todas las iteraciones. k = 4113
# Backtracking está consumiendo todas las iteraciones. k = 4115
# Backtracking está consumiendo todas las iteraciones. k = 4124
# Backtracking está consumiendo todas las iteraciones. k = 4130
# Backtracking está consumiendo todas las iteraciones. k = 4132
# Backtracking está consumiendo todas las iteraciones. k = 4136
# Backtracking está consumiendo todas las iteraciones. k = 4142
# Backtracking está consumiendo todas las iteraciones. k = 4144
# Backtracking está consumiendo todas las iteraciones. k = 4153
# Backtracking está consumiendo todas las iteraciones. k = 4155
# Backtracking está consumiendo todas las iteraciones. k = 4164
# Backtracking está consumiendo todas las iteraciones. k = 4170
# Backtracking está consumiendo todas las iteraciones. k = 4172
# Backtracking está consumiendo todas las iteraciones. k = 4181
# Backtracking está consumiendo todas las iteraciones. k = 4183
# Backtracking está consumiendo todas las iteraciones. k = 4192
# Backtracking está consumiendo todas las iteraciones. k = 4198
# Backtracking está consumiendo todas las iteraciones. k = 4200
# Backtracking está consumiendo todas las iteraciones. k = 4209
# Backtracking está consumiendo todas las iteraciones. k = 4211
# Backtracking está consumiendo todas las iteraciones. k = 4220
# Backtracking está consumiendo todas las iteraciones. k = 4226
# Backtracking está consumiendo todas las iteraciones. k = 4228
# Backtracking está consumiendo todas las iteraciones. k = 4232
# Backtracking está consumiendo todas las iteraciones. k = 4238
# Backtracking está consumiendo todas las iteraciones. k = 4240
# Backtracking está consumiendo todas las iteraciones. k = 4249
# Backtracking está consumiendo todas las iteraciones. k = 4255
# Backtracking está consumiendo todas las iteraciones. k = 4257
# Backtracking está consumiendo todas las iteraciones. k = 4261
# Backtracking está consumiendo todas las iteraciones. k = 4267
# Backtracking está consumiendo todas las iteraciones. k = 4269
# Backtracking está consumiendo todas las iteraciones. k = 4278
# Backtracking está consumiendo todas las iteraciones. k = 4280
# Backtracking está consumiendo todas las iteraciones. k = 4289
# Backtracking está consumiendo todas las iteraciones. k = 4295
# Backtracking está consumiendo todas las iteraciones. k = 4297
# Backtracking está consumiendo todas las iteraciones. k = 4306
# Backtracking está consumiendo todas las iteraciones. k = 4308
# Backtracking está consumiendo todas las iteraciones. k = 4317
# Backtracking está consumiendo todas las iteraciones. k = 4323
# Backtracking está consumiendo todas las iteraciones. k = 4325
# Backtracking está consumiendo todas las iteraciones. k = 4334
# Backtracking está consumiendo todas las iteraciones. k = 4336
# Backtracking está consumiendo todas las iteraciones. k = 4345
# Backtracking está consumiendo todas las iteraciones. k = 4351
# Backtracking está consumiendo todas las iteraciones. k = 4353
# Backtracking está consumiendo todas las iteraciones. k = 4357
# Backtracking está consumiendo todas las iteraciones. k = 4363
# Backtracking está consumiendo todas las iteraciones. k = 4365
# Backtracking está consumiendo todas las iteraciones. k = 4374
# Backtracking está consumiendo todas las iteraciones. k = 4376
# Backtracking está consumiendo todas las iteraciones. k = 4381
# Backtracking está consumiendo todas las iteraciones. k = 4383
# Backtracking está consumiendo todas las iteraciones. k = 4387
# Backtracking está consumiendo todas las iteraciones. k = 4393
# Backtracking está consumiendo todas las iteraciones. k = 4395
# Backtracking está consumiendo todas las iteraciones. k = 4404
# Backtracking está consumiendo todas las iteraciones. k = 4406
# Backtracking está consumiendo todas las iteraciones. k = 4415
# Backtracking está consumiendo todas las iteraciones. k = 4421
# Backtracking está consumiendo todas las iteraciones. k = 4423
# Backtracking está consumiendo todas las iteraciones. k = 4432
# Backtracking está consumiendo todas las iteraciones. k = 4434
# Backtracking está consumiendo todas las iteraciones. k = 4443
# Backtracking está consumiendo todas las iteraciones. k = 4449
# Backtracking está consumiendo todas las iteraciones. k = 4451
# Backtracking está consumiendo todas las iteraciones. k = 4460
# Backtracking está consumiendo todas las iteraciones. k = 4462
# Backtracking está consumiendo todas las iteraciones. k = 4471
# Backtracking está consumiendo todas las iteraciones. k = 4477
# Backtracking está consumiendo todas las iteraciones. k = 4479
# Backtracking está consumiendo todas las iteraciones. k = 4483
# Backtracking está consumiendo todas las iteraciones. k = 4489
# Backtracking está consumiendo todas las iteraciones. k = 4491
# Backtracking está consumiendo todas las iteraciones. k = 4500
# Backtracking está consumiendo todas las iteraciones. k = 4502
# Backtracking está consumiendo todas las iteraciones. k = 4511
# Backtracking está consumiendo todas las iteraciones. k = 4517
# Backtracking está consumiendo todas las iteraciones. k = 4519
# Backtracking está consumiendo todas las iteraciones. k = 4528
# Backtracking está consumiendo todas las iteraciones. k = 4530
# Backtracking está consumiendo todas las iteraciones. k = 4539
# Backtracking está consumiendo todas las iteraciones. k = 4545
# Backtracking está consumiendo todas las iteraciones. k = 4547
# Backtracking está consumiendo todas las iteraciones. k = 4556
# Backtracking está consumiendo todas las iteraciones. k = 4558
# Backtracking está consumiendo todas las iteraciones. k = 4567
# Backtracking está consumiendo todas las iteraciones. k = 4573
# Backtracking está consumiendo todas las iteraciones. k = 4575
# Backtracking está consumiendo todas las iteraciones. k = 4579
# Backtracking está consumiendo todas las iteraciones. k = 4585
# Backtracking está consumiendo todas las iteraciones. k = 4587
# Backtracking está consumiendo todas las iteraciones. k = 4596
# Backtracking está consumiendo todas las iteraciones. k = 4602
# Backtracking está consumiendo todas las iteraciones. k = 4604
# Backtracking está consumiendo todas las iteraciones. k = 4608
# Backtracking está consumiendo todas las iteraciones. k = 4614
# Backtracking está consumiendo todas las iteraciones. k = 4616
# Backtracking está consumiendo todas las iteraciones. k = 4625
# Backtracking está consumiendo todas las iteraciones. k = 4627
# Backtracking está consumiendo todas las iteraciones. k = 4636
# Backtracking está consumiendo todas las iteraciones. k = 4642
# Backtracking está consumiendo todas las iteraciones. k = 4644
# Backtracking está consumiendo todas las iteraciones. k = 4653
# Backtracking está consumiendo todas las iteraciones. k = 4655
# Backtracking está consumiendo todas las iteraciones. k = 4664
# Backtracking está consumiendo todas las iteraciones. k = 4670
# Backtracking está consumiendo todas las iteraciones. k = 4672
# Backtracking está consumiendo todas las iteraciones. k = 4681
# Backtracking está consumiendo todas las iteraciones. k = 4683
# Backtracking está consumiendo todas las iteraciones. k = 4692
# Backtracking está consumiendo todas las iteraciones. k = 4698
# Backtracking está consumiendo todas las iteraciones. k = 4700
# Backtracking está consumiendo todas las iteraciones. k = 4704
# Backtracking está consumiendo todas las iteraciones. k = 4710
# Backtracking está consumiendo todas las iteraciones. k = 4712
# Backtracking está consumiendo todas las iteraciones. k = 4721
# Backtracking está consumiendo todas las iteraciones. k = 4723
# Backtracking está consumiendo todas las iteraciones. k = 4732
# Backtracking está consumiendo todas las iteraciones. k = 4738
# Backtracking está consumiendo todas las iteraciones. k = 4740
# Backtracking está consumiendo todas las iteraciones. k = 4749
# Backtracking está consumiendo todas las iteraciones. k = 4751
# Backtracking está consumiendo todas las iteraciones. k = 4760
# Backtracking está consumiendo todas las iteraciones. k = 4766
# Backtracking está consumiendo todas las iteraciones. k = 4768
# Backtracking está consumiendo todas las iteraciones. k = 4777
# Backtracking está consumiendo todas las iteraciones. k = 4779
# Backtracking está consumiendo todas las iteraciones. k = 4788
# Backtracking está consumiendo todas las iteraciones. k = 4794
# Backtracking está consumiendo todas las iteraciones. k = 4796
# Backtracking está consumiendo todas las iteraciones. k = 4800
# Backtracking está consumiendo todas las iteraciones. k = 4806
# Backtracking está consumiendo todas las iteraciones. k = 4808
# Backtracking está consumiendo todas las iteraciones. k = 4817
# Backtracking está consumiendo todas las iteraciones. k = 4823
# Backtracking está consumiendo todas las iteraciones. k = 4825
# Backtracking está consumiendo todas las iteraciones. k = 4829
# Backtracking está consumiendo todas las iteraciones. k = 4835
# Backtracking está consumiendo todas las iteraciones. k = 4837
# Backtracking está consumiendo todas las iteraciones. k = 4846
# Backtracking está consumiendo todas las iteraciones. k = 4848
# Backtracking está consumiendo todas las iteraciones. k = 4857
# Backtracking está consumiendo todas las iteraciones. k = 4863
# Backtracking está consumiendo todas las iteraciones. k = 4865
# Backtracking está consumiendo todas las iteraciones. k = 4874
# Backtracking está consumiendo todas las iteraciones. k = 4876
# Backtracking está consumiendo todas las iteraciones. k = 4885
# Backtracking está consumiendo todas las iteraciones. k = 4891
# Backtracking está consumiendo todas las iteraciones. k = 4893
# Backtracking está consumiendo todas las iteraciones. k = 4902
# Backtracking está consumiendo todas las iteraciones. k = 4904
# Backtracking está consumiendo todas las iteraciones. k = 4913
# Backtracking está consumiendo todas las iteraciones. k = 4919
# Backtracking está consumiendo todas las iteraciones. k = 4921
# Backtracking está consumiendo todas las iteraciones. k = 4925
# Backtracking está consumiendo todas las iteraciones. k = 4931
# Backtracking está consumiendo todas las iteraciones. k = 4933
# Backtracking está consumiendo todas las iteraciones. k = 4942
# Backtracking está consumiendo todas las iteraciones. k = 4944
# Backtracking está consumiendo todas las iteraciones. k = 4953
# Backtracking está consumiendo todas las iteraciones. k = 4959
# Backtracking está consumiendo todas las iteraciones. k = 4961
# Backtracking está consumiendo todas las iteraciones. k = 4970
# Backtracking está consumiendo todas las iteraciones. k = 4972
# Backtracking está consumiendo todas las iteraciones. k = 4981
# Backtracking está consumiendo todas las iteraciones. k = 4987
# Backtracking está consumiendo todas las iteraciones. k = 4989
# Backtracking está consumiendo todas las iteraciones. k = 4998
# Dimension: 100
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 5000
# La solución alcanzada es:  [ 1.43574711 -1.38364255  2.04861357 -1.33199051] ... [-1.33199051  2.04861357 -1.38364255  1.43574711]
# f(xk)=-14.494146346147428
# f(x0)=0.0
# La norma del gradiente final es: 0.0012286586322716373
# Número de reinicios:  4034

# %%
# con la última dimensión
sol6 = nonlinear_grad_conj1(lambda x: quadratic(x, A6, b6),
                           lambda x: Grad_quadratic(x, A6, b6),
                           np.zeros(n[2]), a0, maxIter, np.sqrt(n[2])*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol6, lambda x: quadratic(x, A6, b6), np.zeros(n[2]))
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 26
# Backtracking está consumiendo todas las iteraciones. k = 28
# Backtracking está consumiendo todas las iteraciones. k = 33
# Backtracking está consumiendo todas las iteraciones. k = 39
# Backtracking está consumiendo todas las iteraciones. k = 45
# Backtracking está consumiendo todas las iteraciones. k = 51
# Backtracking está consumiendo todas las iteraciones. k = 53
# Backtracking está consumiendo todas las iteraciones. k = 58
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 65
# Backtracking está consumiendo todas las iteraciones. k = 67
# Backtracking está consumiendo todas las iteraciones. k = 81
# Backtracking está consumiendo todas las iteraciones. k = 87
# Backtracking está consumiendo todas las iteraciones. k = 89
# Backtracking está consumiendo todas las iteraciones. k = 94
# Backtracking está consumiendo todas las iteraciones. k = 96
# Backtracking está consumiendo todas las iteraciones. k = 105
# Backtracking está consumiendo todas las iteraciones. k = 111
# Backtracking está consumiendo todas las iteraciones. k = 117
# Backtracking está consumiendo todas las iteraciones. k = 119
# Backtracking está consumiendo todas las iteraciones. k = 128
# Backtracking está consumiendo todas las iteraciones. k = 134
# Backtracking está consumiendo todas las iteraciones. k = 140
# Backtracking está consumiendo todas las iteraciones. k = 142
# Backtracking está consumiendo todas las iteraciones. k = 151
# Backtracking está consumiendo todas las iteraciones. k = 157
# Backtracking está consumiendo todas las iteraciones. k = 159
# Backtracking está consumiendo todas las iteraciones. k = 164
# Backtracking está consumiendo todas las iteraciones. k = 166
# Backtracking está consumiendo todas las iteraciones. k = 175
# Backtracking está consumiendo todas las iteraciones. k = 181
# Backtracking está consumiendo todas las iteraciones. k = 183
# Backtracking está consumiendo todas las iteraciones. k = 192
# Backtracking está consumiendo todas las iteraciones. k = 198
# Backtracking está consumiendo todas las iteraciones. k = 200
# Backtracking está consumiendo todas las iteraciones. k = 209
# Backtracking está consumiendo todas las iteraciones. k = 215
# Backtracking está consumiendo todas las iteraciones. k = 217
# Backtracking está consumiendo todas las iteraciones. k = 222
# Backtracking está consumiendo todas las iteraciones. k = 224
# Backtracking está consumiendo todas las iteraciones. k = 233
# Backtracking está consumiendo todas las iteraciones. k = 235
# Backtracking está consumiendo todas las iteraciones. k = 240
# Backtracking está consumiendo todas las iteraciones. k = 242
# Backtracking está consumiendo todas las iteraciones. k = 251
# Backtracking está consumiendo todas las iteraciones. k = 257
# Backtracking está consumiendo todas las iteraciones. k = 259
# Backtracking está consumiendo todas las iteraciones. k = 268
# Backtracking está consumiendo todas las iteraciones. k = 274
# Backtracking está consumiendo todas las iteraciones. k = 276
# Backtracking está consumiendo todas las iteraciones. k = 285
# Backtracking está consumiendo todas las iteraciones. k = 291
# Backtracking está consumiendo todas las iteraciones. k = 293
# Backtracking está consumiendo todas las iteraciones. k = 302
# Backtracking está consumiendo todas las iteraciones. k = 308
# Backtracking está consumiendo todas las iteraciones. k = 310
# Backtracking está consumiendo todas las iteraciones. k = 319
# Backtracking está consumiendo todas las iteraciones. k = 325
# Backtracking está consumiendo todas las iteraciones. k = 327
# Backtracking está consumiendo todas las iteraciones. k = 336
# Backtracking está consumiendo todas las iteraciones. k = 342
# Backtracking está consumiendo todas las iteraciones. k = 344
# Backtracking está consumiendo todas las iteraciones. k = 353
# Backtracking está consumiendo todas las iteraciones. k = 359
# Backtracking está consumiendo todas las iteraciones. k = 361
# Backtracking está consumiendo todas las iteraciones. k = 370
# Backtracking está consumiendo todas las iteraciones. k = 376
# Backtracking está consumiendo todas las iteraciones. k = 378
# Backtracking está consumiendo todas las iteraciones. k = 387
# Backtracking está consumiendo todas las iteraciones. k = 393
# Backtracking está consumiendo todas las iteraciones. k = 395
# Backtracking está consumiendo todas las iteraciones. k = 404
# Backtracking está consumiendo todas las iteraciones. k = 410
# Backtracking está consumiendo todas las iteraciones. k = 412
# Backtracking está consumiendo todas las iteraciones. k = 421
# Backtracking está consumiendo todas las iteraciones. k = 427
# Backtracking está consumiendo todas las iteraciones. k = 429
# Backtracking está consumiendo todas las iteraciones. k = 438
# Backtracking está consumiendo todas las iteraciones. k = 440
# Backtracking está consumiendo todas las iteraciones. k = 445
# Backtracking está consumiendo todas las iteraciones. k = 447
# Backtracking está consumiendo todas las iteraciones. k = 456
# Backtracking está consumiendo todas las iteraciones. k = 458
# Backtracking está consumiendo todas las iteraciones. k = 463
# Backtracking está consumiendo todas las iteraciones. k = 465
# Backtracking está consumiendo todas las iteraciones. k = 469
# Backtracking está consumiendo todas las iteraciones. k = 475
# Backtracking está consumiendo todas las iteraciones. k = 477
# Backtracking está consumiendo todas las iteraciones. k = 486
# Backtracking está consumiendo todas las iteraciones. k = 492
# Backtracking está consumiendo todas las iteraciones. k = 494
# Backtracking está consumiendo todas las iteraciones. k = 503
# Backtracking está consumiendo todas las iteraciones. k = 509
# Backtracking está consumiendo todas las iteraciones. k = 511
# Backtracking está consumiendo todas las iteraciones. k = 520
# Backtracking está consumiendo todas las iteraciones. k = 526
# Backtracking está consumiendo todas las iteraciones. k = 528
# Backtracking está consumiendo todas las iteraciones. k = 537
# Backtracking está consumiendo todas las iteraciones. k = 543
# Backtracking está consumiendo todas las iteraciones. k = 545
# Backtracking está consumiendo todas las iteraciones. k = 554
# Backtracking está consumiendo todas las iteraciones. k = 560
# Backtracking está consumiendo todas las iteraciones. k = 562
# Backtracking está consumiendo todas las iteraciones. k = 571
# Backtracking está consumiendo todas las iteraciones. k = 573
# Backtracking está consumiendo todas las iteraciones. k = 578
# Backtracking está consumiendo todas las iteraciones. k = 580
# Backtracking está consumiendo todas las iteraciones. k = 584
# Backtracking está consumiendo todas las iteraciones. k = 590
# Backtracking está consumiendo todas las iteraciones. k = 592
# Backtracking está consumiendo todas las iteraciones. k = 601
# Backtracking está consumiendo todas las iteraciones. k = 607
# Backtracking está consumiendo todas las iteraciones. k = 609
# Backtracking está consumiendo todas las iteraciones. k = 618
# Backtracking está consumiendo todas las iteraciones. k = 624
# Backtracking está consumiendo todas las iteraciones. k = 626
# Backtracking está consumiendo todas las iteraciones. k = 635
# Backtracking está consumiendo todas las iteraciones. k = 641
# Backtracking está consumiendo todas las iteraciones. k = 643
# Backtracking está consumiendo todas las iteraciones. k = 652
# Backtracking está consumiendo todas las iteraciones. k = 658
# Backtracking está consumiendo todas las iteraciones. k = 660
# Backtracking está consumiendo todas las iteraciones. k = 669
# Backtracking está consumiendo todas las iteraciones. k = 671
# Backtracking está consumiendo todas las iteraciones. k = 680
# Backtracking está consumiendo todas las iteraciones. k = 686
# Backtracking está consumiendo todas las iteraciones. k = 688
# Backtracking está consumiendo todas las iteraciones. k = 697
# Backtracking está consumiendo todas las iteraciones. k = 703
# Backtracking está consumiendo todas las iteraciones. k = 705
# Backtracking está consumiendo todas las iteraciones. k = 714
# Backtracking está consumiendo todas las iteraciones. k = 720
# Backtracking está consumiendo todas las iteraciones. k = 722
# Backtracking está consumiendo todas las iteraciones. k = 731
# Backtracking está consumiendo todas las iteraciones. k = 737
# Backtracking está consumiendo todas las iteraciones. k = 739
# Backtracking está consumiendo todas las iteraciones. k = 748
# Backtracking está consumiendo todas las iteraciones. k = 750
# Backtracking está consumiendo todas las iteraciones. k = 759
# Backtracking está consumiendo todas las iteraciones. k = 765
# Backtracking está consumiendo todas las iteraciones. k = 767
# Backtracking está consumiendo todas las iteraciones. k = 776
# Backtracking está consumiendo todas las iteraciones. k = 782
# Backtracking está consumiendo todas las iteraciones. k = 784
# Backtracking está consumiendo todas las iteraciones. k = 793
# Backtracking está consumiendo todas las iteraciones. k = 799
# Backtracking está consumiendo todas las iteraciones. k = 801
# Backtracking está consumiendo todas las iteraciones. k = 810
# Backtracking está consumiendo todas las iteraciones. k = 812
# Backtracking está consumiendo todas las iteraciones. k = 817
# Backtracking está consumiendo todas las iteraciones. k = 819
# Backtracking está consumiendo todas las iteraciones. k = 823
# Backtracking está consumiendo todas las iteraciones. k = 829
# Backtracking está consumiendo todas las iteraciones. k = 831
# Backtracking está consumiendo todas las iteraciones. k = 840
# Backtracking está consumiendo todas las iteraciones. k = 846
# Backtracking está consumiendo todas las iteraciones. k = 848
# Backtracking está consumiendo todas las iteraciones. k = 857
# Backtracking está consumiendo todas las iteraciones. k = 863
# Backtracking está consumiendo todas las iteraciones. k = 865
# Backtracking está consumiendo todas las iteraciones. k = 874
# Backtracking está consumiendo todas las iteraciones. k = 880
# Backtracking está consumiendo todas las iteraciones. k = 882
# Backtracking está consumiendo todas las iteraciones. k = 891
# Backtracking está consumiendo todas las iteraciones. k = 893
# Backtracking está consumiendo todas las iteraciones. k = 902
# Backtracking está consumiendo todas las iteraciones. k = 908
# Backtracking está consumiendo todas las iteraciones. k = 910
# Backtracking está consumiendo todas las iteraciones. k = 919
# Backtracking está consumiendo todas las iteraciones. k = 925
# Backtracking está consumiendo todas las iteraciones. k = 927
# Backtracking está consumiendo todas las iteraciones. k = 936
# Backtracking está consumiendo todas las iteraciones. k = 942
# Backtracking está consumiendo todas las iteraciones. k = 944
# Backtracking está consumiendo todas las iteraciones. k = 953
# Backtracking está consumiendo todas las iteraciones. k = 955
# Backtracking está consumiendo todas las iteraciones. k = 960
# Backtracking está consumiendo todas las iteraciones. k = 962
# Backtracking está consumiendo todas las iteraciones. k = 966
# Backtracking está consumiendo todas las iteraciones. k = 972
# Backtracking está consumiendo todas las iteraciones. k = 974
# Backtracking está consumiendo todas las iteraciones. k = 983
# Backtracking está consumiendo todas las iteraciones. k = 989
# Backtracking está consumiendo todas las iteraciones. k = 991
# Backtracking está consumiendo todas las iteraciones. k = 1000
# Backtracking está consumiendo todas las iteraciones. k = 1006
# Backtracking está consumiendo todas las iteraciones. k = 1008
# Backtracking está consumiendo todas las iteraciones. k = 1017
# Backtracking está consumiendo todas las iteraciones. k = 1019
# Backtracking está consumiendo todas las iteraciones. k = 1024
# Backtracking está consumiendo todas las iteraciones. k = 1026
# Backtracking está consumiendo todas las iteraciones. k = 1030
# Backtracking está consumiendo todas las iteraciones. k = 1036
# Backtracking está consumiendo todas las iteraciones. k = 1038
# Backtracking está consumiendo todas las iteraciones. k = 1047
# Backtracking está consumiendo todas las iteraciones. k = 1053
# Backtracking está consumiendo todas las iteraciones. k = 1055
# Backtracking está consumiendo todas las iteraciones. k = 1064
# Backtracking está consumiendo todas las iteraciones. k = 1070
# Backtracking está consumiendo todas las iteraciones. k = 1072
# Backtracking está consumiendo todas las iteraciones. k = 1081
# Backtracking está consumiendo todas las iteraciones. k = 1083
# Backtracking está consumiendo todas las iteraciones. k = 1088
# Backtracking está consumiendo todas las iteraciones. k = 1090
# Backtracking está consumiendo todas las iteraciones. k = 1094
# Backtracking está consumiendo todas las iteraciones. k = 1100
# Backtracking está consumiendo todas las iteraciones. k = 1102
# Backtracking está consumiendo todas las iteraciones. k = 1111
# Backtracking está consumiendo todas las iteraciones. k = 1117
# Backtracking está consumiendo todas las iteraciones. k = 1119
# Backtracking está consumiendo todas las iteraciones. k = 1128
# Backtracking está consumiendo todas las iteraciones. k = 1134
# Backtracking está consumiendo todas las iteraciones. k = 1136
# Backtracking está consumiendo todas las iteraciones. k = 1145
# Backtracking está consumiendo todas las iteraciones. k = 1147
# Backtracking está consumiendo todas las iteraciones. k = 1156
# Backtracking está consumiendo todas las iteraciones. k = 1162
# Backtracking está consumiendo todas las iteraciones. k = 1164
# Backtracking está consumiendo todas las iteraciones. k = 1173
# Backtracking está consumiendo todas las iteraciones. k = 1179
# Backtracking está consumiendo todas las iteraciones. k = 1181
# Backtracking está consumiendo todas las iteraciones. k = 1190
# Backtracking está consumiendo todas las iteraciones. k = 1196
# Backtracking está consumiendo todas las iteraciones. k = 1198
# Backtracking está consumiendo todas las iteraciones. k = 1207
# Backtracking está consumiendo todas las iteraciones. k = 1209
# Backtracking está consumiendo todas las iteraciones. k = 1218
# Backtracking está consumiendo todas las iteraciones. k = 1224
# Backtracking está consumiendo todas las iteraciones. k = 1226
# Backtracking está consumiendo todas las iteraciones. k = 1235
# Backtracking está consumiendo todas las iteraciones. k = 1241
# Backtracking está consumiendo todas las iteraciones. k = 1243
# Backtracking está consumiendo todas las iteraciones. k = 1252
# Backtracking está consumiendo todas las iteraciones. k = 1254
# Backtracking está consumiendo todas las iteraciones. k = 1259
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1265
# Backtracking está consumiendo todas las iteraciones. k = 1271
# Backtracking está consumiendo todas las iteraciones. k = 1273
# Backtracking está consumiendo todas las iteraciones. k = 1282
# Backtracking está consumiendo todas las iteraciones. k = 1288
# Backtracking está consumiendo todas las iteraciones. k = 1290
# Backtracking está consumiendo todas las iteraciones. k = 1299
# Backtracking está consumiendo todas las iteraciones. k = 1305
# Backtracking está consumiendo todas las iteraciones. k = 1307
# Backtracking está consumiendo todas las iteraciones. k = 1316
# Backtracking está consumiendo todas las iteraciones. k = 1318
# Backtracking está consumiendo todas las iteraciones. k = 1323
# Backtracking está consumiendo todas las iteraciones. k = 1325
# Backtracking está consumiendo todas las iteraciones. k = 1329
# Backtracking está consumiendo todas las iteraciones. k = 1335
# Backtracking está consumiendo todas las iteraciones. k = 1337
# Backtracking está consumiendo todas las iteraciones. k = 1346
# Backtracking está consumiendo todas las iteraciones. k = 1352
# Backtracking está consumiendo todas las iteraciones. k = 1354
# Backtracking está consumiendo todas las iteraciones. k = 1363
# Backtracking está consumiendo todas las iteraciones. k = 1369
# Backtracking está consumiendo todas las iteraciones. k = 1371
# Backtracking está consumiendo todas las iteraciones. k = 1380
# Backtracking está consumiendo todas las iteraciones. k = 1382
# Backtracking está consumiendo todas las iteraciones. k = 1391
# Backtracking está consumiendo todas las iteraciones. k = 1397
# Backtracking está consumiendo todas las iteraciones. k = 1399
# Backtracking está consumiendo todas las iteraciones. k = 1408
# Backtracking está consumiendo todas las iteraciones. k = 1414
# Backtracking está consumiendo todas las iteraciones. k = 1416
# Backtracking está consumiendo todas las iteraciones. k = 1425
# Backtracking está consumiendo todas las iteraciones. k = 1427
# Backtracking está consumiendo todas las iteraciones. k = 1432
# Backtracking está consumiendo todas las iteraciones. k = 1434
# Backtracking está consumiendo todas las iteraciones. k = 1438
# Backtracking está consumiendo todas las iteraciones. k = 1444
# Backtracking está consumiendo todas las iteraciones. k = 1446
# Backtracking está consumiendo todas las iteraciones. k = 1455
# Backtracking está consumiendo todas las iteraciones. k = 1461
# Backtracking está consumiendo todas las iteraciones. k = 1463
# Backtracking está consumiendo todas las iteraciones. k = 1472
# Backtracking está consumiendo todas las iteraciones. k = 1478
# Backtracking está consumiendo todas las iteraciones. k = 1480
# Backtracking está consumiendo todas las iteraciones. k = 1489
# Backtracking está consumiendo todas las iteraciones. k = 1491
# Backtracking está consumiendo todas las iteraciones. k = 1500
# Backtracking está consumiendo todas las iteraciones. k = 1506
# Backtracking está consumiendo todas las iteraciones. k = 1508
# Backtracking está consumiendo todas las iteraciones. k = 1517
# Backtracking está consumiendo todas las iteraciones. k = 1523
# Backtracking está consumiendo todas las iteraciones. k = 1525
# Backtracking está consumiendo todas las iteraciones. k = 1534
# Backtracking está consumiendo todas las iteraciones. k = 1536
# Backtracking está consumiendo todas las iteraciones. k = 1541
# Backtracking está consumiendo todas las iteraciones. k = 1543
# Backtracking está consumiendo todas las iteraciones. k = 1547
# Backtracking está consumiendo todas las iteraciones. k = 1553
# Backtracking está consumiendo todas las iteraciones. k = 1555
# Backtracking está consumiendo todas las iteraciones. k = 1564
# Backtracking está consumiendo todas las iteraciones. k = 1570
# Backtracking está consumiendo todas las iteraciones. k = 1572
# Backtracking está consumiendo todas las iteraciones. k = 1581
# Backtracking está consumiendo todas las iteraciones. k = 1587
# Backtracking está consumiendo todas las iteraciones. k = 1589
# Backtracking está consumiendo todas las iteraciones. k = 1598
# Backtracking está consumiendo todas las iteraciones. k = 1600
# Backtracking está consumiendo todas las iteraciones. k = 1609
# Backtracking está consumiendo todas las iteraciones. k = 1615
# Backtracking está consumiendo todas las iteraciones. k = 1617
# Backtracking está consumiendo todas las iteraciones. k = 1626
# Backtracking está consumiendo todas las iteraciones. k = 1632
# Backtracking está consumiendo todas las iteraciones. k = 1634
# Backtracking está consumiendo todas las iteraciones. k = 1643
# Backtracking está consumiendo todas las iteraciones. k = 1645
# Backtracking está consumiendo todas las iteraciones. k = 1650
# Backtracking está consumiendo todas las iteraciones. k = 1652
# Backtracking está consumiendo todas las iteraciones. k = 1656
# Backtracking está consumiendo todas las iteraciones. k = 1662
# Backtracking está consumiendo todas las iteraciones. k = 1664
# Backtracking está consumiendo todas las iteraciones. k = 1673
# Backtracking está consumiendo todas las iteraciones. k = 1679
# Backtracking está consumiendo todas las iteraciones. k = 1681
# Backtracking está consumiendo todas las iteraciones. k = 1690
# Backtracking está consumiendo todas las iteraciones. k = 1696
# Backtracking está consumiendo todas las iteraciones. k = 1698
# Backtracking está consumiendo todas las iteraciones. k = 1707
# Backtracking está consumiendo todas las iteraciones. k = 1709
# Backtracking está consumiendo todas las iteraciones. k = 1718
# Backtracking está consumiendo todas las iteraciones. k = 1724
# Backtracking está consumiendo todas las iteraciones. k = 1726
# Backtracking está consumiendo todas las iteraciones. k = 1735
# Backtracking está consumiendo todas las iteraciones. k = 1741
# Backtracking está consumiendo todas las iteraciones. k = 1743
# Backtracking está consumiendo todas las iteraciones. k = 1752
# Backtracking está consumiendo todas las iteraciones. k = 1754
# Backtracking está consumiendo todas las iteraciones. k = 1759
# Backtracking está consumiendo todas las iteraciones. k = 1761
# Backtracking está consumiendo todas las iteraciones. k = 1765
# Backtracking está consumiendo todas las iteraciones. k = 1771
# Backtracking está consumiendo todas las iteraciones. k = 1773
# Backtracking está consumiendo todas las iteraciones. k = 1782
# Backtracking está consumiendo todas las iteraciones. k = 1788
# Backtracking está consumiendo todas las iteraciones. k = 1790
# Backtracking está consumiendo todas las iteraciones. k = 1799
# Backtracking está consumiendo todas las iteraciones. k = 1801
# Backtracking está consumiendo todas las iteraciones. k = 1806
# Backtracking está consumiendo todas las iteraciones. k = 1808
# Backtracking está consumiendo todas las iteraciones. k = 1812
# Backtracking está consumiendo todas las iteraciones. k = 1818
# Backtracking está consumiendo todas las iteraciones. k = 1820
# Backtracking está consumiendo todas las iteraciones. k = 1829
# Backtracking está consumiendo todas las iteraciones. k = 1835
# Backtracking está consumiendo todas las iteraciones. k = 1837
# Backtracking está consumiendo todas las iteraciones. k = 1846
# Backtracking está consumiendo todas las iteraciones. k = 1852
# Backtracking está consumiendo todas las iteraciones. k = 1854
# Backtracking está consumiendo todas las iteraciones. k = 1863
# Backtracking está consumiendo todas las iteraciones. k = 1865
# Backtracking está consumiendo todas las iteraciones. k = 1874
# Backtracking está consumiendo todas las iteraciones. k = 1880
# Backtracking está consumiendo todas las iteraciones. k = 1882
# Backtracking está consumiendo todas las iteraciones. k = 1891
# Backtracking está consumiendo todas las iteraciones. k = 1897
# Backtracking está consumiendo todas las iteraciones. k = 1899
# Backtracking está consumiendo todas las iteraciones. k = 1908
# Backtracking está consumiendo todas las iteraciones. k = 1910
# Backtracking está consumiendo todas las iteraciones. k = 1915
# Backtracking está consumiendo todas las iteraciones. k = 1917
# Backtracking está consumiendo todas las iteraciones. k = 1921
# Backtracking está consumiendo todas las iteraciones. k = 1927
# Backtracking está consumiendo todas las iteraciones. k = 1929
# Backtracking está consumiendo todas las iteraciones. k = 1938
# Backtracking está consumiendo todas las iteraciones. k = 1944
# Backtracking está consumiendo todas las iteraciones. k = 1946
# Backtracking está consumiendo todas las iteraciones. k = 1955
# Backtracking está consumiendo todas las iteraciones. k = 1961
# Backtracking está consumiendo todas las iteraciones. k = 1963
# Backtracking está consumiendo todas las iteraciones. k = 1972
# Backtracking está consumiendo todas las iteraciones. k = 1974
# Backtracking está consumiendo todas las iteraciones. k = 1983
# Backtracking está consumiendo todas las iteraciones. k = 1989
# Backtracking está consumiendo todas las iteraciones. k = 1991
# Backtracking está consumiendo todas las iteraciones. k = 2000
# Backtracking está consumiendo todas las iteraciones. k = 2006
# Backtracking está consumiendo todas las iteraciones. k = 2008
# Backtracking está consumiendo todas las iteraciones. k = 2017
# Backtracking está consumiendo todas las iteraciones. k = 2019
# Backtracking está consumiendo todas las iteraciones. k = 2028
# Backtracking está consumiendo todas las iteraciones. k = 2034
# Backtracking está consumiendo todas las iteraciones. k = 2036
# Backtracking está consumiendo todas las iteraciones. k = 2045
# Backtracking está consumiendo todas las iteraciones. k = 2051
# Backtracking está consumiendo todas las iteraciones. k = 2053
# Backtracking está consumiendo todas las iteraciones. k = 2062
# Backtracking está consumiendo todas las iteraciones. k = 2064
# Backtracking está consumiendo todas las iteraciones. k = 2069
# Backtracking está consumiendo todas las iteraciones. k = 2071
# Backtracking está consumiendo todas las iteraciones. k = 2075
# Backtracking está consumiendo todas las iteraciones. k = 2081
# Backtracking está consumiendo todas las iteraciones. k = 2083
# Backtracking está consumiendo todas las iteraciones. k = 2092
# Backtracking está consumiendo todas las iteraciones. k = 2098
# Backtracking está consumiendo todas las iteraciones. k = 2100
# Backtracking está consumiendo todas las iteraciones. k = 2109
# Backtracking está consumiendo todas las iteraciones. k = 2111
# Backtracking está consumiendo todas las iteraciones. k = 2116
# Backtracking está consumiendo todas las iteraciones. k = 2118
# Backtracking está consumiendo todas las iteraciones. k = 2122
# Backtracking está consumiendo todas las iteraciones. k = 2128
# Backtracking está consumiendo todas las iteraciones. k = 2130
# Backtracking está consumiendo todas las iteraciones. k = 2139
# Backtracking está consumiendo todas las iteraciones. k = 2145
# Backtracking está consumiendo todas las iteraciones. k = 2147
# Backtracking está consumiendo todas las iteraciones. k = 2156
# Backtracking está consumiendo todas las iteraciones. k = 2162
# Backtracking está consumiendo todas las iteraciones. k = 2164
# Backtracking está consumiendo todas las iteraciones. k = 2173
# Backtracking está consumiendo todas las iteraciones. k = 2175
# Backtracking está consumiendo todas las iteraciones. k = 2184
# Backtracking está consumiendo todas las iteraciones. k = 2190
# Backtracking está consumiendo todas las iteraciones. k = 2192
# Backtracking está consumiendo todas las iteraciones. k = 2201
# Backtracking está consumiendo todas las iteraciones. k = 2207
# Backtracking está consumiendo todas las iteraciones. k = 2209
# Backtracking está consumiendo todas las iteraciones. k = 2218
# Backtracking está consumiendo todas las iteraciones. k = 2220
# Backtracking está consumiendo todas las iteraciones. k = 2229
# Backtracking está consumiendo todas las iteraciones. k = 2235
# Backtracking está consumiendo todas las iteraciones. k = 2237
# Backtracking está consumiendo todas las iteraciones. k = 2246
# Backtracking está consumiendo todas las iteraciones. k = 2252
# Backtracking está consumiendo todas las iteraciones. k = 2254
# Backtracking está consumiendo todas las iteraciones. k = 2263
# Backtracking está consumiendo todas las iteraciones. k = 2265
# Backtracking está consumiendo todas las iteraciones. k = 2270
# Backtracking está consumiendo todas las iteraciones. k = 2272
# Backtracking está consumiendo todas las iteraciones. k = 2276
# Backtracking está consumiendo todas las iteraciones. k = 2282
# Backtracking está consumiendo todas las iteraciones. k = 2284
# Backtracking está consumiendo todas las iteraciones. k = 2293
# Backtracking está consumiendo todas las iteraciones. k = 2299
# Backtracking está consumiendo todas las iteraciones. k = 2301
# Backtracking está consumiendo todas las iteraciones. k = 2310
# Backtracking está consumiendo todas las iteraciones. k = 2312
# Backtracking está consumiendo todas las iteraciones. k = 2317
# Backtracking está consumiendo todas las iteraciones. k = 2319
# Backtracking está consumiendo todas las iteraciones. k = 2323
# Backtracking está consumiendo todas las iteraciones. k = 2329
# Backtracking está consumiendo todas las iteraciones. k = 2331
# Backtracking está consumiendo todas las iteraciones. k = 2340
# Backtracking está consumiendo todas las iteraciones. k = 2346
# Backtracking está consumiendo todas las iteraciones. k = 2348
# Backtracking está consumiendo todas las iteraciones. k = 2357
# Backtracking está consumiendo todas las iteraciones. k = 2363
# Backtracking está consumiendo todas las iteraciones. k = 2365
# Backtracking está consumiendo todas las iteraciones. k = 2374
# Backtracking está consumiendo todas las iteraciones. k = 2376
# Backtracking está consumiendo todas las iteraciones. k = 2385
# Backtracking está consumiendo todas las iteraciones. k = 2391
# Backtracking está consumiendo todas las iteraciones. k = 2393
# Backtracking está consumiendo todas las iteraciones. k = 2402
# Backtracking está consumiendo todas las iteraciones. k = 2408
# Backtracking está consumiendo todas las iteraciones. k = 2410
# Backtracking está consumiendo todas las iteraciones. k = 2419
# Backtracking está consumiendo todas las iteraciones. k = 2421
# Backtracking está consumiendo todas las iteraciones. k = 2430
# Backtracking está consumiendo todas las iteraciones. k = 2436
# Backtracking está consumiendo todas las iteraciones. k = 2438
# Backtracking está consumiendo todas las iteraciones. k = 2447
# Backtracking está consumiendo todas las iteraciones. k = 2453
# Backtracking está consumiendo todas las iteraciones. k = 2455
# Backtracking está consumiendo todas las iteraciones. k = 2464
# Backtracking está consumiendo todas las iteraciones. k = 2466
# Backtracking está consumiendo todas las iteraciones. k = 2475
# Backtracking está consumiendo todas las iteraciones. k = 2481
# Backtracking está consumiendo todas las iteraciones. k = 2483
# Backtracking está consumiendo todas las iteraciones. k = 2492
# Backtracking está consumiendo todas las iteraciones. k = 2498
# Backtracking está consumiendo todas las iteraciones. k = 2500
# Backtracking está consumiendo todas las iteraciones. k = 2509
# Backtracking está consumiendo todas las iteraciones. k = 2511
# Backtracking está consumiendo todas las iteraciones. k = 2516
# Backtracking está consumiendo todas las iteraciones. k = 2518
# Backtracking está consumiendo todas las iteraciones. k = 2522
# Backtracking está consumiendo todas las iteraciones. k = 2528
# Backtracking está consumiendo todas las iteraciones. k = 2530
# Backtracking está consumiendo todas las iteraciones. k = 2539
# Backtracking está consumiendo todas las iteraciones. k = 2545
# Backtracking está consumiendo todas las iteraciones. k = 2547
# Backtracking está consumiendo todas las iteraciones. k = 2556
# Backtracking está consumiendo todas las iteraciones. k = 2558
# Backtracking está consumiendo todas las iteraciones. k = 2563
# Backtracking está consumiendo todas las iteraciones. k = 2565
# Backtracking está consumiendo todas las iteraciones. k = 2569
# Backtracking está consumiendo todas las iteraciones. k = 2575
# Backtracking está consumiendo todas las iteraciones. k = 2577
# Backtracking está consumiendo todas las iteraciones. k = 2586
# Backtracking está consumiendo todas las iteraciones. k = 2592
# Backtracking está consumiendo todas las iteraciones. k = 2594
# Backtracking está consumiendo todas las iteraciones. k = 2603
# Backtracking está consumiendo todas las iteraciones. k = 2609
# Backtracking está consumiendo todas las iteraciones. k = 2611
# Backtracking está consumiendo todas las iteraciones. k = 2620
# Backtracking está consumiendo todas las iteraciones. k = 2622
# Backtracking está consumiendo todas las iteraciones. k = 2631
# Backtracking está consumiendo todas las iteraciones. k = 2637
# Backtracking está consumiendo todas las iteraciones. k = 2639
# Backtracking está consumiendo todas las iteraciones. k = 2648
# Backtracking está consumiendo todas las iteraciones. k = 2654
# Backtracking está consumiendo todas las iteraciones. k = 2656
# Backtracking está consumiendo todas las iteraciones. k = 2665
# Backtracking está consumiendo todas las iteraciones. k = 2667
# Backtracking está consumiendo todas las iteraciones. k = 2676
# Backtracking está consumiendo todas las iteraciones. k = 2682
# Backtracking está consumiendo todas las iteraciones. k = 2684
# Backtracking está consumiendo todas las iteraciones. k = 2693
# Backtracking está consumiendo todas las iteraciones. k = 2699
# Backtracking está consumiendo todas las iteraciones. k = 2701
# Backtracking está consumiendo todas las iteraciones. k = 2710
# Backtracking está consumiendo todas las iteraciones. k = 2712
# Backtracking está consumiendo todas las iteraciones. k = 2721
# Backtracking está consumiendo todas las iteraciones. k = 2727
# Backtracking está consumiendo todas las iteraciones. k = 2729
# Backtracking está consumiendo todas las iteraciones. k = 2738
# Backtracking está consumiendo todas las iteraciones. k = 2744
# Backtracking está consumiendo todas las iteraciones. k = 2746
# Backtracking está consumiendo todas las iteraciones. k = 2755
# Backtracking está consumiendo todas las iteraciones. k = 2757
# Backtracking está consumiendo todas las iteraciones. k = 2762
# Backtracking está consumiendo todas las iteraciones. k = 2764
# Backtracking está consumiendo todas las iteraciones. k = 2768
# Backtracking está consumiendo todas las iteraciones. k = 2774
# Backtracking está consumiendo todas las iteraciones. k = 2776
# Backtracking está consumiendo todas las iteraciones. k = 2785
# Backtracking está consumiendo todas las iteraciones. k = 2791
# Backtracking está consumiendo todas las iteraciones. k = 2793
# Backtracking está consumiendo todas las iteraciones. k = 2802
# Backtracking está consumiendo todas las iteraciones. k = 2804
# Backtracking está consumiendo todas las iteraciones. k = 2809
# Backtracking está consumiendo todas las iteraciones. k = 2811
# Backtracking está consumiendo todas las iteraciones. k = 2815
# Backtracking está consumiendo todas las iteraciones. k = 2821
# Backtracking está consumiendo todas las iteraciones. k = 2823
# Backtracking está consumiendo todas las iteraciones. k = 2832
# Backtracking está consumiendo todas las iteraciones. k = 2838
# Backtracking está consumiendo todas las iteraciones. k = 2840
# Backtracking está consumiendo todas las iteraciones. k = 2849
# Backtracking está consumiendo todas las iteraciones. k = 2851
# Backtracking está consumiendo todas las iteraciones. k = 2856
# Backtracking está consumiendo todas las iteraciones. k = 2858
# Backtracking está consumiendo todas las iteraciones. k = 2862
# Backtracking está consumiendo todas las iteraciones. k = 2868
# Backtracking está consumiendo todas las iteraciones. k = 2870
# Backtracking está consumiendo todas las iteraciones. k = 2879
# Backtracking está consumiendo todas las iteraciones. k = 2885
# Backtracking está consumiendo todas las iteraciones. k = 2887
# Backtracking está consumiendo todas las iteraciones. k = 2896
# Backtracking está consumiendo todas las iteraciones. k = 2902
# Backtracking está consumiendo todas las iteraciones. k = 2904
# Backtracking está consumiendo todas las iteraciones. k = 2908
# Backtracking está consumiendo todas las iteraciones. k = 2914
# Backtracking está consumiendo todas las iteraciones. k = 2916
# Backtracking está consumiendo todas las iteraciones. k = 2925
# Backtracking está consumiendo todas las iteraciones. k = 2931
# Backtracking está consumiendo todas las iteraciones. k = 2933
# Backtracking está consumiendo todas las iteraciones. k = 2942
# Backtracking está consumiendo todas las iteraciones. k = 2948
# Backtracking está consumiendo todas las iteraciones. k = 2950
# Backtracking está consumiendo todas las iteraciones. k = 2959
# Backtracking está consumiendo todas las iteraciones. k = 2961
# Backtracking está consumiendo todas las iteraciones. k = 2970
# Backtracking está consumiendo todas las iteraciones. k = 2976
# Backtracking está consumiendo todas las iteraciones. k = 2978
# Backtracking está consumiendo todas las iteraciones. k = 2987
# Backtracking está consumiendo todas las iteraciones. k = 2993
# Backtracking está consumiendo todas las iteraciones. k = 2995
# Backtracking está consumiendo todas las iteraciones. k = 3004
# Backtracking está consumiendo todas las iteraciones. k = 3006
# Backtracking está consumiendo todas las iteraciones. k = 3015
# Backtracking está consumiendo todas las iteraciones. k = 3021
# Backtracking está consumiendo todas las iteraciones. k = 3023
# Backtracking está consumiendo todas las iteraciones. k = 3032
# Backtracking está consumiendo todas las iteraciones. k = 3038
# Backtracking está consumiendo todas las iteraciones. k = 3040
# Backtracking está consumiendo todas las iteraciones. k = 3049
# Backtracking está consumiendo todas las iteraciones. k = 3051
# Backtracking está consumiendo todas las iteraciones. k = 3060
# Backtracking está consumiendo todas las iteraciones. k = 3066
# Backtracking está consumiendo todas las iteraciones. k = 3068
# Backtracking está consumiendo todas las iteraciones. k = 3077
# Backtracking está consumiendo todas las iteraciones. k = 3083
# Backtracking está consumiendo todas las iteraciones. k = 3085
# Backtracking está consumiendo todas las iteraciones. k = 3094
# Backtracking está consumiendo todas las iteraciones. k = 3096
# Backtracking está consumiendo todas las iteraciones. k = 3105
# Backtracking está consumiendo todas las iteraciones. k = 3111
# Backtracking está consumiendo todas las iteraciones. k = 3113
# Backtracking está consumiendo todas las iteraciones. k = 3122
# Backtracking está consumiendo todas las iteraciones. k = 3128
# Backtracking está consumiendo todas las iteraciones. k = 3130
# Backtracking está consumiendo todas las iteraciones. k = 3139
# Backtracking está consumiendo todas las iteraciones. k = 3141
# Backtracking está consumiendo todas las iteraciones. k = 3146
# Backtracking está consumiendo todas las iteraciones. k = 3148
# Backtracking está consumiendo todas las iteraciones. k = 3152
# Backtracking está consumiendo todas las iteraciones. k = 3158
# Backtracking está consumiendo todas las iteraciones. k = 3160
# Backtracking está consumiendo todas las iteraciones. k = 3169
# Backtracking está consumiendo todas las iteraciones. k = 3175
# Backtracking está consumiendo todas las iteraciones. k = 3177
# Backtracking está consumiendo todas las iteraciones. k = 3186
# Backtracking está consumiendo todas las iteraciones. k = 3188
# Backtracking está consumiendo todas las iteraciones. k = 3193
# Backtracking está consumiendo todas las iteraciones. k = 3195
# Backtracking está consumiendo todas las iteraciones. k = 3199
# Backtracking está consumiendo todas las iteraciones. k = 3205
# Backtracking está consumiendo todas las iteraciones. k = 3207
# Backtracking está consumiendo todas las iteraciones. k = 3216
# Backtracking está consumiendo todas las iteraciones. k = 3222
# Backtracking está consumiendo todas las iteraciones. k = 3224
# Backtracking está consumiendo todas las iteraciones. k = 3233
# Backtracking está consumiendo todas las iteraciones. k = 3235
# Backtracking está consumiendo todas las iteraciones. k = 3240
# Backtracking está consumiendo todas las iteraciones. k = 3242
# Backtracking está consumiendo todas las iteraciones. k = 3246
# Backtracking está consumiendo todas las iteraciones. k = 3252
# Backtracking está consumiendo todas las iteraciones. k = 3254
# Backtracking está consumiendo todas las iteraciones. k = 3263
# Backtracking está consumiendo todas las iteraciones. k = 3269
# Backtracking está consumiendo todas las iteraciones. k = 3271
# Backtracking está consumiendo todas las iteraciones. k = 3280
# Backtracking está consumiendo todas las iteraciones. k = 3282
# Backtracking está consumiendo todas las iteraciones. k = 3287
# Backtracking está consumiendo todas las iteraciones. k = 3289
# Backtracking está consumiendo todas las iteraciones. k = 3293
# Backtracking está consumiendo todas las iteraciones. k = 3299
# Backtracking está consumiendo todas las iteraciones. k = 3301
# Backtracking está consumiendo todas las iteraciones. k = 3310
# Backtracking está consumiendo todas las iteraciones. k = 3316
# Backtracking está consumiendo todas las iteraciones. k = 3318
# Backtracking está consumiendo todas las iteraciones. k = 3327
# Backtracking está consumiendo todas las iteraciones. k = 3329
# Backtracking está consumiendo todas las iteraciones. k = 3334
# Backtracking está consumiendo todas las iteraciones. k = 3336
# Backtracking está consumiendo todas las iteraciones. k = 3340
# Backtracking está consumiendo todas las iteraciones. k = 3346
# Backtracking está consumiendo todas las iteraciones. k = 3348
# Backtracking está consumiendo todas las iteraciones. k = 3357
# Backtracking está consumiendo todas las iteraciones. k = 3363
# Backtracking está consumiendo todas las iteraciones. k = 3365
# Backtracking está consumiendo todas las iteraciones. k = 3374
# Backtracking está consumiendo todas las iteraciones. k = 3380
# Backtracking está consumiendo todas las iteraciones. k = 3382
# Backtracking está consumiendo todas las iteraciones. k = 3386
# Backtracking está consumiendo todas las iteraciones. k = 3392
# Backtracking está consumiendo todas las iteraciones. k = 3394
# Backtracking está consumiendo todas las iteraciones. k = 3403
# Backtracking está consumiendo todas las iteraciones. k = 3409
# Backtracking está consumiendo todas las iteraciones. k = 3411
# Backtracking está consumiendo todas las iteraciones. k = 3420
# Backtracking está consumiendo todas las iteraciones. k = 3426
# Backtracking está consumiendo todas las iteraciones. k = 3428
# Backtracking está consumiendo todas las iteraciones. k = 3437
# Backtracking está consumiendo todas las iteraciones. k = 3439
# Backtracking está consumiendo todas las iteraciones. k = 3448
# Backtracking está consumiendo todas las iteraciones. k = 3454
# Backtracking está consumiendo todas las iteraciones. k = 3456
# Backtracking está consumiendo todas las iteraciones. k = 3465
# Backtracking está consumiendo todas las iteraciones. k = 3471
# Backtracking está consumiendo todas las iteraciones. k = 3473
# Backtracking está consumiendo todas las iteraciones. k = 3482
# Backtracking está consumiendo todas las iteraciones. k = 3484
# Backtracking está consumiendo todas las iteraciones. k = 3493
# Backtracking está consumiendo todas las iteraciones. k = 3499
# Backtracking está consumiendo todas las iteraciones. k = 3501
# Backtracking está consumiendo todas las iteraciones. k = 3510
# Backtracking está consumiendo todas las iteraciones. k = 3516
# Backtracking está consumiendo todas las iteraciones. k = 3518
# Backtracking está consumiendo todas las iteraciones. k = 3527
# Backtracking está consumiendo todas las iteraciones. k = 3529
# Backtracking está consumiendo todas las iteraciones. k = 3538
# Backtracking está consumiendo todas las iteraciones. k = 3544
# Backtracking está consumiendo todas las iteraciones. k = 3546
# Backtracking está consumiendo todas las iteraciones. k = 3555
# Backtracking está consumiendo todas las iteraciones. k = 3561
# Backtracking está consumiendo todas las iteraciones. k = 3563
# Backtracking está consumiendo todas las iteraciones. k = 3572
# Backtracking está consumiendo todas las iteraciones. k = 3574
# Backtracking está consumiendo todas las iteraciones. k = 3583
# Backtracking está consumiendo todas las iteraciones. k = 3589
# Backtracking está consumiendo todas las iteraciones. k = 3591
# Backtracking está consumiendo todas las iteraciones. k = 3600
# Backtracking está consumiendo todas las iteraciones. k = 3606
# Backtracking está consumiendo todas las iteraciones. k = 3608
# Backtracking está consumiendo todas las iteraciones. k = 3617
# Backtracking está consumiendo todas las iteraciones. k = 3619
# Backtracking está consumiendo todas las iteraciones. k = 3628
# Backtracking está consumiendo todas las iteraciones. k = 3634
# Backtracking está consumiendo todas las iteraciones. k = 3636
# Backtracking está consumiendo todas las iteraciones. k = 3645
# Backtracking está consumiendo todas las iteraciones. k = 3651
# Backtracking está consumiendo todas las iteraciones. k = 3653
# Backtracking está consumiendo todas las iteraciones. k = 3662
# Backtracking está consumiendo todas las iteraciones. k = 3664
# Backtracking está consumiendo todas las iteraciones. k = 3673
# Backtracking está consumiendo todas las iteraciones. k = 3679
# Backtracking está consumiendo todas las iteraciones. k = 3681
# Backtracking está consumiendo todas las iteraciones. k = 3690
# Backtracking está consumiendo todas las iteraciones. k = 3696
# Backtracking está consumiendo todas las iteraciones. k = 3698
# Backtracking está consumiendo todas las iteraciones. k = 3707
# Backtracking está consumiendo todas las iteraciones. k = 3709
# Backtracking está consumiendo todas las iteraciones. k = 3718
# Backtracking está consumiendo todas las iteraciones. k = 3724
# Backtracking está consumiendo todas las iteraciones. k = 3726
# Backtracking está consumiendo todas las iteraciones. k = 3735
# Backtracking está consumiendo todas las iteraciones. k = 3741
# Backtracking está consumiendo todas las iteraciones. k = 3743
# Backtracking está consumiendo todas las iteraciones. k = 3752
# Backtracking está consumiendo todas las iteraciones. k = 3754
# Backtracking está consumiendo todas las iteraciones. k = 3763
# Backtracking está consumiendo todas las iteraciones. k = 3769
# Backtracking está consumiendo todas las iteraciones. k = 3771
# Backtracking está consumiendo todas las iteraciones. k = 3780
# Backtracking está consumiendo todas las iteraciones. k = 3786
# Backtracking está consumiendo todas las iteraciones. k = 3788
# Backtracking está consumiendo todas las iteraciones. k = 3797
# Backtracking está consumiendo todas las iteraciones. k = 3799
# Backtracking está consumiendo todas las iteraciones. k = 3804
# Backtracking está consumiendo todas las iteraciones. k = 3806
# Backtracking está consumiendo todas las iteraciones. k = 3810
# Backtracking está consumiendo todas las iteraciones. k = 3816
# Backtracking está consumiendo todas las iteraciones. k = 3818
# Backtracking está consumiendo todas las iteraciones. k = 3827
# Backtracking está consumiendo todas las iteraciones. k = 3833
# Backtracking está consumiendo todas las iteraciones. k = 3835
# Backtracking está consumiendo todas las iteraciones. k = 3844
# Backtracking está consumiendo todas las iteraciones. k = 3846
# Backtracking está consumiendo todas las iteraciones. k = 3851
# Backtracking está consumiendo todas las iteraciones. k = 3853
# Backtracking está consumiendo todas las iteraciones. k = 3857
# Backtracking está consumiendo todas las iteraciones. k = 3863
# Backtracking está consumiendo todas las iteraciones. k = 3865
# Backtracking está consumiendo todas las iteraciones. k = 3874
# Backtracking está consumiendo todas las iteraciones. k = 3880
# Backtracking está consumiendo todas las iteraciones. k = 3882
# Backtracking está consumiendo todas las iteraciones. k = 3891
# Backtracking está consumiendo todas las iteraciones. k = 3893
# Backtracking está consumiendo todas las iteraciones. k = 3898
# Backtracking está consumiendo todas las iteraciones. k = 3900
# Backtracking está consumiendo todas las iteraciones. k = 3904
# Backtracking está consumiendo todas las iteraciones. k = 3910
# Backtracking está consumiendo todas las iteraciones. k = 3912
# Backtracking está consumiendo todas las iteraciones. k = 3921
# Backtracking está consumiendo todas las iteraciones. k = 3927
# Backtracking está consumiendo todas las iteraciones. k = 3929
# Backtracking está consumiendo todas las iteraciones. k = 3938
# Backtracking está consumiendo todas las iteraciones. k = 3940
# Backtracking está consumiendo todas las iteraciones. k = 3945
# Backtracking está consumiendo todas las iteraciones. k = 3947
# Backtracking está consumiendo todas las iteraciones. k = 3951
# Backtracking está consumiendo todas las iteraciones. k = 3957
# Backtracking está consumiendo todas las iteraciones. k = 3959
# Backtracking está consumiendo todas las iteraciones. k = 3968
# Backtracking está consumiendo todas las iteraciones. k = 3974
# Backtracking está consumiendo todas las iteraciones. k = 3976
# Backtracking está consumiendo todas las iteraciones. k = 3985
# Backtracking está consumiendo todas las iteraciones. k = 3987
# Backtracking está consumiendo todas las iteraciones. k = 3992
# Backtracking está consumiendo todas las iteraciones. k = 3994
# Backtracking está consumiendo todas las iteraciones. k = 3998
# Backtracking está consumiendo todas las iteraciones. k = 4004
# Backtracking está consumiendo todas las iteraciones. k = 4006
# Backtracking está consumiendo todas las iteraciones. k = 4015
# Backtracking está consumiendo todas las iteraciones. k = 4021
# Backtracking está consumiendo todas las iteraciones. k = 4023
# Backtracking está consumiendo todas las iteraciones. k = 4032
# Backtracking está consumiendo todas las iteraciones. k = 4034
# Backtracking está consumiendo todas las iteraciones. k = 4039
# Backtracking está consumiendo todas las iteraciones. k = 4041
# Backtracking está consumiendo todas las iteraciones. k = 4045
# Backtracking está consumiendo todas las iteraciones. k = 4051
# Backtracking está consumiendo todas las iteraciones. k = 4053
# Backtracking está consumiendo todas las iteraciones. k = 4062
# Backtracking está consumiendo todas las iteraciones. k = 4068
# Backtracking está consumiendo todas las iteraciones. k = 4070
# Backtracking está consumiendo todas las iteraciones. k = 4079
# Backtracking está consumiendo todas las iteraciones. k = 4081
# Backtracking está consumiendo todas las iteraciones. k = 4086
# Backtracking está consumiendo todas las iteraciones. k = 4088
# Backtracking está consumiendo todas las iteraciones. k = 4092
# Backtracking está consumiendo todas las iteraciones. k = 4098
# Backtracking está consumiendo todas las iteraciones. k = 4100
# Backtracking está consumiendo todas las iteraciones. k = 4109
# Backtracking está consumiendo todas las iteraciones. k = 4115
# Backtracking está consumiendo todas las iteraciones. k = 4117
# Backtracking está consumiendo todas las iteraciones. k = 4126
# Backtracking está consumiendo todas las iteraciones. k = 4128
# Backtracking está consumiendo todas las iteraciones. k = 4133
# Backtracking está consumiendo todas las iteraciones. k = 4135
# Backtracking está consumiendo todas las iteraciones. k = 4139
# Backtracking está consumiendo todas las iteraciones. k = 4145
# Backtracking está consumiendo todas las iteraciones. k = 4147
# Backtracking está consumiendo todas las iteraciones. k = 4156
# Backtracking está consumiendo todas las iteraciones. k = 4162
# Backtracking está consumiendo todas las iteraciones. k = 4164
# Backtracking está consumiendo todas las iteraciones. k = 4173
# Backtracking está consumiendo todas las iteraciones. k = 4175
# Backtracking está consumiendo todas las iteraciones. k = 4180
# Backtracking está consumiendo todas las iteraciones. k = 4182
# Backtracking está consumiendo todas las iteraciones. k = 4186
# Backtracking está consumiendo todas las iteraciones. k = 4192
# Backtracking está consumiendo todas las iteraciones. k = 4194
# Backtracking está consumiendo todas las iteraciones. k = 4203
# Backtracking está consumiendo todas las iteraciones. k = 4209
# Backtracking está consumiendo todas las iteraciones. k = 4211
# Backtracking está consumiendo todas las iteraciones. k = 4220
# Backtracking está consumiendo todas las iteraciones. k = 4222
# Backtracking está consumiendo todas las iteraciones. k = 4227
# Backtracking está consumiendo todas las iteraciones. k = 4229
# Backtracking está consumiendo todas las iteraciones. k = 4233
# Backtracking está consumiendo todas las iteraciones. k = 4239
# Backtracking está consumiendo todas las iteraciones. k = 4241
# Backtracking está consumiendo todas las iteraciones. k = 4250
# Backtracking está consumiendo todas las iteraciones. k = 4256
# Backtracking está consumiendo todas las iteraciones. k = 4258
# Backtracking está consumiendo todas las iteraciones. k = 4267
# Backtracking está consumiendo todas las iteraciones. k = 4269
# Backtracking está consumiendo todas las iteraciones. k = 4274
# Backtracking está consumiendo todas las iteraciones. k = 4276
# Backtracking está consumiendo todas las iteraciones. k = 4280
# Backtracking está consumiendo todas las iteraciones. k = 4286
# Backtracking está consumiendo todas las iteraciones. k = 4288
# Backtracking está consumiendo todas las iteraciones. k = 4297
# Backtracking está consumiendo todas las iteraciones. k = 4303
# Backtracking está consumiendo todas las iteraciones. k = 4305
# Backtracking está consumiendo todas las iteraciones. k = 4314
# Backtracking está consumiendo todas las iteraciones. k = 4316
# Backtracking está consumiendo todas las iteraciones. k = 4321
# Backtracking está consumiendo todas las iteraciones. k = 4323
# Backtracking está consumiendo todas las iteraciones. k = 4327
# Backtracking está consumiendo todas las iteraciones. k = 4333
# Backtracking está consumiendo todas las iteraciones. k = 4335
# Backtracking está consumiendo todas las iteraciones. k = 4344
# Backtracking está consumiendo todas las iteraciones. k = 4350
# Backtracking está consumiendo todas las iteraciones. k = 4352
# Backtracking está consumiendo todas las iteraciones. k = 4361
# Backtracking está consumiendo todas las iteraciones. k = 4363
# Backtracking está consumiendo todas las iteraciones. k = 4368
# Backtracking está consumiendo todas las iteraciones. k = 4370
# Backtracking está consumiendo todas las iteraciones. k = 4374
# Backtracking está consumiendo todas las iteraciones. k = 4380
# Backtracking está consumiendo todas las iteraciones. k = 4382
# Backtracking está consumiendo todas las iteraciones. k = 4391
# Backtracking está consumiendo todas las iteraciones. k = 4397
# Backtracking está consumiendo todas las iteraciones. k = 4399
# Backtracking está consumiendo todas las iteraciones. k = 4408
# Backtracking está consumiendo todas las iteraciones. k = 4410
# Backtracking está consumiendo todas las iteraciones. k = 4415
# Backtracking está consumiendo todas las iteraciones. k = 4417
# Backtracking está consumiendo todas las iteraciones. k = 4421
# Backtracking está consumiendo todas las iteraciones. k = 4427
# Backtracking está consumiendo todas las iteraciones. k = 4429
# Backtracking está consumiendo todas las iteraciones. k = 4438
# Backtracking está consumiendo todas las iteraciones. k = 4444
# Backtracking está consumiendo todas las iteraciones. k = 4446
# Backtracking está consumiendo todas las iteraciones. k = 4455
# Backtracking está consumiendo todas las iteraciones. k = 4457
# Backtracking está consumiendo todas las iteraciones. k = 4462
# Backtracking está consumiendo todas las iteraciones. k = 4464
# Backtracking está consumiendo todas las iteraciones. k = 4468
# Backtracking está consumiendo todas las iteraciones. k = 4474
# Backtracking está consumiendo todas las iteraciones. k = 4476
# Backtracking está consumiendo todas las iteraciones. k = 4485
# Backtracking está consumiendo todas las iteraciones. k = 4491
# Backtracking está consumiendo todas las iteraciones. k = 4493
# Backtracking está consumiendo todas las iteraciones. k = 4502
# Backtracking está consumiendo todas las iteraciones. k = 4504
# Backtracking está consumiendo todas las iteraciones. k = 4509
# Backtracking está consumiendo todas las iteraciones. k = 4511
# Backtracking está consumiendo todas las iteraciones. k = 4515
# Backtracking está consumiendo todas las iteraciones. k = 4521
# Backtracking está consumiendo todas las iteraciones. k = 4523
# Backtracking está consumiendo todas las iteraciones. k = 4532
# Backtracking está consumiendo todas las iteraciones. k = 4538
# Backtracking está consumiendo todas las iteraciones. k = 4540
# Backtracking está consumiendo todas las iteraciones. k = 4549
# Backtracking está consumiendo todas las iteraciones. k = 4551
# Backtracking está consumiendo todas las iteraciones. k = 4556
# Backtracking está consumiendo todas las iteraciones. k = 4558
# Backtracking está consumiendo todas las iteraciones. k = 4562
# Backtracking está consumiendo todas las iteraciones. k = 4568
# Backtracking está consumiendo todas las iteraciones. k = 4570
# Backtracking está consumiendo todas las iteraciones. k = 4579
# Backtracking está consumiendo todas las iteraciones. k = 4585
# Backtracking está consumiendo todas las iteraciones. k = 4587
# Backtracking está consumiendo todas las iteraciones. k = 4596
# Backtracking está consumiendo todas las iteraciones. k = 4598
# Backtracking está consumiendo todas las iteraciones. k = 4603
# Backtracking está consumiendo todas las iteraciones. k = 4605
# Backtracking está consumiendo todas las iteraciones. k = 4609
# Backtracking está consumiendo todas las iteraciones. k = 4615
# Backtracking está consumiendo todas las iteraciones. k = 4617
# Backtracking está consumiendo todas las iteraciones. k = 4626
# Backtracking está consumiendo todas las iteraciones. k = 4632
# Backtracking está consumiendo todas las iteraciones. k = 4634
# Backtracking está consumiendo todas las iteraciones. k = 4643
# Backtracking está consumiendo todas las iteraciones. k = 4645
# Backtracking está consumiendo todas las iteraciones. k = 4650
# Backtracking está consumiendo todas las iteraciones. k = 4652
# Backtracking está consumiendo todas las iteraciones. k = 4656
# Backtracking está consumiendo todas las iteraciones. k = 4662
# Backtracking está consumiendo todas las iteraciones. k = 4664
# Backtracking está consumiendo todas las iteraciones. k = 4673
# Backtracking está consumiendo todas las iteraciones. k = 4679
# Backtracking está consumiendo todas las iteraciones. k = 4681
# Backtracking está consumiendo todas las iteraciones. k = 4690
# Backtracking está consumiendo todas las iteraciones. k = 4692
# Backtracking está consumiendo todas las iteraciones. k = 4697
# Backtracking está consumiendo todas las iteraciones. k = 4699
# Backtracking está consumiendo todas las iteraciones. k = 4703
# Backtracking está consumiendo todas las iteraciones. k = 4709
# Backtracking está consumiendo todas las iteraciones. k = 4711
# Backtracking está consumiendo todas las iteraciones. k = 4720
# Backtracking está consumiendo todas las iteraciones. k = 4726
# Backtracking está consumiendo todas las iteraciones. k = 4728
# Backtracking está consumiendo todas las iteraciones. k = 4737
# Backtracking está consumiendo todas las iteraciones. k = 4739
# Backtracking está consumiendo todas las iteraciones. k = 4744
# Backtracking está consumiendo todas las iteraciones. k = 4746
# Backtracking está consumiendo todas las iteraciones. k = 4750
# Backtracking está consumiendo todas las iteraciones. k = 4756
# Backtracking está consumiendo todas las iteraciones. k = 4758
# Backtracking está consumiendo todas las iteraciones. k = 4767
# Backtracking está consumiendo todas las iteraciones. k = 4773
# Backtracking está consumiendo todas las iteraciones. k = 4775
# Backtracking está consumiendo todas las iteraciones. k = 4784
# Backtracking está consumiendo todas las iteraciones. k = 4786
# Backtracking está consumiendo todas las iteraciones. k = 4791
# Backtracking está consumiendo todas las iteraciones. k = 4793
# Backtracking está consumiendo todas las iteraciones. k = 4797
# Backtracking está consumiendo todas las iteraciones. k = 4803
# Backtracking está consumiendo todas las iteraciones. k = 4805
# Backtracking está consumiendo todas las iteraciones. k = 4814
# Backtracking está consumiendo todas las iteraciones. k = 4820
# Backtracking está consumiendo todas las iteraciones. k = 4822
# Backtracking está consumiendo todas las iteraciones. k = 4831
# Backtracking está consumiendo todas las iteraciones. k = 4833
# Backtracking está consumiendo todas las iteraciones. k = 4838
# Backtracking está consumiendo todas las iteraciones. k = 4840
# Backtracking está consumiendo todas las iteraciones. k = 4844
# Backtracking está consumiendo todas las iteraciones. k = 4850
# Backtracking está consumiendo todas las iteraciones. k = 4852
# Backtracking está consumiendo todas las iteraciones. k = 4861
# Backtracking está consumiendo todas las iteraciones. k = 4867
# Backtracking está consumiendo todas las iteraciones. k = 4869
# Backtracking está consumiendo todas las iteraciones. k = 4878
# Backtracking está consumiendo todas las iteraciones. k = 4880
# Backtracking está consumiendo todas las iteraciones. k = 4885
# Backtracking está consumiendo todas las iteraciones. k = 4887
# Backtracking está consumiendo todas las iteraciones. k = 4891
# Backtracking está consumiendo todas las iteraciones. k = 4897
# Backtracking está consumiendo todas las iteraciones. k = 4899
# Backtracking está consumiendo todas las iteraciones. k = 4908
# Backtracking está consumiendo todas las iteraciones. k = 4914
# Backtracking está consumiendo todas las iteraciones. k = 4916
# Backtracking está consumiendo todas las iteraciones. k = 4925
# Backtracking está consumiendo todas las iteraciones. k = 4927
# Backtracking está consumiendo todas las iteraciones. k = 4932
# Backtracking está consumiendo todas las iteraciones. k = 4934
# Backtracking está consumiendo todas las iteraciones. k = 4938
# Backtracking está consumiendo todas las iteraciones. k = 4944
# Backtracking está consumiendo todas las iteraciones. k = 4946
# Backtracking está consumiendo todas las iteraciones. k = 4955
# Backtracking está consumiendo todas las iteraciones. k = 4961
# Backtracking está consumiendo todas las iteraciones. k = 4963
# Backtracking está consumiendo todas las iteraciones. k = 4972
# Backtracking está consumiendo todas las iteraciones. k = 4974
# Backtracking está consumiendo todas las iteraciones. k = 4979
# Backtracking está consumiendo todas las iteraciones. k = 4981
# Backtracking está consumiendo todas las iteraciones. k = 4985
# Backtracking está consumiendo todas las iteraciones. k = 4991
# Backtracking está consumiendo todas las iteraciones. k = 4993
# Dimension: 1000
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 5000
# La solución alcanzada es:  [ 1.43564286 -1.38333078  2.04801979 -1.3311241 ] ... [-1.3311241   2.04801979 -1.38333078  1.43564286]
# f(xk)=-141.43679994717382
# f(x0)=0.0
# La norma del gradiente final es: 0.0009311074872784663
# Número de reinicios:  4021

# %%
# con beale
x07 = np.array([2,3])
sol7 = nonlinear_grad_conj1(beale, Grad_beale, x07, a0, maxIter, np.sqrt(2)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol7, beale, x07)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 30
# Backtracking está consumiendo todas las iteraciones. k = 32
# Backtracking está consumiendo todas las iteraciones. k = 38
# Backtracking está consumiendo todas las iteraciones. k = 46
# Backtracking está consumiendo todas las iteraciones. k = 48
# Backtracking está consumiendo todas las iteraciones. k = 53
# Backtracking está consumiendo todas las iteraciones. k = 55
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 62
# Backtracking está consumiendo todas las iteraciones. k = 67
# Backtracking está consumiendo todas las iteraciones. k = 69
# Backtracking está consumiendo todas las iteraciones. k = 74
# Backtracking está consumiendo todas las iteraciones. k = 76
# Backtracking está consumiendo todas las iteraciones. k = 81
# Backtracking está consumiendo todas las iteraciones. k = 83
# Backtracking está consumiendo todas las iteraciones. k = 91
# Backtracking está consumiendo todas las iteraciones. k = 96
# Backtracking está consumiendo todas las iteraciones. k = 98
# Backtracking está consumiendo todas las iteraciones. k = 103
# Backtracking está consumiendo todas las iteraciones. k = 105
# Backtracking está consumiendo todas las iteraciones. k = 108
# Backtracking está consumiendo todas las iteraciones. k = 113
# Backtracking está consumiendo todas las iteraciones. k = 115
# Backtracking está consumiendo todas las iteraciones. k = 122
# Backtracking está consumiendo todas las iteraciones. k = 124
# Backtracking está consumiendo todas las iteraciones. k = 132
# Backtracking está consumiendo todas las iteraciones. k = 140
# Backtracking está consumiendo todas las iteraciones. k = 147
# Backtracking está consumiendo todas las iteraciones. k = 149
# Backtracking está consumiendo todas las iteraciones. k = 156
# Backtracking está consumiendo todas las iteraciones. k = 158
# Backtracking está consumiendo todas las iteraciones. k = 161
# Backtracking está consumiendo todas las iteraciones. k = 166
# Backtracking está consumiendo todas las iteraciones. k = 168
# Backtracking está consumiendo todas las iteraciones. k = 171
# Backtracking está consumiendo todas las iteraciones. k = 178
# Backtracking está consumiendo todas las iteraciones. k = 180
# Backtracking está consumiendo todas las iteraciones. k = 183
# Backtracking está consumiendo todas las iteraciones. k = 190
# Backtracking está consumiendo todas las iteraciones. k = 192
# Backtracking está consumiendo todas las iteraciones. k = 199
# Backtracking está consumiendo todas las iteraciones. k = 201
# Backtracking está consumiendo todas las iteraciones. k = 204
# Backtracking está consumiendo todas las iteraciones. k = 211
# Backtracking está consumiendo todas las iteraciones. k = 213
# Backtracking está consumiendo todas las iteraciones. k = 216
# Backtracking está consumiendo todas las iteraciones. k = 223
# Backtracking está consumiendo todas las iteraciones. k = 225
# Backtracking está consumiendo todas las iteraciones. k = 228
# Backtracking está consumiendo todas las iteraciones. k = 237
# Backtracking está consumiendo todas las iteraciones. k = 239
# Backtracking está consumiendo todas las iteraciones. k = 242
# Backtracking está consumiendo todas las iteraciones. k = 249
# Backtracking está consumiendo todas las iteraciones. k = 251
# Backtracking está consumiendo todas las iteraciones. k = 254
# Backtracking está consumiendo todas las iteraciones. k = 261
# Backtracking está consumiendo todas las iteraciones. k = 263
# Backtracking está consumiendo todas las iteraciones. k = 266
# Backtracking está consumiendo todas las iteraciones. k = 275
# Backtracking está consumiendo todas las iteraciones. k = 277
# Backtracking está consumiendo todas las iteraciones. k = 280
# Backtracking está consumiendo todas las iteraciones. k = 287
# Backtracking está consumiendo todas las iteraciones. k = 289
# Backtracking está consumiendo todas las iteraciones. k = 292
# Backtracking está consumiendo todas las iteraciones. k = 301
# Backtracking está consumiendo todas las iteraciones. k = 303
# Backtracking está consumiendo todas las iteraciones. k = 306
# Backtracking está consumiendo todas las iteraciones. k = 315
# Backtracking está consumiendo todas las iteraciones. k = 317
# Backtracking está consumiendo todas las iteraciones. k = 320
# Backtracking está consumiendo todas las iteraciones. k = 327
# Backtracking está consumiendo todas las iteraciones. k = 329
# Backtracking está consumiendo todas las iteraciones. k = 331
# Backtracking está consumiendo todas las iteraciones. k = 333
# Backtracking está consumiendo todas las iteraciones. k = 336
# Backtracking está consumiendo todas las iteraciones. k = 343
# Backtracking está consumiendo todas las iteraciones. k = 345
# Backtracking está consumiendo todas las iteraciones. k = 348
# Backtracking está consumiendo todas las iteraciones. k = 351
# Backtracking está consumiendo todas las iteraciones. k = 358
# Backtracking está consumiendo todas las iteraciones. k = 360
# Backtracking está consumiendo todas las iteraciones. k = 363
# Backtracking está consumiendo todas las iteraciones. k = 372
# Backtracking está consumiendo todas las iteraciones. k = 374
# Backtracking está consumiendo todas las iteraciones. k = 377
# Backtracking está consumiendo todas las iteraciones. k = 386
# Backtracking está consumiendo todas las iteraciones. k = 388
# Backtracking está consumiendo todas las iteraciones. k = 391
# Backtracking está consumiendo todas las iteraciones. k = 400
# Backtracking está consumiendo todas las iteraciones. k = 402
# Backtracking está consumiendo todas las iteraciones. k = 405
# Backtracking está consumiendo todas las iteraciones. k = 408
# Backtracking está consumiendo todas las iteraciones. k = 415
# Backtracking está consumiendo todas las iteraciones. k = 417
# Backtracking está consumiendo todas las iteraciones. k = 420
# Backtracking está consumiendo todas las iteraciones. k = 423
# Backtracking está consumiendo todas las iteraciones. k = 430
# Backtracking está consumiendo todas las iteraciones. k = 432
# Backtracking está consumiendo todas las iteraciones. k = 434
# Backtracking está consumiendo todas las iteraciones. k = 436
# Backtracking está consumiendo todas las iteraciones. k = 439
# Backtracking está consumiendo todas las iteraciones. k = 446
# Backtracking está consumiendo todas las iteraciones. k = 448
# Backtracking está consumiendo todas las iteraciones. k = 450
# Backtracking está consumiendo todas las iteraciones. k = 452
# Backtracking está consumiendo todas las iteraciones. k = 455
# Backtracking está consumiendo todas las iteraciones. k = 464
# Backtracking está consumiendo todas las iteraciones. k = 466
# Backtracking está consumiendo todas las iteraciones. k = 469
# Backtracking está consumiendo todas las iteraciones. k = 478
# Backtracking está consumiendo todas las iteraciones. k = 480
# Backtracking está consumiendo todas las iteraciones. k = 483
# Backtracking está consumiendo todas las iteraciones. k = 492
# Backtracking está consumiendo todas las iteraciones. k = 494
# Backtracking está consumiendo todas las iteraciones. k = 497
# Backtracking está consumiendo todas las iteraciones. k = 506
# Backtracking está consumiendo todas las iteraciones. k = 508
# Backtracking está consumiendo todas las iteraciones. k = 511
# Backtracking está consumiendo todas las iteraciones. k = 514
# Backtracking está consumiendo todas las iteraciones. k = 521
# Backtracking está consumiendo todas las iteraciones. k = 523
# Backtracking está consumiendo todas las iteraciones. k = 525
# Backtracking está consumiendo todas las iteraciones. k = 527
# Backtracking está consumiendo todas las iteraciones. k = 530
# Backtracking está consumiendo todas las iteraciones. k = 539
# Backtracking está consumiendo todas las iteraciones. k = 541
# Backtracking está consumiendo todas las iteraciones. k = 544
# Backtracking está consumiendo todas las iteraciones. k = 553
# Backtracking está consumiendo todas las iteraciones. k = 555
# Backtracking está consumiendo todas las iteraciones. k = 558
# Backtracking está consumiendo todas las iteraciones. k = 567
# Backtracking está consumiendo todas las iteraciones. k = 569
# Backtracking está consumiendo todas las iteraciones. k = 572
# Backtracking está consumiendo todas las iteraciones. k = 575
# Backtracking está consumiendo todas las iteraciones. k = 582
# Backtracking está consumiendo todas las iteraciones. k = 584
# Backtracking está consumiendo todas las iteraciones. k = 586
# Backtracking está consumiendo todas las iteraciones. k = 588
# Backtracking está consumiendo todas las iteraciones. k = 591
# Backtracking está consumiendo todas las iteraciones. k = 600
# Backtracking está consumiendo todas las iteraciones. k = 602
# Backtracking está consumiendo todas las iteraciones. k = 605
# Backtracking está consumiendo todas las iteraciones. k = 614
# Backtracking está consumiendo todas las iteraciones. k = 616
# Backtracking está consumiendo todas las iteraciones. k = 619
# Backtracking está consumiendo todas las iteraciones. k = 628
# Backtracking está consumiendo todas las iteraciones. k = 630
# Backtracking está consumiendo todas las iteraciones. k = 633
# Backtracking está consumiendo todas las iteraciones. k = 636
# Backtracking está consumiendo todas las iteraciones. k = 643
# Backtracking está consumiendo todas las iteraciones. k = 645
# Backtracking está consumiendo todas las iteraciones. k = 647
# Backtracking está consumiendo todas las iteraciones. k = 649
# Backtracking está consumiendo todas las iteraciones. k = 652
# Backtracking está consumiendo todas las iteraciones. k = 661
# Backtracking está consumiendo todas las iteraciones. k = 663
# Backtracking está consumiendo todas las iteraciones. k = 666
# Backtracking está consumiendo todas las iteraciones. k = 675
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 680
# Backtracking está consumiendo todas las iteraciones. k = 689
# Backtracking está consumiendo todas las iteraciones. k = 691
# Backtracking está consumiendo todas las iteraciones. k = 694
# Backtracking está consumiendo todas las iteraciones. k = 697
# Backtracking está consumiendo todas las iteraciones. k = 704
# Backtracking está consumiendo todas las iteraciones. k = 706
# Backtracking está consumiendo todas las iteraciones. k = 708
# Backtracking está consumiendo todas las iteraciones. k = 710
# Backtracking está consumiendo todas las iteraciones. k = 713
# Backtracking está consumiendo todas las iteraciones. k = 722
# Backtracking está consumiendo todas las iteraciones. k = 724
# Backtracking está consumiendo todas las iteraciones. k = 727
# Backtracking está consumiendo todas las iteraciones. k = 736
# Backtracking está consumiendo todas las iteraciones. k = 738
# Backtracking está consumiendo todas las iteraciones. k = 741
# Backtracking está consumiendo todas las iteraciones. k = 744
# Backtracking está consumiendo todas las iteraciones. k = 751
# Backtracking está consumiendo todas las iteraciones. k = 753
# Backtracking está consumiendo todas las iteraciones. k = 755
# Backtracking está consumiendo todas las iteraciones. k = 757
# Backtracking está consumiendo todas las iteraciones. k = 760
# Dimension: 2
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 769
# La solución alcanzada es:  [3.00001871 0.50000457] ... [3.00001871 0.50000457]
# f(xk)=5.6113870648033834e-11
# f(x0)=3347.203125
# La norma del gradiente final es: 7.496323664379619e-06
# Número de reinicios:  585

# %%
# con himmelbleau
x08 = np.array([2,4])
sol8 = nonlinear_grad_conj1(himmelblau, Grad_himmelblau, x08, a0, maxIter, np.sqrt(2)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol8, himmelblau, x08)
# Out:
# Dimension: 2
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 37
# La solución alcanzada es:  [ 3.58442828 -1.84812653] ... [ 3.58442828 -1.84812653]
# f(xk)=1.983378785152025e-13
# f(x0)=130
# La norma del gradiente final es: 6.466611390455732e-06
# Número de reinicios:  36

# %%
# con rosen
x09 = np.array([-1.2,1])
sol9 = nonlinear_grad_conj1(rosenbrock, Grad_rosenbrock, x09, a0, maxIter, np.sqrt(2)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol9, rosenbrock, x09)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 23
# Backtracking está consumiendo todas las iteraciones. k = 25
# Backtracking está consumiendo todas las iteraciones. k = 36
# Backtracking está consumiendo todas las iteraciones. k = 38
# Backtracking está consumiendo todas las iteraciones. k = 40
# Backtracking está consumiendo todas las iteraciones. k = 51
# Backtracking está consumiendo todas las iteraciones. k = 54
# Backtracking está consumiendo todas las iteraciones. k = 58
# Backtracking está consumiendo todas las iteraciones. k = 61
# Backtracking está consumiendo todas las iteraciones. k = 65
# Backtracking está consumiendo todas las iteraciones. k = 69
# Backtracking está consumiendo todas las iteraciones. k = 72
# Backtracking está consumiendo todas las iteraciones. k = 76
# Backtracking está consumiendo todas las iteraciones. k = 79
# Backtracking está consumiendo todas las iteraciones. k = 83
# Backtracking está consumiendo todas las iteraciones. k = 86
# Backtracking está consumiendo todas las iteraciones. k = 90
# Backtracking está consumiendo todas las iteraciones. k = 94
# Backtracking está consumiendo todas las iteraciones. k = 97
# Backtracking está consumiendo todas las iteraciones. k = 101
# Backtracking está consumiendo todas las iteraciones. k = 104
# Backtracking está consumiendo todas las iteraciones. k = 108
# Backtracking está consumiendo todas las iteraciones. k = 111
# Backtracking está consumiendo todas las iteraciones. k = 115
# Backtracking está consumiendo todas las iteraciones. k = 118
# Backtracking está consumiendo todas las iteraciones. k = 122
# Backtracking está consumiendo todas las iteraciones. k = 125
# Backtracking está consumiendo todas las iteraciones. k = 129
# Backtracking está consumiendo todas las iteraciones. k = 132
# Backtracking está consumiendo todas las iteraciones. k = 136
# Backtracking está consumiendo todas las iteraciones. k = 139
# Backtracking está consumiendo todas las iteraciones. k = 143
# Backtracking está consumiendo todas las iteraciones. k = 146
# Backtracking está consumiendo todas las iteraciones. k = 149
# Backtracking está consumiendo todas las iteraciones. k = 151
# Backtracking está consumiendo todas las iteraciones. k = 154
# Backtracking está consumiendo todas las iteraciones. k = 157
# Backtracking está consumiendo todas las iteraciones. k = 161
# Backtracking está consumiendo todas las iteraciones. k = 164
# Backtracking está consumiendo todas las iteraciones. k = 168
# Backtracking está consumiendo todas las iteraciones. k = 171
# Backtracking está consumiendo todas las iteraciones. k = 175
# Backtracking está consumiendo todas las iteraciones. k = 178
# Backtracking está consumiendo todas las iteraciones. k = 181
# Backtracking está consumiendo todas las iteraciones. k = 185
# Backtracking está consumiendo todas las iteraciones. k = 188
# Backtracking está consumiendo todas las iteraciones. k = 192
# Backtracking está consumiendo todas las iteraciones. k = 195
# Backtracking está consumiendo todas las iteraciones. k = 198
# Backtracking está consumiendo todas las iteraciones. k = 202
# Backtracking está consumiendo todas las iteraciones. k = 205
# Backtracking está consumiendo todas las iteraciones. k = 208
# Backtracking está consumiendo todas las iteraciones. k = 210
# Backtracking está consumiendo todas las iteraciones. k = 213
# Backtracking está consumiendo todas las iteraciones. k = 216
# Backtracking está consumiendo todas las iteraciones. k = 220
# Backtracking está consumiendo todas las iteraciones. k = 223
# Backtracking está consumiendo todas las iteraciones. k = 226
# Backtracking está consumiendo todas las iteraciones. k = 230
# Backtracking está consumiendo todas las iteraciones. k = 233
# Backtracking está consumiendo todas las iteraciones. k = 236
# Backtracking está consumiendo todas las iteraciones. k = 240
# Backtracking está consumiendo todas las iteraciones. k = 243
# Backtracking está consumiendo todas las iteraciones. k = 246
# Backtracking está consumiendo todas las iteraciones. k = 250
# Backtracking está consumiendo todas las iteraciones. k = 253
# Backtracking está consumiendo todas las iteraciones. k = 256
# Backtracking está consumiendo todas las iteraciones. k = 259
# Backtracking está consumiendo todas las iteraciones. k = 261
# Backtracking está consumiendo todas las iteraciones. k = 264
# Backtracking está consumiendo todas las iteraciones. k = 267
# Backtracking está consumiendo todas las iteraciones. k = 270
# Backtracking está consumiendo todas las iteraciones. k = 274
# Backtracking está consumiendo todas las iteraciones. k = 277
# Backtracking está consumiendo todas las iteraciones. k = 280
# Backtracking está consumiendo todas las iteraciones. k = 283
# Backtracking está consumiendo todas las iteraciones. k = 285
# Backtracking está consumiendo todas las iteraciones. k = 288
# Backtracking está consumiendo todas las iteraciones. k = 291
# Backtracking está consumiendo todas las iteraciones. k = 294
# Backtracking está consumiendo todas las iteraciones. k = 297
# Backtracking está consumiendo todas las iteraciones. k = 299
# Backtracking está consumiendo todas las iteraciones. k = 302
# Backtracking está consumiendo todas las iteraciones. k = 305
# Backtracking está consumiendo todas las iteraciones. k = 308
# Backtracking está consumiendo todas las iteraciones. k = 311
# Backtracking está consumiendo todas las iteraciones. k = 313
# Backtracking está consumiendo todas las iteraciones. k = 316
# Backtracking está consumiendo todas las iteraciones. k = 319
# Backtracking está consumiendo todas las iteraciones. k = 322
# Backtracking está consumiendo todas las iteraciones. k = 325
# Backtracking está consumiendo todas las iteraciones. k = 328
# Backtracking está consumiendo todas las iteraciones. k = 330
# Backtracking está consumiendo todas las iteraciones. k = 333
# Backtracking está consumiendo todas las iteraciones. k = 336
# Backtracking está consumiendo todas las iteraciones. k = 339
# Backtracking está consumiendo todas las iteraciones. k = 342
# Backtracking está consumiendo todas las iteraciones. k = 345
# Backtracking está consumiendo todas las iteraciones. k = 347
# Backtracking está consumiendo todas las iteraciones. k = 350
# Backtracking está consumiendo todas las iteraciones. k = 353
# Backtracking está consumiendo todas las iteraciones. k = 356
# Backtracking está consumiendo todas las iteraciones. k = 359
# Backtracking está consumiendo todas las iteraciones. k = 364
# Backtracking está consumiendo todas las iteraciones. k = 367
# Backtracking está consumiendo todas las iteraciones. k = 370
# Backtracking está consumiendo todas las iteraciones. k = 372
# Backtracking está consumiendo todas las iteraciones. k = 375
# Backtracking está consumiendo todas las iteraciones. k = 378
# Backtracking está consumiendo todas las iteraciones. k = 381
# Backtracking está consumiendo todas las iteraciones. k = 384
# Backtracking está consumiendo todas las iteraciones. k = 387
# Backtracking está consumiendo todas las iteraciones. k = 390
# Backtracking está consumiendo todas las iteraciones. k = 393
# Backtracking está consumiendo todas las iteraciones. k = 395
# Backtracking está consumiendo todas las iteraciones. k = 397
# Backtracking está consumiendo todas las iteraciones. k = 399
# Backtracking está consumiendo todas las iteraciones. k = 402
# Backtracking está consumiendo todas las iteraciones. k = 405
# Backtracking está consumiendo todas las iteraciones. k = 408
# Backtracking está consumiendo todas las iteraciones. k = 411
# Backtracking está consumiendo todas las iteraciones. k = 642
# Backtracking está consumiendo todas las iteraciones. k = 644
# Backtracking está consumiendo todas las iteraciones. k = 646
# Backtracking está consumiendo todas las iteraciones. k = 648
# Backtracking está consumiendo todas las iteraciones. k = 650
# Backtracking está consumiendo todas las iteraciones. k = 673
# Backtracking está consumiendo todas las iteraciones. k = 675
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 679
# Backtracking está consumiendo todas las iteraciones. k = 681
# Backtracking está consumiendo todas las iteraciones. k = 704
# Backtracking está consumiendo todas las iteraciones. k = 706
# Backtracking está consumiendo todas las iteraciones. k = 708
# Backtracking está consumiendo todas las iteraciones. k = 710
# Backtracking está consumiendo todas las iteraciones. k = 712
# Backtracking está consumiendo todas las iteraciones. k = 735
# Backtracking está consumiendo todas las iteraciones. k = 737
# Backtracking está consumiendo todas las iteraciones. k = 739
# Backtracking está consumiendo todas las iteraciones. k = 741
# Backtracking está consumiendo todas las iteraciones. k = 743
# Backtracking está consumiendo todas las iteraciones. k = 766
# Backtracking está consumiendo todas las iteraciones. k = 768
# Backtracking está consumiendo todas las iteraciones. k = 770
# Backtracking está consumiendo todas las iteraciones. k = 772
# Backtracking está consumiendo todas las iteraciones. k = 774
# Backtracking está consumiendo todas las iteraciones. k = 797
# Backtracking está consumiendo todas las iteraciones. k = 799
# Backtracking está consumiendo todas las iteraciones. k = 801
# Backtracking está consumiendo todas las iteraciones. k = 803
# Backtracking está consumiendo todas las iteraciones. k = 805
# Backtracking está consumiendo todas las iteraciones. k = 828
# Backtracking está consumiendo todas las iteraciones. k = 830
# Backtracking está consumiendo todas las iteraciones. k = 832
# Backtracking está consumiendo todas las iteraciones. k = 834
# Backtracking está consumiendo todas las iteraciones. k = 836
# Backtracking está consumiendo todas las iteraciones. k = 859
# Backtracking está consumiendo todas las iteraciones. k = 861
# Backtracking está consumiendo todas las iteraciones. k = 863
# Backtracking está consumiendo todas las iteraciones. k = 865
# Backtracking está consumiendo todas las iteraciones. k = 867
# Backtracking está consumiendo todas las iteraciones. k = 890
# Backtracking está consumiendo todas las iteraciones. k = 892
# Backtracking está consumiendo todas las iteraciones. k = 894
# Backtracking está consumiendo todas las iteraciones. k = 896
# Backtracking está consumiendo todas las iteraciones. k = 898
# Backtracking está consumiendo todas las iteraciones. k = 921
# Backtracking está consumiendo todas las iteraciones. k = 923
# Backtracking está consumiendo todas las iteraciones. k = 925
# Backtracking está consumiendo todas las iteraciones. k = 927
# Backtracking está consumiendo todas las iteraciones. k = 929
# Backtracking está consumiendo todas las iteraciones. k = 940
# Backtracking está consumiendo todas las iteraciones. k = 942
# Backtracking está consumiendo todas las iteraciones. k = 944
# Backtracking está consumiendo todas las iteraciones. k = 946
# Backtracking está consumiendo todas las iteraciones. k = 948
# Backtracking está consumiendo todas las iteraciones. k = 970
# Backtracking está consumiendo todas las iteraciones. k = 972
# Backtracking está consumiendo todas las iteraciones. k = 974
# Backtracking está consumiendo todas las iteraciones. k = 976
# Backtracking está consumiendo todas las iteraciones. k = 999
# Backtracking está consumiendo todas las iteraciones. k = 1001
# Backtracking está consumiendo todas las iteraciones. k = 1003
# Backtracking está consumiendo todas las iteraciones. k = 1005
# Backtracking está consumiendo todas las iteraciones. k = 1007
# Backtracking está consumiendo todas las iteraciones. k = 1030
# Backtracking está consumiendo todas las iteraciones. k = 1032
# Backtracking está consumiendo todas las iteraciones. k = 1034
# Backtracking está consumiendo todas las iteraciones. k = 1036
# Backtracking está consumiendo todas las iteraciones. k = 1059
# Backtracking está consumiendo todas las iteraciones. k = 1061
# Backtracking está consumiendo todas las iteraciones. k = 1063
# Backtracking está consumiendo todas las iteraciones. k = 1065
# Backtracking está consumiendo todas las iteraciones. k = 1067
# Backtracking está consumiendo todas las iteraciones. k = 1090
# Backtracking está consumiendo todas las iteraciones. k = 1092
# Backtracking está consumiendo todas las iteraciones. k = 1094
# Backtracking está consumiendo todas las iteraciones. k = 1096
# Backtracking está consumiendo todas las iteraciones. k = 1119
# Backtracking está consumiendo todas las iteraciones. k = 1121
# Backtracking está consumiendo todas las iteraciones. k = 1123
# Backtracking está consumiendo todas las iteraciones. k = 1125
# Backtracking está consumiendo todas las iteraciones. k = 1127
# Backtracking está consumiendo todas las iteraciones. k = 1150
# Backtracking está consumiendo todas las iteraciones. k = 1152
# Backtracking está consumiendo todas las iteraciones. k = 1154
# Backtracking está consumiendo todas las iteraciones. k = 1156
# Backtracking está consumiendo todas las iteraciones. k = 1158
# Backtracking está consumiendo todas las iteraciones. k = 1174
# Backtracking está consumiendo todas las iteraciones. k = 1176
# Backtracking está consumiendo todas las iteraciones. k = 1178
# Backtracking está consumiendo todas las iteraciones. k = 1180
# Backtracking está consumiendo todas las iteraciones. k = 1203
# Backtracking está consumiendo todas las iteraciones. k = 1205
# Backtracking está consumiendo todas las iteraciones. k = 1207
# Backtracking está consumiendo todas las iteraciones. k = 1209
# Backtracking está consumiendo todas las iteraciones. k = 1211
# Backtracking está consumiendo todas las iteraciones. k = 1230
# Backtracking está consumiendo todas las iteraciones. k = 1232
# Backtracking está consumiendo todas las iteraciones. k = 1234
# Backtracking está consumiendo todas las iteraciones. k = 1236
# Backtracking está consumiendo todas las iteraciones. k = 1259
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1263
# Backtracking está consumiendo todas las iteraciones. k = 1265
# Backtracking está consumiendo todas las iteraciones. k = 1267
# Backtracking está consumiendo todas las iteraciones. k = 1286
# Backtracking está consumiendo todas las iteraciones. k = 1288
# Backtracking está consumiendo todas las iteraciones. k = 1290
# Backtracking está consumiendo todas las iteraciones. k = 1292
# Backtracking está consumiendo todas las iteraciones. k = 1315
# Backtracking está consumiendo todas las iteraciones. k = 1317
# Backtracking está consumiendo todas las iteraciones. k = 1319
# Backtracking está consumiendo todas las iteraciones. k = 1321
# Backtracking está consumiendo todas las iteraciones. k = 1344
# Backtracking está consumiendo todas las iteraciones. k = 1346
# Backtracking está consumiendo todas las iteraciones. k = 1348
# Backtracking está consumiendo todas las iteraciones. k = 1350
# Backtracking está consumiendo todas las iteraciones. k = 1352
# Backtracking está consumiendo todas las iteraciones. k = 1370
# Backtracking está consumiendo todas las iteraciones. k = 1372
# Backtracking está consumiendo todas las iteraciones. k = 1374
# Backtracking está consumiendo todas las iteraciones. k = 1376
# Backtracking está consumiendo todas las iteraciones. k = 1378
# Dimension: 2
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 1382
# La solución alcanzada es:  [0.999996   0.99999198] ... [0.999996   0.99999198]
# f(xk)=1.606990862536676e-11
# f(x0)=24.199999999999996
# La norma del gradiente final es: 8.384887632319202e-06
# Número de reinicios:  1128

# %%
# con rosen
x010 = np.ones(20)
for i in range(0, 20, 2):
    x010[i] = -1.2
sol10 = nonlinear_grad_conj1(rosenbrock, Grad_rosenbrock, x010, a0, maxIter, np.sqrt(20)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol10, rosenbrock, x010)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 138
# Backtracking está consumiendo todas las iteraciones. k = 140
# Backtracking está consumiendo todas las iteraciones. k = 143
# Backtracking está consumiendo todas las iteraciones. k = 145
# Backtracking está consumiendo todas las iteraciones. k = 155
# Backtracking está consumiendo todas las iteraciones. k = 157
# Backtracking está consumiendo todas las iteraciones. k = 170
# Backtracking está consumiendo todas las iteraciones. k = 172
# Backtracking está consumiendo todas las iteraciones. k = 182
# Backtracking está consumiendo todas las iteraciones. k = 184
# Backtracking está consumiendo todas las iteraciones. k = 187
# Backtracking está consumiendo todas las iteraciones. k = 189
# Backtracking está consumiendo todas las iteraciones. k = 196
# Backtracking está consumiendo todas las iteraciones. k = 198
# Backtracking está consumiendo todas las iteraciones. k = 201
# Backtracking está consumiendo todas las iteraciones. k = 203
# Backtracking está consumiendo todas las iteraciones. k = 213
# Backtracking está consumiendo todas las iteraciones. k = 215
# Backtracking está consumiendo todas las iteraciones. k = 225
# Backtracking está consumiendo todas las iteraciones. k = 227
# Backtracking está consumiendo todas las iteraciones. k = 237
# Backtracking está consumiendo todas las iteraciones. k = 239
# Backtracking está consumiendo todas las iteraciones. k = 246
# Backtracking está consumiendo todas las iteraciones. k = 248
# Backtracking está consumiendo todas las iteraciones. k = 251
# Backtracking está consumiendo todas las iteraciones. k = 253
# Backtracking está consumiendo todas las iteraciones. k = 260
# Backtracking está consumiendo todas las iteraciones. k = 262
# Backtracking está consumiendo todas las iteraciones. k = 272
# Backtracking está consumiendo todas las iteraciones. k = 274
# Backtracking está consumiendo todas las iteraciones. k = 281
# Backtracking está consumiendo todas las iteraciones. k = 283
# Backtracking está consumiendo todas las iteraciones. k = 293
# Backtracking está consumiendo todas las iteraciones. k = 295
# Backtracking está consumiendo todas las iteraciones. k = 302
# Backtracking está consumiendo todas las iteraciones. k = 304
# Backtracking está consumiendo todas las iteraciones. k = 314
# Backtracking está consumiendo todas las iteraciones. k = 316
# Backtracking está consumiendo todas las iteraciones. k = 323
# Backtracking está consumiendo todas las iteraciones. k = 325
# Backtracking está consumiendo todas las iteraciones. k = 332
# Backtracking está consumiendo todas las iteraciones. k = 334
# Backtracking está consumiendo todas las iteraciones. k = 341
# Backtracking está consumiendo todas las iteraciones. k = 343
# Backtracking está consumiendo todas las iteraciones. k = 346
# Backtracking está consumiendo todas las iteraciones. k = 354
# Backtracking está consumiendo todas las iteraciones. k = 356
# Backtracking está consumiendo todas las iteraciones. k = 363
# Backtracking está consumiendo todas las iteraciones. k = 365
# Backtracking está consumiendo todas las iteraciones. k = 372
# Backtracking está consumiendo todas las iteraciones. k = 374
# Backtracking está consumiendo todas las iteraciones. k = 381
# Backtracking está consumiendo todas las iteraciones. k = 383
# Backtracking está consumiendo todas las iteraciones. k = 390
# Backtracking está consumiendo todas las iteraciones. k = 392
# Backtracking está consumiendo todas las iteraciones. k = 399
# Backtracking está consumiendo todas las iteraciones. k = 401
# Backtracking está consumiendo todas las iteraciones. k = 408
# Backtracking está consumiendo todas las iteraciones. k = 410
# Backtracking está consumiendo todas las iteraciones. k = 417
# Backtracking está consumiendo todas las iteraciones. k = 419
# Backtracking está consumiendo todas las iteraciones. k = 426
# Backtracking está consumiendo todas las iteraciones. k = 428
# Backtracking está consumiendo todas las iteraciones. k = 435
# Backtracking está consumiendo todas las iteraciones. k = 437
# Backtracking está consumiendo todas las iteraciones. k = 444
# Backtracking está consumiendo todas las iteraciones. k = 446
# Backtracking está consumiendo todas las iteraciones. k = 457
# Backtracking está consumiendo todas las iteraciones. k = 459
# Backtracking está consumiendo todas las iteraciones. k = 466
# Backtracking está consumiendo todas las iteraciones. k = 468
# Backtracking está consumiendo todas las iteraciones. k = 475
# Backtracking está consumiendo todas las iteraciones. k = 477
# Backtracking está consumiendo todas las iteraciones. k = 484
# Backtracking está consumiendo todas las iteraciones. k = 486
# Backtracking está consumiendo todas las iteraciones. k = 497
# Backtracking está consumiendo todas las iteraciones. k = 499
# Backtracking está consumiendo todas las iteraciones. k = 506
# Backtracking está consumiendo todas las iteraciones. k = 508
# Backtracking está consumiendo todas las iteraciones. k = 515
# Backtracking está consumiendo todas las iteraciones. k = 520
# Backtracking está consumiendo todas las iteraciones. k = 522
# Backtracking está consumiendo todas las iteraciones. k = 529
# Backtracking está consumiendo todas las iteraciones. k = 531
# Backtracking está consumiendo todas las iteraciones. k = 538
# Backtracking está consumiendo todas las iteraciones. k = 543
# Backtracking está consumiendo todas las iteraciones. k = 545
# Backtracking está consumiendo todas las iteraciones. k = 552
# Backtracking está consumiendo todas las iteraciones. k = 554
# Backtracking está consumiendo todas las iteraciones. k = 565
# Backtracking está consumiendo todas las iteraciones. k = 567
# Backtracking está consumiendo todas las iteraciones. k = 574
# Backtracking está consumiendo todas las iteraciones. k = 579
# Backtracking está consumiendo todas las iteraciones. k = 581
# Backtracking está consumiendo todas las iteraciones. k = 588
# Backtracking está consumiendo todas las iteraciones. k = 590
# Backtracking está consumiendo todas las iteraciones. k = 594
# Backtracking está consumiendo todas las iteraciones. k = 596
# Backtracking está consumiendo todas las iteraciones. k = 603
# Backtracking está consumiendo todas las iteraciones. k = 605
# Backtracking está consumiendo todas las iteraciones. k = 616
# Backtracking está consumiendo todas las iteraciones. k = 618
# Backtracking está consumiendo todas las iteraciones. k = 629
# Backtracking está consumiendo todas las iteraciones. k = 631
# Backtracking está consumiendo todas las iteraciones. k = 642
# Backtracking está consumiendo todas las iteraciones. k = 644
# Backtracking está consumiendo todas las iteraciones. k = 648
# Backtracking está consumiendo todas las iteraciones. k = 650
# Backtracking está consumiendo todas las iteraciones. k = 657
# Backtracking está consumiendo todas las iteraciones. k = 659
# Backtracking está consumiendo todas las iteraciones. k = 663
# Backtracking está consumiendo todas las iteraciones. k = 665
# Backtracking está consumiendo todas las iteraciones. k = 672
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 679
# Backtracking está consumiendo todas las iteraciones. k = 690
# Backtracking está consumiendo todas las iteraciones. k = 692
# Backtracking está consumiendo todas las iteraciones. k = 696
# Backtracking está consumiendo todas las iteraciones. k = 698
# Backtracking está consumiendo todas las iteraciones. k = 705
# Backtracking está consumiendo todas las iteraciones. k = 707
# Backtracking está consumiendo todas las iteraciones. k = 711
# Backtracking está consumiendo todas las iteraciones. k = 713
# Backtracking está consumiendo todas las iteraciones. k = 724
# Backtracking está consumiendo todas las iteraciones. k = 726
# Backtracking está consumiendo todas las iteraciones. k = 730
# Backtracking está consumiendo todas las iteraciones. k = 732
# Backtracking está consumiendo todas las iteraciones. k = 743
# Backtracking está consumiendo todas las iteraciones. k = 745
# Backtracking está consumiendo todas las iteraciones. k = 756
# Backtracking está consumiendo todas las iteraciones. k = 761
# Backtracking está consumiendo todas las iteraciones. k = 763
# Backtracking está consumiendo todas las iteraciones. k = 774
# Backtracking está consumiendo todas las iteraciones. k = 779
# Backtracking está consumiendo todas las iteraciones. k = 781
# Backtracking está consumiendo todas las iteraciones. k = 785
# Backtracking está consumiendo todas las iteraciones. k = 787
# Backtracking está consumiendo todas las iteraciones. k = 798
# Backtracking está consumiendo todas las iteraciones. k = 800
# Backtracking está consumiendo todas las iteraciones. k = 804
# Backtracking está consumiendo todas las iteraciones. k = 806
# Backtracking está consumiendo todas las iteraciones. k = 817
# Backtracking está consumiendo todas las iteraciones. k = 819
# Backtracking está consumiendo todas las iteraciones. k = 823
# Backtracking está consumiendo todas las iteraciones. k = 825
# Backtracking está consumiendo todas las iteraciones. k = 840
# Backtracking está consumiendo todas las iteraciones. k = 842
# Backtracking está consumiendo todas las iteraciones. k = 846
# Backtracking está consumiendo todas las iteraciones. k = 848
# Backtracking está consumiendo todas las iteraciones. k = 859
# Backtracking está consumiendo todas las iteraciones. k = 864
# Backtracking está consumiendo todas las iteraciones. k = 866
# Backtracking está consumiendo todas las iteraciones. k = 870
# Backtracking está consumiendo todas las iteraciones. k = 872
# Backtracking está consumiendo todas las iteraciones. k = 887
# Backtracking está consumiendo todas las iteraciones. k = 889
# Backtracking está consumiendo todas las iteraciones. k = 893
# Backtracking está consumiendo todas las iteraciones. k = 895
# Backtracking está consumiendo todas las iteraciones. k = 910
# Backtracking está consumiendo todas las iteraciones. k = 915
# Backtracking está consumiendo todas las iteraciones. k = 917
# Backtracking está consumiendo todas las iteraciones. k = 921
# Backtracking está consumiendo todas las iteraciones. k = 923
# Backtracking está consumiendo todas las iteraciones. k = 938
# Backtracking está consumiendo todas las iteraciones. k = 943
# Backtracking está consumiendo todas las iteraciones. k = 945
# Backtracking está consumiendo todas las iteraciones. k = 949
# Backtracking está consumiendo todas las iteraciones. k = 951
# Backtracking está consumiendo todas las iteraciones. k = 966
# Backtracking está consumiendo todas las iteraciones. k = 971
# Backtracking está consumiendo todas las iteraciones. k = 973
# Backtracking está consumiendo todas las iteraciones. k = 977
# Backtracking está consumiendo todas las iteraciones. k = 979
# Backtracking está consumiendo todas las iteraciones. k = 983
# Backtracking está consumiendo todas las iteraciones. k = 985
# Backtracking está consumiendo todas las iteraciones. k = 1000
# Backtracking está consumiendo todas las iteraciones. k = 1005
# Backtracking está consumiendo todas las iteraciones. k = 1007
# Backtracking está consumiendo todas las iteraciones. k = 1011
# Backtracking está consumiendo todas las iteraciones. k = 1013
# Backtracking está consumiendo todas las iteraciones. k = 1017
# Backtracking está consumiendo todas las iteraciones. k = 1019
# Backtracking está consumiendo todas las iteraciones. k = 1038
# Backtracking está consumiendo todas las iteraciones. k = 1043
# Backtracking está consumiendo todas las iteraciones. k = 1045
# Backtracking está consumiendo todas las iteraciones. k = 1049
# Backtracking está consumiendo todas las iteraciones. k = 1051
# Backtracking está consumiendo todas las iteraciones. k = 1055
# Backtracking está consumiendo todas las iteraciones. k = 1057
# Backtracking está consumiendo todas las iteraciones. k = 1061
# Backtracking está consumiendo todas las iteraciones. k = 1063
# Backtracking está consumiendo todas las iteraciones. k = 1082
# Backtracking está consumiendo todas las iteraciones. k = 1087
# Backtracking está consumiendo todas las iteraciones. k = 1089
# Backtracking está consumiendo todas las iteraciones. k = 1093
# Backtracking está consumiendo todas las iteraciones. k = 1095
# Backtracking está consumiendo todas las iteraciones. k = 1099
# Backtracking está consumiendo todas las iteraciones. k = 1101
# Backtracking está consumiendo todas las iteraciones. k = 1105
# Backtracking está consumiendo todas las iteraciones. k = 1107
# Backtracking está consumiendo todas las iteraciones. k = 1111
# Backtracking está consumiendo todas las iteraciones. k = 1113
# Backtracking está consumiendo todas las iteraciones. k = 1136
# Backtracking está consumiendo todas las iteraciones. k = 1141
# Backtracking está consumiendo todas las iteraciones. k = 1146
# Backtracking está consumiendo todas las iteraciones. k = 1148
# Backtracking está consumiendo todas las iteraciones. k = 1152
# Backtracking está consumiendo todas las iteraciones. k = 1154
# Backtracking está consumiendo todas las iteraciones. k = 1158
# Backtracking está consumiendo todas las iteraciones. k = 1160
# Backtracking está consumiendo todas las iteraciones. k = 1164
# Backtracking está consumiendo todas las iteraciones. k = 1166
# Backtracking está consumiendo todas las iteraciones. k = 1170
# Backtracking está consumiendo todas las iteraciones. k = 1172
# Backtracking está consumiendo todas las iteraciones. k = 1176
# Backtracking está consumiendo todas las iteraciones. k = 1178
# Backtracking está consumiendo todas las iteraciones. k = 1209
# Backtracking está consumiendo todas las iteraciones. k = 1214
# Backtracking está consumiendo todas las iteraciones. k = 1219
# Backtracking está consumiendo todas las iteraciones. k = 1224
# Backtracking está consumiendo todas las iteraciones. k = 1226
# Backtracking está consumiendo todas las iteraciones. k = 1230
# Backtracking está consumiendo todas las iteraciones. k = 1232
# Backtracking está consumiendo todas las iteraciones. k = 1236
# Backtracking está consumiendo todas las iteraciones. k = 1238
# Backtracking está consumiendo todas las iteraciones. k = 1242
# Backtracking está consumiendo todas las iteraciones. k = 1244
# Backtracking está consumiendo todas las iteraciones. k = 1248
# Backtracking está consumiendo todas las iteraciones. k = 1250
# Backtracking está consumiendo todas las iteraciones. k = 1254
# Backtracking está consumiendo todas las iteraciones. k = 1256
# Backtracking está consumiendo todas las iteraciones. k = 1260
# Backtracking está consumiendo todas las iteraciones. k = 1262
# Backtracking está consumiendo todas las iteraciones. k = 1266
# Backtracking está consumiendo todas las iteraciones. k = 1268
# Backtracking está consumiendo todas las iteraciones. k = 1272
# Backtracking está consumiendo todas las iteraciones. k = 1274
# Backtracking está consumiendo todas las iteraciones. k = 1278
# Backtracking está consumiendo todas las iteraciones. k = 1280
# Backtracking está consumiendo todas las iteraciones. k = 1284
# Backtracking está consumiendo todas las iteraciones. k = 1286
# Backtracking está consumiendo todas las iteraciones. k = 1290
# Backtracking está consumiendo todas las iteraciones. k = 1292
# Backtracking está consumiendo todas las iteraciones. k = 1296
# Backtracking está consumiendo todas las iteraciones. k = 1298
# Backtracking está consumiendo todas las iteraciones. k = 1302
# Backtracking está consumiendo todas las iteraciones. k = 1304
# Backtracking está consumiendo todas las iteraciones. k = 1308
# Backtracking está consumiendo todas las iteraciones. k = 1310
# Backtracking está consumiendo todas las iteraciones. k = 1314
# Backtracking está consumiendo todas las iteraciones. k = 1316
# Backtracking está consumiendo todas las iteraciones. k = 1320
# Backtracking está consumiendo todas las iteraciones. k = 1322
# Backtracking está consumiendo todas las iteraciones. k = 1326
# Backtracking está consumiendo todas las iteraciones. k = 1328
# Backtracking está consumiendo todas las iteraciones. k = 1356
# Backtracking está consumiendo todas las iteraciones. k = 1358
# Backtracking está consumiendo todas las iteraciones. k = 1362
# Backtracking está consumiendo todas las iteraciones. k = 1364
# Backtracking está consumiendo todas las iteraciones. k = 1368
# Backtracking está consumiendo todas las iteraciones. k = 1370
# Backtracking está consumiendo todas las iteraciones. k = 1374
# Backtracking está consumiendo todas las iteraciones. k = 1376
# Backtracking está consumiendo todas las iteraciones. k = 1380
# Backtracking está consumiendo todas las iteraciones. k = 1382
# Backtracking está consumiendo todas las iteraciones. k = 1386
# Backtracking está consumiendo todas las iteraciones. k = 1388
# Backtracking está consumiendo todas las iteraciones. k = 1392
# Backtracking está consumiendo todas las iteraciones. k = 1394
# Backtracking está consumiendo todas las iteraciones. k = 1398
# Backtracking está consumiendo todas las iteraciones. k = 1400
# Backtracking está consumiendo todas las iteraciones. k = 1404
# Backtracking está consumiendo todas las iteraciones. k = 1406
# Backtracking está consumiendo todas las iteraciones. k = 1410
# Backtracking está consumiendo todas las iteraciones. k = 1412
# Backtracking está consumiendo todas las iteraciones. k = 1416
# Backtracking está consumiendo todas las iteraciones. k = 1418
# Backtracking está consumiendo todas las iteraciones. k = 1422
# Backtracking está consumiendo todas las iteraciones. k = 1424
# Backtracking está consumiendo todas las iteraciones. k = 1428
# Backtracking está consumiendo todas las iteraciones. k = 1430
# Backtracking está consumiendo todas las iteraciones. k = 1434
# Backtracking está consumiendo todas las iteraciones. k = 1436
# Backtracking está consumiendo todas las iteraciones. k = 1440
# Backtracking está consumiendo todas las iteraciones. k = 1442
# Backtracking está consumiendo todas las iteraciones. k = 1446
# Backtracking está consumiendo todas las iteraciones. k = 1448
# Backtracking está consumiendo todas las iteraciones. k = 1452
# Backtracking está consumiendo todas las iteraciones. k = 1454
# Backtracking está consumiendo todas las iteraciones. k = 1458
# Backtracking está consumiendo todas las iteraciones. k = 1460
# Backtracking está consumiendo todas las iteraciones. k = 1464
# Backtracking está consumiendo todas las iteraciones. k = 1466
# Backtracking está consumiendo todas las iteraciones. k = 1470
# Backtracking está consumiendo todas las iteraciones. k = 1472
# Dimension: 20
# ¿Terminó por criterio de paro?: True
# Número de iteraciones realizadas: 1636
# La solución alcanzada es:  [0.99999999 0.99999999 0.99999999 1.        ] ... [0.99999679 0.99999356 0.99998708 0.9999741 ]
# f(xk)=2.2299248656329405e-10
# f(x0)=4597.999999999999
# La norma del gradiente final es: 2.6669859385786324e-05
# Número de reinicios:  1270

# %%
# con rosen
x011 = np.ones(40)
for i in range(0, 40, 2):
    x011[i] = -1.2
sol11 = nonlinear_grad_conj1(rosenbrock, Grad_rosenbrock, x011, a0, maxIter, np.sqrt(40)*eps**(1/3.0), c1, c2, rho, maxIter2)
solution2(sol11, rosenbrock, x011)
# Out:
# Backtracking está consumiendo todas las iteraciones. k = 12
# Backtracking está consumiendo todas las iteraciones. k = 17
# Backtracking está consumiendo todas las iteraciones. k = 19
# Backtracking está consumiendo todas las iteraciones. k = 21
# Backtracking está consumiendo todas las iteraciones. k = 24
# Backtracking está consumiendo todas las iteraciones. k = 26
# Backtracking está consumiendo todas las iteraciones. k = 28
# Backtracking está consumiendo todas las iteraciones. k = 30
# Backtracking está consumiendo todas las iteraciones. k = 34
# Backtracking está consumiendo todas las iteraciones. k = 39
# Backtracking está consumiendo todas las iteraciones. k = 41
# Backtracking está consumiendo todas las iteraciones. k = 44
# Backtracking está consumiendo todas las iteraciones. k = 47
# Backtracking está consumiendo todas las iteraciones. k = 49
# Backtracking está consumiendo todas las iteraciones. k = 58
# Backtracking está consumiendo todas las iteraciones. k = 60
# Backtracking está consumiendo todas las iteraciones. k = 68
# Backtracking está consumiendo todas las iteraciones. k = 120
# Backtracking está consumiendo todas las iteraciones. k = 167
# Backtracking está consumiendo todas las iteraciones. k = 169
# Backtracking está consumiendo todas las iteraciones. k = 172
# Backtracking está consumiendo todas las iteraciones. k = 174
# Backtracking está consumiendo todas las iteraciones. k = 184
# Backtracking está consumiendo todas las iteraciones. k = 186
# Backtracking está consumiendo todas las iteraciones. k = 196
# Backtracking está consumiendo todas las iteraciones. k = 198
# Backtracking está consumiendo todas las iteraciones. k = 208
# Backtracking está consumiendo todas las iteraciones. k = 210
# Backtracking está consumiendo todas las iteraciones. k = 220
# Backtracking está consumiendo todas las iteraciones. k = 222
# Backtracking está consumiendo todas las iteraciones. k = 232
# Backtracking está consumiendo todas las iteraciones. k = 234
# Backtracking está consumiendo todas las iteraciones. k = 244
# Backtracking está consumiendo todas las iteraciones. k = 246
# Backtracking está consumiendo todas las iteraciones. k = 253
# Backtracking está consumiendo todas las iteraciones. k = 255
# Backtracking está consumiendo todas las iteraciones. k = 258
# Backtracking está consumiendo todas las iteraciones. k = 260
# Backtracking está consumiendo todas las iteraciones. k = 267
# Backtracking está consumiendo todas las iteraciones. k = 269
# Backtracking está consumiendo todas las iteraciones. k = 276
# Backtracking está consumiendo todas las iteraciones. k = 278
# Backtracking está consumiendo todas las iteraciones. k = 281
# Backtracking está consumiendo todas las iteraciones. k = 283
# Backtracking está consumiendo todas las iteraciones. k = 290
# Backtracking está consumiendo todas las iteraciones. k = 292
# Backtracking está consumiendo todas las iteraciones. k = 299
# Backtracking está consumiendo todas las iteraciones. k = 301
# Backtracking está consumiendo todas las iteraciones. k = 311
# Backtracking está consumiendo todas las iteraciones. k = 313
# Backtracking está consumiendo todas las iteraciones. k = 320
# Backtracking está consumiendo todas las iteraciones. k = 322
# Backtracking está consumiendo todas las iteraciones. k = 329
# Backtracking está consumiendo todas las iteraciones. k = 331
# Backtracking está consumiendo todas las iteraciones. k = 341
# Backtracking está consumiendo todas las iteraciones. k = 349
# Backtracking está consumiendo todas las iteraciones. k = 351
# Backtracking está consumiendo todas las iteraciones. k = 358
# Backtracking está consumiendo todas las iteraciones. k = 360
# Backtracking está consumiendo todas las iteraciones. k = 367
# Backtracking está consumiendo todas las iteraciones. k = 369
# Backtracking está consumiendo todas las iteraciones. k = 376
# Backtracking está consumiendo todas las iteraciones. k = 378
# Backtracking está consumiendo todas las iteraciones. k = 385
# Backtracking está consumiendo todas las iteraciones. k = 387
# Backtracking está consumiendo todas las iteraciones. k = 394
# Backtracking está consumiendo todas las iteraciones. k = 396
# Backtracking está consumiendo todas las iteraciones. k = 403
# Backtracking está consumiendo todas las iteraciones. k = 405
# Backtracking está consumiendo todas las iteraciones. k = 412
# Backtracking está consumiendo todas las iteraciones. k = 414
# Backtracking está consumiendo todas las iteraciones. k = 421
# Backtracking está consumiendo todas las iteraciones. k = 423
# Backtracking está consumiendo todas las iteraciones. k = 430
# Backtracking está consumiendo todas las iteraciones. k = 432
# Backtracking está consumiendo todas las iteraciones. k = 443
# Backtracking está consumiendo todas las iteraciones. k = 445
# Backtracking está consumiendo todas las iteraciones. k = 452
# Backtracking está consumiendo todas las iteraciones. k = 454
# Backtracking está consumiendo todas las iteraciones. k = 461
# Backtracking está consumiendo todas las iteraciones. k = 463
# Backtracking está consumiendo todas las iteraciones. k = 470
# Backtracking está consumiendo todas las iteraciones. k = 472
# Backtracking está consumiendo todas las iteraciones. k = 483
# Backtracking está consumiendo todas las iteraciones. k = 485
# Backtracking está consumiendo todas las iteraciones. k = 492
# Backtracking está consumiendo todas las iteraciones. k = 494
# Backtracking está consumiendo todas las iteraciones. k = 501
# Backtracking está consumiendo todas las iteraciones. k = 503
# Backtracking está consumiendo todas las iteraciones. k = 507
# Backtracking está consumiendo todas las iteraciones. k = 509
# Backtracking está consumiendo todas las iteraciones. k = 516
# Backtracking está consumiendo todas las iteraciones. k = 518
# Backtracking está consumiendo todas las iteraciones. k = 525
# Backtracking está consumiendo todas las iteraciones. k = 527
# Backtracking está consumiendo todas las iteraciones. k = 531
# Backtracking está consumiendo todas las iteraciones. k = 533
# Backtracking está consumiendo todas las iteraciones. k = 540
# Backtracking está consumiendo todas las iteraciones. k = 542
# Backtracking está consumiendo todas las iteraciones. k = 549
# Backtracking está consumiendo todas las iteraciones. k = 554
# Backtracking está consumiendo todas las iteraciones. k = 556
# Backtracking está consumiendo todas las iteraciones. k = 563
# Backtracking está consumiendo todas las iteraciones. k = 565
# Backtracking está consumiendo todas las iteraciones. k = 569
# Backtracking está consumiendo todas las iteraciones. k = 571
# Backtracking está consumiendo todas las iteraciones. k = 578
# Backtracking está consumiendo todas las iteraciones. k = 580
# Backtracking está consumiendo todas las iteraciones. k = 591
# Backtracking está consumiendo todas las iteraciones. k = 593
# Backtracking está consumiendo todas las iteraciones. k = 604
# Backtracking está consumiendo todas las iteraciones. k = 606
# Backtracking está consumiendo todas las iteraciones. k = 617
# Backtracking está consumiendo todas las iteraciones. k = 619
# Backtracking está consumiendo todas las iteraciones. k = 630
# Backtracking está consumiendo todas las iteraciones. k = 632
# Backtracking está consumiendo todas las iteraciones. k = 643
# Backtracking está consumiendo todas las iteraciones. k = 645
# Backtracking está consumiendo todas las iteraciones. k = 656
# Backtracking está consumiendo todas las iteraciones. k = 658
# Backtracking está consumiendo todas las iteraciones. k = 662
# Backtracking está consumiendo todas las iteraciones. k = 664
# Backtracking está consumiendo todas las iteraciones. k = 671
# Backtracking está consumiendo todas las iteraciones. k = 673
# Backtracking está consumiendo todas las iteraciones. k = 677
# Backtracking está consumiendo todas las iteraciones. k = 679
# Backtracking está consumiendo todas las iteraciones. k = 690
# Backtracking está consumiendo todas las iteraciones. k = 692
# Backtracking está consumiendo todas las iteraciones. k = 703
# Backtracking está consumiendo todas las iteraciones. k = 705
# Backtracking está consumiendo todas las iteraciones. k = 709
# Backtracking está consumiendo todas las iteraciones. k = 711
# Backtracking está consumiendo todas las iteraciones. k = 722
# Backtracking está consumiendo todas las iteraciones. k = 724
# Backtracking está consumiendo todas las iteraciones. k = 728
# Backtracking está consumiendo todas las iteraciones. k = 730
# Backtracking está consumiendo todas las iteraciones. k = 741
# Backtracking está consumiendo todas las iteraciones. k = 743
# Backtracking está consumiendo todas las iteraciones. k = 747
# Backtracking está consumiendo todas las iteraciones. k = 749
# Backtracking está consumiendo todas las iteraciones. k = 760
# Backtracking está consumiendo todas las iteraciones. k = 762
# Backtracking está consumiendo todas las iteraciones. k = 766
# Backtracking está consumiendo todas las iteraciones. k = 768
# Backtracking está consumiendo todas las iteraciones. k = 779
# Backtracking está consumiendo todas las iteraciones. k = 781
# Backtracking está consumiendo todas las iteraciones. k = 785
# Backtracking está consumiendo todas las iteraciones. k = 787
# Backtracking está consumiendo todas las iteraciones. k = 798
# Backtracking está consumiendo todas las iteraciones. k = 800
# Backtracking está consumiendo todas las iteraciones. k = 804
# Backtracking está consumiendo todas las iteraciones. k = 806
# Backtracking está consumiendo todas las iteraciones. k = 817
# Backtracking está consumiendo todas las iteraciones. k = 822
# Backtracking está consumiendo todas las iteraciones. k = 824
# Backtracking está consumiendo todas las iteraciones. k = 828
# Backtracking está consumiendo todas las iteraciones. k = 830
# Backtracking está consumiendo todas las iteraciones. k = 841
# Backtracking está consumiendo todas las iteraciones. k = 846
# Backtracking está consumiendo todas las iteraciones. k = 848
# Backtracking está consumiendo todas las iteraciones. k = 852
# Backtracking está consumiendo todas las iteraciones. k = 854
# Backtracking está consumiendo todas las iteraciones. k = 865
# Backtracking está consumiendo todas las iteraciones. k = 870
# Backtracking está consumiendo todas las iteraciones. k = 872
# Backtracking está consumiendo todas las iteraciones. k = 876
# Backtracking está consumiendo todas las iteraciones. k = 878
# Backtracking está consumiendo todas las iteraciones. k = 893
# Backtracking está consumiendo todas las iteraciones. k = 895
# Backtracking está consumiendo todas las iteraciones. k = 899
# Backtracking está consumiendo todas las iteraciones. k = 901
# Backtracking está consumiendo todas las iteraciones. k = 905
# Backtracking está consumiendo todas las iteraciones. k = 907
# Backtracking está consumiendo todas las iteraciones. k = 918
# Backtracking está consumiendo todas las iteraciones. k = 923
# Backtracking está consumiendo todas las iteraciones. k = 925
# Backtracking está consumiendo todas las iteraciones. k = 929
# Backtracking está consumiendo todas las iteraciones. k = 931
# Backtracking está consumiendo todas las iteraciones. k = 946
# Backtracking está consumiendo todas las iteraciones. k = 951
# Backtracking está consumiendo todas las iteraciones. k = 953
# Backtracking está consumiendo todas las iteraciones. k = 957
# Backtracking está consumiendo todas las iteraciones. k = 959
# Backtracking está consumiendo todas las iteraciones. k = 963
# Backtracking está consumiendo todas las iteraciones. k = 965
# Backtracking está consumiendo todas las iteraciones. k = 980
# Backtracking está consumiendo todas las iteraciones. k = 985
# Backtracking está consumiendo todas las iteraciones. k = 987
# Backtracking está consumiendo todas las iteraciones. k = 991
# Backtracking está consumiendo todas las iteraciones. k = 993
# Backtracking está consumiendo todas las iteraciones. k = 997
# Backtracking está consumiendo todas las iteraciones. k = 999
# Backtracking está consumiendo todas las iteraciones. k = 1014
# Backtracking está consumiendo todas las iteraciones. k = 1019
# Backtracking está consumiendo todas las iteraciones. k = 1021
# Backtracking está consumiendo todas las iteraciones. k = 1025
# Backtracking está consumiendo todas las iteraciones. k = 1027
# Backtracking está consumiendo todas las iteraciones. k = 1031
# Backtracking está consumiendo todas las iteraciones. k = 1033
# Backtracking está consumiendo todas las iteraciones. k = 1037
# Backtracking está consumiendo todas las iteraciones. k = 1039
# Backtracking está consumiendo todas las iteraciones. k = 1058
# Backtracking está consumiendo todas las iteraciones. k = 1063
# Backtracking está consumiendo todas las iteraciones. k = 1065
# Backtracking está consumiendo todas las iteraciones. k = 1069
# Backtracking está consumiendo todas las iteraciones. k = 1071
# Backtracking está consumiendo todas las iteraciones. k = 1075
# Backtracking está consumiendo todas las iteraciones. k = 1077
# Backtracking está consumiendo todas las iteraciones. k = 1081
# Backtracking está consumiendo todas las iteraciones. k = 1083
# Backtracking está consumiendo todas las iteraciones. k = 1106
# Backtracking está consumiendo todas las iteraciones. k = 1111
# Backtracking está consumiendo todas las iteraciones. k = 1113
# Backtracking está consumiendo todas las iteraciones. k = 1117
# Backtracking está consumiendo todas las iteraciones. k = 1119
# Backtracking está consumiendo todas las iteraciones. k = 1123
# Backtracking está consumiendo todas las iteraciones. k = 1125
# Backtracking está consumiendo todas las iteraciones. k = 1129
# Backtracking está consumiendo todas las iteraciones. k = 1131
# Backtracking está consumiendo todas las iteraciones. k = 1135
# Backtracking está consumiendo todas las iteraciones. k = 1137
# Backtracking está consumiendo todas las iteraciones. k = 1164
# Backtracking está consumiendo todas las iteraciones. k = 1169
# Backtracking está consumiendo todas las iteraciones. k = 1171
# Backtracking está consumiendo todas las iteraciones. k = 1175
# Backtracking está consumiendo todas las iteraciones. k = 1177
# Backtracking está consumiendo todas las iteraciones. k = 1181
# Backtracking está consumiendo todas las iteraciones. k = 1183
# Backtracking está consumiendo todas las iteraciones. k = 1187
# Backtracking está consumiendo todas las iteraciones. k = 1189
# Backtracking está consumiendo todas las iteraciones. k = 1193
# Backtracking está consumiendo todas las iteraciones. k = 1195
# Backtracking está consumiendo todas las iteraciones. k = 1199
# Backtracking está consumiendo todas las iteraciones. k = 1201
# Backtracking está consumiendo todas las iteraciones. k = 1205
# Backtracking está consumiendo todas las iteraciones. k = 1207
# Backtracking está consumiendo todas las iteraciones. k = 1246
# Backtracking está consumiendo todas las iteraciones. k = 1251
# Backtracking está consumiendo todas las iteraciones. k = 1256
# Backtracking está consumiendo todas las iteraciones. k = 1261
# Backtracking está consumiendo todas las iteraciones. k = 1263
# Backtracking está consumiendo todas las iteraciones. k = 1267
# Backtracking está consumiendo todas las iteraciones. k = 1269
# Backtracking está consumiendo todas las iteraciones. k = 1273
# Backtracking está consumiendo todas las iteraciones. k = 1275
# Backtracking está consumiendo todas las iteraciones. k = 1279
# Backtracking está consumiendo todas las iteraciones. k = 1281
# Backtracking está consumiendo todas las iteraciones. k = 1285
# Backtracking está consumiendo todas las iteraciones. k = 1287
# Backtracking está consumiendo todas las iteraciones. k = 1291
# Backtracking está consumiendo todas las iteraciones. k = 1293
# Backtracking está consumiendo todas las iteraciones. k = 1297
# Backtracking está consumiendo todas las iteraciones. k = 1299
# Backtracking está consumiendo todas las iteraciones. k = 1303
# Backtracking está consumiendo todas las iteraciones. k = 1305
# Backtracking está consumiendo todas las iteraciones. k = 1309
# Backtracking está consumiendo todas las iteraciones. k = 1311
# Backtracking está consumiendo todas las iteraciones. k = 1315
# Backtracking está consumiendo todas las iteraciones. k = 1317
# Backtracking está consumiendo todas las iteraciones. k = 1321
# Backtracking está consumiendo todas las iteraciones. k = 1323
# Backtracking está consumiendo todas las iteraciones. k = 1327
# Backtracking está consumiendo todas las iteraciones. k = 1329
# Backtracking está consumiendo todas las iteraciones. k = 1333
# Backtracking está consumiendo todas las iteraciones. k = 1335
# Backtracking está consumiendo todas las iteraciones. k = 1339
# Backtracking está consumiendo todas las iteraciones. k = 1341
# Backtracking está consumiendo todas las iteraciones. k = 1345
# Backtracking está consumiendo todas las iteraciones. k = 1347
# Backtracking está consumiendo todas las iteraciones. k = 1351
# Backtracking está consumiendo todas las iteraciones. k = 1353
# Backtracking está consumiendo todas las iteraciones. k = 1453
# Backtracking está consumiendo todas las iteraciones. k = 1455
# Backtracking está consumiendo todas las iteraciones. k = 1459
# Backtracking está consumiendo todas las iteraciones. k = 1461
# Backtracking está consumiendo todas las iteraciones. k = 1465
# Backtracking está consumiendo todas las iteraciones. k = 1467
# Backtracking está consumiendo todas las iteraciones. k = 1471
# Backtracking está consumiendo todas las iteraciones. k = 1473
# Backtracking está consumiendo todas las iteraciones. k = 1477
# Backtracking está consumiendo todas las iteraciones. k = 1479
# Backtracking está consumiendo todas las iteraciones. k = 1483
# Backtracking está consumiendo todas las iteraciones. k = 1485
# Backtracking está consumiendo todas las iteraciones. k = 1489
# Backtracking está consumiendo todas las iteraciones. k = 1491
# Backtracking está consumiendo todas las iteraciones. k = 1495
# Backtracking está consumiendo todas las iteraciones. k = 1497
# Backtracking está consumiendo todas las iteraciones. k = 1501
# Backtracking está consumiendo todas las iteraciones. k = 1503
# Backtracking está consumiendo todas las iteraciones. k = 1507
# Backtracking está consumiendo todas las iteraciones. k = 1509
# Backtracking está consumiendo todas las iteraciones. k = 1513
# Backtracking está consumiendo todas las iteraciones. k = 1515
# Backtracking está consumiendo todas las iteraciones. k = 1519
# Backtracking está consumiendo todas las iteraciones. k = 1521
# Backtracking está consumiendo todas las iteraciones. k = 1525
# Backtracking está consumiendo todas las iteraciones. k = 1527
# Backtracking está consumiendo todas las iteraciones. k = 1531
# Backtracking está consumiendo todas las iteraciones. k = 1533
# Backtracking está consumiendo todas las iteraciones. k = 1537
# Backtracking está consumiendo todas las iteraciones. k = 1539
# Backtracking está consumiendo todas las iteraciones. k = 1543
# Backtracking está consumiendo todas las iteraciones. k = 1545
# Backtracking está consumiendo todas las iteraciones. k = 1549
# Backtracking está consumiendo todas las iteraciones. k = 1551
# Backtracking está consumiendo todas las iteraciones. k = 1555
# Backtracking está consumiendo todas las iteraciones. k = 1560
# Backtracking está consumiendo todas las iteraciones. k = 1565
# Backtracking está consumiendo todas las iteraciones. k = 1611
# Backtracking está consumiendo todas las iteraciones. k = 1613
# Backtracking está consumiendo todas las iteraciones. k = 1617
# Backtracking está consumiendo todas las iteraciones. k = 1619
# Backtracking está consumiendo todas las iteraciones. k = 1623
# Backtracking está consumiendo todas las iteraciones. k = 1625
# Backtracking está consumiendo todas las iteraciones. k = 1629
# Backtracking está consumiendo todas las iteraciones. k = 1631
# Backtracking está consumiendo todas las iteraciones. k = 1635
# Backtracking está consumiendo todas las iteraciones. k = 1637
# Backtracking está consumiendo todas las iteraciones. k = 1641
# Backtracking está consumiendo todas las iteraciones. k = 1643
# Backtracking está consumiendo todas las iteraciones. k = 1647
# Backtracking está consumiendo todas las iteraciones. k = 1649
# Backtracking está consumiendo todas las iteraciones. k = 1653
# Backtracking está consumiendo todas las iteraciones. k = 1658
# Backtracking está consumiendo todas las iteraciones. k = 1663
# Backtracking está consumiendo todas las iteraciones. k = 1693
# Backtracking está consumiendo todas las iteraciones. k = 1695
# Backtracking está consumiendo todas las iteraciones. k = 1699
# Backtracking está consumiendo todas las iteraciones. k = 1701
# Backtracking está consumiendo todas las iteraciones. k = 1705
# Backtracking está consumiendo todas las iteraciones. k = 1707
# Backtracking está consumiendo todas las iteraciones. k = 1711
# Backtracking está consumiendo todas las iteraciones. k = 1713
# Backtracking está consumiendo todas las iteraciones. k = 1717
# Backtracking está consumiendo todas las iteraciones. k = 1719
# Backtracking está consumiendo todas las iteraciones. k = 1723
# Backtracking está consumiendo todas las iteraciones. k = 1725
# Backtracking está consumiendo todas las iteraciones. k = 1729
# Backtracking está consumiendo todas las iteraciones. k = 1734
# Backtracking está consumiendo todas las iteraciones. k = 1764
# Backtracking está consumiendo todas las iteraciones. k = 1766
# Backtracking está consumiendo todas las iteraciones. k = 1770
# Backtracking está consumiendo todas las iteraciones. k = 1772
# Backtracking está consumiendo todas las iteraciones. k = 1776
# Backtracking está consumiendo todas las iteraciones. k = 1778
# Backtracking está consumiendo todas las iteraciones. k = 1782
# Backtracking está consumiendo todas las iteraciones. k = 1784
# Backtracking está consumiendo todas las iteraciones. k = 1788
# Backtracking está consumiendo todas las iteraciones. k = 1790
# Backtracking está consumiendo todas las iteraciones. k = 1794
# Backtracking está consumiendo todas las iteraciones. k = 1799
# Backtracking está consumiendo todas las iteraciones. k = 1821
# Backtracking está consumiendo todas las iteraciones. k = 1823
# Backtracking está consumiendo todas las iteraciones. k = 1827
# Backtracking está consumiendo todas las iteraciones. k = 1829
# Backtracking está consumiendo todas las iteraciones. k = 1833
# Backtracking está consumiendo todas las iteraciones. k = 1835
# Backtracking está consumiendo todas las iteraciones. k = 1839
# Backtracking está consumiendo todas las iteraciones. k = 1841
# Backtracking está consumiendo todas las iteraciones. k = 1845
# Backtracking está consumiendo todas las iteraciones. k = 1847
# Backtracking está consumiendo todas las iteraciones. k = 1851
# Backtracking está consumiendo todas las iteraciones. k = 1877
# Backtracking está consumiendo todas las iteraciones. k = 1879
# Backtracking está consumiendo todas las iteraciones. k = 1883
# Backtracking está consumiendo todas las iteraciones. k = 1885
# Backtracking está consumiendo todas las iteraciones. k = 1889
# Backtracking está consumiendo todas las iteraciones. k = 1891
# Backtracking está consumiendo todas las iteraciones. k = 1895
# Backtracking está consumiendo todas las iteraciones. k = 1897
# Backtracking está consumiendo todas las iteraciones. k = 1901
# Backtracking está consumiendo todas las iteraciones. k = 1923
# Backtracking está consumiendo todas las iteraciones. k = 1925
# Backtracking está consumiendo todas las iteraciones. k = 1929
# Backtracking está consumiendo todas las iteraciones. k = 1931
# Backtracking está consumiendo todas las iteraciones. k = 1935
# Backtracking está consumiendo todas las iteraciones. k = 1937
# Backtracking está consumiendo todas las iteraciones. k = 1941
# Backtracking está consumiendo todas las iteraciones. k = 1943
# Backtracking está consumiendo todas las iteraciones. k = 1947
# Backtracking está consumiendo todas las iteraciones. k = 1969
# Backtracking está consumiendo todas las iteraciones. k = 1971
# Backtracking está consumiendo todas las iteraciones. k = 1975
# Backtracking está consumiendo todas las iteraciones. k = 1977
# Backtracking está consumiendo todas las iteraciones. k = 1981
# Backtracking está consumiendo todas las iteraciones. k = 1983
# Backtracking está consumiendo todas las iteraciones. k = 1987
# Backtracking está consumiendo todas las iteraciones. k = 1989
# Backtracking está consumiendo todas las iteraciones. k = 1993
# Backtracking está consumiendo todas las iteraciones. k = 2011
# Backtracking está consumiendo todas las iteraciones. k = 2013
# Backtracking está consumiendo todas las iteraciones. k = 2017
# Backtracking está consumiendo todas las iteraciones. k = 2019
# Backtracking está consumiendo todas las iteraciones. k = 2023
# Backtracking está consumiendo todas las iteraciones. k = 2025
# Backtracking está consumiendo todas las iteraciones. k = 2029
# Backtracking está consumiendo todas las iteraciones. k = 2031
# Backtracking está consumiendo todas las iteraciones. k = 2035
# Backtracking está consumiendo todas las iteraciones. k = 2053
# Backtracking está consumiendo todas las iteraciones. k = 2055
# Backtracking está consumiendo todas las iteraciones. k = 2059
# Backtracking está consumiendo todas las iteraciones. k = 2061
# Backtracking está consumiendo todas las iteraciones. k = 2065
# Backtracking está consumiendo todas las iteraciones. k = 2067
# Backtracking está consumiendo todas las iteraciones. k = 2071
# Backtracking está consumiendo todas las iteraciones. k = 2073
# Backtracking está consumiendo todas las iteraciones. k = 2077
# Backtracking está consumiendo todas las iteraciones. k = 2095
# Backtracking está consumiendo todas las iteraciones. k = 2097
# Backtracking está consumiendo todas las iteraciones. k = 2101
# Backtracking está consumiendo todas las iteraciones. k = 2103
# Backtracking está consumiendo todas las iteraciones. k = 2107
# Backtracking está consumiendo todas las iteraciones. k = 2109
# Backtracking está consumiendo todas las iteraciones. k = 2113
# Backtracking está consumiendo todas las iteraciones. k = 2131
# Backtracking está consumiendo todas las iteraciones. k = 2133
# Backtracking está consumiendo todas las iteraciones. k = 2137
# Backtracking está consumiendo todas las iteraciones. k = 2139
# Backtracking está consumiendo todas las iteraciones. k = 2143
# Backtracking está consumiendo todas las iteraciones. k = 2145
# Backtracking está consumiendo todas las iteraciones. k = 2149
# Backtracking está consumiendo todas las iteraciones. k = 2167
# Backtracking está consumiendo todas las iteraciones. k = 2169
# Backtracking está consumiendo todas las iteraciones. k = 2173
# Backtracking está consumiendo todas las iteraciones. k = 2175
# Backtracking está consumiendo todas las iteraciones. k = 2179
# Backtracking está consumiendo todas las iteraciones. k = 2181
# Backtracking está consumiendo todas las iteraciones. k = 2185
# Backtracking está consumiendo todas las iteraciones. k = 2203
# Backtracking está consumiendo todas las iteraciones. k = 2205
# Backtracking está consumiendo todas las iteraciones. k = 2209
# Backtracking está consumiendo todas las iteraciones. k = 2211
# Backtracking está consumiendo todas las iteraciones. k = 2215
# Backtracking está consumiendo todas las iteraciones. k = 2217
# Backtracking está consumiendo todas las iteraciones. k = 2221
# Backtracking está consumiendo todas las iteraciones. k = 2239
# Backtracking está consumiendo todas las iteraciones. k = 2241
# Backtracking está consumiendo todas las iteraciones. k = 2245
# Backtracking está consumiendo todas las iteraciones. k = 2247
# Backtracking está consumiendo todas las iteraciones. k = 2251
# Backtracking está consumiendo todas las iteraciones. k = 2256
# Backtracking está consumiendo todas las iteraciones. k = 2270
# Backtracking está consumiendo todas las iteraciones. k = 2272
# Backtracking está consumiendo todas las iteraciones. k = 2276
# Backtracking está consumiendo todas las iteraciones. k = 2278
# Backtracking está consumiendo todas las iteraciones. k = 2282
# Backtracking está consumiendo todas las iteraciones. k = 2284
# Backtracking está consumiendo todas las iteraciones. k = 2288
# Backtracking está consumiendo todas las iteraciones. k = 2302
# Backtracking está consumiendo todas las iteraciones. k = 2304
# Backtracking está consumiendo todas las iteraciones. k = 2308
# Backtracking está consumiendo todas las iteraciones. k = 2310
# Backtracking está consumiendo todas las iteraciones. k = 2314
# Backtracking está consumiendo todas las iteraciones. k = 2316
# Backtracking está consumiendo todas las iteraciones. k = 2320
# Backtracking está consumiendo todas las iteraciones. k = 2338
# Backtracking está consumiendo todas las iteraciones. k = 2340
# Backtracking está consumiendo todas las iteraciones. k = 2344
# Backtracking está consumiendo todas las iteraciones. k = 2346
# Backtracking está consumiendo todas las iteraciones. k = 2350
# Backtracking está consumiendo todas las iteraciones. k = 2368
# Backtracking está consumiendo todas las iteraciones. k = 2370
# Backtracking está consumiendo todas las iteraciones. k = 2374
# Backtracking está consumiendo todas las iteraciones. k = 2376
# Backtracking está consumiendo todas las iteraciones. k = 2380
# Backtracking está consumiendo todas las iteraciones. k = 2394
# Backtracking está consumiendo todas las iteraciones. k = 2396
# Backtracking está consumiendo todas las iteraciones. k = 2400
# Backtracking está consumiendo todas las iteraciones. k = 2402
# Backtracking está consumiendo todas las iteraciones. k = 2406
# Backtracking está consumiendo todas las iteraciones. k = 2408
# Backtracking está consumiendo todas las iteraciones. k = 2412
# Backtracking está consumiendo todas las iteraciones. k = 2426
# Backtracking está consumiendo todas las iteraciones. k = 2428
# Backtracking está consumiendo todas las iteraciones. k = 2432
# Backtracking está consumiendo todas las iteraciones. k = 2434
# Backtracking está consumiendo todas las iteraciones. k = 2438
# Backtracking está consumiendo todas las iteraciones. k = 2440
# Backtracking está consumiendo todas las iteraciones. k = 2444
# Backtracking está consumiendo todas las iteraciones. k = 2458
# Backtracking está consumiendo todas las iteraciones. k = 2460
# Backtracking está consumiendo todas las iteraciones. k = 2464
# Backtracking está consumiendo todas las iteraciones. k = 2466
# Backtracking está consumiendo todas las iteraciones. k = 2470
# Backtracking está consumiendo todas las iteraciones. k = 2484
# Backtracking está consumiendo todas las iteraciones. k = 2486
# Backtracking está consumiendo todas las iteraciones. k = 2490
# Backtracking está consumiendo todas las iteraciones. k = 2492
# Backtracking está consumiendo todas las iteraciones. k = 2496
# Backtracking está consumiendo todas las iteraciones. k = 2498
# Backtracking está consumiendo todas las iteraciones. k = 2502
# Backtracking está consumiendo todas las iteraciones. k = 2516
# Backtracking está consumiendo todas las iteraciones. k = 2518
# Backtracking está consumiendo todas las iteraciones. k = 2522
# Backtracking está consumiendo todas las iteraciones. k = 2524
# Backtracking está consumiendo todas las iteraciones. k = 2528
# Backtracking está consumiendo todas las iteraciones. k = 2542
# Backtracking está consumiendo todas las iteraciones. k = 2544
# Backtracking está consumiendo todas las iteraciones. k = 2548
# Backtracking está consumiendo todas las iteraciones. k = 2550
# Backtracking está consumiendo todas las iteraciones. k = 2554
# Backtracking está consumiendo todas las iteraciones. k = 2556
# Backtracking está consumiendo todas las iteraciones. k = 2560
# Backtracking está consumiendo todas las iteraciones. k = 2574
# Backtracking está consumiendo todas las iteraciones. k = 2576
# Backtracking está consumiendo todas las iteraciones. k = 2580
# Backtracking está consumiendo todas las iteraciones. k = 2582
# Backtracking está consumiendo todas las iteraciones. k = 2586
# Backtracking está consumiendo todas las iteraciones. k = 2600
# Backtracking está consumiendo todas las iteraciones. k = 2602
# Backtracking está consumiendo todas las iteraciones. k = 2606
# Backtracking está consumiendo todas las iteraciones. k = 2608
# Backtracking está consumiendo todas las iteraciones. k = 2612
# Backtracking está consumiendo todas las iteraciones. k = 2626
# Backtracking está consumiendo todas las iteraciones. k = 2628
# Backtracking está consumiendo todas las iteraciones. k = 2632
# Backtracking está consumiendo todas las iteraciones. k = 2634
# Backtracking está consumiendo todas las iteraciones. k = 2638
# Backtracking está consumiendo todas las iteraciones. k = 2652
# Backtracking está consumiendo todas las iteraciones. k = 2654
# Backtracking está consumiendo todas las iteraciones. k = 2658
# Backtracking está consumiendo todas las iteraciones. k = 2660
# Backtracking está consumiendo todas las iteraciones. k = 2664
# Backtracking está consumiendo todas las iteraciones. k = 2666
# Backtracking está consumiendo todas las iteraciones. k = 2679
# Backtracking está consumiendo todas las iteraciones. k = 2681
# Backtracking está consumiendo todas las iteraciones. k = 2685
# Backtracking está consumiendo todas las iteraciones. k = 2687
# Backtracking está consumiendo todas las iteraciones. k = 2691
# Backtracking está consumiendo todas las iteraciones. k = 2693
# Backtracking está consumiendo todas las iteraciones. k = 2706
# Backtracking está consumiendo todas las iteraciones. k = 2708
# Backtracking está consumiendo todas las iteraciones. k = 2712
# Backtracking está consumiendo todas las iteraciones. k = 2714
# Backtracking está consumiendo todas las iteraciones. k = 2718
# Backtracking está consumiendo todas las iteraciones. k = 2720
# Backtracking está consumiendo todas las iteraciones. k = 2733
# Backtracking está consumiendo todas las iteraciones. k = 2735
# Backtracking está consumiendo todas las iteraciones. k = 2739
# Backtracking está consumiendo todas las iteraciones. k = 2741
# Backtracking está consumiendo todas las iteraciones. k = 2745
# Backtracking está consumiendo todas las iteraciones. k = 2759
# Backtracking está consumiendo todas las iteraciones. k = 2761
# Backtracking está consumiendo todas las iteraciones. k = 2765
# Backtracking está consumiendo todas las iteraciones. k = 2767
# Backtracking está consumiendo todas las iteraciones. k = 2771
# Backtracking está consumiendo todas las iteraciones. k = 2785
# Backtracking está consumiendo todas las iteraciones. k = 2787
# Backtracking está consumiendo todas las iteraciones. k = 2791
# Backtracking está consumiendo todas las iteraciones. k = 2793
# Backtracking está consumiendo todas las iteraciones. k = 2797
# Backtracking está consumiendo todas las iteraciones. k = 2811
# Backtracking está consumiendo todas las iteraciones. k = 2813
# Backtracking está consumiendo todas las iteraciones. k = 2817
# Backtracking está consumiendo todas las iteraciones. k = 2819
# Backtracking está consumiendo todas las iteraciones. k = 2823
# Backtracking está consumiendo todas las iteraciones. k = 2837
# Backtracking está consumiendo todas las iteraciones. k = 2839
# Backtracking está consumiendo todas las iteraciones. k = 2843
# Backtracking está consumiendo todas las iteraciones. k = 2845
# Backtracking está consumiendo todas las iteraciones. k = 2849
# Backtracking está consumiendo todas las iteraciones. k = 2859
# Backtracking está consumiendo todas las iteraciones. k = 2861
# Backtracking está consumiendo todas las iteraciones. k = 2865
# Backtracking está consumiendo todas las iteraciones. k = 2867
# Backtracking está consumiendo todas las iteraciones. k = 2871
# Backtracking está consumiendo todas las iteraciones. k = 2885
# Backtracking está consumiendo todas las iteraciones. k = 2887
# Backtracking está consumiendo todas las iteraciones. k = 2891
# Backtracking está consumiendo todas las iteraciones. k = 2893
# Backtracking está consumiendo todas las iteraciones. k = 2897
# Backtracking está consumiendo todas las iteraciones. k = 2911
# Backtracking está consumiendo todas las iteraciones. k = 2913
# Backtracking está consumiendo todas las iteraciones. k = 2917
# Backtracking está consumiendo todas las iteraciones. k = 2919
# Backtracking está consumiendo todas las iteraciones. k = 2923
# Backtracking está consumiendo todas las iteraciones. k = 2933
# Backtracking está consumiendo todas las iteraciones. k = 2935
# Backtracking está consumiendo todas las iteraciones. k = 2939
# Backtracking está consumiendo todas las iteraciones. k = 2941
# Backtracking está consumiendo todas las iteraciones. k = 2945
# Backtracking está consumiendo todas las iteraciones. k = 2959
# Backtracking está consumiendo todas las iteraciones. k = 2961
# Backtracking está consumiendo todas las iteraciones. k = 2965
# Backtracking está consumiendo todas las iteraciones. k = 2967
# Backtracking está consumiendo todas las iteraciones. k = 2971
# Backtracking está consumiendo todas las iteraciones. k = 2981
# Backtracking está consumiendo todas las iteraciones. k = 2983
# Backtracking está consumiendo todas las iteraciones. k = 2987
# Backtracking está consumiendo todas las iteraciones. k = 2989
# Backtracking está consumiendo todas las iteraciones. k = 2993
# Backtracking está consumiendo todas las iteraciones. k = 3007
# Backtracking está consumiendo todas las iteraciones. k = 3009
# Backtracking está consumiendo todas las iteraciones. k = 3013
# Backtracking está consumiendo todas las iteraciones. k = 3015
# Backtracking está consumiendo todas las iteraciones. k = 3019
# Backtracking está consumiendo todas las iteraciones. k = 3029
# Backtracking está consumiendo todas las iteraciones. k = 3031
# Backtracking está consumiendo todas las iteraciones. k = 3035
# Backtracking está consumiendo todas las iteraciones. k = 3037
# Backtracking está consumiendo todas las iteraciones. k = 3041
# Backtracking está consumiendo todas las iteraciones. k = 3055
# Backtracking está consumiendo todas las iteraciones. k = 3057
# Backtracking está consumiendo todas las iteraciones. k = 3061
# Backtracking está consumiendo todas las iteraciones. k = 3063
# Backtracking está consumiendo todas las iteraciones. k = 3067
# Backtracking está consumiendo todas las iteraciones. k = 3077
# Backtracking está consumiendo todas las iteraciones. k = 3079
# Backtracking está consumiendo todas las iteraciones. k = 3083
# Backtracking está consumiendo todas las iteraciones. k = 3085
# Backtracking está consumiendo todas las iteraciones. k = 3089
# Backtracking está consumiendo todas las iteraciones. k = 3103
# Backtracking está consumiendo todas las iteraciones. k = 3105
# Backtracking está consumiendo todas las iteraciones. k = 3109
# Backtracking está consumiendo todas las iteraciones. k = 3111
# Backtracking está consumiendo todas las iteraciones. k = 3124
# Backtracking está consumiendo todas las iteraciones. k = 3126
# Backtracking está consumiendo todas las iteraciones. k = 3130
# Backtracking está consumiendo todas las iteraciones. k = 3132
# Backtracking está consumiendo todas las iteraciones. k = 3136
# Backtracking está consumiendo todas las iteraciones. k = 3146
# Backtracking está consumiendo todas las iteraciones. k = 3148
# Backtracking está consumiendo todas las iteraciones. k = 3152
# Backtracking está consumiendo todas las iteraciones. k = 3154
# Backtracking está consumiendo todas las iteraciones. k = 3158
# Backtracking está consumiendo todas las iteraciones. k = 3172
# Backtracking está consumiendo todas las iteraciones. k = 3174
# Backtracking está consumiendo todas las iteraciones. k = 3178
# Backtracking está consumiendo todas las iteraciones. k = 3192
# Backtracking está consumiendo todas las iteraciones. k = 3194
# Backtracking está consumiendo todas las iteraciones. k = 3198
# Backtracking está consumiendo todas las iteraciones. k = 3200
# Backtracking está consumiendo todas las iteraciones. k = 3204
# Backtracking está consumiendo todas las iteraciones. k = 3214
# Backtracking está consumiendo todas las iteraciones. k = 3216
# Backtracking está consumiendo todas las iteraciones. k = 3220
# Backtracking está consumiendo todas las iteraciones. k = 3222
# Backtracking está consumiendo todas las iteraciones. k = 3226
# Backtracking está consumiendo todas las iteraciones. k = 3236
# Backtracking está consumiendo todas las iteraciones. k = 3238
# Backtracking está consumiendo todas las iteraciones. k = 3242
# Backtracking está consumiendo todas las iteraciones. k = 3244
# Backtracking está consumiendo todas las iteraciones. k = 3248
# Backtracking está consumiendo todas las iteraciones. k = 3262
# Backtracking está consumiendo todas las iteraciones. k = 3264
# Backtracking está consumiendo todas las iteraciones. k = 3268
# Backtracking está consumiendo todas las iteraciones. k = 3282
# Backtracking está consumiendo todas las iteraciones. k = 3284
# Backtracking está consumiendo todas las iteraciones. k = 3288
# Backtracking está consumiendo todas las iteraciones. k = 3290
# Backtracking está consumiendo todas las iteraciones. k = 3303
# Backtracking está consumiendo todas las iteraciones. k = 3305
# Backtracking está consumiendo todas las iteraciones. k = 3309
# Backtracking está consumiendo todas las iteraciones. k = 3311
# Backtracking está consumiendo todas las iteraciones. k = 3324
# Backtracking está consumiendo todas las iteraciones. k = 3326
# Backtracking está consumiendo todas las iteraciones. k = 3330
# Backtracking está consumiendo todas las iteraciones. k = 3332
# Backtracking está consumiendo todas las iteraciones. k = 3336
# Backtracking está consumiendo todas las iteraciones. k = 3346
# Backtracking está consumiendo todas las iteraciones. k = 3348
# Backtracking está consumiendo todas las iteraciones. k = 3352
# Backtracking está consumiendo todas las iteraciones. k = 3354
# Backtracking está consumiendo todas las iteraciones. k = 3358
# Backtracking está consumiendo todas las iteraciones. k = 3368
# Backtracking está consumiendo todas las iteraciones. k = 3370
# Backtracking está consumiendo todas las iteraciones. k = 3374
# Backtracking está consumiendo todas las iteraciones. k = 3376
# Backtracking está consumiendo todas las iteraciones. k = 3380
# Backtracking está consumiendo todas las iteraciones. k = 3390
# Backtracking está consumiendo todas las iteraciones. k = 3392
# Backtracking está consumiendo todas las iteraciones. k = 3396
# Backtracking está consumiendo todas las iteraciones. k = 3398
# Backtracking está consumiendo todas las iteraciones. k = 3402
# Backtracking está consumiendo todas las iteraciones. k = 3412
# Backtracking está consumiendo todas las iteraciones. k = 3414
# Backtracking está consumiendo todas las iteraciones. k = 3418
# Backtracking está consumiendo todas las iteraciones. k = 3420
# Backtracking está consumiendo todas las iteraciones. k = 3424
# Backtracking está consumiendo todas las iteraciones. k = 3434
# Backtracking está consumiendo todas las iteraciones. k = 3436
# Backtracking está consumiendo todas las iteraciones. k = 3440
# Backtracking está consumiendo todas las iteraciones. k = 3442
# Backtracking está consumiendo todas las iteraciones. k = 3446
# Backtracking está consumiendo todas las iteraciones. k = 3456
# Backtracking está consumiendo todas las iteraciones. k = 3458
# Backtracking está consumiendo todas las iteraciones. k = 3462
# Backtracking está consumiendo todas las iteraciones. k = 3464
# Backtracking está consumiendo todas las iteraciones. k = 3468
# Backtracking está consumiendo todas las iteraciones. k = 3478
# Backtracking está consumiendo todas las iteraciones. k = 3480
# Backtracking está consumiendo todas las iteraciones. k = 3484
# Backtracking está consumiendo todas las iteraciones. k = 3486
# Backtracking está consumiendo todas las iteraciones. k = 3490
# Backtracking está consumiendo todas las iteraciones. k = 3500
# Backtracking está consumiendo todas las iteraciones. k = 3502
# Backtracking está consumiendo todas las iteraciones. k = 3506
# Backtracking está consumiendo todas las iteraciones. k = 3508
# Backtracking está consumiendo todas las iteraciones. k = 3512
# Backtracking está consumiendo todas las iteraciones. k = 3522
# Backtracking está consumiendo todas las iteraciones. k = 3524
# Backtracking está consumiendo todas las iteraciones. k = 3528
# Backtracking está consumiendo todas las iteraciones. k = 3530
# Backtracking está consumiendo todas las iteraciones. k = 3534
# Backtracking está consumiendo todas las iteraciones. k = 3544
# Backtracking está consumiendo todas las iteraciones. k = 3546
# Backtracking está consumiendo todas las iteraciones. k = 3550
# Backtracking está consumiendo todas las iteraciones. k = 3552
# Backtracking está consumiendo todas las iteraciones. k = 3556
# Backtracking está consumiendo todas las iteraciones. k = 3566
# Backtracking está consumiendo todas las iteraciones. k = 3568
# Backtracking está consumiendo todas las iteraciones. k = 3572
# Backtracking está consumiendo todas las iteraciones. k = 3574
# Backtracking está consumiendo todas las iteraciones. k = 3578
# Backtracking está consumiendo todas las iteraciones. k = 3588
# Backtracking está consumiendo todas las iteraciones. k = 3590
# Backtracking está consumiendo todas las iteraciones. k = 3594
# Backtracking está consumiendo todas las iteraciones. k = 3596
# Backtracking está consumiendo todas las iteraciones. k = 3600
# Backtracking está consumiendo todas las iteraciones. k = 3610
# Backtracking está consumiendo todas las iteraciones. k = 3612
# Backtracking está consumiendo todas las iteraciones. k = 3616
# Backtracking está consumiendo todas las iteraciones. k = 3618
# Backtracking está consumiendo todas las iteraciones. k = 3622
# Backtracking está consumiendo todas las iteraciones. k = 3632
# Backtracking está consumiendo todas las iteraciones. k = 3634
# Backtracking está consumiendo todas las iteraciones. k = 3638
# Backtracking está consumiendo todas las iteraciones. k = 3640
# Backtracking está consumiendo todas las iteraciones. k = 3653
# Backtracking está consumiendo todas las iteraciones. k = 3655
# Backtracking está consumiendo todas las iteraciones. k = 3659
# Backtracking está consumiendo todas las iteraciones. k = 3661
# Backtracking está consumiendo todas las iteraciones. k = 3674
# Backtracking está consumiendo todas las iteraciones. k = 3676
# Backtracking está consumiendo todas las iteraciones. k = 3680
# Backtracking está consumiendo todas las iteraciones. k = 3682
# Backtracking está consumiendo todas las iteraciones. k = 3695
# Backtracking está consumiendo todas las iteraciones. k = 3697
# Backtracking está consumiendo todas las iteraciones. k = 3701
# Backtracking está consumiendo todas las iteraciones. k = 3715
# Backtracking está consumiendo todas las iteraciones. k = 3717
# Backtracking está consumiendo todas las iteraciones. k = 3721
# Backtracking está consumiendo todas las iteraciones. k = 3731
# Backtracking está consumiendo todas las iteraciones. k = 3733
# Backtracking está consumiendo todas las iteraciones. k = 3737
# Backtracking está consumiendo todas las iteraciones. k = 3739
# Backtracking está consumiendo todas las iteraciones. k = 3743
# Backtracking está consumiendo todas las iteraciones. k = 3753
# Backtracking está consumiendo todas las iteraciones. k = 3755
# Backtracking está consumiendo todas las iteraciones. k = 3759
# Backtracking está consumiendo todas las iteraciones. k = 3761
# Backtracking está consumiendo todas las iteraciones. k = 3765
# Backtracking está consumiendo todas las iteraciones. k = 3775
# Backtracking está consumiendo todas las iteraciones. k = 3777
# Backtracking está consumiendo todas las iteraciones. k = 3781
# Backtracking está consumiendo todas las iteraciones. k = 3783
# Backtracking está consumiendo todas las iteraciones. k = 3796
# Backtracking está consumiendo todas las iteraciones. k = 3798
# Backtracking está consumiendo todas las iteraciones. k = 3802
# Backtracking está consumiendo todas las iteraciones. k = 3816
# Backtracking está consumiendo todas las iteraciones. k = 3818
# Backtracking está consumiendo todas las iteraciones. k = 3822
# Backtracking está consumiendo todas las iteraciones. k = 3832
# Backtracking está consumiendo todas las iteraciones. k = 3834
# Backtracking está consumiendo todas las iteraciones. k = 3838
# Backtracking está consumiendo todas las iteraciones. k = 3840
# Backtracking está consumiendo todas las iteraciones. k = 3844
# Backtracking está consumiendo todas las iteraciones. k = 3854
# Backtracking está consumiendo todas las iteraciones. k = 3856
# Backtracking está consumiendo todas las iteraciones. k = 3860
# Backtracking está consumiendo todas las iteraciones. k = 3862
# Backtracking está consumiendo todas las iteraciones. k = 3875
# Backtracking está consumiendo todas las iteraciones. k = 3877
# Backtracking está consumiendo todas las iteraciones. k = 3881
# Backtracking está consumiendo todas las iteraciones. k = 3895
# Backtracking está consumiendo todas las iteraciones. k = 3897
# Backtracking está consumiendo todas las iteraciones. k = 3901
# Backtracking está consumiendo todas las iteraciones. k = 3911
# Backtracking está consumiendo todas las iteraciones. k = 3913
# Backtracking está consumiendo todas las iteraciones. k = 3917
# Backtracking está consumiendo todas las iteraciones. k = 3919
# Backtracking está consumiendo todas las iteraciones. k = 3923
# Backtracking está consumiendo todas las iteraciones. k = 3933
# Backtracking está consumiendo todas las iteraciones. k = 3935
# Backtracking está consumiendo todas las iteraciones. k = 3939
# Backtracking está consumiendo todas las iteraciones. k = 3941
# Backtracking está consumiendo todas las iteraciones. k = 3954
# Backtracking está consumiendo todas las iteraciones. k = 3956
# Backtracking está consumiendo todas las iteraciones. k = 3960
# Backtracking está consumiendo todas las iteraciones. k = 3970
# Backtracking está consumiendo todas las iteraciones. k = 3972
# Backtracking está consumiendo todas las iteraciones. k = 3976
# Backtracking está consumiendo todas las iteraciones. k = 3978
# Backtracking está consumiendo todas las iteraciones. k = 3982
# Backtracking está consumiendo todas las iteraciones. k = 3992
# Backtracking está consumiendo todas las iteraciones. k = 3994
# Backtracking está consumiendo todas las iteraciones. k = 3998
# Backtracking está consumiendo todas las iteraciones. k = 4000
# Backtracking está consumiendo todas las iteraciones. k = 4013
# Backtracking está consumiendo todas las iteraciones. k = 4015
# Backtracking está consumiendo todas las iteraciones. k = 4019
# Backtracking está consumiendo todas las iteraciones. k = 4029
# Backtracking está consumiendo todas las iteraciones. k = 4031
# Backtracking está consumiendo todas las iteraciones. k = 4035
# Backtracking está consumiendo todas las iteraciones. k = 4037
# Backtracking está consumiendo todas las iteraciones. k = 4041
# Backtracking está consumiendo todas las iteraciones. k = 4051
# Backtracking está consumiendo todas las iteraciones. k = 4053
# Backtracking está consumiendo todas las iteraciones. k = 4057
# Backtracking está consumiendo todas las iteraciones. k = 4059
# Backtracking está consumiendo todas las iteraciones. k = 4072
# Backtracking está consumiendo todas las iteraciones. k = 4074
# Backtracking está consumiendo todas las iteraciones. k = 4078
# Backtracking está consumiendo todas las iteraciones. k = 4088
# Backtracking está consumiendo todas las iteraciones. k = 4090
# Backtracking está consumiendo todas las iteraciones. k = 4094
# Backtracking está consumiendo todas las iteraciones. k = 4096
# Backtracking está consumiendo todas las iteraciones. k = 4100
# Backtracking está consumiendo todas las iteraciones. k = 4110
# Backtracking está consumiendo todas las iteraciones. k = 4112
# Backtracking está consumiendo todas las iteraciones. k = 4116
# Backtracking está consumiendo todas las iteraciones. k = 4118
# Backtracking está consumiendo todas las iteraciones. k = 4131
# Backtracking está consumiendo todas las iteraciones. k = 4133
# Backtracking está consumiendo todas las iteraciones. k = 4137
# Backtracking está consumiendo todas las iteraciones. k = 4147
# Backtracking está consumiendo todas las iteraciones. k = 4149
# Backtracking está consumiendo todas las iteraciones. k = 4153
# Backtracking está consumiendo todas las iteraciones. k = 4155
# Backtracking está consumiendo todas las iteraciones. k = 4159
# Backtracking está consumiendo todas las iteraciones. k = 4169
# Backtracking está consumiendo todas las iteraciones. k = 4171
# Backtracking está consumiendo todas las iteraciones. k = 4175
# Backtracking está consumiendo todas las iteraciones. k = 4185
# Backtracking está consumiendo todas las iteraciones. k = 4187
# Backtracking está consumiendo todas las iteraciones. k = 4191
# Backtracking está consumiendo todas las iteraciones. k = 4193
# Backtracking está consumiendo todas las iteraciones. k = 4197
# Backtracking está consumiendo todas las iteraciones. k = 4207
# Backtracking está consumiendo todas las iteraciones. k = 4209
# Backtracking está consumiendo todas las iteraciones. k = 4213
# Backtracking está consumiendo todas las iteraciones. k = 4215
# Backtracking está consumiendo todas las iteraciones. k = 4228
# Backtracking está consumiendo todas las iteraciones. k = 4230
# Backtracking está consumiendo todas las iteraciones. k = 4234
# Backtracking está consumiendo todas las iteraciones. k = 4244
# Backtracking está consumiendo todas las iteraciones. k = 4246
# Backtracking está consumiendo todas las iteraciones. k = 4250
# Backtracking está consumiendo todas las iteraciones. k = 4252
# Backtracking está consumiendo todas las iteraciones. k = 4265
# Backtracking está consumiendo todas las iteraciones. k = 4267
# Backtracking está consumiendo todas las iteraciones. k = 4271
# Backtracking está consumiendo todas las iteraciones. k = 4281
# Backtracking está consumiendo todas las iteraciones. k = 4283
# Backtracking está consumiendo todas las iteraciones. k = 4287
# Backtracking está consumiendo todas las iteraciones. k = 4289
# Backtracking está consumiendo todas las iteraciones. k = 4293
# Backtracking está consumiendo todas las iteraciones. k = 4303
# Backtracking está consumiendo todas las iteraciones. k = 4305
# Backtracking está consumiendo todas las iteraciones. k = 4309
# Backtracking está consumiendo todas las iteraciones. k = 4319
# Backtracking está consumiendo todas las iteraciones. k = 4321
# Backtracking está consumiendo todas las iteraciones. k = 4325
# Backtracking está consumiendo todas las iteraciones. k = 4327
# Backtracking está consumiendo todas las iteraciones. k = 4331
# Backtracking está consumiendo todas las iteraciones. k = 4341
# Backtracking está consumiendo todas las iteraciones. k = 4343
# Backtracking está consumiendo todas las iteraciones. k = 4347
# Backtracking está consumiendo todas las iteraciones. k = 4349
# Backtracking está consumiendo todas las iteraciones. k = 4362
# Backtracking está consumiendo todas las iteraciones. k = 4364
# Backtracking está consumiendo todas las iteraciones. k = 4368
# Backtracking está consumiendo todas las iteraciones. k = 4378
# Backtracking está consumiendo todas las iteraciones. k = 4380
# Backtracking está consumiendo todas las iteraciones. k = 4384
# Backtracking está consumiendo todas las iteraciones. k = 4386
# Backtracking está consumiendo todas las iteraciones. k = 4399
# Backtracking está consumiendo todas las iteraciones. k = 4401
# Backtracking está consumiendo todas las iteraciones. k = 4405
# Backtracking está consumiendo todas las iteraciones. k = 4415
# Backtracking está consumiendo todas las iteraciones. k = 4417
# Backtracking está consumiendo todas las iteraciones. k = 4421
# Backtracking está consumiendo todas las iteraciones. k = 4423
# Backtracking está consumiendo todas las iteraciones. k = 4436
# Backtracking está consumiendo todas las iteraciones. k = 4438
# Backtracking está consumiendo todas las iteraciones. k = 4442
# Backtracking está consumiendo todas las iteraciones. k = 4452
# Backtracking está consumiendo todas las iteraciones. k = 4454
# Backtracking está consumiendo todas las iteraciones. k = 4458
# Backtracking está consumiendo todas las iteraciones. k = 4460
# Backtracking está consumiendo todas las iteraciones. k = 4473
# Backtracking está consumiendo todas las iteraciones. k = 4475
# Backtracking está consumiendo todas las iteraciones. k = 4479
# Backtracking está consumiendo todas las iteraciones. k = 4489
# Backtracking está consumiendo todas las iteraciones. k = 4491
# Backtracking está consumiendo todas las iteraciones. k = 4495
# Backtracking está consumiendo todas las iteraciones. k = 4497
# Backtracking está consumiendo todas las iteraciones. k = 4510
# Backtracking está consumiendo todas las iteraciones. k = 4512
# Backtracking está consumiendo todas las iteraciones. k = 4516
# Backtracking está consumiendo todas las iteraciones. k = 4526
# Backtracking está consumiendo todas las iteraciones. k = 4528
# Backtracking está consumiendo todas las iteraciones. k = 4532
# Backtracking está consumiendo todas las iteraciones. k = 4542
# Backtracking está consumiendo todas las iteraciones. k = 4544
# Backtracking está consumiendo todas las iteraciones. k = 4548
# Backtracking está consumiendo todas las iteraciones. k = 4550
# Backtracking está consumiendo todas las iteraciones. k = 4554
# Backtracking está consumiendo todas las iteraciones. k = 4564
# Backtracking está consumiendo todas las iteraciones. k = 4566
# Backtracking está consumiendo todas las iteraciones. k = 4570
# Backtracking está consumiendo todas las iteraciones. k = 4580
# Backtracking está consumiendo todas las iteraciones. k = 4582
# Backtracking está consumiendo todas las iteraciones. k = 4586
# Backtracking está consumiendo todas las iteraciones. k = 4588
# Backtracking está consumiendo todas las iteraciones. k = 4592
# Backtracking está consumiendo todas las iteraciones. k = 4602
# Backtracking está consumiendo todas las iteraciones. k = 4604
# Backtracking está consumiendo todas las iteraciones. k = 4608
# Backtracking está consumiendo todas las iteraciones. k = 4618
# Backtracking está consumiendo todas las iteraciones. k = 4620
# Backtracking está consumiendo todas las iteraciones. k = 4624
# Backtracking está consumiendo todas las iteraciones. k = 4626
# Backtracking está consumiendo todas las iteraciones. k = 4639
# Backtracking está consumiendo todas las iteraciones. k = 4641
# Backtracking está consumiendo todas las iteraciones. k = 4645
# Backtracking está consumiendo todas las iteraciones. k = 4655
# Backtracking está consumiendo todas las iteraciones. k = 4657
# Backtracking está consumiendo todas las iteraciones. k = 4661
# Backtracking está consumiendo todas las iteraciones. k = 4671
# Backtracking está consumiendo todas las iteraciones. k = 4673
# Backtracking está consumiendo todas las iteraciones. k = 4677
# Backtracking está consumiendo todas las iteraciones. k = 4679
# Backtracking está consumiendo todas las iteraciones. k = 4683
# Backtracking está consumiendo todas las iteraciones. k = 4693
# Backtracking está consumiendo todas las iteraciones. k = 4695
# Backtracking está consumiendo todas las iteraciones. k = 4699
# Backtracking está consumiendo todas las iteraciones. k = 4709
# Backtracking está consumiendo todas las iteraciones. k = 4711
# Backtracking está consumiendo todas las iteraciones. k = 4715
# Backtracking está consumiendo todas las iteraciones. k = 4717
# Backtracking está consumiendo todas las iteraciones. k = 4726
# Backtracking está consumiendo todas las iteraciones. k = 4728
# Backtracking está consumiendo todas las iteraciones. k = 4732
# Backtracking está consumiendo todas las iteraciones. k = 4734
# Backtracking está consumiendo todas las iteraciones. k = 4747
# Backtracking está consumiendo todas las iteraciones. k = 4749
# Backtracking está consumiendo todas las iteraciones. k = 4753
# Backtracking está consumiendo todas las iteraciones. k = 4763
# Backtracking está consumiendo todas las iteraciones. k = 4765
# Backtracking está consumiendo todas las iteraciones. k = 4769
# Backtracking está consumiendo todas las iteraciones. k = 4779
# Backtracking está consumiendo todas las iteraciones. k = 4781
# Backtracking está consumiendo todas las iteraciones. k = 4785
# Backtracking está consumiendo todas las iteraciones. k = 4787
# Backtracking está consumiendo todas las iteraciones. k = 4796
# Backtracking está consumiendo todas las iteraciones. k = 4798
# Backtracking está consumiendo todas las iteraciones. k = 4802
# Backtracking está consumiendo todas las iteraciones. k = 4804
# Backtracking está consumiendo todas las iteraciones. k = 4813
# Backtracking está consumiendo todas las iteraciones. k = 4815
# Backtracking está consumiendo todas las iteraciones. k = 4819
# Backtracking está consumiendo todas las iteraciones. k = 4821
# Backtracking está consumiendo todas las iteraciones. k = 4834
# Backtracking está consumiendo todas las iteraciones. k = 4836
# Backtracking está consumiendo todas las iteraciones. k = 4840
# Backtracking está consumiendo todas las iteraciones. k = 4850
# Backtracking está consumiendo todas las iteraciones. k = 4852
# Backtracking está consumiendo todas las iteraciones. k = 4856
# Backtracking está consumiendo todas las iteraciones. k = 4866
# Backtracking está consumiendo todas las iteraciones. k = 4868
# Backtracking está consumiendo todas las iteraciones. k = 4872
# Backtracking está consumiendo todas las iteraciones. k = 4882
# Backtracking está consumiendo todas las iteraciones. k = 4884
# Backtracking está consumiendo todas las iteraciones. k = 4888
# Backtracking está consumiendo todas las iteraciones. k = 4898
# Backtracking está consumiendo todas las iteraciones. k = 4900
# Backtracking está consumiendo todas las iteraciones. k = 4904
# Backtracking está consumiendo todas las iteraciones. k = 4914
# Backtracking está consumiendo todas las iteraciones. k = 4916
# Backtracking está consumiendo todas las iteraciones. k = 4920
# Backtracking está consumiendo todas las iteraciones. k = 4930
# Backtracking está consumiendo todas las iteraciones. k = 4932
# Backtracking está consumiendo todas las iteraciones. k = 4936
# Backtracking está consumiendo todas las iteraciones. k = 4946
# Backtracking está consumiendo todas las iteraciones. k = 4948
# Backtracking está consumiendo todas las iteraciones. k = 4952
# Backtracking está consumiendo todas las iteraciones. k = 4962
# Backtracking está consumiendo todas las iteraciones. k = 4964
# Backtracking está consumiendo todas las iteraciones. k = 4968
# Dimension: 40
# ¿Terminó por criterio de paro?: False
# Número de iteraciones realizadas: 5000
# La solución alcanzada es:  [0.99999007 1.00002595 0.99996032 1.00005607] ... [0.92154914 0.84764153 0.71680822 0.51236402]
# f(xk)=0.11344471780179793
# f(x0)=9680.0
# La norma del gradiente final es: 1.6152532236334145
# Número de reinicios:  3976

# %% [markdown]
# Como se observa, no parece haber mucha diferencia entre ambas fórmulas para $\beta$, pues para la mismas funciones el comportamiento es prácticamente el mismo.
#
# En cuanto al número de reinicios, no hay mucho que decir, pues el número de reinicios varía según la función, en algunas se reinicia en cada iteración mientras que en otras es mucho menor el número de reinicios. Esto puede depender de factores como la complejidad de la función así como de su forma. Pues notamos que, en las que son formas cuadráticas, los reinicios eran en cada iteración mientras que, en las que no, esto no era así.

# %% [markdown]
# ```
#
#
# ```
# ---
